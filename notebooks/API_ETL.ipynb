# %%
# Import package to make HTTP requests, i.e. fetch URL similar to a browser request
import requests
# Import Json library to decode Json
import json
# for data manipulation and analysis
import pandas as pd
# for sql
from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv, dotenv_values

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Extract Team Data

# %%
# Define the URL for the API endpoint.
team_url = 'https://api.sportradar.com/nhl/production/v7/en/league/teams.json'
# Retrieve the API key from the environment variables
api_key = os.getenv('API_KEY')
# Create a dictionary of parameters to be sent with the API request.
team_params = {'api_key': api_key}
# Send a GET request to the API endpoint
team_api_request = requests.get(team_url, params=team_params)

# %%
team_api_request
# Out:
# <Response [200]>

# %%
team_api_request.url
# Out:
# 'https://api.sportradar.com/nhl/production/v7/en/league/teams.json?api_key=3XZ4cbvj3w6hRONhHDelw92rvKqucxRk5ux3ZBpI'

# %%
# converts the JSON response text into a Python dictionary.
json.loads(team_api_request.text)
# Out:
# {'league': {'id': 'fd560107-a85b-4388-ab0d-655ad022aff7',
#   'name': 'NHL',
#   'alias': 'NHL'},
#  'teams': [{'id': '4415ce44-0f24-11e2-8525-18a905767e44',
#    'name': 'Avalanche',
#    'market': 'Colorado',
#    'alias': 'COL'},
#   {'id': '4416272f-0f24-11e2-8525-18a905767e44',
#    'name': 'Blackhawks',
#    'market': 'Chicago',
#    'alias': 'CHI'},
#   {'id': '44167db4-0f24-11e2-8525-18a905767e44',
#    'name': 'Blue Jackets',
#    'market': 'Columbus',
#    'alias': 'CBJ'},
#   {'id': '441660ea-0f24-11e2-8525-18a905767e44',
#    'name': 'Blues',
#    'market': 'St. Louis',
#    'alias': 'STL'},
#   {'id': '4416ba1a-0f24-11e2-8525-18a905767e44',
#    'name': 'Bruins',
#    'market': 'Boston',
#    'alias': 'BOS'},
#   {'id': '441713b7-0f24-11e2-8525-18a905767e44',
#    'name': 'Canadiens',
#    'market': 'Montreal',
#    'alias': 'MTL'},
#   {'id': '4415b0a7-0f24-11e2-8525-18a905767e44',
#    'name': 'Canucks',
#    'market': 'Vancouver',
#    'alias': 'VAN'},
#   {'id': '4417eede-0f24-11e2-8525-18a905767e44',
#    'name': 'Capitals',
#    'market': 'Washington',
#    'alias': 'WSH'},
#   {'id': '44153da1-0f24-11e2-8525-18a905767e44',
#    'name': 'Coyotes',
#    'market': 'Arizona',
#    'alias': 'ARI'},
#   {'id': '44174b0c-0f24-11e2-8525-18a905767e44',
#    'name': 'Devils',
#    'market': 'New Jersey',
#    'alias': 'NJ'},
#   {'id': '1cd2b521-9090-4692-bb78-29973ef2d748',
#    'name': 'Division',
#    'market': 'Pacific',
#    'alias': 'PAC'},
#   {'id': '49e876e9-2e57-4ba4-96fd-ba8e92932227',
#    'name': 'Division',
#    'market': 'Central',
#    'alias': 'CEN'},
#   {'id': '4bea8be7-44fb-4a3e-9abe-26ab3e7f5500',
#    'name': 'Division',
#    'market': 'Atlantic',
#    'alias': 'ATL'},
#   {'id': '99c773e4-ff9f-404e-9a00-4bf5d18caa66',
#    'name': 'Division',
#    'market': 'Metropolitan',
#    'alias': 'MET'},
#   {'id': '441862de-0f24-11e2-8525-18a905767e44',
#    'name': 'Ducks',
#    'market': 'Anaheim',
#    'alias': 'ANA'},
#   {'id': '535534b6-78cf-4650-824c-fb9a15be5988',
#    'name': 'Eisbaren Berlin',
#    'alias': 'EIS'},
#   {'id': '44159241-0f24-11e2-8525-18a905767e44',
#    'name': 'Flames',
#    'market': 'Calgary',
#    'alias': 'CGY'},
#   {'id': '44179d47-0f24-11e2-8525-18a905767e44',
#    'name': 'Flyers',
#    'market': 'Philadelphia',
#    'alias': 'PHI'},
#   {'id': '42376e1c-6da8-461e-9443-cfcf0a9fcc4d',
#    'name': 'Golden Knights',
#    'market': 'Vegas',
#    'alias': 'VGK'},
#   {'id': '468e2568-b105-4472-9c6c-bf53d9cf2e19',
#    'name': 'Hughes',
#    'market': 'Team',
#    'alias': 'HGS'},
#   {'id': '44182a9d-0f24-11e2-8525-18a905767e44',
#    'name': 'Hurricanes',
#    'market': 'Carolina',
#    'alias': 'CAR'},
#   {'id': '441766b9-0f24-11e2-8525-18a905767e44',
#    'name': 'Islanders',
#    'market': 'New York',
#    'alias': 'NYI'},
#   {'id': '44180e55-0f24-11e2-8525-18a905767e44',
#    'name': 'Jets',
#    'market': 'Winnipeg',
#    'alias': 'WPG'},
#   {'id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'name': 'Kings',
#    'market': 'Los Angeles',
#    'alias': 'LA'},
#   {'id': '1fb48e65-9688-4084-8868-02173525c3e1',
#    'name': 'Kraken',
#    'market': 'Seattle',
#    'alias': 'SEA'},
#   {'id': '4417d3cb-0f24-11e2-8525-18a905767e44',
#    'name': 'Lightning',
#    'market': 'Tampa Bay',
#    'alias': 'TB'},
#   {'id': '2bac13fb-85e2-4901-adbc-dab87365e6c9',
#    'name': 'MacKinnon',
#    'market': 'Team',
#    'alias': 'MKN'},
#   {'id': '441730a9-0f24-11e2-8525-18a905767e44',
#    'name': 'Maple Leafs',
#    'market': 'Toronto',
#    'alias': 'TOR'},
#   {'id': 'b7c79007-995e-4961-8a02-0c6f9dd65269',
#    'name': 'Matthews',
#    'market': 'Team',
#    'alias': 'MAT'},
#   {'id': '67be4fe9-b990-4f1a-83ff-82c9a62f71b8',
#    'name': 'McDavid',
#    'market': 'Team',
#    'alias': 'MCD'},
#   {'id': '4415ea6c-0f24-11e2-8525-18a905767e44',
#    'name': 'Oilers',
#    'market': 'Edmonton',
#    'alias': 'EDM'},
#   {'id': '4418464d-0f24-11e2-8525-18a905767e44',
#    'name': 'Panthers',
#    'market': 'Florida',
#    'alias': 'FLA'},
#   {'id': '4417b7d7-0f24-11e2-8525-18a905767e44',
#    'name': 'Penguins',
#    'market': 'Pittsburgh',
#    'alias': 'PIT'},
#   {'id': '441643b7-0f24-11e2-8525-18a905767e44',
#    'name': 'Predators',
#    'market': 'Nashville',
#    'alias': 'NSH'},
#   {'id': '441781b9-0f24-11e2-8525-18a905767e44',
#    'name': 'Rangers',
#    'market': 'New York',
#    'alias': 'NYR'},
#   {'id': '44169bb9-0f24-11e2-8525-18a905767e44',
#    'name': 'Red Wings',
#    'market': 'Detroit',
#    'alias': 'DET'},
#   {'id': '9aa0e461-0d27-4a08-a9f5-5cdea0acd772',
#    'name': 'SC Bern',
#    'alias': 'SCB'},
#   {'id': '4416d559-0f24-11e2-8525-18a905767e44',
#    'name': 'Sabres',
#    'market': 'Buffalo',
#    'alias': 'BUF'},
#   {'id': '4416f5e2-0f24-11e2-8525-18a905767e44',
#    'name': 'Senators',
#    'market': 'Ottawa',
#    'alias': 'OTT'},
#   {'id': '44155909-0f24-11e2-8525-18a905767e44',
#    'name': 'Sharks',
#    'market': 'San Jose',
#    'alias': 'SJ'},
#   {'id': '44157522-0f24-11e2-8525-18a905767e44',
#    'name': 'Stars',
#    'market': 'Dallas',
#    'alias': 'DAL'},
#   {'id': '062d9e85-6d5b-463b-91c6-2d1cd044a6cf',
#    'name': 'TBD',
#    'market': 'Team',
#    'alias': 'TBD'},
#   {'id': '4416091c-0f24-11e2-8525-18a905767e44',
#    'name': 'Wild',
#    'market': 'Minnesota',
#    'alias': 'MIN'}],
#  '_comment': 'Generated started @ 2024-04-28 23:24:15 UTC ended @ 2024-04-28 23:24:15 UTC'}

# %%
# Check data type
type(json.loads(team_api_request.text))
# Out:
# dict

# %%
team_api_response = json.loads(team_api_request.text)

# %%
# only get teams information
team_api_response['teams']
# Out:
# [{'id': '4415ce44-0f24-11e2-8525-18a905767e44',
#   'name': 'Avalanche',
#   'market': 'Colorado',
#   'alias': 'COL'},
#  {'id': '4416272f-0f24-11e2-8525-18a905767e44',
#   'name': 'Blackhawks',
#   'market': 'Chicago',
#   'alias': 'CHI'},
#  {'id': '44167db4-0f24-11e2-8525-18a905767e44',
#   'name': 'Blue Jackets',
#   'market': 'Columbus',
#   'alias': 'CBJ'},
#  {'id': '441660ea-0f24-11e2-8525-18a905767e44',
#   'name': 'Blues',
#   'market': 'St. Louis',
#   'alias': 'STL'},
#  {'id': '4416ba1a-0f24-11e2-8525-18a905767e44',
#   'name': 'Bruins',
#   'market': 'Boston',
#   'alias': 'BOS'},
#  {'id': '441713b7-0f24-11e2-8525-18a905767e44',
#   'name': 'Canadiens',
#   'market': 'Montreal',
#   'alias': 'MTL'},
#  {'id': '4415b0a7-0f24-11e2-8525-18a905767e44',
#   'name': 'Canucks',
#   'market': 'Vancouver',
#   'alias': 'VAN'},
#  {'id': '4417eede-0f24-11e2-8525-18a905767e44',
#   'name': 'Capitals',
#   'market': 'Washington',
#   'alias': 'WSH'},
#  {'id': '44153da1-0f24-11e2-8525-18a905767e44',
#   'name': 'Coyotes',
#   'market': 'Arizona',
#   'alias': 'ARI'},
#  {'id': '44174b0c-0f24-11e2-8525-18a905767e44',
#   'name': 'Devils',
#   'market': 'New Jersey',
#   'alias': 'NJ'},
#  {'id': '1cd2b521-9090-4692-bb78-29973ef2d748',
#   'name': 'Division',
#   'market': 'Pacific',
#   'alias': 'PAC'},
#  {'id': '49e876e9-2e57-4ba4-96fd-ba8e92932227',
#   'name': 'Division',
#   'market': 'Central',
#   'alias': 'CEN'},
#  {'id': '4bea8be7-44fb-4a3e-9abe-26ab3e7f5500',
#   'name': 'Division',
#   'market': 'Atlantic',
#   'alias': 'ATL'},
#  {'id': '99c773e4-ff9f-404e-9a00-4bf5d18caa66',
#   'name': 'Division',
#   'market': 'Metropolitan',
#   'alias': 'MET'},
#  {'id': '441862de-0f24-11e2-8525-18a905767e44',
#   'name': 'Ducks',
#   'market': 'Anaheim',
#   'alias': 'ANA'},
#  {'id': '535534b6-78cf-4650-824c-fb9a15be5988',
#   'name': 'Eisbaren Berlin',
#   'alias': 'EIS'},
#  {'id': '44159241-0f24-11e2-8525-18a905767e44',
#   'name': 'Flames',
#   'market': 'Calgary',
#   'alias': 'CGY'},
#  {'id': '44179d47-0f24-11e2-8525-18a905767e44',
#   'name': 'Flyers',
#   'market': 'Philadelphia',
#   'alias': 'PHI'},
#  {'id': '42376e1c-6da8-461e-9443-cfcf0a9fcc4d',
#   'name': 'Golden Knights',
#   'market': 'Vegas',
#   'alias': 'VGK'},
#  {'id': '468e2568-b105-4472-9c6c-bf53d9cf2e19',
#   'name': 'Hughes',
#   'market': 'Team',
#   'alias': 'HGS'},
#  {'id': '44182a9d-0f24-11e2-8525-18a905767e44',
#   'name': 'Hurricanes',
#   'market': 'Carolina',
#   'alias': 'CAR'},
#  {'id': '441766b9-0f24-11e2-8525-18a905767e44',
#   'name': 'Islanders',
#   'market': 'New York',
#   'alias': 'NYI'},
#  {'id': '44180e55-0f24-11e2-8525-18a905767e44',
#   'name': 'Jets',
#   'market': 'Winnipeg',
#   'alias': 'WPG'},
#  {'id': '44151f7a-0f24-11e2-8525-18a905767e44',
#   'name': 'Kings',
#   'market': 'Los Angeles',
#   'alias': 'LA'},
#  {'id': '1fb48e65-9688-4084-8868-02173525c3e1',
#   'name': 'Kraken',
#   'market': 'Seattle',
#   'alias': 'SEA'},
#  {'id': '4417d3cb-0f24-11e2-8525-18a905767e44',
#   'name': 'Lightning',
#   'market': 'Tampa Bay',
#   'alias': 'TB'},
#  {'id': '2bac13fb-85e2-4901-adbc-dab87365e6c9',
#   'name': 'MacKinnon',
#   'market': 'Team',
#   'alias': 'MKN'},
#  {'id': '441730a9-0f24-11e2-8525-18a905767e44',
#   'name': 'Maple Leafs',
#   'market': 'Toronto',
#   'alias': 'TOR'},
#  {'id': 'b7c79007-995e-4961-8a02-0c6f9dd65269',
#   'name': 'Matthews',
#   'market': 'Team',
#   'alias': 'MAT'},
#  {'id': '67be4fe9-b990-4f1a-83ff-82c9a62f71b8',
#   'name': 'McDavid',
#   'market': 'Team',
#   'alias': 'MCD'},
#  {'id': '4415ea6c-0f24-11e2-8525-18a905767e44',
#   'name': 'Oilers',
#   'market': 'Edmonton',
#   'alias': 'EDM'},
#  {'id': '4418464d-0f24-11e2-8525-18a905767e44',
#   'name': 'Panthers',
#   'market': 'Florida',
#   'alias': 'FLA'},
#  {'id': '4417b7d7-0f24-11e2-8525-18a905767e44',
#   'name': 'Penguins',
#   'market': 'Pittsburgh',
#   'alias': 'PIT'},
#  {'id': '441643b7-0f24-11e2-8525-18a905767e44',
#   'name': 'Predators',
#   'market': 'Nashville',
#   'alias': 'NSH'},
#  {'id': '441781b9-0f24-11e2-8525-18a905767e44',
#   'name': 'Rangers',
#   'market': 'New York',
#   'alias': 'NYR'},
#  {'id': '44169bb9-0f24-11e2-8525-18a905767e44',
#   'name': 'Red Wings',
#   'market': 'Detroit',
#   'alias': 'DET'},
#  {'id': '9aa0e461-0d27-4a08-a9f5-5cdea0acd772',
#   'name': 'SC Bern',
#   'alias': 'SCB'},
#  {'id': '4416d559-0f24-11e2-8525-18a905767e44',
#   'name': 'Sabres',
#   'market': 'Buffalo',
#   'alias': 'BUF'},
#  {'id': '4416f5e2-0f24-11e2-8525-18a905767e44',
#   'name': 'Senators',
#   'market': 'Ottawa',
#   'alias': 'OTT'},
#  {'id': '44155909-0f24-11e2-8525-18a905767e44',
#   'name': 'Sharks',
#   'market': 'San Jose',
#   'alias': 'SJ'},
#  {'id': '44157522-0f24-11e2-8525-18a905767e44',
#   'name': 'Stars',
#   'market': 'Dallas',
#   'alias': 'DAL'},
#  {'id': '062d9e85-6d5b-463b-91c6-2d1cd044a6cf',
#   'name': 'TBD',
#   'market': 'Team',
#   'alias': 'TBD'},
#  {'id': '4416091c-0f24-11e2-8525-18a905767e44',
#   'name': 'Wild',
#   'market': 'Minnesota',
#   'alias': 'MIN'}]

# %%
teams = team_api_response['teams']

# %%
type(teams)
# Out:
# list

# %%
# Set a dictionary to store data
teams_data = {
    'id':[],
    'name':[],
    'area':[],
    'alias':[]
}
# get information from the loop
for team in teams:
    id = team['id']
    teams_data['id'].append(id)
    print(id)
    
    name = team['name']
    teams_data['name'].append(name)
    print(name)
    
    area = team.get('market', None)
    teams_data['area'].append(area)
    print(area if area is not None else 'None')
    
    alias = team['alias']
    teams_data['alias'].append(alias)
    print(alias)
    
    print('-'*75)
    #alis = team[]
# Out:
# 4415ce44-0f24-11e2-8525-18a905767e44
# Avalanche
# Colorado
# COL
# ---------------------------------------------------------------------------
# 4416272f-0f24-11e2-8525-18a905767e44
# Blackhawks
# Chicago
# CHI
# ---------------------------------------------------------------------------
# 44167db4-0f24-11e2-8525-18a905767e44
# Blue Jackets
# Columbus
# CBJ
# ---------------------------------------------------------------------------
# 441660ea-0f24-11e2-8525-18a905767e44
# Blues
# St. Louis
# STL
# ---------------------------------------------------------------------------
# 4416ba1a-0f24-11e2-8525-18a905767e44
# Bruins
# Boston
# BOS
# ---------------------------------------------------------------------------
# 441713b7-0f24-11e2-8525-18a905767e44
# Canadiens
# Montreal
# MTL
# ---------------------------------------------------------------------------
# 4415b0a7-0f24-11e2-8525-18a905767e44
# Canucks
# Vancouver
# VAN
# ---------------------------------------------------------------------------
# 4417eede-0f24-11e2-8525-18a905767e44
# Capitals
# Washington
# WSH
# ---------------------------------------------------------------------------
# 44153da1-0f24-11e2-8525-18a905767e44
# Coyotes
# Arizona
# ARI
# ---------------------------------------------------------------------------
# 44174b0c-0f24-11e2-8525-18a905767e44
# Devils
# New Jersey
# NJ
# ---------------------------------------------------------------------------
# 1cd2b521-9090-4692-bb78-29973ef2d748
# Division
# Pacific
# PAC
# ---------------------------------------------------------------------------
# 49e876e9-2e57-4ba4-96fd-ba8e92932227
# Division
# Central
# CEN
# ---------------------------------------------------------------------------
# 4bea8be7-44fb-4a3e-9abe-26ab3e7f5500
# Division
# Atlantic
# ATL
# ---------------------------------------------------------------------------
# 99c773e4-ff9f-404e-9a00-4bf5d18caa66
# Division
# Metropolitan
# MET
# ---------------------------------------------------------------------------
# 441862de-0f24-11e2-8525-18a905767e44
# Ducks
# Anaheim
# ANA
# ---------------------------------------------------------------------------
# 535534b6-78cf-4650-824c-fb9a15be5988
# Eisbaren Berlin
# None
# EIS
# ---------------------------------------------------------------------------
# 44159241-0f24-11e2-8525-18a905767e44
# Flames
# Calgary
# CGY
# ---------------------------------------------------------------------------
# 44179d47-0f24-11e2-8525-18a905767e44
# Flyers
# Philadelphia
# PHI
# ---------------------------------------------------------------------------
# 42376e1c-6da8-461e-9443-cfcf0a9fcc4d
# Golden Knights
# Vegas
# VGK
# ---------------------------------------------------------------------------
# 468e2568-b105-4472-9c6c-bf53d9cf2e19
# Hughes
# Team
# HGS
# ---------------------------------------------------------------------------
# 44182a9d-0f24-11e2-8525-18a905767e44
# Hurricanes
# Carolina
# CAR
# ---------------------------------------------------------------------------
# 441766b9-0f24-11e2-8525-18a905767e44
# Islanders
# New York
# NYI
# ---------------------------------------------------------------------------
# 44180e55-0f24-11e2-8525-18a905767e44
# Jets
# Winnipeg
# WPG
# ---------------------------------------------------------------------------
# 44151f7a-0f24-11e2-8525-18a905767e44
# Kings
# Los Angeles
# LA
# ---------------------------------------------------------------------------
# 1fb48e65-9688-4084-8868-02173525c3e1
# Kraken
# Seattle
# SEA
# ---------------------------------------------------------------------------
# 4417d3cb-0f24-11e2-8525-18a905767e44
# Lightning
# Tampa Bay
# TB
# ---------------------------------------------------------------------------
# 2bac13fb-85e2-4901-adbc-dab87365e6c9
# MacKinnon
# Team
# MKN
# ---------------------------------------------------------------------------
# 441730a9-0f24-11e2-8525-18a905767e44
# Maple Leafs
# Toronto
# TOR
# ---------------------------------------------------------------------------
# b7c79007-995e-4961-8a02-0c6f9dd65269
# Matthews
# Team
# MAT
# ---------------------------------------------------------------------------
# 67be4fe9-b990-4f1a-83ff-82c9a62f71b8
# McDavid
# Team
# MCD
# ---------------------------------------------------------------------------
# 4415ea6c-0f24-11e2-8525-18a905767e44
# Oilers
# Edmonton
# EDM
# ---------------------------------------------------------------------------
# 4418464d-0f24-11e2-8525-18a905767e44
# Panthers
# Florida
# FLA
# ---------------------------------------------------------------------------
# 4417b7d7-0f24-11e2-8525-18a905767e44
# Penguins
# Pittsburgh
# PIT
# ---------------------------------------------------------------------------
# 441643b7-0f24-11e2-8525-18a905767e44
# Predators
# Nashville
# NSH
# ---------------------------------------------------------------------------
# 441781b9-0f24-11e2-8525-18a905767e44
# Rangers
# New York
# NYR
# ---------------------------------------------------------------------------
# 44169bb9-0f24-11e2-8525-18a905767e44
# Red Wings
# Detroit
# DET
# ---------------------------------------------------------------------------
# 9aa0e461-0d27-4a08-a9f5-5cdea0acd772
# SC Bern
# None
# SCB
# ---------------------------------------------------------------------------
# 4416d559-0f24-11e2-8525-18a905767e44
# Sabres
# Buffalo
# BUF
# ---------------------------------------------------------------------------
# 4416f5e2-0f24-11e2-8525-18a905767e44
# Senators
# Ottawa
# OTT
# ---------------------------------------------------------------------------
# 44155909-0f24-11e2-8525-18a905767e44
# Sharks
# San Jose
# SJ
# ---------------------------------------------------------------------------
# 44157522-0f24-11e2-8525-18a905767e44
# Stars
# Dallas
# DAL
# ---------------------------------------------------------------------------
# 062d9e85-6d5b-463b-91c6-2d1cd044a6cf
# TBD
# Team
# TBD
# ---------------------------------------------------------------------------
# 4416091c-0f24-11e2-8525-18a905767e44
# Wild
# Minnesota
# MIN
# ---------------------------------------------------------------------------

# %%
teams_data
# Out:
# {'id': ['4415ce44-0f24-11e2-8525-18a905767e44',
#   '4416272f-0f24-11e2-8525-18a905767e44',
#   '44167db4-0f24-11e2-8525-18a905767e44',
#   '441660ea-0f24-11e2-8525-18a905767e44',
#   '4416ba1a-0f24-11e2-8525-18a905767e44',
#   '441713b7-0f24-11e2-8525-18a905767e44',
#   '4415b0a7-0f24-11e2-8525-18a905767e44',
#   '4417eede-0f24-11e2-8525-18a905767e44',
#   '44153da1-0f24-11e2-8525-18a905767e44',
#   '44174b0c-0f24-11e2-8525-18a905767e44',
#   '1cd2b521-9090-4692-bb78-29973ef2d748',
#   '49e876e9-2e57-4ba4-96fd-ba8e92932227',
#   '4bea8be7-44fb-4a3e-9abe-26ab3e7f5500',
#   '99c773e4-ff9f-404e-9a00-4bf5d18caa66',
#   '441862de-0f24-11e2-8525-18a905767e44',
#   '535534b6-78cf-4650-824c-fb9a15be5988',
#   '44159241-0f24-11e2-8525-18a905767e44',
#   '44179d47-0f24-11e2-8525-18a905767e44',
#   '42376e1c-6da8-461e-9443-cfcf0a9fcc4d',
#   '468e2568-b105-4472-9c6c-bf53d9cf2e19',
#   '44182a9d-0f24-11e2-8525-18a905767e44',
#   '441766b9-0f24-11e2-8525-18a905767e44',
#   '44180e55-0f24-11e2-8525-18a905767e44',
#   '44151f7a-0f24-11e2-8525-18a905767e44',
#   '1fb48e65-9688-4084-8868-02173525c3e1',
#   '4417d3cb-0f24-11e2-8525-18a905767e44',
#   '2bac13fb-85e2-4901-adbc-dab87365e6c9',
#   '441730a9-0f24-11e2-8525-18a905767e44',
#   'b7c79007-995e-4961-8a02-0c6f9dd65269',
#   '67be4fe9-b990-4f1a-83ff-82c9a62f71b8',
#   '4415ea6c-0f24-11e2-8525-18a905767e44',
#   '4418464d-0f24-11e2-8525-18a905767e44',
#   '4417b7d7-0f24-11e2-8525-18a905767e44',
#   '441643b7-0f24-11e2-8525-18a905767e44',
#   '441781b9-0f24-11e2-8525-18a905767e44',
#   '44169bb9-0f24-11e2-8525-18a905767e44',
#   '9aa0e461-0d27-4a08-a9f5-5cdea0acd772',
#   '4416d559-0f24-11e2-8525-18a905767e44',
#   '4416f5e2-0f24-11e2-8525-18a905767e44',
#   '44155909-0f24-11e2-8525-18a905767e44',
#   '44157522-0f24-11e2-8525-18a905767e44',
#   '062d9e85-6d5b-463b-91c6-2d1cd044a6cf',
#   '4416091c-0f24-11e2-8525-18a905767e44'],
#  'name': ['Avalanche',
#   'Blackhawks',
#   'Blue Jackets',
#   'Blues',
#   'Bruins',
#   'Canadiens',
#   'Canucks',
#   'Capitals',
#   'Coyotes',
#   'Devils',
#   'Division',
#   'Division',
#   'Division',
#   'Division',
#   'Ducks',
#   'Eisbaren Berlin',
#   'Flames',
#   'Flyers',
#   'Golden Knights',
#   'Hughes',
#   'Hurricanes',
#   'Islanders',
#   'Jets',
#   'Kings',
#   'Kraken',
#   'Lightning',
#   'MacKinnon',
#   'Maple Leafs',
#   'Matthews',
#   'McDavid',
#   'Oilers',
#   'Panthers',
#   'Penguins',
#   'Predators',
#   'Rangers',
#   'Red Wings',
#   'SC Bern',
#   'Sabres',
#   'Senators',
#   'Sharks',
#   'Stars',
#   'TBD',
#   'Wild'],
#  'area': ['Colorado',
#   'Chicago',
#   'Columbus',
#   'St. Louis',
#   'Boston',
#   'Montreal',
#   'Vancouver',
#   'Washington',
#   'Arizona',
#   'New Jersey',
#   'Pacific',
#   'Central',
#   'Atlantic',
#   'Metropolitan',
#   'Anaheim',
#   None,
#   'Calgary',
#   'Philadelphia',
#   'Vegas',
#   'Team',
#   'Carolina',
#   'New York',
#   'Winnipeg',
#   'Los Angeles',
#   'Seattle',
#   'Tampa Bay',
#   'Team',
#   'Toronto',
#   'Team',
#   'Team',
#   'Edmonton',
#   'Florida',
#   'Pittsburgh',
#   'Nashville',
#   'New York',
#   'Detroit',
#   None,
#   'Buffalo',
#   'Ottawa',
#   'San Jose',
#   'Dallas',
#   'Team',
#   'Minnesota'],
#  'alias': ['COL',
#   'CHI',
#   'CBJ',
#   'STL',
#   'BOS',
#   'MTL',
#   'VAN',
#   'WSH',
#   'ARI',
#   'NJ',
#   'PAC',
#   'CEN',
#   'ATL',
#   'MET',
#   'ANA',
#   'EIS',
#   'CGY',
#   'PHI',
#   'VGK',
#   'HGS',
#   'CAR',
#   'NYI',
#   'WPG',
#   'LA',
#   'SEA',
#   'TB',
#   'MKN',
#   'TOR',
#   'MAT',
#   'MCD',
#   'EDM',
#   'FLA',
#   'PIT',
#   'NSH',
#   'NYR',
#   'DET',
#   'SCB',
#   'BUF',
#   'OTT',
#   'SJ',
#   'DAL',
#   'TBD',
#   'MIN']}

# %%
df =pd.DataFrame(teams_data)

# %%
df.head()
# Out:
#                                      id          name       area alias
# 0  4415ce44-0f24-11e2-8525-18a905767e44     Avalanche   Colorado   COL
# 1  4416272f-0f24-11e2-8525-18a905767e44    Blackhawks    Chicago   CHI
# 2  44167db4-0f24-11e2-8525-18a905767e44  Blue Jackets   Columbus   CBJ
# 3  441660ea-0f24-11e2-8525-18a905767e44         Blues  St. Louis   STL
# 4  4416ba1a-0f24-11e2-8525-18a905767e44        Bruins     Boston   BOS

# %%
df.to_csv('nhl_teams.csv', index=False)

# %% [markdown]
# # Extract Player Data

# %%
player_url = 'https://api.sportradar.com/nhl/production/v7/en/teams/44151f7a-0f24-11e2-8525-18a905767e44/profile.json'
# 3XZ4cbvj3w6hRONhHDelw92rvKqucxRk5ux3ZBpI

player_api_request = requests.get(player_url, params=team_params)

# %%
player_api_request
# Out:
# <Response [200]>

# %%
json.loads(player_api_request.text)
# Out:
# {'id': '44151f7a-0f24-11e2-8525-18a905767e44',
#  'name': 'Kings',
#  'market': 'Los Angeles',
#  'alias': 'LA',
#  'sr_id': 'sr:team:3688',
#  'reference': '26',
#  'venue': {'id': 'dec253d4-68df-470b-b8fc-d663a7fa4704',
#   'name': 'Crypto.com Arena',
#   'capacity': 18230,
#   'address': '1111 S Figueroa Street',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'zip': '90015',
#   'country': 'USA',
#   'time_zone': 'US/Pacific',
#   'sr_id': 'sr:venue:6008'},
#  'league': {'id': 'fd560107-a85b-4388-ab0d-655ad022aff7',
#   'name': 'NHL',
#   'alias': 'NHL'},
#  'conference': {'id': '64901512-9ca9-4bea-aa80-16dbcbdae230',
#   'name': 'WESTERN CONFERENCE',
#   'alias': 'WESTERN'},
#  'division': {'id': '17101b65-e8b9-4cda-a963-eea874aed81f',
#   'name': 'Pacific',
#   'alias': 'PACIFIC'},
#  'coaches': [{'id': 'bc3a259f-6efc-4a7f-9f13-5a723309b5bd',
#    'full_name': 'Jim Hiller',
#    'first_name': 'Jim',
#    'last_name': 'Hiller',
#    'position': 'Interim Head Coach'}],
#  'players': [{'id': '070ff077-e59b-4135-b060-352ee716bc7e',
#    'status': 'ACT',
#    'full_name': 'Blake Lizotte',
#    'first_name': 'Blake',
#    'last_name': 'Lizotte',
#    'abbr_name': 'B.Lizotte',
#    'height': 69,
#    'weight': 170,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '46',
#    'college': 'St. Cloud State',
#    'experience': '5',
#    'birth_place': 'Lindstrom, MN, USA',
#    'birthdate': '1997-12-13',
#    'updated': '2024-02-22T20:10:35Z',
#    'sr_id': 'sr:player:1726708',
#    'reference': '8481481',
#    'rookie_year': 2018},
#   {'id': '0a1a1d3a-7118-4d30-a2bd-a2f95822d22c',
#    'status': 'IR',
#    'full_name': 'Pheonix Copley',
#    'first_name': 'Pheonix',
#    'last_name': 'Copley',
#    'abbr_name': 'P.Copley',
#    'height': 76,
#    'weight': 200,
#    'handedness': 'L',
#    'position': 'G',
#    'primary_position': 'G',
#    'jersey_number': '29',
#    'college': 'Michigan Tech',
#    'experience': '5',
#    'birth_place': 'North Pole, AK, USA',
#    'birthdate': '1992-01-18',
#    'updated': '2023-12-17T22:18:20Z',
#    'sr_id': 'sr:player:791897',
#    'reference': '8477831',
#    'rookie_year': 2015,
#    'injuries': [{'id': '33a12b66-3e5e-481e-a12e-2a8d797675cd',
#      'status': 'Out For Season',
#      'start_date': '2023-12-15',
#      'update_date': '2024-01-06',
#      'comment': 'The Kings announced that Copley underwent surgery for a torn ACL and is out for the season.',
#      'desc': 'Knee'}]},
#   {'id': '0cc94754-1f54-4723-939f-8c14dd930759',
#    'status': 'ACT',
#    'full_name': 'Matt Roy',
#    'first_name': 'Matt',
#    'last_name': 'Roy',
#    'abbr_name': 'M.Roy',
#    'height': 73,
#    'weight': 205,
#    'handedness': 'R',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '3',
#    'college': 'Michigan Tech',
#    'experience': '5',
#    'birth_place': 'Detroit, MI, USA',
#    'birthdate': '1995-03-01',
#    'updated': '2023-10-05T21:10:12Z',
#    'sr_id': 'sr:player:1299308',
#    'reference': '8478911',
#    'rookie_year': 2018,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2015,
#     'round': '7',
#     'pick': '194'}},
#   {'id': '240ad2f4-8860-45a6-94d0-79b87dffd3ea',
#    'status': 'ACT',
#    'full_name': 'Aaron Dell',
#    'first_name': 'Aaron',
#    'last_name': 'Dell',
#    'abbr_name': 'A.Dell',
#    'height': 72,
#    'weight': 213,
#    'handedness': 'L',
#    'position': 'G',
#    'primary_position': 'G',
#    'jersey_number': '30',
#    'college': 'North Dakota',
#    'experience': '7',
#    'birth_place': 'Airdrie, AB, CAN',
#    'birthdate': '1989-05-04',
#    'updated': '2024-04-22T15:29:59Z',
#    'sr_id': 'sr:player:899396',
#    'reference': '8477180',
#    'rookie_year': 2016},
#   {'id': '421f9f71-d1ee-4917-afc6-ca11f6b761b0',
#    'status': 'ACT',
#    'full_name': 'Trevor Moore',
#    'first_name': 'Trevor',
#    'last_name': 'Moore',
#    'abbr_name': 'T.Moore',
#    'height': 70,
#    'weight': 195,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'LW',
#    'jersey_number': '12',
#    'college': 'Denver',
#    'experience': '5',
#    'birth_place': 'Thousand Oaks, CA, USA',
#    'birthdate': '1995-03-31',
#    'updated': '2023-10-05T21:09:54Z',
#    'sr_id': 'sr:player:1051357',
#    'reference': '8479675',
#    'rookie_year': 2018},
#   {'id': '427d1fda-0f24-11e2-8525-18a905767e44',
#    'status': 'ACT',
#    'full_name': 'Anze Kopitar',
#    'first_name': 'Anze',
#    'last_name': 'Kopitar',
#    'abbr_name': 'A.Kopitar',
#    'height': 75,
#    'weight': 225,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '11',
#    'experience': '17',
#    'birth_place': 'Jesenice,, SVN',
#    'birthdate': '1987-08-24',
#    'updated': '2023-10-05T21:09:00Z',
#    'sr_id': 'sr:player:29571',
#    'reference': '8471685',
#    'rookie_year': 2006,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2005,
#     'round': '1',
#     'pick': '11'}},
#   {'id': '427d4479-0f24-11e2-8525-18a905767e44',
#    'status': 'ACT',
#    'full_name': 'Trevor Lewis',
#    'first_name': 'Trevor',
#    'last_name': 'Lewis',
#    'abbr_name': 'T.Lewis',
#    'height': 73,
#    'weight': 201,
#    'handedness': 'R',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '61',
#    'experience': '15',
#    'birth_place': 'Salt Lake City, UT, USA',
#    'birthdate': '1987-01-08',
#    'updated': '2023-10-05T21:09:30Z',
#    'sr_id': 'sr:player:93721',
#    'reference': '8473453',
#    'rookie_year': 2008,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2006,
#     'round': '1',
#     'pick': '17'}},
#   {'id': '4281a6e1-0f24-11e2-8525-18a905767e44',
#    'status': 'ACT',
#    'full_name': 'Drew Doughty',
#    'first_name': 'Drew',
#    'last_name': 'Doughty',
#    'abbr_name': 'D.Doughty',
#    'height': 73,
#    'weight': 210,
#    'handedness': 'R',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '8',
#    'experience': '15',
#    'birth_place': 'London, ON, CAN',
#    'birthdate': '1989-12-08',
#    'updated': '2023-10-05T21:07:32Z',
#    'sr_id': 'sr:player:42413',
#    'reference': '8474563',
#    'rookie_year': 2008,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2008,
#     'round': '1',
#     'pick': '2'}},
#   {'id': '4333f6f1-0f24-11e2-8525-18a905767e44',
#    'status': 'ACT',
#    'full_name': 'Cam Talbot',
#    'first_name': 'Cam',
#    'last_name': 'Talbot',
#    'abbr_name': 'C.Talbot',
#    'height': 76,
#    'weight': 201,
#    'handedness': 'L',
#    'position': 'G',
#    'primary_position': 'G',
#    'jersey_number': '39',
#    'college': 'Alabama Huntsville',
#    'experience': '10',
#    'birth_place': 'Caledonia, ON, CAN',
#    'birthdate': '1987-07-05',
#    'updated': '2023-10-05T21:10:52Z',
#    'sr_id': 'sr:player:606874',
#    'reference': '8475660',
#    'rookie_year': 2013},
#   {'id': '533ebbc8-ad3c-459e-8b29-660030ac140f',
#    'status': 'ACT',
#    'full_name': 'Alex Laferriere',
#    'first_name': 'Alex',
#    'last_name': 'Laferriere',
#    'abbr_name': 'A.Laferriere',
#    'height': 73,
#    'weight': 205,
#    'handedness': 'R',
#    'position': 'F',
#    'primary_position': 'RW',
#    'jersey_number': '78',
#    'college': 'Harvard',
#    'experience': '0',
#    'birth_place': 'Chatham, NJ, USA',
#    'birthdate': '2001-10-28',
#    'updated': '2023-11-13T19:08:23Z',
#    'sr_id': 'sr:player:2056465',
#    'reference': '8482155',
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2020,
#     'round': '3',
#     'pick': '83'}},
#   {'id': '59a7f500-cc98-4dd4-bc25-5ad948f4577e',
#    'status': 'ACT',
#    'full_name': 'Quinton Byfield',
#    'first_name': 'Quinton',
#    'last_name': 'Byfield',
#    'abbr_name': 'Q.Byfield',
#    'height': 77,
#    'weight': 220,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'RW',
#    'jersey_number': '55',
#    'experience': '3',
#    'birth_place': 'Newmarket, ON, CAN',
#    'birthdate': '2002-08-19',
#    'updated': '2023-11-09T15:14:19Z',
#    'sr_id': 'sr:player:1980393',
#    'reference': '8482124',
#    'rookie_year': 2020,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2020,
#     'round': '1',
#     'pick': '2'}},
#   {'id': '5b0377bd-412a-44aa-8b8d-8e8eabeb290e',
#    'status': 'ACT',
#    'full_name': 'Carl Grundstrom',
#    'first_name': 'Carl',
#    'last_name': 'Grundstrom',
#    'abbr_name': 'C.Grundstrom',
#    'height': 72,
#    'weight': 195,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'RW',
#    'jersey_number': '91',
#    'experience': '5',
#    'birth_place': 'Umea,, SWE',
#    'birthdate': '1997-12-01',
#    'updated': '2024-04-20T17:26:55Z',
#    'sr_id': 'sr:player:774887',
#    'reference': '8479336',
#    'rookie_year': 2018,
#    'draft': {'team_id': '441730a9-0f24-11e2-8525-18a905767e44',
#     'year': 2016,
#     'round': '2',
#     'pick': '57'}},
#   {'id': '623e4a05-3a49-4921-9f90-da01969ff084',
#    'status': 'ACT',
#    'full_name': 'Angus Booth',
#    'first_name': 'Angus',
#    'last_name': 'Booth',
#    'abbr_name': 'A.Booth',
#    'height': 72,
#    'weight': 177,
#    'handedness': 'L',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '81',
#    'experience': '0',
#    'birth_place': 'Montreal, QC, CAN',
#    'birthdate': '2004-04-27',
#    'updated': '2024-01-23T19:38:35Z',
#    'sr_id': 'sr:player:2265695',
#    'reference': '8483699',
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2022,
#     'round': '4',
#     'pick': '116'}},
#   {'id': '6767e821-5a9c-4379-9bfa-9f19314cfc2f',
#    'status': 'ACT',
#    'full_name': 'Mikey Anderson',
#    'first_name': 'Mikey',
#    'last_name': 'Anderson',
#    'abbr_name': 'M.Anderson',
#    'height': 72,
#    'weight': 195,
#    'handedness': 'L',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '44',
#    'college': 'Minnesota Duluth',
#    'experience': '4',
#    'birth_place': 'Roseville, MN, USA',
#    'birthdate': '1999-05-25',
#    'updated': '2023-10-05T21:05:58Z',
#    'sr_id': 'sr:player:1117735',
#    'reference': '8479998',
#    'rookie_year': 2019,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2017,
#     'round': '4',
#     'pick': '103'}},
#   {'id': '677c3651-f73b-4fbf-9a71-f6f16874617d',
#    'status': 'ACT',
#    'full_name': 'David Rittich',
#    'first_name': 'David',
#    'last_name': 'Rittich',
#    'abbr_name': 'D.Rittich',
#    'height': 75,
#    'weight': 206,
#    'handedness': 'L',
#    'position': 'G',
#    'primary_position': 'G',
#    'jersey_number': '31',
#    'experience': '7',
#    'birth_place': 'Jihlava,, CZE',
#    'birthdate': '1992-08-19',
#    'updated': '2023-12-15T21:44:49Z',
#    'sr_id': 'sr:player:604562',
#    'reference': '8479496',
#    'rookie_year': 2016},
#   {'id': '76967e78-08fa-4e9c-8ec5-b42ea00d0a37',
#    'status': 'ACT',
#    'full_name': 'Phillip Danault',
#    'first_name': 'Phillip',
#    'last_name': 'Danault',
#    'abbr_name': 'P.Danault',
#    'height': 73,
#    'weight': 200,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '24',
#    'experience': '9',
#    'birth_place': 'Victoriaville, QC, CAN',
#    'birthdate': '1993-02-24',
#    'updated': '2023-10-05T21:07:20Z',
#    'sr_id': 'sr:player:353682',
#    'reference': '8476479',
#    'rookie_year': 2014,
#    'draft': {'team_id': '4416272f-0f24-11e2-8525-18a905767e44',
#     'year': 2011,
#     'round': '1',
#     'pick': '26'}},
#   {'id': '7fa5b22b-b106-45aa-89d1-02861c739aa7',
#    'status': 'ACT',
#    'full_name': 'Pierre-Luc Dubois',
#    'first_name': 'Pierre-Luc',
#    'last_name': 'Dubois',
#    'abbr_name': 'P.Dubois',
#    'height': 76,
#    'weight': 225,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '80',
#    'experience': '6',
#    'birth_place': 'Ste-Agathe-des-Monts, QC, CAN',
#    'birthdate': '1998-06-24',
#    'updated': '2023-11-09T15:14:49Z',
#    'sr_id': 'sr:player:983715',
#    'reference': '8479400',
#    'rookie_year': 2017,
#    'draft': {'team_id': '44167db4-0f24-11e2-8525-18a905767e44',
#     'year': 2016,
#     'round': '1',
#     'pick': '3'}},
#   {'id': '8eef97c0-56c8-493b-bd12-9ab5b1456bda',
#    'status': 'ACT',
#    'full_name': 'Andreas Englund',
#    'first_name': 'Andreas',
#    'last_name': 'Englund',
#    'abbr_name': 'A.Englund',
#    'height': 75,
#    'weight': 189,
#    'handedness': 'L',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '5',
#    'experience': '5',
#    'birth_place': 'Stockholm,, SWE',
#    'birthdate': '1996-01-21',
#    'updated': '2023-10-05T21:07:56Z',
#    'sr_id': 'sr:player:382576',
#    'reference': '8477971',
#    'rookie_year': 2016,
#    'draft': {'team_id': '4416f5e2-0f24-11e2-8525-18a905767e44',
#     'year': 2014,
#     'round': '2',
#     'pick': '40'}},
#   {'id': '9a2d02cf-a8f2-43a4-9079-d9f72238facb',
#    'status': 'ACT',
#    'full_name': 'Jacob Moverare',
#    'first_name': 'Jacob',
#    'last_name': 'Moverare',
#    'abbr_name': 'J.Moverare',
#    'height': 75,
#    'weight': 210,
#    'handedness': 'L',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '43',
#    'experience': '2',
#    'birth_place': 'Ostersund,, SWE',
#    'birthdate': '1998-08-31',
#    'updated': '2024-03-29T18:40:07Z',
#    'sr_id': 'sr:player:983687',
#    'reference': '8479421',
#    'rookie_year': 2021,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2016,
#     'round': '4',
#     'pick': '112'}},
#   {'id': 'a0b91f2e-bb6d-409a-9e58-cc764edafe64',
#    'status': 'ACT',
#    'full_name': 'Adrian Kempe',
#    'first_name': 'Adrian',
#    'last_name': 'Kempe',
#    'abbr_name': 'A.Kempe',
#    'height': 74,
#    'weight': 200,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '9',
#    'experience': '7',
#    'birth_place': 'Kramfors,, SWE',
#    'birthdate': '1996-09-13',
#    'updated': '2023-10-05T21:08:40Z',
#    'sr_id': 'sr:player:361870',
#    'reference': '8477960',
#    'rookie_year': 2016,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2014,
#     'round': '1',
#     'pick': '29'}},
#   {'id': 'bceebd33-2eee-4987-9a24-39ff8d8b01eb',
#    'status': 'ACT',
#    'full_name': 'Jordan Spence',
#    'first_name': 'Jordan',
#    'last_name': 'Spence',
#    'abbr_name': 'J.Spence',
#    'height': 70,
#    'weight': 180,
#    'handedness': 'R',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '21',
#    'experience': '2',
#    'birth_place': 'Sydney,, AUS',
#    'birthdate': '2001-02-24',
#    'updated': '2024-02-24T18:49:33Z',
#    'sr_id': 'sr:player:1770298',
#    'reference': '8481606',
#    'rookie_year': 2021,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2019,
#     'round': '4',
#     'pick': '95'}},
#   {'id': 'c86ff633-7f27-420c-84a7-be1e08ede9a6',
#    'status': 'ACT',
#    'full_name': 'Kevin Fiala',
#    'first_name': 'Kevin',
#    'last_name': 'Fiala',
#    'abbr_name': 'K.Fiala',
#    'height': 70,
#    'weight': 204,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'LW',
#    'jersey_number': '22',
#    'experience': '9',
#    'birth_place': 'St. Gallen,, CHE',
#    'birthdate': '1996-07-22',
#    'updated': '2023-10-05T21:08:04Z',
#    'sr_id': 'sr:player:376846',
#    'reference': '8477942',
#    'rookie_year': 2014,
#    'draft': {'team_id': '441643b7-0f24-11e2-8525-18a905767e44',
#     'year': 2014,
#     'round': '1',
#     'pick': '11'}},
#   {'id': 'cd3e3e6c-23c2-4a3e-af08-e498246c50ad',
#    'status': 'ACT',
#    'full_name': 'Viktor Arvidsson',
#    'first_name': 'Viktor',
#    'last_name': 'Arvidsson',
#    'abbr_name': 'V.Arvidsson',
#    'height': 70,
#    'weight': 185,
#    'handedness': 'R',
#    'position': 'F',
#    'primary_position': 'RW',
#    'jersey_number': '33',
#    'experience': '9',
#    'birth_place': 'Skelleftea,, SWE',
#    'birthdate': '1993-04-08',
#    'updated': '2024-03-20T18:49:00Z',
#    'sr_id': 'sr:player:266577',
#    'reference': '8478042',
#    'rookie_year': 2014,
#    'draft': {'team_id': '441643b7-0f24-11e2-8525-18a905767e44',
#     'year': 2014,
#     'round': '4',
#     'pick': '112'}},
#   {'id': 'd57c7da4-b733-4137-94d3-388dd2b60cba',
#    'status': 'ACT',
#    'full_name': 'Vladislav Gavrikov',
#    'first_name': 'Vladislav',
#    'last_name': 'Gavrikov',
#    'abbr_name': 'V.Gavrikov',
#    'height': 75,
#    'weight': 221,
#    'handedness': 'L',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '84',
#    'experience': '4',
#    'birth_place': 'Yaroslavl,, RUS',
#    'birthdate': '1995-11-21',
#    'updated': '2023-12-27T20:12:18Z',
#    'sr_id': 'sr:player:793408',
#    'reference': '8478882',
#    'rookie_year': 2019,
#    'draft': {'team_id': '44167db4-0f24-11e2-8525-18a905767e44',
#     'year': 2015,
#     'round': '6',
#     'pick': '159'}},
#   {'id': 'f0cdc175-e8c9-4dd9-877d-0f067d8c2e31',
#    'status': 'ACT',
#    'full_name': 'Arthur Kaliyev',
#    'first_name': 'Arthur',
#    'last_name': 'Kaliyev',
#    'abbr_name': 'A.Kaliyev',
#    'height': 74,
#    'weight': 210,
#    'handedness': 'L',
#    'position': 'F',
#    'primary_position': 'RW',
#    'jersey_number': '34',
#    'experience': '3',
#    'birth_place': 'Tashkent,, UZB',
#    'birthdate': '2001-06-26',
#    'updated': '2024-02-05T15:58:05Z',
#    'sr_id': 'sr:player:1650147',
#    'reference': '8481560',
#    'rookie_year': 2020,
#    'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#     'year': 2019,
#     'round': '2',
#     'pick': '33'}}]}

# %%
player_api_request = json.loads(player_api_request.text)

# %%
type(player_api_request)
# Out:
# dict

# %%
player_api_request['players']
# Out:
# [{'id': '070ff077-e59b-4135-b060-352ee716bc7e',
#   'status': 'ACT',
#   'full_name': 'Blake Lizotte',
#   'first_name': 'Blake',
#   'last_name': 'Lizotte',
#   'abbr_name': 'B.Lizotte',
#   'height': 69,
#   'weight': 170,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '46',
#   'college': 'St. Cloud State',
#   'experience': '5',
#   'birth_place': 'Lindstrom, MN, USA',
#   'birthdate': '1997-12-13',
#   'updated': '2024-02-22T20:10:35Z',
#   'sr_id': 'sr:player:1726708',
#   'reference': '8481481',
#   'rookie_year': 2018},
#  {'id': '0a1a1d3a-7118-4d30-a2bd-a2f95822d22c',
#   'status': 'IR',
#   'full_name': 'Pheonix Copley',
#   'first_name': 'Pheonix',
#   'last_name': 'Copley',
#   'abbr_name': 'P.Copley',
#   'height': 76,
#   'weight': 200,
#   'handedness': 'L',
#   'position': 'G',
#   'primary_position': 'G',
#   'jersey_number': '29',
#   'college': 'Michigan Tech',
#   'experience': '5',
#   'birth_place': 'North Pole, AK, USA',
#   'birthdate': '1992-01-18',
#   'updated': '2023-12-17T22:18:20Z',
#   'sr_id': 'sr:player:791897',
#   'reference': '8477831',
#   'rookie_year': 2015,
#   'injuries': [{'id': '33a12b66-3e5e-481e-a12e-2a8d797675cd',
#     'status': 'Out For Season',
#     'start_date': '2023-12-15',
#     'update_date': '2024-01-06',
#     'comment': 'The Kings announced that Copley underwent surgery for a torn ACL and is out for the season.',
#     'desc': 'Knee'}]},
#  {'id': '0cc94754-1f54-4723-939f-8c14dd930759',
#   'status': 'ACT',
#   'full_name': 'Matt Roy',
#   'first_name': 'Matt',
#   'last_name': 'Roy',
#   'abbr_name': 'M.Roy',
#   'height': 73,
#   'weight': 205,
#   'handedness': 'R',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '3',
#   'college': 'Michigan Tech',
#   'experience': '5',
#   'birth_place': 'Detroit, MI, USA',
#   'birthdate': '1995-03-01',
#   'updated': '2023-10-05T21:10:12Z',
#   'sr_id': 'sr:player:1299308',
#   'reference': '8478911',
#   'rookie_year': 2018,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2015,
#    'round': '7',
#    'pick': '194'}},
#  {'id': '240ad2f4-8860-45a6-94d0-79b87dffd3ea',
#   'status': 'ACT',
#   'full_name': 'Aaron Dell',
#   'first_name': 'Aaron',
#   'last_name': 'Dell',
#   'abbr_name': 'A.Dell',
#   'height': 72,
#   'weight': 213,
#   'handedness': 'L',
#   'position': 'G',
#   'primary_position': 'G',
#   'jersey_number': '30',
#   'college': 'North Dakota',
#   'experience': '7',
#   'birth_place': 'Airdrie, AB, CAN',
#   'birthdate': '1989-05-04',
#   'updated': '2024-04-22T15:29:59Z',
#   'sr_id': 'sr:player:899396',
#   'reference': '8477180',
#   'rookie_year': 2016},
#  {'id': '421f9f71-d1ee-4917-afc6-ca11f6b761b0',
#   'status': 'ACT',
#   'full_name': 'Trevor Moore',
#   'first_name': 'Trevor',
#   'last_name': 'Moore',
#   'abbr_name': 'T.Moore',
#   'height': 70,
#   'weight': 195,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'LW',
#   'jersey_number': '12',
#   'college': 'Denver',
#   'experience': '5',
#   'birth_place': 'Thousand Oaks, CA, USA',
#   'birthdate': '1995-03-31',
#   'updated': '2023-10-05T21:09:54Z',
#   'sr_id': 'sr:player:1051357',
#   'reference': '8479675',
#   'rookie_year': 2018},
#  {'id': '427d1fda-0f24-11e2-8525-18a905767e44',
#   'status': 'ACT',
#   'full_name': 'Anze Kopitar',
#   'first_name': 'Anze',
#   'last_name': 'Kopitar',
#   'abbr_name': 'A.Kopitar',
#   'height': 75,
#   'weight': 225,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '11',
#   'experience': '17',
#   'birth_place': 'Jesenice,, SVN',
#   'birthdate': '1987-08-24',
#   'updated': '2023-10-05T21:09:00Z',
#   'sr_id': 'sr:player:29571',
#   'reference': '8471685',
#   'rookie_year': 2006,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2005,
#    'round': '1',
#    'pick': '11'}},
#  {'id': '427d4479-0f24-11e2-8525-18a905767e44',
#   'status': 'ACT',
#   'full_name': 'Trevor Lewis',
#   'first_name': 'Trevor',
#   'last_name': 'Lewis',
#   'abbr_name': 'T.Lewis',
#   'height': 73,
#   'weight': 201,
#   'handedness': 'R',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '61',
#   'experience': '15',
#   'birth_place': 'Salt Lake City, UT, USA',
#   'birthdate': '1987-01-08',
#   'updated': '2023-10-05T21:09:30Z',
#   'sr_id': 'sr:player:93721',
#   'reference': '8473453',
#   'rookie_year': 2008,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2006,
#    'round': '1',
#    'pick': '17'}},
#  {'id': '4281a6e1-0f24-11e2-8525-18a905767e44',
#   'status': 'ACT',
#   'full_name': 'Drew Doughty',
#   'first_name': 'Drew',
#   'last_name': 'Doughty',
#   'abbr_name': 'D.Doughty',
#   'height': 73,
#   'weight': 210,
#   'handedness': 'R',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '8',
#   'experience': '15',
#   'birth_place': 'London, ON, CAN',
#   'birthdate': '1989-12-08',
#   'updated': '2023-10-05T21:07:32Z',
#   'sr_id': 'sr:player:42413',
#   'reference': '8474563',
#   'rookie_year': 2008,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2008,
#    'round': '1',
#    'pick': '2'}},
#  {'id': '4333f6f1-0f24-11e2-8525-18a905767e44',
#   'status': 'ACT',
#   'full_name': 'Cam Talbot',
#   'first_name': 'Cam',
#   'last_name': 'Talbot',
#   'abbr_name': 'C.Talbot',
#   'height': 76,
#   'weight': 201,
#   'handedness': 'L',
#   'position': 'G',
#   'primary_position': 'G',
#   'jersey_number': '39',
#   'college': 'Alabama Huntsville',
#   'experience': '10',
#   'birth_place': 'Caledonia, ON, CAN',
#   'birthdate': '1987-07-05',
#   'updated': '2023-10-05T21:10:52Z',
#   'sr_id': 'sr:player:606874',
#   'reference': '8475660',
#   'rookie_year': 2013},
#  {'id': '533ebbc8-ad3c-459e-8b29-660030ac140f',
#   'status': 'ACT',
#   'full_name': 'Alex Laferriere',
#   'first_name': 'Alex',
#   'last_name': 'Laferriere',
#   'abbr_name': 'A.Laferriere',
#   'height': 73,
#   'weight': 205,
#   'handedness': 'R',
#   'position': 'F',
#   'primary_position': 'RW',
#   'jersey_number': '78',
#   'college': 'Harvard',
#   'experience': '0',
#   'birth_place': 'Chatham, NJ, USA',
#   'birthdate': '2001-10-28',
#   'updated': '2023-11-13T19:08:23Z',
#   'sr_id': 'sr:player:2056465',
#   'reference': '8482155',
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2020,
#    'round': '3',
#    'pick': '83'}},
#  {'id': '59a7f500-cc98-4dd4-bc25-5ad948f4577e',
#   'status': 'ACT',
#   'full_name': 'Quinton Byfield',
#   'first_name': 'Quinton',
#   'last_name': 'Byfield',
#   'abbr_name': 'Q.Byfield',
#   'height': 77,
#   'weight': 220,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'RW',
#   'jersey_number': '55',
#   'experience': '3',
#   'birth_place': 'Newmarket, ON, CAN',
#   'birthdate': '2002-08-19',
#   'updated': '2023-11-09T15:14:19Z',
#   'sr_id': 'sr:player:1980393',
#   'reference': '8482124',
#   'rookie_year': 2020,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2020,
#    'round': '1',
#    'pick': '2'}},
#  {'id': '5b0377bd-412a-44aa-8b8d-8e8eabeb290e',
#   'status': 'ACT',
#   'full_name': 'Carl Grundstrom',
#   'first_name': 'Carl',
#   'last_name': 'Grundstrom',
#   'abbr_name': 'C.Grundstrom',
#   'height': 72,
#   'weight': 195,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'RW',
#   'jersey_number': '91',
#   'experience': '5',
#   'birth_place': 'Umea,, SWE',
#   'birthdate': '1997-12-01',
#   'updated': '2024-04-20T17:26:55Z',
#   'sr_id': 'sr:player:774887',
#   'reference': '8479336',
#   'rookie_year': 2018,
#   'draft': {'team_id': '441730a9-0f24-11e2-8525-18a905767e44',
#    'year': 2016,
#    'round': '2',
#    'pick': '57'}},
#  {'id': '623e4a05-3a49-4921-9f90-da01969ff084',
#   'status': 'ACT',
#   'full_name': 'Angus Booth',
#   'first_name': 'Angus',
#   'last_name': 'Booth',
#   'abbr_name': 'A.Booth',
#   'height': 72,
#   'weight': 177,
#   'handedness': 'L',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '81',
#   'experience': '0',
#   'birth_place': 'Montreal, QC, CAN',
#   'birthdate': '2004-04-27',
#   'updated': '2024-01-23T19:38:35Z',
#   'sr_id': 'sr:player:2265695',
#   'reference': '8483699',
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2022,
#    'round': '4',
#    'pick': '116'}},
#  {'id': '6767e821-5a9c-4379-9bfa-9f19314cfc2f',
#   'status': 'ACT',
#   'full_name': 'Mikey Anderson',
#   'first_name': 'Mikey',
#   'last_name': 'Anderson',
#   'abbr_name': 'M.Anderson',
#   'height': 72,
#   'weight': 195,
#   'handedness': 'L',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '44',
#   'college': 'Minnesota Duluth',
#   'experience': '4',
#   'birth_place': 'Roseville, MN, USA',
#   'birthdate': '1999-05-25',
#   'updated': '2023-10-05T21:05:58Z',
#   'sr_id': 'sr:player:1117735',
#   'reference': '8479998',
#   'rookie_year': 2019,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2017,
#    'round': '4',
#    'pick': '103'}},
#  {'id': '677c3651-f73b-4fbf-9a71-f6f16874617d',
#   'status': 'ACT',
#   'full_name': 'David Rittich',
#   'first_name': 'David',
#   'last_name': 'Rittich',
#   'abbr_name': 'D.Rittich',
#   'height': 75,
#   'weight': 206,
#   'handedness': 'L',
#   'position': 'G',
#   'primary_position': 'G',
#   'jersey_number': '31',
#   'experience': '7',
#   'birth_place': 'Jihlava,, CZE',
#   'birthdate': '1992-08-19',
#   'updated': '2023-12-15T21:44:49Z',
#   'sr_id': 'sr:player:604562',
#   'reference': '8479496',
#   'rookie_year': 2016},
#  {'id': '76967e78-08fa-4e9c-8ec5-b42ea00d0a37',
#   'status': 'ACT',
#   'full_name': 'Phillip Danault',
#   'first_name': 'Phillip',
#   'last_name': 'Danault',
#   'abbr_name': 'P.Danault',
#   'height': 73,
#   'weight': 200,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '24',
#   'experience': '9',
#   'birth_place': 'Victoriaville, QC, CAN',
#   'birthdate': '1993-02-24',
#   'updated': '2023-10-05T21:07:20Z',
#   'sr_id': 'sr:player:353682',
#   'reference': '8476479',
#   'rookie_year': 2014,
#   'draft': {'team_id': '4416272f-0f24-11e2-8525-18a905767e44',
#    'year': 2011,
#    'round': '1',
#    'pick': '26'}},
#  {'id': '7fa5b22b-b106-45aa-89d1-02861c739aa7',
#   'status': 'ACT',
#   'full_name': 'Pierre-Luc Dubois',
#   'first_name': 'Pierre-Luc',
#   'last_name': 'Dubois',
#   'abbr_name': 'P.Dubois',
#   'height': 76,
#   'weight': 225,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '80',
#   'experience': '6',
#   'birth_place': 'Ste-Agathe-des-Monts, QC, CAN',
#   'birthdate': '1998-06-24',
#   'updated': '2023-11-09T15:14:49Z',
#   'sr_id': 'sr:player:983715',
#   'reference': '8479400',
#   'rookie_year': 2017,
#   'draft': {'team_id': '44167db4-0f24-11e2-8525-18a905767e44',
#    'year': 2016,
#    'round': '1',
#    'pick': '3'}},
#  {'id': '8eef97c0-56c8-493b-bd12-9ab5b1456bda',
#   'status': 'ACT',
#   'full_name': 'Andreas Englund',
#   'first_name': 'Andreas',
#   'last_name': 'Englund',
#   'abbr_name': 'A.Englund',
#   'height': 75,
#   'weight': 189,
#   'handedness': 'L',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '5',
#   'experience': '5',
#   'birth_place': 'Stockholm,, SWE',
#   'birthdate': '1996-01-21',
#   'updated': '2023-10-05T21:07:56Z',
#   'sr_id': 'sr:player:382576',
#   'reference': '8477971',
#   'rookie_year': 2016,
#   'draft': {'team_id': '4416f5e2-0f24-11e2-8525-18a905767e44',
#    'year': 2014,
#    'round': '2',
#    'pick': '40'}},
#  {'id': '9a2d02cf-a8f2-43a4-9079-d9f72238facb',
#   'status': 'ACT',
#   'full_name': 'Jacob Moverare',
#   'first_name': 'Jacob',
#   'last_name': 'Moverare',
#   'abbr_name': 'J.Moverare',
#   'height': 75,
#   'weight': 210,
#   'handedness': 'L',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '43',
#   'experience': '2',
#   'birth_place': 'Ostersund,, SWE',
#   'birthdate': '1998-08-31',
#   'updated': '2024-03-29T18:40:07Z',
#   'sr_id': 'sr:player:983687',
#   'reference': '8479421',
#   'rookie_year': 2021,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2016,
#    'round': '4',
#    'pick': '112'}},
#  {'id': 'a0b91f2e-bb6d-409a-9e58-cc764edafe64',
#   'status': 'ACT',
#   'full_name': 'Adrian Kempe',
#   'first_name': 'Adrian',
#   'last_name': 'Kempe',
#   'abbr_name': 'A.Kempe',
#   'height': 74,
#   'weight': 200,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '9',
#   'experience': '7',
#   'birth_place': 'Kramfors,, SWE',
#   'birthdate': '1996-09-13',
#   'updated': '2023-10-05T21:08:40Z',
#   'sr_id': 'sr:player:361870',
#   'reference': '8477960',
#   'rookie_year': 2016,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2014,
#    'round': '1',
#    'pick': '29'}},
#  {'id': 'bceebd33-2eee-4987-9a24-39ff8d8b01eb',
#   'status': 'ACT',
#   'full_name': 'Jordan Spence',
#   'first_name': 'Jordan',
#   'last_name': 'Spence',
#   'abbr_name': 'J.Spence',
#   'height': 70,
#   'weight': 180,
#   'handedness': 'R',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '21',
#   'experience': '2',
#   'birth_place': 'Sydney,, AUS',
#   'birthdate': '2001-02-24',
#   'updated': '2024-02-24T18:49:33Z',
#   'sr_id': 'sr:player:1770298',
#   'reference': '8481606',
#   'rookie_year': 2021,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2019,
#    'round': '4',
#    'pick': '95'}},
#  {'id': 'c86ff633-7f27-420c-84a7-be1e08ede9a6',
#   'status': 'ACT',
#   'full_name': 'Kevin Fiala',
#   'first_name': 'Kevin',
#   'last_name': 'Fiala',
#   'abbr_name': 'K.Fiala',
#   'height': 70,
#   'weight': 204,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'LW',
#   'jersey_number': '22',
#   'experience': '9',
#   'birth_place': 'St. Gallen,, CHE',
#   'birthdate': '1996-07-22',
#   'updated': '2023-10-05T21:08:04Z',
#   'sr_id': 'sr:player:376846',
#   'reference': '8477942',
#   'rookie_year': 2014,
#   'draft': {'team_id': '441643b7-0f24-11e2-8525-18a905767e44',
#    'year': 2014,
#    'round': '1',
#    'pick': '11'}},
#  {'id': 'cd3e3e6c-23c2-4a3e-af08-e498246c50ad',
#   'status': 'ACT',
#   'full_name': 'Viktor Arvidsson',
#   'first_name': 'Viktor',
#   'last_name': 'Arvidsson',
#   'abbr_name': 'V.Arvidsson',
#   'height': 70,
#   'weight': 185,
#   'handedness': 'R',
#   'position': 'F',
#   'primary_position': 'RW',
#   'jersey_number': '33',
#   'experience': '9',
#   'birth_place': 'Skelleftea,, SWE',
#   'birthdate': '1993-04-08',
#   'updated': '2024-03-20T18:49:00Z',
#   'sr_id': 'sr:player:266577',
#   'reference': '8478042',
#   'rookie_year': 2014,
#   'draft': {'team_id': '441643b7-0f24-11e2-8525-18a905767e44',
#    'year': 2014,
#    'round': '4',
#    'pick': '112'}},
#  {'id': 'd57c7da4-b733-4137-94d3-388dd2b60cba',
#   'status': 'ACT',
#   'full_name': 'Vladislav Gavrikov',
#   'first_name': 'Vladislav',
#   'last_name': 'Gavrikov',
#   'abbr_name': 'V.Gavrikov',
#   'height': 75,
#   'weight': 221,
#   'handedness': 'L',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '84',
#   'experience': '4',
#   'birth_place': 'Yaroslavl,, RUS',
#   'birthdate': '1995-11-21',
#   'updated': '2023-12-27T20:12:18Z',
#   'sr_id': 'sr:player:793408',
#   'reference': '8478882',
#   'rookie_year': 2019,
#   'draft': {'team_id': '44167db4-0f24-11e2-8525-18a905767e44',
#    'year': 2015,
#    'round': '6',
#    'pick': '159'}},
#  {'id': 'f0cdc175-e8c9-4dd9-877d-0f067d8c2e31',
#   'status': 'ACT',
#   'full_name': 'Arthur Kaliyev',
#   'first_name': 'Arthur',
#   'last_name': 'Kaliyev',
#   'abbr_name': 'A.Kaliyev',
#   'height': 74,
#   'weight': 210,
#   'handedness': 'L',
#   'position': 'F',
#   'primary_position': 'RW',
#   'jersey_number': '34',
#   'experience': '3',
#   'birth_place': 'Tashkent,, UZB',
#   'birthdate': '2001-06-26',
#   'updated': '2024-02-05T15:58:05Z',
#   'sr_id': 'sr:player:1650147',
#   'reference': '8481560',
#   'rookie_year': 2020,
#   'draft': {'team_id': '44151f7a-0f24-11e2-8525-18a905767e44',
#    'year': 2019,
#    'round': '2',
#    'pick': '33'}}]

# %%
players = player_api_request['players']

# %%
# Create a dictionary store data
players_data = {
    'id':[],
    'status':[],
    'full_name':[],
    'first_name':[],
    'last_name':[],
    'height':[],
    'weight':[],
    'handedness':[],
    'position':[],
    'primary_position':[],
    'jersey_number':[],
    'experience':[],
    'birth_place':[],
    'birthdate':[]
}
# Create a loop to get information and store in dictionary
for player in players:
    id = player['id']
    players_data['id'].append(id)
    print('Id:',id)
    
    status = player['status']
    players_data['status'].append(status)
    print('status:',status)
    
    full_name = player['full_name']
    players_data['full_name'].append(full_name)
    print('full name:',full_name)
    
    first_name = player['first_name']
    players_data['first_name'].append(first_name)
    print('first name:',first_name)
    
    last_name = player['last_name']
    players_data['last_name'].append(last_name)
    print('last name:',last_name)
    
    height = player['height']
    players_data['height'].append(height)
    print('height:',height)
    
    weight = player['weight']
    players_data['weight'].append(weight)
    print('weight:',weight)
    
    handedness = player['handedness']
    players_data['handedness'].append(handedness)
    print('handedness:',handedness)
    
    position = player['position']
    players_data['position'].append(position)
    print('position:',position)
    
    primary_position = player['primary_position']
    players_data['primary_position'].append(primary_position)
    print('primary position:',primary_position)
 
    jersey_number = player['jersey_number']
    players_data['jersey_number'].append(jersey_number)
    print('jersey number:',jersey_number)
    
    experience = player['experience']
    players_data['experience'].append(experience)
    print('experience:',experience)
    
    birth_place = player['birth_place']
    players_data['birth_place'].append(birth_place)
    print('birth place:',birth_place)
    
    birthdate = player['birthdate']
    players_data['birthdate'].append(pd.to_datetime(birthdate).date())
    print('birthdate:',pd.to_datetime(birthdate).date())
    
    print('-'*75)
# Out:
# Id: 070ff077-e59b-4135-b060-352ee716bc7e
# status: ACT
# full name: Blake Lizotte
# first name: Blake
# last name: Lizotte
# height: 69
# weight: 170
# handedness: L
# position: F
# primary position: C
# jersey number: 46
# experience: 5
# birth place: Lindstrom, MN, USA
# birthdate: 1997-12-13
# ---------------------------------------------------------------------------
# Id: 0a1a1d3a-7118-4d30-a2bd-a2f95822d22c
# status: IR
# full name: Pheonix Copley
# first name: Pheonix
# last name: Copley
# height: 76
# weight: 200
# handedness: L
# position: G
# primary position: G
# jersey number: 29
# experience: 5
# birth place: North Pole, AK, USA
# birthdate: 1992-01-18
# ---------------------------------------------------------------------------
# Id: 0cc94754-1f54-4723-939f-8c14dd930759
# status: ACT
# full name: Matt Roy
# first name: Matt
# last name: Roy
# height: 73
# weight: 205
# handedness: R
# position: D
# primary position: D
# jersey number: 3
# experience: 5
# birth place: Detroit, MI, USA
# birthdate: 1995-03-01
# ---------------------------------------------------------------------------
# Id: 240ad2f4-8860-45a6-94d0-79b87dffd3ea
# status: ACT
# full name: Aaron Dell
# first name: Aaron
# last name: Dell
# height: 72
# weight: 213
# handedness: L
# position: G
# primary position: G
# jersey number: 30
# experience: 7
# birth place: Airdrie, AB, CAN
# birthdate: 1989-05-04
# ---------------------------------------------------------------------------
# Id: 421f9f71-d1ee-4917-afc6-ca11f6b761b0
# status: ACT
# full name: Trevor Moore
# first name: Trevor
# last name: Moore
# height: 70
# weight: 195
# handedness: L
# position: F
# primary position: LW
# jersey number: 12
# experience: 5
# birth place: Thousand Oaks, CA, USA
# birthdate: 1995-03-31
# ---------------------------------------------------------------------------
# Id: 427d1fda-0f24-11e2-8525-18a905767e44
# status: ACT
# full name: Anze Kopitar
# first name: Anze
# last name: Kopitar
# height: 75
# weight: 225
# handedness: L
# position: F
# primary position: C
# jersey number: 11
# experience: 17
# birth place: Jesenice,, SVN
# birthdate: 1987-08-24
# ---------------------------------------------------------------------------
# Id: 427d4479-0f24-11e2-8525-18a905767e44
# status: ACT
# full name: Trevor Lewis
# first name: Trevor
# last name: Lewis
# height: 73
# weight: 201
# handedness: R
# position: F
# primary position: C
# jersey number: 61
# experience: 15
# birth place: Salt Lake City, UT, USA
# birthdate: 1987-01-08
# ---------------------------------------------------------------------------
# Id: 4281a6e1-0f24-11e2-8525-18a905767e44
# status: ACT
# full name: Drew Doughty
# first name: Drew
# last name: Doughty
# height: 73
# weight: 210
# handedness: R
# position: D
# primary position: D
# jersey number: 8
# experience: 15
# birth place: London, ON, CAN
# birthdate: 1989-12-08
# ---------------------------------------------------------------------------
# Id: 4333f6f1-0f24-11e2-8525-18a905767e44
# status: ACT
# full name: Cam Talbot
# first name: Cam
# last name: Talbot
# height: 76
# weight: 201
# handedness: L
# position: G
# primary position: G
# jersey number: 39
# experience: 10
# birth place: Caledonia, ON, CAN
# birthdate: 1987-07-05
# ---------------------------------------------------------------------------
# Id: 533ebbc8-ad3c-459e-8b29-660030ac140f
# status: ACT
# full name: Alex Laferriere
# first name: Alex
# last name: Laferriere
# height: 73
# weight: 205
# handedness: R
# position: F
# primary position: RW
# jersey number: 78
# experience: 0
# birth place: Chatham, NJ, USA
# birthdate: 2001-10-28
# ---------------------------------------------------------------------------
# Id: 59a7f500-cc98-4dd4-bc25-5ad948f4577e
# status: ACT
# full name: Quinton Byfield
# first name: Quinton
# last name: Byfield
# height: 77
# weight: 220
# handedness: L
# position: F
# primary position: RW
# jersey number: 55
# experience: 3
# birth place: Newmarket, ON, CAN
# birthdate: 2002-08-19
# ---------------------------------------------------------------------------
# Id: 5b0377bd-412a-44aa-8b8d-8e8eabeb290e
# status: ACT
# full name: Carl Grundstrom
# first name: Carl
# last name: Grundstrom
# height: 72
# weight: 195
# handedness: L
# position: F
# primary position: RW
# jersey number: 91
# experience: 5
# birth place: Umea,, SWE
# birthdate: 1997-12-01
# ---------------------------------------------------------------------------
# Id: 623e4a05-3a49-4921-9f90-da01969ff084
# status: ACT
# full name: Angus Booth
# first name: Angus
# last name: Booth
# height: 72
# weight: 177
# handedness: L
# position: D
# primary position: D
# jersey number: 81
# experience: 0
# birth place: Montreal, QC, CAN
# birthdate: 2004-04-27
# ---------------------------------------------------------------------------
# Id: 6767e821-5a9c-4379-9bfa-9f19314cfc2f
# status: ACT
# full name: Mikey Anderson
# first name: Mikey
# last name: Anderson
# height: 72
# weight: 195
# handedness: L
# position: D
# primary position: D
# jersey number: 44
# experience: 4
# birth place: Roseville, MN, USA
# birthdate: 1999-05-25
# ---------------------------------------------------------------------------
# Id: 677c3651-f73b-4fbf-9a71-f6f16874617d
# status: ACT
# full name: David Rittich
# first name: David
# last name: Rittich
# height: 75
# weight: 206
# handedness: L
# position: G
# primary position: G
# jersey number: 31
# experience: 7
# birth place: Jihlava,, CZE
# birthdate: 1992-08-19
# ---------------------------------------------------------------------------
# Id: 76967e78-08fa-4e9c-8ec5-b42ea00d0a37
# status: ACT
# full name: Phillip Danault
# first name: Phillip
# last name: Danault
# height: 73
# weight: 200
# handedness: L
# position: F
# primary position: C
# jersey number: 24
# experience: 9
# birth place: Victoriaville, QC, CAN
# birthdate: 1993-02-24
# ---------------------------------------------------------------------------
# Id: 7fa5b22b-b106-45aa-89d1-02861c739aa7
# status: ACT
# full name: Pierre-Luc Dubois
# first name: Pierre-Luc
# last name: Dubois
# height: 76
# weight: 225
# handedness: L
# position: F
# primary position: C
# jersey number: 80
# experience: 6
# birth place: Ste-Agathe-des-Monts, QC, CAN
# birthdate: 1998-06-24
# ---------------------------------------------------------------------------
# Id: 8eef97c0-56c8-493b-bd12-9ab5b1456bda
# status: ACT
# full name: Andreas Englund
# first name: Andreas
# last name: Englund
# height: 75
# weight: 189
# handedness: L
# position: D
# primary position: D
# jersey number: 5
# experience: 5
# birth place: Stockholm,, SWE
# birthdate: 1996-01-21
# ---------------------------------------------------------------------------
# Id: 9a2d02cf-a8f2-43a4-9079-d9f72238facb
# status: ACT
# full name: Jacob Moverare
# first name: Jacob
# last name: Moverare
# height: 75
# weight: 210
# handedness: L
# position: D
# primary position: D
# jersey number: 43
# experience: 2
# birth place: Ostersund,, SWE
# birthdate: 1998-08-31
# ---------------------------------------------------------------------------
# Id: a0b91f2e-bb6d-409a-9e58-cc764edafe64
# status: ACT
# full name: Adrian Kempe
# first name: Adrian
# last name: Kempe
# height: 74
# weight: 200
# handedness: L
# position: F
# primary position: C
# jersey number: 9
# experience: 7
# birth place: Kramfors,, SWE
# birthdate: 1996-09-13
# ---------------------------------------------------------------------------
# Id: bceebd33-2eee-4987-9a24-39ff8d8b01eb
# status: ACT
# full name: Jordan Spence
# first name: Jordan
# last name: Spence
# height: 70
# weight: 180
# handedness: R
# position: D
# primary position: D
# jersey number: 21
# experience: 2
# birth place: Sydney,, AUS
# birthdate: 2001-02-24
# ---------------------------------------------------------------------------
# Id: c86ff633-7f27-420c-84a7-be1e08ede9a6
# status: ACT
# full name: Kevin Fiala
# first name: Kevin
# last name: Fiala
# height: 70
# weight: 204
# handedness: L
# position: F
# primary position: LW
# jersey number: 22
# experience: 9
# birth place: St. Gallen,, CHE
# birthdate: 1996-07-22
# ---------------------------------------------------------------------------
# Id: cd3e3e6c-23c2-4a3e-af08-e498246c50ad
# status: ACT
# full name: Viktor Arvidsson
# first name: Viktor
# last name: Arvidsson
# height: 70
# weight: 185
# handedness: R
# position: F
# primary position: RW
# jersey number: 33
# experience: 9
# birth place: Skelleftea,, SWE
# birthdate: 1993-04-08
# ---------------------------------------------------------------------------
# Id: d57c7da4-b733-4137-94d3-388dd2b60cba
# status: ACT
# full name: Vladislav Gavrikov
# first name: Vladislav
# last name: Gavrikov
# height: 75
# weight: 221
# handedness: L
# position: D
# primary position: D
# jersey number: 84
# experience: 4
# birth place: Yaroslavl,, RUS
# birthdate: 1995-11-21
# ---------------------------------------------------------------------------
# Id: f0cdc175-e8c9-4dd9-877d-0f067d8c2e31
# status: ACT
# full name: Arthur Kaliyev
# first name: Arthur
# last name: Kaliyev
# height: 74
# weight: 210
# handedness: L
# position: F
# primary position: RW
# jersey number: 34
# experience: 3
# birth place: Tashkent,, UZB
# birthdate: 2001-06-26
# ---------------------------------------------------------------------------

# %%
players_data
# Out:
# {'id': ['070ff077-e59b-4135-b060-352ee716bc7e',
#   '0a1a1d3a-7118-4d30-a2bd-a2f95822d22c',
#   '0cc94754-1f54-4723-939f-8c14dd930759',
#   '240ad2f4-8860-45a6-94d0-79b87dffd3ea',
#   '421f9f71-d1ee-4917-afc6-ca11f6b761b0',
#   '427d1fda-0f24-11e2-8525-18a905767e44',
#   '427d4479-0f24-11e2-8525-18a905767e44',
#   '4281a6e1-0f24-11e2-8525-18a905767e44',
#   '4333f6f1-0f24-11e2-8525-18a905767e44',
#   '533ebbc8-ad3c-459e-8b29-660030ac140f',
#   '59a7f500-cc98-4dd4-bc25-5ad948f4577e',
#   '5b0377bd-412a-44aa-8b8d-8e8eabeb290e',
#   '623e4a05-3a49-4921-9f90-da01969ff084',
#   '6767e821-5a9c-4379-9bfa-9f19314cfc2f',
#   '677c3651-f73b-4fbf-9a71-f6f16874617d',
#   '76967e78-08fa-4e9c-8ec5-b42ea00d0a37',
#   '7fa5b22b-b106-45aa-89d1-02861c739aa7',
#   '8eef97c0-56c8-493b-bd12-9ab5b1456bda',
#   '9a2d02cf-a8f2-43a4-9079-d9f72238facb',
#   'a0b91f2e-bb6d-409a-9e58-cc764edafe64',
#   'bceebd33-2eee-4987-9a24-39ff8d8b01eb',
#   'c86ff633-7f27-420c-84a7-be1e08ede9a6',
#   'cd3e3e6c-23c2-4a3e-af08-e498246c50ad',
#   'd57c7da4-b733-4137-94d3-388dd2b60cba',
#   'f0cdc175-e8c9-4dd9-877d-0f067d8c2e31'],
#  'status': ['ACT',
#   'IR',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT',
#   'ACT'],
#  'full_name': ['Blake Lizotte',
#   'Pheonix Copley',
#   'Matt Roy',
#   'Aaron Dell',
#   'Trevor Moore',
#   'Anze Kopitar',
#   'Trevor Lewis',
#   'Drew Doughty',
#   'Cam Talbot',
#   'Alex Laferriere',
#   'Quinton Byfield',
#   'Carl Grundstrom',
#   'Angus Booth',
#   'Mikey Anderson',
#   'David Rittich',
#   'Phillip Danault',
#   'Pierre-Luc Dubois',
#   'Andreas Englund',
#   'Jacob Moverare',
#   'Adrian Kempe',
#   'Jordan Spence',
#   'Kevin Fiala',
#   'Viktor Arvidsson',
#   'Vladislav Gavrikov',
#   'Arthur Kaliyev'],
#  'first_name': ['Blake',
#   'Pheonix',
#   'Matt',
#   'Aaron',
#   'Trevor',
#   'Anze',
#   'Trevor',
#   'Drew',
#   'Cam',
#   'Alex',
#   'Quinton',
#   'Carl',
#   'Angus',
#   'Mikey',
#   'David',
#   'Phillip',
#   'Pierre-Luc',
#   'Andreas',
#   'Jacob',
#   'Adrian',
#   'Jordan',
#   'Kevin',
#   'Viktor',
#   'Vladislav',
#   'Arthur'],
#  'last_name': ['Lizotte',
#   'Copley',
#   'Roy',
#   'Dell',
#   'Moore',
#   'Kopitar',
#   'Lewis',
#   'Doughty',
#   'Talbot',
#   'Laferriere',
#   'Byfield',
#   'Grundstrom',
#   'Booth',
#   'Anderson',
#   'Rittich',
#   'Danault',
#   'Dubois',
#   'Englund',
#   'Moverare',
#   'Kempe',
#   'Spence',
#   'Fiala',
#   'Arvidsson',
#   'Gavrikov',
#   'Kaliyev'],
#  'height': [69,
#   76,
#   73,
#   72,
#   70,
#   75,
#   73,
#   73,
#   76,
#   73,
#   77,
#   72,
#   72,
#   72,
#   75,
#   73,
#   76,
#   75,
#   75,
#   74,
#   70,
#   70,
#   70,
#   75,
#   74],
#  'weight': [170,
#   200,
#   205,
#   213,
#   195,
#   225,
#   201,
#   210,
#   201,
#   205,
#   220,
#   195,
#   177,
#   195,
#   206,
#   200,
#   225,
#   189,
#   210,
#   200,
#   180,
#   204,
#   185,
#   221,
#   210],
#  'handedness': ['L',
#   'L',
#   'R',
#   'L',
#   'L',
#   'L',
#   'R',
#   'R',
#   'L',
#   'R',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'R',
#   'L',
#   'R',
#   'L',
#   'L'],
#  'position': ['F',
#   'G',
#   'D',
#   'G',
#   'F',
#   'F',
#   'F',
#   'D',
#   'G',
#   'F',
#   'F',
#   'F',
#   'D',
#   'D',
#   'G',
#   'F',
#   'F',
#   'D',
#   'D',
#   'F',
#   'D',
#   'F',
#   'F',
#   'D',
#   'F'],
#  'primary_position': ['C',
#   'G',
#   'D',
#   'G',
#   'LW',
#   'C',
#   'C',
#   'D',
#   'G',
#   'RW',
#   'RW',
#   'RW',
#   'D',
#   'D',
#   'G',
#   'C',
#   'C',
#   'D',
#   'D',
#   'C',
#   'D',
#   'LW',
#   'RW',
#   'D',
#   'RW'],
#  'jersey_number': ['46',
#   '29',
#   '3',
#   '30',
#   '12',
#   '11',
#   '61',
#   '8',
#   '39',
#   '78',
#   '55',
#   '91',
#   '81',
#   '44',
#   '31',
#   '24',
#   '80',
#   '5',
#   '43',
#   '9',
#   '21',
#   '22',
#   '33',
#   '84',
#   '34'],
#  'experience': ['5',
#   '5',
#   '5',
#   '7',
#   '5',
#   '17',
#   '15',
#   '15',
#   '10',
#   '0',
#   '3',
#   '5',
#   '0',
#   '4',
#   '7',
#   '9',
#   '6',
#   '5',
#   '2',
#   '7',
#   '2',
#   '9',
#   '9',
#   '4',
#   '3'],
#  'birth_place': ['Lindstrom, MN, USA',
#   'North Pole, AK, USA',
#   'Detroit, MI, USA',
#   'Airdrie, AB, CAN',
#   'Thousand Oaks, CA, USA',
#   'Jesenice,, SVN',
#   'Salt Lake City, UT, USA',
#   'London, ON, CAN',
#   'Caledonia, ON, CAN',
#   'Chatham, NJ, USA',
#   'Newmarket, ON, CAN',
#   'Umea,, SWE',
#   'Montreal, QC, CAN',
#   'Roseville, MN, USA',
#   'Jihlava,, CZE',
#   'Victoriaville, QC, CAN',
#   'Ste-Agathe-des-Monts, QC, CAN',
#   'Stockholm,, SWE',
#   'Ostersund,, SWE',
#   'Kramfors,, SWE',
#   'Sydney,, AUS',
#   'St. Gallen,, CHE',
#   'Skelleftea,, SWE',
#   'Yaroslavl,, RUS',
#   'Tashkent,, UZB'],
#  'birthdate': [datetime.date(1997, 12, 13),
#   datetime.date(1992, 1, 18),
#   datetime.date(1995, 3, 1),
#   datetime.date(1989, 5, 4),
#   datetime.date(1995, 3, 31),
#   datetime.date(1987, 8, 24),
#   datetime.date(1987, 1, 8),
#   datetime.date(1989, 12, 8),
#   datetime.date(1987, 7, 5),
#   datetime.date(2001, 10, 28),
#   datetime.date(2002, 8, 19),
#   datetime.date(1997, 12, 1),
#   datetime.date(2004, 4, 27),
#   datetime.date(1999, 5, 25),
#   datetime.date(1992, 8, 19),
#   datetime.date(1993, 2, 24),
#   datetime.date(1998, 6, 24),
#   datetime.date(1996, 1, 21),
#   datetime.date(1998, 8, 31),
#   datetime.date(1996, 9, 13),
#   datetime.date(2001, 2, 24),
#   datetime.date(1996, 7, 22),
#   datetime.date(1993, 4, 8),
#   datetime.date(1995, 11, 21),
#   datetime.date(2001, 6, 26)]}

# %%
players_df =pd.DataFrame(players_data)

# %%
players_df.head()
# Out:
#                                      id status       full_name first_name  \
# 0  070ff077-e59b-4135-b060-352ee716bc7e    ACT   Blake Lizotte      Blake
# 1  0a1a1d3a-7118-4d30-a2bd-a2f95822d22c     IR  Pheonix Copley    Pheonix
# 2  0cc94754-1f54-4723-939f-8c14dd930759    ACT        Matt Roy       Matt
# 3  240ad2f4-8860-45a6-94d0-79b87dffd3ea    ACT      Aaron Dell      Aaron
# 4  421f9f71-d1ee-4917-afc6-ca11f6b761b0    ACT    Trevor Moore     Trevor
#
#   last_name  height  weight handedness position primary_position  \
# 0   Lizotte      69     170          L        F                C
# 1    Copley      76     200          L        G                G
# 2       Roy      73     205          R        D                D
# 3      Dell      72     213          L        G                G
# 4     Moore      70     195          L        F               LW
#
#   jersey_number experience             birth_place   birthdate
# 0            46          5      Lindstrom, MN, USA  1997-12-13
# 1            29          5     North Pole, AK, USA  1992-01-18
# 2             3          5        Detroit, MI, USA  1995-03-01
# 3            30          7        Airdrie, AB, CAN  1989-05-04
# 4            12          5  Thousand Oaks, CA, USA  1995-03-31

# %%
players_df.to_csv('nhl_players.csv', index=False)

# %% [markdown]
# # Extract Team Stats Data

# %%
import time # Importing the time module to use the sleep function for handling rate limits

# Initialize an empty dictionary to store statistics data for each team.
team_stats_data  = {}
# Iterate over each team ID obtained from 'teams_data' dictionary.
for team_id in teams_data['id']:
    team_stats_url = f'https://api.sportradar.com/nhl/production/v7/en/seasons/2023/REG/teams/{team_id}/statistics.json'
    
    while True:  # Loop to retry requests if 429 error is encountered
        team_stats_api_request = requests.get(team_stats_url, params=team_params)
        if team_stats_api_request.status_code == 429:
            wait_time = int(team_stats_api_request.headers.get('Retry-After', 60))  # Use the Retry-After header if available
            print(f"Rate limit hit, retrying after {wait_time} seconds...")
            time.sleep(wait_time)  # Wait for the time specified before retrying
            continue  # Retry the request
        if team_stats_api_request.status_code == 200:
            team_stats_data[team_id] = json.loads(team_stats_api_request.text)
            break  # Exit the loop if successful
        else:
            print(f"Failed to fetch data for team ID {team_id}: {team_stats_api_request.status_code}")
            break  # Exit loop on other errors
# Out:
# Rate limit hit, retrying after 60 seconds...
# Failed to fetch data for team ID 1cd2b521-9090-4692-bb78-29973ef2d748: 404
# Failed to fetch data for team ID 49e876e9-2e57-4ba4-96fd-ba8e92932227: 404
# Failed to fetch data for team ID 4bea8be7-44fb-4a3e-9abe-26ab3e7f5500: 404
# Rate limit hit, retrying after 60 seconds...
# Failed to fetch data for team ID 99c773e4-ff9f-404e-9a00-4bf5d18caa66: 404
# Rate limit hit, retrying after 60 seconds...
# Failed to fetch data for team ID 535534b6-78cf-4650-824c-fb9a15be5988: 404
# Failed to fetch data for team ID 468e2568-b105-4472-9c6c-bf53d9cf2e19: 404
# Rate limit hit, retrying after 60 seconds...
# Rate limit hit, retrying after 60 seconds...
# Failed to fetch data for team ID 2bac13fb-85e2-4901-adbc-dab87365e6c9: 404
# Rate limit hit, retrying after 60 seconds...
# Failed to fetch data for team ID b7c79007-995e-4961-8a02-0c6f9dd65269: 404
# Failed to fetch data for team ID 67be4fe9-b990-4f1a-83ff-82c9a62f71b8: 404
# Rate limit hit, retrying after 60 seconds...
# Rate limit hit, retrying after 60 seconds...
# Failed to fetch data for team ID 9aa0e461-0d27-4a08-a9f5-5cdea0acd772: 404
# Rate limit hit, retrying after 60 seconds...
# Rate limit hit, retrying after 60 seconds...
# Failed to fetch data for team ID 062d9e85-6d5b-463b-91c6-2d1cd044a6cf: 404
# Rate limit hit, retrying after 60 seconds...

# %%
# Assuming team_stats_data is your dictionary containing all the team data
team_name_and_records = {}

for team_id, team_info in team_stats_data.items():
    if 'own_record' in team_info:
        team_name_and_records[team_info['name']] = team_info['own_record']
    else:
        team_name_and_records[team_info['name']] = "No own record found"

# Now team_name_and_records contains the names and 'own_record' for each team
for name, record in team_name_and_records.items():
    print(f"Team Name: {name}")
    print("Own Record:", record)
    print("-" * 50)  # Print a separator line for clarity
# Out:
# Team Name: Avalanche
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 302, 'assists': 525, 'penalties': 307, 'penalty_minutes': 731, 'team_penalties': 13, 'team_penalty_minutes': 26, 'shots': 2705, 'blocked_att': 1506, 'missed_shots': 1119, 'hits': 1671, 'giveaways': 603, 'takeaways': 647, 'blocked_shots': 1214, 'faceoffs_won': 2297, 'faceoffs_lost': 2494, 'powerplays': 278, 'shooting_pct': 11.2, 'faceoff_win_pct': 47.9, 'faceoffs': 4791, 'points': 827, 'plus_minus': 159, 'overtime_goals': 6, 'overtime_assists': 11, 'overtime_shots': 30, 'emptynet_goals': 19, 'penalties_major': 11, 'penalties_match': 0, 'penalties_minor': 268, 'penalties_misconduct': 9}, 'powerplay': {'faceoffs_won': 255, 'faceoffs_lost': 208, 'shots': 443, 'goals': 68, 'missed_shots': 177, 'assists': 134, 'faceoff_win_pct': 55.1, 'opportunities': 278, 'faceoffs': 463, 'percentage': 24.5, 'strength': [{'opportunities': 266, 'shots': 424, 'goals': 62, 'type': '5v4'}, {'opportunities': 9, 'shots': 5, 'goals': 2, 'type': '5v3'}, {'opportunities': 10, 'shots': 14, 'goals': 4, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 183, 'faceoffs_lost': 276, 'shots': 72, 'goals': 7, 'missed_shots': 21, 'assists': 12, 'faceoff_win_pct': 39.9, 'opportunities': 264, 'faceoffs': 459, 'goals_against': 53, 'kill_pct': 79.9, 'strength': [{'shots': 72, 'goals': 7, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1859, 'faceoffs_lost': 2010, 'shots': 2190, 'goals': 227, 'missed_shots': 921, 'assists': 379, 'faceoff_win_pct': 48.0, 'faceoffs': 3869, 'strength': [{'shots': 2133, 'goals': 217, 'type': '5v5'}, {'shots': 32, 'goals': 7, 'type': '4v4'}, {'shots': 25, 'goals': 3, 'type': '3v3'}]}, 'penalty': {'shots': 2, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 6.4, 'blocked_shots': 14.8, 'points': 10.09, 'blocked_att': 18.37, 'team_penalty_minutes': 0.32, 'penalties': 3.74, 'missed_shots': 13.65, 'hits': 20.38, 'shots': 32.99, 'takeaways': 7.89, 'giveaways': 7.35, 'goals': 3.68, 'team_penalties': 0.16, 'penalty_minutes': 8.91}}, 'shootout': {'shots': 9, 'missed_shots': 1, 'goals': 2, 'shots_against': 11, 'goals_against': 3, 'saves': 8, 'saves_pct': 0.727}, 'goaltending': {'total': {'shots_against': 2432, 'goals_against': 239, 'saves': 2193, 'total_goals_against': 252, 'total_shots_against': 2445, 'saves_pct': 0.897, 'losses': 25, 'overtime_losses': 7, 'shutouts': 4, 'wins': 50}, 'powerplay': {'shots_against': 76, 'goals_against': 6, 'saves': 70, 'saves_pct': 0.921}, 'shorthanded': {'shots_against': 397, 'goals_against': 53, 'saves': 344, 'saves_pct': 0.866}, 'evenstrength': {'shots_against': 1972, 'goals_against': 193, 'saves': 1779, 'saves_pct': 0.902}, 'penalty': {'shots_against': 1, 'goals_against': 1, 'saves': 0, 'saves_pct': 0.0}, 'average': {'goals_against': 2.91, 'shots_against': 29.66}, 'emptynet': {'total': {'goals_against': 13, 'shots_against': 13}, 'powerplay': {'goals_against': 0}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 13}}, 'time_on_ice': {'total': '4969:24'}}}
# --------------------------------------------------
# Team Name: Blackhawks
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 178, 'assists': 303, 'penalties': 292, 'penalty_minutes': 715, 'team_penalties': 7, 'team_penalty_minutes': 14, 'shots': 2153, 'blocked_att': 1210, 'missed_shots': 893, 'hits': 1874, 'giveaways': 747, 'takeaways': 714, 'blocked_shots': 1340, 'faceoffs_won': 2029, 'faceoffs_lost': 2357, 'powerplays': 235, 'shooting_pct': 8.3, 'faceoff_win_pct': 46.3, 'faceoffs': 4386, 'points': 481, 'plus_minus': -483, 'overtime_goals': 5, 'overtime_assists': 7, 'overtime_shots': 19, 'emptynet_goals': 6, 'penalties_major': 27, 'penalties_match': 0, 'penalties_minor': 251, 'penalties_misconduct': 6}, 'powerplay': {'faceoffs_won': 196, 'faceoffs_lost': 193, 'shots': 314, 'goals': 39, 'missed_shots': 144, 'assists': 74, 'faceoff_win_pct': 50.4, 'opportunities': 235, 'faceoffs': 389, 'percentage': 16.6, 'strength': [{'opportunities': 228, 'shots': 294, 'goals': 33, 'type': '5v4'}, {'opportunities': 7, 'shots': 14, 'goals': 4, 'type': '5v3'}, {'opportunities': 4, 'shots': 6, 'goals': 2, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 167, 'faceoffs_lost': 245, 'shots': 65, 'goals': 3, 'missed_shots': 17, 'assists': 1, 'faceoff_win_pct': 40.5, 'opportunities': 231, 'faceoffs': 412, 'goals_against': 56, 'kill_pct': 75.8, 'strength': [{'shots': 65, 'goals': 3, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1666, 'faceoffs_lost': 1919, 'shots': 1774, 'goals': 136, 'missed_shots': 732, 'assists': 228, 'faceoff_win_pct': 46.5, 'faceoffs': 3585, 'strength': [{'shots': 1740, 'goals': 128, 'type': '5v5'}, {'shots': 19, 'goals': 4, 'type': '4v4'}, {'shots': 15, 'goals': 4, 'type': '3v3'}]}, 'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 3.7, 'blocked_shots': 16.34, 'points': 5.87, 'blocked_att': 14.76, 'team_penalty_minutes': 0.17, 'penalties': 3.56, 'missed_shots': 10.89, 'hits': 22.85, 'shots': 26.26, 'takeaways': 8.71, 'giveaways': 9.11, 'goals': 2.17, 'team_penalties': 0.09, 'penalty_minutes': 8.72}}, 'shootout': {'shots': 7, 'missed_shots': 4, 'goals': 3, 'shots_against': 10, 'goals_against': 4, 'saves': 6, 'saves_pct': 0.6}, 'goaltending': {'total': {'shots_against': 2667, 'goals_against': 274, 'saves': 2393, 'total_goals_against': 289, 'total_shots_against': 2682, 'saves_pct': 0.892, 'losses': 53, 'overtime_losses': 6, 'shutouts': 1, 'wins': 23}, 'powerplay': {'shots_against': 54, 'goals_against': 7, 'saves': 47, 'saves_pct': 0.87}, 'shorthanded': {'shots_against': 330, 'goals_against': 56, 'saves': 274, 'saves_pct': 0.83}, 'evenstrength': {'shots_against': 2297, 'goals_against': 225, 'saves': 2072, 'saves_pct': 0.902}, 'penalty': {'shots_against': 0, 'goals_against': 0, 'saves': 0, 'saves_pct': 0.0}, 'average': {'goals_against': 3.34, 'shots_against': 32.52}, 'emptynet': {'total': {'goals_against': 15, 'shots_against': 15}, 'powerplay': {'goals_against': 1}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 14}}, 'time_on_ice': {'total': '4949:58'}}}
# --------------------------------------------------
# Team Name: Blue Jackets
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 234, 'assists': 389, 'penalties': 291, 'penalty_minutes': 670, 'team_penalties': 8, 'team_penalty_minutes': 14, 'shots': 2458, 'blocked_att': 1474, 'missed_shots': 1120, 'hits': 1577, 'giveaways': 463, 'takeaways': 517, 'blocked_shots': 1396, 'faceoffs_won': 2184, 'faceoffs_lost': 2441, 'powerplays': 212, 'shooting_pct': 9.5, 'faceoff_win_pct': 47.2, 'faceoffs': 4625, 'points': 623, 'plus_minus': -206, 'overtime_goals': 3, 'overtime_assists': 5, 'overtime_shots': 31, 'emptynet_goals': 11, 'penalties_major': 18, 'penalties_match': 0, 'penalties_minor': 259, 'penalties_misconduct': 4}, 'powerplay': {'faceoffs_won': 190, 'faceoffs_lost': 198, 'shots': 329, 'goals': 32, 'missed_shots': 163, 'assists': 59, 'faceoff_win_pct': 49.0, 'opportunities': 212, 'faceoffs': 388, 'percentage': 15.1, 'strength': [{'opportunities': 205, 'shots': 316, 'goals': 29, 'type': '5v4'}, {'opportunities': 3, 'shots': 4, 'goals': 2, 'type': '5v3'}, {'opportunities': 5, 'shots': 9, 'goals': 1, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 162, 'faceoffs_lost': 232, 'shots': 60, 'goals': 5, 'missed_shots': 16, 'assists': 6, 'faceoff_win_pct': 41.1, 'opportunities': 236, 'faceoffs': 394, 'goals_against': 56, 'kill_pct': 76.3, 'strength': [{'shots': 58, 'goals': 5, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 2, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1832, 'faceoffs_lost': 2011, 'shots': 2069, 'goals': 197, 'missed_shots': 941, 'assists': 324, 'faceoff_win_pct': 47.7, 'faceoffs': 3843, 'strength': [{'shots': 2012, 'goals': 190, 'type': '5v5'}, {'shots': 31, 'goals': 4, 'type': '4v4'}, {'shots': 26, 'goals': 3, 'type': '3v3'}]}, 'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 4.74, 'blocked_shots': 17.02, 'points': 7.6, 'blocked_att': 17.98, 'team_penalty_minutes': 0.17, 'penalties': 3.55, 'missed_shots': 13.66, 'hits': 19.23, 'shots': 29.98, 'takeaways': 6.3, 'giveaways': 5.65, 'goals': 2.85, 'team_penalties': 0.1, 'penalty_minutes': 8.17}}, 'shootout': {'shots': 13, 'missed_shots': 4, 'goals': 5, 'shots_against': 18, 'goals_against': 4, 'saves': 14, 'saves_pct': 0.778}, 'goaltending': {'total': {'shots_against': 2803, 'goals_against': 279, 'saves': 2524, 'total_goals_against': 298, 'total_shots_against': 2822, 'saves_pct': 0.894, 'losses': 43, 'overtime_losses': 12, 'shutouts': 1, 'wins': 27}, 'powerplay': {'shots_against': 70, 'goals_against': 6, 'saves': 64, 'saves_pct': 0.914}, 'shorthanded': {'shots_against': 410, 'goals_against': 56, 'saves': 354, 'saves_pct': 0.863}, 'evenstrength': {'shots_against': 2342, 'goals_against': 236, 'saves': 2106, 'saves_pct': 0.899}, 'penalty': {'shots_against': 2, 'goals_against': 0, 'saves': 2, 'saves_pct': 1.0}, 'average': {'goals_against': 3.4, 'shots_against': 34.18}, 'emptynet': {'total': {'goals_against': 19, 'shots_against': 19}, 'powerplay': {'goals_against': 0}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 19}}, 'time_on_ice': {'total': '4978:38'}}}
# --------------------------------------------------
# Team Name: Blues
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 234, 'assists': 401, 'penalties': 263, 'penalty_minutes': 608, 'team_penalties': 9, 'team_penalty_minutes': 18, 'shots': 2370, 'blocked_att': 1182, 'missed_shots': 999, 'hits': 1654, 'giveaways': 621, 'takeaways': 726, 'blocked_shots': 1219, 'faceoffs_won': 2253, 'faceoffs_lost': 2262, 'powerplays': 250, 'shooting_pct': 9.9, 'faceoff_win_pct': 49.9, 'faceoffs': 4515, 'points': 635, 'plus_minus': -99, 'overtime_goals': 7, 'overtime_assists': 9, 'overtime_shots': 32, 'emptynet_goals': 15, 'penalties_major': 16, 'penalties_match': 0, 'penalties_minor': 233, 'penalties_misconduct': 4}, 'powerplay': {'faceoffs_won': 249, 'faceoffs_lost': 188, 'shots': 362, 'goals': 45, 'missed_shots': 158, 'assists': 90, 'faceoff_win_pct': 57.0, 'opportunities': 250, 'faceoffs': 437, 'percentage': 18.0, 'strength': [{'opportunities': 239, 'shots': 343, 'goals': 43, 'type': '5v4'}, {'opportunities': 9, 'shots': 17, 'goals': 2, 'type': '5v3'}, {'opportunities': 2, 'shots': 2, 'goals': 0, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 179, 'faceoffs_lost': 204, 'shots': 71, 'goals': 11, 'missed_shots': 20, 'assists': 9, 'faceoff_win_pct': 46.7, 'opportunities': 215, 'faceoffs': 383, 'goals_against': 46, 'kill_pct': 78.6, 'strength': [{'shots': 71, 'goals': 11, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1825, 'faceoffs_lost': 1870, 'shots': 1937, 'goals': 178, 'missed_shots': 821, 'assists': 302, 'faceoff_win_pct': 49.4, 'faceoffs': 3695, 'strength': [{'shots': 1879, 'goals': 170, 'type': '5v5'}, {'shots': 27, 'goals': 1, 'type': '4v4'}, {'shots': 31, 'goals': 7, 'type': '3v3'}]}, 'penalty': {'shots': 2, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 4.89, 'blocked_shots': 14.87, 'points': 7.74, 'blocked_att': 14.41, 'team_penalty_minutes': 0.22, 'penalties': 3.21, 'missed_shots': 12.18, 'hits': 20.17, 'shots': 28.9, 'takeaways': 8.85, 'giveaways': 7.57, 'goals': 2.85, 'team_penalties': 0.11, 'penalty_minutes': 7.41}}, 'shootout': {'shots': 18, 'missed_shots': 5, 'goals': 9, 'shots_against': 25, 'goals_against': 6, 'saves': 19, 'saves_pct': 0.76}, 'goaltending': {'total': {'shots_against': 2616, 'goals_against': 228, 'saves': 2388, 'total_goals_against': 248, 'total_shots_against': 2636, 'saves_pct': 0.906, 'losses': 33, 'overtime_losses': 6, 'shutouts': 4, 'wins': 43}, 'powerplay': {'shots_against': 66, 'goals_against': 5, 'saves': 61, 'saves_pct': 0.924}, 'shorthanded': {'shots_against': 337, 'goals_against': 45, 'saves': 292, 'saves_pct': 0.866}, 'evenstrength': {'shots_against': 2231, 'goals_against': 196, 'saves': 2035, 'saves_pct': 0.912}, 'penalty': {'shots_against': 1, 'goals_against': 0, 'saves': 1, 'saves_pct': 1.0}, 'average': {'goals_against': 2.78, 'shots_against': 31.9}, 'emptynet': {'total': {'goals_against': 20, 'shots_against': 20}, 'powerplay': {'goals_against': 2}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 18}}, 'time_on_ice': {'total': '4977:27'}}}
# --------------------------------------------------
# Team Name: Bruins
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 263, 'assists': 443, 'penalties': 334, 'penalty_minutes': 776, 'team_penalties': 11, 'team_penalty_minutes': 22, 'shots': 2399, 'blocked_att': 1227, 'missed_shots': 984, 'hits': 2258, 'giveaways': 698, 'takeaways': 516, 'blocked_shots': 1299, 'faceoffs_won': 2298, 'faceoffs_lost': 2344, 'powerplays': 243, 'shooting_pct': 11.0, 'faceoff_win_pct': 49.5, 'faceoffs': 4642, 'points': 706, 'plus_minus': 157, 'overtime_goals': 7, 'overtime_assists': 7, 'overtime_shots': 63, 'emptynet_goals': 13, 'penalties_major': 21, 'penalties_match': 1, 'penalties_minor': 295, 'penalties_misconduct': 4}, 'powerplay': {'faceoffs_won': 237, 'faceoffs_lost': 183, 'shots': 386, 'goals': 54, 'missed_shots': 147, 'assists': 106, 'faceoff_win_pct': 56.4, 'opportunities': 243, 'faceoffs': 420, 'percentage': 22.2, 'strength': [{'opportunities': 232, 'shots': 360, 'goals': 50, 'type': '5v4'}, {'opportunities': 8, 'shots': 12, 'goals': 4, 'type': '5v3'}, {'opportunities': 7, 'shots': 14, 'goals': 0, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 218, 'faceoffs_lost': 265, 'shots': 76, 'goals': 7, 'missed_shots': 20, 'assists': 6, 'faceoff_win_pct': 45.1, 'opportunities': 268, 'faceoffs': 483, 'goals_against': 47, 'kill_pct': 82.5, 'strength': [{'shots': 74, 'goals': 7, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 2, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1843, 'faceoffs_lost': 1896, 'shots': 1937, 'goals': 202, 'missed_shots': 817, 'assists': 331, 'faceoff_win_pct': 49.3, 'faceoffs': 3739, 'strength': [{'shots': 1840, 'goals': 189, 'type': '5v5'}, {'shots': 44, 'goals': 6, 'type': '4v4'}, {'shots': 53, 'goals': 7, 'type': '3v3'}]}, 'penalty': {'shots': 2, 'goals': 2, 'missed_shots': 0}, 'average': {'assists': 5.4, 'blocked_shots': 15.84, 'points': 8.61, 'blocked_att': 14.96, 'team_penalty_minutes': 0.27, 'penalties': 4.07, 'missed_shots': 12.0, 'hits': 27.54, 'shots': 29.26, 'takeaways': 6.29, 'giveaways': 8.51, 'goals': 3.21, 'team_penalties': 0.13, 'penalty_minutes': 9.46}}, 'shootout': {'shots': 24, 'missed_shots': 3, 'goals': 9, 'shots_against': 26, 'goals_against': 7, 'saves': 19, 'saves_pct': 0.731}, 'goaltending': {'total': {'shots_against': 2495, 'goals_against': 211, 'saves': 2284, 'total_goals_against': 221, 'total_shots_against': 2505, 'saves_pct': 0.912, 'losses': 20, 'overtime_losses': 15, 'shutouts': 5, 'wins': 47}, 'powerplay': {'shots_against': 78, 'goals_against': 5, 'saves': 73, 'saves_pct': 0.936}, 'shorthanded': {'shots_against': 384, 'goals_against': 47, 'saves': 336, 'saves_pct': 0.875}, 'evenstrength': {'shots_against': 2042, 'goals_against': 168, 'saves': 1875, 'saves_pct': 0.918}, 'penalty': {'shots_against': 1, 'goals_against': 0, 'saves': 1, 'saves_pct': 1.0}, 'average': {'goals_against': 2.57, 'shots_against': 30.43}, 'emptynet': {'total': {'goals_against': 10, 'shots_against': 10}, 'powerplay': {'goals_against': 1}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 9}}, 'time_on_ice': {'total': '5002:41'}}}
# --------------------------------------------------
# Team Name: Canadiens
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 232, 'assists': 380, 'penalties': 348, 'penalty_minutes': 825, 'team_penalties': 10, 'team_penalty_minutes': 20, 'shots': 2269, 'blocked_att': 1257, 'missed_shots': 1007, 'hits': 1808, 'giveaways': 788, 'takeaways': 463, 'blocked_shots': 1464, 'faceoffs_won': 2332, 'faceoffs_lost': 2200, 'powerplays': 252, 'shooting_pct': 10.2, 'faceoff_win_pct': 51.5, 'faceoffs': 4532, 'points': 612, 'plus_minus': -139, 'overtime_goals': 6, 'overtime_assists': 10, 'overtime_shots': 53, 'emptynet_goals': 7, 'penalties_major': 24, 'penalties_match': 1, 'penalties_minor': 301, 'penalties_misconduct': 5}, 'powerplay': {'faceoffs_won': 243, 'faceoffs_lost': 178, 'shots': 344, 'goals': 44, 'missed_shots': 145, 'assists': 86, 'faceoff_win_pct': 57.7, 'opportunities': 252, 'faceoffs': 421, 'percentage': 17.5, 'strength': [{'opportunities': 241, 'shots': 327, 'goals': 42, 'type': '5v4'}, {'opportunities': 9, 'shots': 7, 'goals': 0, 'type': '5v3'}, {'opportunities': 11, 'shots': 10, 'goals': 2, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 227, 'faceoffs_lost': 258, 'shots': 64, 'goals': 7, 'missed_shots': 8, 'assists': 1, 'faceoff_win_pct': 46.8, 'opportunities': 277, 'faceoffs': 485, 'goals_against': 65, 'kill_pct': 76.5, 'strength': [{'shots': 63, 'goals': 7, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 1, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1862, 'faceoffs_lost': 1764, 'shots': 1861, 'goals': 181, 'missed_shots': 854, 'assists': 293, 'faceoff_win_pct': 51.4, 'faceoffs': 3626, 'strength': [{'shots': 1784, 'goals': 171, 'type': '5v5'}, {'shots': 33, 'goals': 6, 'type': '4v4'}, {'shots': 44, 'goals': 4, 'type': '3v3'}]}, 'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 4.63, 'blocked_shots': 17.85, 'points': 7.46, 'blocked_att': 15.33, 'team_penalty_minutes': 0.24, 'penalties': 4.24, 'missed_shots': 12.28, 'hits': 22.05, 'shots': 27.67, 'takeaways': 5.65, 'giveaways': 9.61, 'goals': 2.83, 'team_penalties': 0.12, 'penalty_minutes': 10.06}}, 'shootout': {'shots': 39, 'missed_shots': 12, 'goals': 13, 'shots_against': 53, 'goals_against': 17, 'saves': 36, 'saves_pct': 0.679}, 'goaltending': {'total': {'shots_against': 2724, 'goals_against': 267, 'saves': 2457, 'total_goals_against': 281, 'total_shots_against': 2738, 'saves_pct': 0.897, 'losses': 36, 'overtime_losses': 16, 'shutouts': 2, 'wins': 30}, 'powerplay': {'shots_against': 85, 'goals_against': 12, 'saves': 73, 'saves_pct': 0.859}, 'shorthanded': {'shots_against': 464, 'goals_against': 64, 'saves': 400, 'saves_pct': 0.862}, 'evenstrength': {'shots_against': 2188, 'goals_against': 204, 'saves': 1984, 'saves_pct': 0.907}, 'penalty': {'shots_against': 3, 'goals_against': 2, 'saves': 1, 'saves_pct': 0.333}, 'average': {'goals_against': 3.26, 'shots_against': 33.22}, 'emptynet': {'total': {'goals_against': 14, 'shots_against': 14}, 'powerplay': {'goals_against': 0}, 'shorthanded': {'goals_against': 1}, 'evenstrength': {'goals_against': 13}}, 'time_on_ice': {'total': '5013:07'}}}
# --------------------------------------------------
# Team Name: Canucks
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 279, 'assists': 484, 'penalties': 314, 'penalty_minutes': 764, 'team_penalties': 14, 'team_penalty_minutes': 28, 'shots': 2328, 'blocked_att': 1360, 'missed_shots': 1149, 'hits': 2178, 'giveaways': 492, 'takeaways': 499, 'blocked_shots': 1152, 'faceoffs_won': 2336, 'faceoffs_lost': 2145, 'powerplays': 257, 'shooting_pct': 12.0, 'faceoff_win_pct': 52.1, 'faceoffs': 4481, 'points': 763, 'plus_minus': 269, 'overtime_goals': 6, 'overtime_assists': 9, 'overtime_shots': 28, 'emptynet_goals': 14, 'penalties_major': 20, 'penalties_match': 2, 'penalties_minor': 267, 'penalties_misconduct': 8}, 'powerplay': {'faceoffs_won': 253, 'faceoffs_lost': 164, 'shots': 393, 'goals': 58, 'missed_shots': 182, 'assists': 112, 'faceoff_win_pct': 60.7, 'opportunities': 257, 'faceoffs': 417, 'percentage': 22.6, 'strength': [{'opportunities': 249, 'shots': 382, 'goals': 55, 'type': '5v4'}, {'opportunities': 10, 'shots': 9, 'goals': 2, 'type': '5v3'}, {'opportunities': 4, 'shots': 2, 'goals': 1, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 224, 'faceoffs_lost': 248, 'shots': 71, 'goals': 7, 'missed_shots': 12, 'assists': 7, 'faceoff_win_pct': 47.5, 'opportunities': 254, 'faceoffs': 472, 'goals_against': 53, 'kill_pct': 79.1, 'strength': [{'shots': 70, 'goals': 7, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 1, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1859, 'faceoffs_lost': 1733, 'shots': 1864, 'goals': 214, 'missed_shots': 955, 'assists': 365, 'faceoff_win_pct': 51.8, 'faceoffs': 3592, 'strength': [{'shots': 1815, 'goals': 206, 'type': '5v5'}, {'shots': 23, 'goals': 3, 'type': '4v4'}, {'shots': 26, 'goals': 5, 'type': '3v3'}]}, 'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 5.9, 'blocked_shots': 14.05, 'points': 9.3, 'blocked_att': 16.59, 'team_penalty_minutes': 0.34, 'penalties': 3.83, 'missed_shots': 14.01, 'hits': 26.56, 'shots': 28.39, 'takeaways': 6.09, 'giveaways': 6.0, 'goals': 3.4, 'team_penalties': 0.17, 'penalty_minutes': 9.32}}, 'shootout': {'shots': 6, 'missed_shots': 1, 'goals': 0, 'shots_against': 7, 'goals_against': 2, 'saves': 5, 'saves_pct': 0.714}, 'goaltending': {'total': {'shots_against': 2335, 'goals_against': 213, 'saves': 2122, 'total_goals_against': 221, 'total_shots_against': 2343, 'saves_pct': 0.906, 'losses': 23, 'overtime_losses': 9, 'shutouts': 6, 'wins': 50}, 'powerplay': {'shots_against': 72, 'goals_against': 7, 'saves': 65, 'saves_pct': 0.903}, 'shorthanded': {'shots_against': 384, 'goals_against': 53, 'saves': 331, 'saves_pct': 0.862}, 'evenstrength': {'shots_against': 1887, 'goals_against': 161, 'saves': 1726, 'saves_pct': 0.915}, 'penalty': {'shots_against': 3, 'goals_against': 2, 'saves': 1, 'saves_pct': 0.333}, 'average': {'goals_against': 2.6, 'shots_against': 28.48}, 'emptynet': {'total': {'goals_against': 8, 'shots_against': 8}, 'powerplay': {'goals_against': 0}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 8}}, 'time_on_ice': {'total': '4964:45'}}}
# --------------------------------------------------
# Team Name: Capitals
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 216, 'assists': 371, 'penalties': 272, 'penalty_minutes': 628, 'team_penalties': 9, 'team_penalty_minutes': 18, 'shots': 2173, 'blocked_att': 1353, 'missed_shots': 1047, 'hits': 1880, 'giveaways': 700, 'takeaways': 628, 'blocked_shots': 1419, 'faceoffs_won': 2126, 'faceoffs_lost': 2431, 'powerplays': 228, 'shooting_pct': 9.9, 'faceoff_win_pct': 46.7, 'faceoffs': 4557, 'points': 587, 'plus_minus': -169, 'overtime_goals': 4, 'overtime_assists': 7, 'overtime_shots': 41, 'emptynet_goals': 12, 'penalties_major': 12, 'penalties_match': 0, 'penalties_minor': 242, 'penalties_misconduct': 5}, 'powerplay': {'faceoffs_won': 235, 'faceoffs_lost': 203, 'shots': 349, 'goals': 47, 'missed_shots': 150, 'assists': 86, 'faceoff_win_pct': 53.7, 'opportunities': 228, 'faceoffs': 438, 'percentage': 20.6, 'strength': [{'opportunities': 219, 'shots': 324, 'goals': 44, 'type': '5v4'}, {'opportunities': 5, 'shots': 14, 'goals': 1, 'type': '5v3'}, {'opportunities': 7, 'shots': 12, 'goals': 2, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 162, 'faceoffs_lost': 234, 'shots': 49, 'goals': 3, 'missed_shots': 16, 'assists': 5, 'faceoff_win_pct': 40.9, 'opportunities': 233, 'faceoffs': 396, 'goals_against': 49, 'kill_pct': 79.0, 'strength': [{'shots': 49, 'goals': 3, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1729, 'faceoffs_lost': 1994, 'shots': 1775, 'goals': 166, 'missed_shots': 881, 'assists': 280, 'faceoff_win_pct': 46.4, 'faceoffs': 3723, 'strength': [{'shots': 1726, 'goals': 160, 'type': '5v5'}, {'shots': 18, 'goals': 4, 'type': '4v4'}, {'shots': 29, 'goals': 2, 'type': '3v3'}]}, 'penalty': {'shots': 3, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 4.52, 'blocked_shots': 17.3, 'points': 7.16, 'blocked_att': 16.5, 'team_penalty_minutes': 0.22, 'penalties': 3.32, 'missed_shots': 12.77, 'hits': 22.93, 'shots': 26.5, 'takeaways': 7.66, 'giveaways': 8.54, 'goals': 2.63, 'team_penalties': 0.11, 'penalty_minutes': 7.66}}, 'shootout': {'shots': 27, 'missed_shots': 7, 'goals': 8, 'shots_against': 34, 'goals_against': 10, 'saves': 24, 'saves_pct': 0.706}, 'goaltending': {'total': {'shots_against': 2494, 'goals_against': 243, 'saves': 2251, 'total_goals_against': 252, 'total_shots_against': 2503, 'saves_pct': 0.899, 'losses': 31, 'overtime_losses': 11, 'shutouts': 7, 'wins': 40}, 'powerplay': {'shots_against': 67, 'goals_against': 4, 'saves': 63, 'saves_pct': 0.94}, 'shorthanded': {'shots_against': 368, 'goals_against': 49, 'saves': 319, 'saves_pct': 0.867}, 'evenstrength': {'shots_against': 2067, 'goals_against': 198, 'saves': 1869, 'saves_pct': 0.904}, 'penalty': {'shots_against': 1, 'goals_against': 0, 'saves': 1, 'saves_pct': 1.0}, 'average': {'goals_against': 2.96, 'shots_against': 30.41}, 'emptynet': {'total': {'goals_against': 9, 'shots_against': 9}, 'powerplay': {'goals_against': 1}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 8}}, 'time_on_ice': {'total': '4991:21'}}}
# --------------------------------------------------
# Team Name: Coyotes
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 254, 'assists': 424, 'penalties': 358, 'penalty_minutes': 944, 'team_penalties': 15, 'team_penalty_minutes': 30, 'shots': 2273, 'blocked_att': 1281, 'missed_shots': 1094, 'hits': 1849, 'giveaways': 669, 'takeaways': 474, 'blocked_shots': 1228, 'faceoffs_won': 2113, 'faceoffs_lost': 2574, 'powerplays': 241, 'shooting_pct': 11.2, 'faceoff_win_pct': 45.1, 'faceoffs': 4687, 'points': 678, 'plus_minus': -71, 'overtime_goals': 6, 'overtime_assists': 9, 'overtime_shots': 32, 'emptynet_goals': 13, 'penalties_major': 32, 'penalties_match': 0, 'penalties_minor': 293, 'penalties_misconduct': 16}, 'powerplay': {'faceoffs_won': 198, 'faceoffs_lost': 215, 'shots': 329, 'goals': 53, 'missed_shots': 143, 'assists': 100, 'faceoff_win_pct': 47.9, 'opportunities': 241, 'faceoffs': 413, 'percentage': 22.0, 'strength': [{'opportunities': 232, 'shots': 312, 'goals': 52, 'type': '5v4'}, {'opportunities': 6, 'shots': 7, 'goals': 1, 'type': '5v3'}, {'opportunities': 5, 'shots': 9, 'goals': 0, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 206, 'faceoffs_lost': 290, 'shots': 61, 'goals': 7, 'missed_shots': 20, 'assists': 7, 'faceoff_win_pct': 41.5, 'opportunities': 266, 'faceoffs': 496, 'goals_against': 63, 'kill_pct': 76.3, 'strength': [{'shots': 61, 'goals': 7, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1709, 'faceoffs_lost': 2069, 'shots': 1883, 'goals': 194, 'missed_shots': 931, 'assists': 317, 'faceoff_win_pct': 45.2, 'faceoffs': 3778, 'strength': [{'shots': 1832, 'goals': 187, 'type': '5v5'}, {'shots': 28, 'goals': 1, 'type': '4v4'}, {'shots': 24, 'goals': 6, 'type': '3v3'}]}, 'penalty': {'shots': 2, 'goals': 1, 'missed_shots': 0}, 'average': {'assists': 5.17, 'blocked_shots': 14.98, 'points': 8.27, 'blocked_att': 15.62, 'team_penalty_minutes': 0.37, 'penalties': 4.37, 'missed_shots': 13.34, 'hits': 22.55, 'shots': 27.72, 'takeaways': 5.78, 'giveaways': 8.16, 'goals': 3.1, 'team_penalties': 0.18, 'penalty_minutes': 11.51}}, 'shootout': {'shots': 5, 'missed_shots': 0, 'goals': 3, 'shots_against': 5, 'goals_against': 0, 'saves': 5, 'saves_pct': 1.0}, 'goaltending': {'total': {'shots_against': 2579, 'goals_against': 255, 'saves': 2324, 'total_goals_against': 274, 'total_shots_against': 2598, 'saves_pct': 0.895, 'losses': 41, 'overtime_losses': 5, 'shutouts': 7, 'wins': 36}, 'powerplay': {'shots_against': 72, 'goals_against': 7, 'saves': 65, 'saves_pct': 0.903}, 'shorthanded': {'shots_against': 451, 'goals_against': 63, 'saves': 388, 'saves_pct': 0.86}, 'evenstrength': {'shots_against': 2075, 'goals_against': 204, 'saves': 1871, 'saves_pct': 0.902}, 'penalty': {'shots_against': 2, 'goals_against': 1, 'saves': 1, 'saves_pct': 0.5}, 'average': {'goals_against': 3.11, 'shots_against': 31.45}, 'emptynet': {'total': {'goals_against': 19, 'shots_against': 19}, 'powerplay': {'goals_against': 0}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 19}}, 'time_on_ice': {'total': '4964:02'}}}
# --------------------------------------------------
# Team Name: Devils
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 264, 'assists': 423, 'penalties': 303, 'penalty_minutes': 747, 'team_penalties': 10, 'team_penalty_minutes': 20, 'shots': 2516, 'blocked_att': 1534, 'missed_shots': 1081, 'hits': 1668, 'giveaways': 644, 'takeaways': 563, 'blocked_shots': 1116, 'faceoffs_won': 2461, 'faceoffs_lost': 2136, 'powerplays': 245, 'shooting_pct': 10.5, 'faceoff_win_pct': 53.5, 'faceoffs': 4597, 'points': 687, 'plus_minus': -151, 'overtime_goals': 5, 'overtime_assists': 7, 'overtime_shots': 27, 'emptynet_goals': 14, 'penalties_major': 19, 'penalties_match': 0, 'penalties_minor': 262, 'penalties_misconduct': 10}, 'powerplay': {'faceoffs_won': 234, 'faceoffs_lost': 194, 'shots': 368, 'goals': 55, 'missed_shots': 127, 'assists': 102, 'faceoff_win_pct': 54.7, 'opportunities': 245, 'faceoffs': 428, 'percentage': 22.4, 'strength': [{'opportunities': 237, 'shots': 356, 'goals': 48, 'type': '5v4'}, {'opportunities': 6, 'shots': 7, 'goals': 4, 'type': '5v3'}, {'opportunities': 6, 'shots': 5, 'goals': 3, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 212, 'faceoffs_lost': 185, 'shots': 63, 'goals': 3, 'missed_shots': 18, 'assists': 2, 'faceoff_win_pct': 53.4, 'opportunities': 243, 'faceoffs': 397, 'goals_against': 47, 'kill_pct': 80.7, 'strength': [{'shots': 62, 'goals': 3, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 1, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 2015, 'faceoffs_lost': 1757, 'shots': 2085, 'goals': 206, 'missed_shots': 936, 'assists': 319, 'faceoff_win_pct': 53.4, 'faceoffs': 3772, 'strength': [{'shots': 2030, 'goals': 196, 'type': '5v5'}, {'shots': 29, 'goals': 5, 'type': '4v4'}, {'shots': 26, 'goals': 5, 'type': '3v3'}]}, 'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 1}, 'average': {'assists': 5.16, 'blocked_shots': 13.61, 'points': 8.38, 'blocked_att': 18.71, 'team_penalty_minutes': 0.24, 'penalties': 3.7, 'missed_shots': 13.18, 'hits': 20.34, 'shots': 30.68, 'takeaways': 6.87, 'giveaways': 7.85, 'goals': 3.22, 'team_penalties': 0.12, 'penalty_minutes': 9.11}}, 'shootout': {'shots': 5, 'missed_shots': 0, 'goals': 0, 'shots_against': 4, 'goals_against': 3, 'saves': 1, 'saves_pct': 0.25}, 'goaltending': {'total': {'shots_against': 2431, 'goals_against': 254, 'saves': 2177, 'total_goals_against': 281, 'total_shots_against': 2458, 'saves_pct': 0.886, 'losses': 39, 'overtime_losses': 5, 'shutouts': 1, 'wins': 38}, 'powerplay': {'shots_against': 68, 'goals_against': 8, 'saves': 60, 'saves_pct': 0.882}, 'shorthanded': {'shots_against': 335, 'goals_against': 47, 'saves': 288, 'saves_pct': 0.86}, 'evenstrength': {'shots_against': 2054, 'goals_against': 225, 'saves': 1829, 'saves_pct': 0.89}, 'penalty': {'shots_against': 0, 'goals_against': 0, 'saves': 0, 'saves_pct': 0.0}, 'average': {'goals_against': 3.1, 'shots_against': 29.65}, 'emptynet': {'total': {'goals_against': 27, 'shots_against': 27}, 'powerplay': {'goals_against': 1}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 26}}, 'time_on_ice': {'total': '4949:18'}}}
# --------------------------------------------------
# Team Name: Ducks
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 203, 'assists': 351, 'penalties': 440, 'penalty_minutes': 1108, 'team_penalties': 17, 'team_penalty_minutes': 32, 'shots': 2194, 'blocked_att': 1175, 'missed_shots': 962, 'hits': 1912, 'giveaways': 579, 'takeaways': 502, 'blocked_shots': 1343, 'faceoffs_won': 2115, 'faceoffs_lost': 2419, 'powerplays': 235, 'shooting_pct': 9.3, 'faceoff_win_pct': 46.6, 'faceoffs': 4534, 'points': 554, 'plus_minus': -227, 'overtime_goals': 5, 'overtime_assists': 8, 'overtime_shots': 23, 'emptynet_goals': 7, 'penalties_major': 30, 'penalties_match': 0, 'penalties_minor': 371, 'penalties_misconduct': 16}, 'powerplay': {'faceoffs_won': 206, 'faceoffs_lost': 215, 'shots': 322, 'goals': 43, 'missed_shots': 129, 'assists': 79, 'faceoff_win_pct': 48.9, 'opportunities': 235, 'faceoffs': 421, 'percentage': 18.3, 'strength': [{'opportunities': 231, 'shots': 306, 'goals': 39, 'type': '5v4'}, {'opportunities': 7, 'shots': 11, 'goals': 2, 'type': '5v3'}, {'opportunities': 4, 'shots': 5, 'goals': 1, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 261, 'faceoffs_lost': 322, 'shots': 85, 'goals': 12, 'missed_shots': 19, 'assists': 12, 'faceoff_win_pct': 44.8, 'opportunities': 330, 'faceoffs': 583, 'goals_against': 91, 'kill_pct': 72.4, 'strength': [{'shots': 83, 'goals': 12, 'type': '4v5'}, {'shots': 1, 'goals': 0, 'type': '3v5'}, {'shots': 1, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1648, 'faceoffs_lost': 1882, 'shots': 1787, 'goals': 148, 'missed_shots': 814, 'assists': 260, 'faceoff_win_pct': 46.7, 'faceoffs': 3530, 'strength': [{'shots': 1721, 'goals': 138, 'type': '5v5'}, {'shots': 43, 'goals': 6, 'type': '4v4'}, {'shots': 23, 'goals': 5, 'type': '3v3'}]}, 'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 4.28, 'blocked_shots': 16.38, 'points': 6.76, 'blocked_att': 14.33, 'team_penalty_minutes': 0.39, 'penalties': 5.37, 'missed_shots': 11.73, 'hits': 23.32, 'shots': 26.76, 'takeaways': 6.12, 'giveaways': 7.06, 'goals': 2.48, 'team_penalties': 0.21, 'penalty_minutes': 13.51}}, 'shootout': {'shots': 7, 'missed_shots': 1, 'goals': 2, 'shots_against': 8, 'goals_against': 3, 'saves': 5, 'saves_pct': 0.625}, 'goaltending': {'total': {'shots_against': 2653, 'goals_against': 280, 'saves': 2373, 'total_goals_against': 293, 'total_shots_against': 2666, 'saves_pct': 0.89, 'losses': 50, 'overtime_losses': 5, 'shutouts': 1, 'wins': 27}, 'powerplay': {'shots_against': 59, 'goals_against': 4, 'saves': 55, 'saves_pct': 0.932}, 'shorthanded': {'shots_against': 559, 'goals_against': 90, 'saves': 469, 'saves_pct': 0.839}, 'evenstrength': {'shots_against': 2046, 'goals_against': 197, 'saves': 1849, 'saves_pct': 0.904}, 'penalty': {'shots_against': 0, 'goals_against': 0, 'saves': 0, 'saves_pct': 0.0}, 'average': {'goals_against': 3.41, 'shots_against': 32.35}, 'emptynet': {'total': {'goals_against': 13, 'shots_against': 13}, 'powerplay': {'goals_against': 1}, 'shorthanded': {'goals_against': 1}, 'evenstrength': {'goals_against': 11}}, 'time_on_ice': {'total': '4951:39'}}}
# --------------------------------------------------
# Team Name: Flames
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 253, 'assists': 433, 'penalties': 317, 'penalty_minutes': 757, 'team_penalties': 9, 'team_penalty_minutes': 18, 'shots': 2572, 'blocked_att': 1486, 'missed_shots': 1198, 'hits': 1749, 'giveaways': 811, 'takeaways': 621, 'blocked_shots': 1379, 'faceoffs_won': 2393, 'faceoffs_lost': 2429, 'powerplays': 252, 'shooting_pct': 9.8, 'faceoff_win_pct': 49.6, 'faceoffs': 4822, 'points': 686, 'plus_minus': -92, 'overtime_goals': 6, 'overtime_assists': 8, 'overtime_shots': 37, 'emptynet_goals': 18, 'penalties_major': 20, 'penalties_match': 1, 'penalties_minor': 278, 'penalties_misconduct': 7}, 'powerplay': {'faceoffs_won': 261, 'faceoffs_lost': 203, 'shots': 363, 'goals': 45, 'missed_shots': 184, 'assists': 89, 'faceoff_win_pct': 56.3, 'opportunities': 252, 'faceoffs': 464, 'percentage': 17.9, 'strength': [{'opportunities': 246, 'shots': 338, 'goals': 42, 'type': '5v4'}, {'opportunities': 8, 'shots': 14, 'goals': 1, 'type': '5v3'}, {'opportunities': 4, 'shots': 11, 'goals': 2, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 188, 'faceoffs_lost': 236, 'shots': 81, 'goals': 11, 'missed_shots': 25, 'assists': 13, 'faceoff_win_pct': 44.3, 'opportunities': 245, 'faceoffs': 424, 'goals_against': 47, 'kill_pct': 80.8, 'strength': [{'shots': 81, 'goals': 11, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1944, 'faceoffs_lost': 1990, 'shots': 2128, 'goals': 197, 'missed_shots': 989, 'assists': 331, 'faceoff_win_pct': 49.4, 'faceoffs': 3934, 'strength': [{'shots': 2054, 'goals': 186, 'type': '5v5'}, {'shots': 48, 'goals': 7, 'type': '4v4'}, {'shots': 26, 'goals': 4, 'type': '3v3'}]}, 'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 5.28, 'blocked_shots': 16.82, 'points': 8.37, 'blocked_att': 18.12, 'team_penalty_minutes': 0.22, 'penalties': 3.87, 'missed_shots': 14.61, 'hits': 21.33, 'shots': 31.37, 'takeaways': 7.57, 'giveaways': 9.89, 'goals': 3.09, 'team_penalties': 0.11, 'penalty_minutes': 9.23}}, 'shootout': {'shots': 13, 'missed_shots': 3, 'goals': 3, 'shots_against': 16, 'goals_against': 7, 'saves': 9, 'saves_pct': 0.563}, 'goaltending': {'total': {'shots_against': 2420, 'goals_against': 249, 'saves': 2171, 'total_goals_against': 267, 'total_shots_against': 2438, 'saves_pct': 0.89, 'losses': 39, 'overtime_losses': 5, 'shutouts': 2, 'wins': 38}, 'powerplay': {'shots_against': 78, 'goals_against': 11, 'saves': 67, 'saves_pct': 0.859}, 'shorthanded': {'shots_against': 345, 'goals_against': 47, 'saves': 298, 'saves_pct': 0.864}, 'evenstrength': {'shots_against': 2015, 'goals_against': 209, 'saves': 1806, 'saves_pct': 0.896}, 'penalty': {'shots_against': 2, 'goals_against': 1, 'saves': 1, 'saves_pct': 0.5}, 'average': {'goals_against': 3.04, 'shots_against': 29.51}, 'emptynet': {'total': {'goals_against': 18, 'shots_against': 18}, 'powerplay': {'goals_against': 0}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 18}}, 'time_on_ice': {'total': '4962:12'}}}
# --------------------------------------------------
# Team Name: Flyers
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 231, 'assists': 369, 'penalties': 321, 'penalty_minutes': 830, 'team_penalties': 10, 'team_penalty_minutes': 18, 'shots': 2708, 'blocked_att': 1425, 'missed_shots': 1119, 'hits': 2024, 'giveaways': 507, 'takeaways': 496, 'blocked_shots': 1533, 'faceoffs_won': 2321, 'faceoffs_lost': 2351, 'powerplays': 254, 'shooting_pct': 8.5, 'faceoff_win_pct': 49.7, 'faceoffs': 4672, 'points': 600, 'plus_minus': -120, 'overtime_goals': 4, 'overtime_assists': 4, 'overtime_shots': 40, 'emptynet_goals': 9, 'penalties_major': 24, 'penalties_match': 0, 'penalties_minor': 270, 'penalties_misconduct': 14}, 'powerplay': {'faceoffs_won': 230, 'faceoffs_lost': 185, 'shots': 380, 'goals': 31, 'missed_shots': 152, 'assists': 60, 'faceoff_win_pct': 55.4, 'opportunities': 254, 'faceoffs': 415, 'percentage': 12.2, 'strength': [{'opportunities': 247, 'shots': 359, 'goals': 29, 'type': '5v4'}, {'opportunities': 7, 'shots': 14, 'goals': 1, 'type': '5v3'}, {'opportunities': 2, 'shots': 7, 'goals': 1, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 183, 'faceoffs_lost': 230, 'shots': 112, 'goals': 16, 'missed_shots': 20, 'assists': 25, 'faceoff_win_pct': 44.3, 'opportunities': 241, 'faceoffs': 413, 'goals_against': 40, 'kill_pct': 83.4, 'strength': [{'shots': 112, 'goals': 16, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1908, 'faceoffs_lost': 1936, 'shots': 2216, 'goals': 184, 'missed_shots': 947, 'assists': 284, 'faceoff_win_pct': 49.6, 'faceoffs': 3844, 'strength': [{'shots': 2134, 'goals': 178, 'type': '5v5'}, {'shots': 46, 'goals': 3, 'type': '4v4'}, {'shots': 36, 'goals': 3, 'type': '3v3'}]}, 'penalty': {'shots': 5, 'goals': 5, 'missed_shots': 0}, 'average': {'assists': 4.5, 'blocked_shots': 18.7, 'points': 7.32, 'blocked_att': 17.38, 'team_penalty_minutes': 0.22, 'penalties': 3.91, 'missed_shots': 13.65, 'hits': 24.68, 'shots': 33.02, 'takeaways': 6.05, 'giveaways': 6.18, 'goals': 2.82, 'team_penalties': 0.12, 'penalty_minutes': 10.12}}, 'shootout': {'shots': 16, 'missed_shots': 6, 'goals': 6, 'shots_against': 22, 'goals_against': 6, 'saves': 16, 'saves_pct': 0.727}, 'goaltending': {'total': {'shots_against': 2212, 'goals_against': 245, 'saves': 1967, 'total_goals_against': 258, 'total_shots_against': 2225, 'saves_pct': 0.884, 'losses': 33, 'overtime_losses': 11, 'shutouts': 5, 'wins': 38}, 'powerplay': {'shots_against': 80, 'goals_against': 4, 'saves': 76, 'saves_pct': 0.95}, 'shorthanded': {'shots_against': 299, 'goals_against': 40, 'saves': 259, 'saves_pct': 0.866}, 'evenstrength': {'shots_against': 1846, 'goals_against': 214, 'saves': 1632, 'saves_pct': 0.884}, 'penalty': {'shots_against': 0, 'goals_against': 0, 'saves': 0, 'saves_pct': 0.0}, 'average': {'goals_against': 2.99, 'shots_against': 26.98}, 'emptynet': {'total': {'goals_against': 13, 'shots_against': 13}, 'powerplay': {'goals_against': 0}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 13}}, 'time_on_ice': {'total': '4976:52'}}}
# --------------------------------------------------
# Team Name: Golden Knights
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 263, 'assists': 459, 'penalties': 248, 'penalty_minutes': 605, 'team_penalties': 8, 'team_penalty_minutes': 16, 'shots': 2548, 'blocked_att': 1432, 'missed_shots': 1002, 'hits': 2022, 'giveaways': 565, 'takeaways': 690, 'blocked_shots': 1506, 'faceoffs_won': 2314, 'faceoffs_lost': 2296, 'powerplays': 252, 'shooting_pct': 10.3, 'faceoff_win_pct': 50.2, 'faceoffs': 4610, 'points': 722, 'plus_minus': 40, 'overtime_goals': 7, 'overtime_assists': 12, 'overtime_shots': 29, 'emptynet_goals': 18, 'penalties_major': 15, 'penalties_match': 2, 'penalties_minor': 216, 'penalties_misconduct': 4}, 'powerplay': {'faceoffs_won': 255, 'faceoffs_lost': 199, 'shots': 385, 'goals': 51, 'missed_shots': 137, 'assists': 98, 'faceoff_win_pct': 56.2, 'opportunities': 252, 'faceoffs': 454, 'percentage': 20.2, 'strength': [{'opportunities': 245, 'shots': 377, 'goals': 49, 'type': '5v4'}, {'opportunities': 8, 'shots': 5, 'goals': 1, 'type': '5v3'}, {'opportunities': 2, 'shots': 3, 'goals': 1, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 152, 'faceoffs_lost': 204, 'shots': 64, 'goals': 9, 'missed_shots': 20, 'assists': 11, 'faceoff_win_pct': 42.7, 'opportunities': 213, 'faceoffs': 356, 'goals_against': 44, 'kill_pct': 79.3, 'strength': [{'shots': 64, 'goals': 9, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1907, 'faceoffs_lost': 1893, 'shots': 2099, 'goals': 203, 'missed_shots': 845, 'assists': 350, 'faceoff_win_pct': 50.2, 'faceoffs': 3800, 'strength': [{'shots': 2055, 'goals': 194, 'type': '5v5'}, {'shots': 18, 'goals': 3, 'type': '4v4'}, {'shots': 26, 'goals': 6, 'type': '3v3'}]}, 'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 5.6, 'blocked_shots': 18.37, 'points': 8.8, 'blocked_att': 17.46, 'team_penalty_minutes': 0.2, 'penalties': 3.02, 'missed_shots': 12.22, 'hits': 24.66, 'shots': 31.07, 'takeaways': 8.41, 'giveaways': 6.89, 'goals': 3.21, 'team_penalties': 0.1, 'penalty_minutes': 7.38}}, 'shootout': {'shots': 13, 'missed_shots': 4, 'goals': 7, 'shots_against': 17, 'goals_against': 5, 'saves': 12, 'saves_pct': 0.706}, 'goaltending': {'total': {'shots_against': 2473, 'goals_against': 229, 'saves': 2244, 'total_goals_against': 243, 'total_shots_against': 2487, 'saves_pct': 0.902, 'losses': 29, 'overtime_losses': 8, 'shutouts': 3, 'wins': 45}, 'powerplay': {'shots_against': 78, 'goals_against': 7, 'saves': 71, 'saves_pct': 0.91}, 'shorthanded': {'shots_against': 337, 'goals_against': 44, 'saves': 293, 'saves_pct': 0.869}, 'evenstrength': {'shots_against': 2071, 'goals_against': 191, 'saves': 1880, 'saves_pct': 0.908}, 'penalty': {'shots_against': 1, 'goals_against': 0, 'saves': 1, 'saves_pct': 1.0}, 'average': {'goals_against': 2.79, 'shots_against': 30.16}, 'emptynet': {'total': {'goals_against': 14, 'shots_against': 14}, 'powerplay': {'goals_against': 1}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 13}}, 'time_on_ice': {'total': '4975:15'}}}
# --------------------------------------------------
# Team Name: Hurricanes
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 277, 'assists': 485, 'penalties': 300, 'penalty_minutes': 693, 'team_penalties': 11, 'team_penalty_minutes': 22, 'shots': 2733, 'blocked_att': 1663, 'missed_shots': 1423, 'hits': 1384, 'giveaways': 680, 'takeaways': 621, 'blocked_shots': 937, 'faceoffs_won': 2551, 'faceoffs_lost': 2302, 'powerplays': 249, 'shooting_pct': 10.1, 'faceoff_win_pct': 52.6, 'faceoffs': 4853, 'points': 762, 'plus_minus': 143, 'overtime_goals': 6, 'overtime_assists': 11, 'overtime_shots': 21, 'emptynet_goals': 19, 'penalties_major': 9, 'penalties_match': 0, 'penalties_minor': 268, 'penalties_misconduct': 7}, 'powerplay': {'faceoffs_won': 253, 'faceoffs_lost': 190, 'shots': 391, 'goals': 67, 'missed_shots': 152, 'assists': 124, 'faceoff_win_pct': 57.1, 'opportunities': 249, 'faceoffs': 443, 'percentage': 26.9, 'strength': [{'opportunities': 245, 'shots': 382, 'goals': 65, 'type': '5v4'}, {'opportunities': 6, 'shots': 7, 'goals': 1, 'type': '5v3'}, {'opportunities': 2, 'shots': 2, 'goals': 1, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 213, 'faceoffs_lost': 225, 'shots': 94, 'goals': 11, 'missed_shots': 23, 'assists': 13, 'faceoff_win_pct': 48.6, 'opportunities': 258, 'faceoffs': 438, 'goals_against': 35, 'kill_pct': 86.4, 'strength': [{'shots': 94, 'goals': 11, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 2085, 'faceoffs_lost': 1887, 'shots': 2248, 'goals': 199, 'missed_shots': 1248, 'assists': 348, 'faceoff_win_pct': 52.5, 'faceoffs': 3972, 'strength': [{'shots': 2203, 'goals': 189, 'type': '5v5'}, {'shots': 24, 'goals': 4, 'type': '4v4'}, {'shots': 21, 'goals': 6, 'type': '3v3'}]}, 'penalty': {'shots': 2, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 5.91, 'blocked_shots': 11.43, 'points': 9.29, 'blocked_att': 20.28, 'team_penalty_minutes': 0.27, 'penalties': 3.66, 'missed_shots': 17.35, 'hits': 16.88, 'shots': 33.33, 'takeaways': 7.57, 'giveaways': 8.29, 'goals': 3.38, 'team_penalties': 0.13, 'penalty_minutes': 8.45}}, 'shootout': {'shots': 24, 'missed_shots': 8, 'goals': 5, 'shots_against': 31, 'goals_against': 8, 'saves': 23, 'saves_pct': 0.742}, 'goaltending': {'total': {'shots_against': 2089, 'goals_against': 199, 'saves': 1890, 'total_goals_against': 211, 'total_shots_against': 2101, 'saves_pct': 0.9, 'losses': 23, 'overtime_losses': 7, 'shutouts': 8, 'wins': 52}, 'powerplay': {'shots_against': 68, 'goals_against': 7, 'saves': 61, 'saves_pct': 0.897}, 'shorthanded': {'shots_against': 272, 'goals_against': 35, 'saves': 237, 'saves_pct': 0.871}, 'evenstrength': {'shots_against': 1760, 'goals_against': 168, 'saves': 1592, 'saves_pct': 0.905}, 'penalty': {'shots_against': 1, 'goals_against': 0, 'saves': 1, 'saves_pct': 1.0}, 'average': {'goals_against': 2.43, 'shots_against': 25.48}, 'emptynet': {'total': {'goals_against': 12, 'shots_against': 12}, 'powerplay': {'goals_against': 1}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 11}}, 'time_on_ice': {'total': '4972:42'}}}
# --------------------------------------------------
# Team Name: Islanders
# ...
# --------------------------------------------------
# Team Name: Sabres
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 244, 'assists': 391, 'penalties': 309, 'penalty_minutes': 789, 'team_penalties': 7, 'team_penalty_minutes': 14, 'shots': 2534, 'blocked_att': 1335, 'missed_shots': 1056, 'hits': 1788, 'giveaways': 491, 'takeaways': 542, 'blocked_shots': 1201, 'faceoffs_won': 2054, 'faceoffs_lost': 2508, 'powerplays': 223, 'shooting_pct': 9.6, 'faceoff_win_pct': 45.0, 'faceoffs': 4562, 'points': 635, 'plus_minus': 52, 'overtime_goals': 4, 'overtime_assists': 8, 'overtime_shots': 26, 'emptynet_goals': 17, 'penalties_major': 17, 'penalties_match': 2, 'penalties_minor': 267, 'penalties_misconduct': 13}, 'powerplay': {'faceoffs_won': 194, 'faceoffs_lost': 211, 'shots': 347, 'goals': 37, 'missed_shots': 125, 'assists': 69, 'faceoff_win_pct': 47.9, 'opportunities': 223, 'faceoffs': 405, 'percentage': 16.6, 'strength': [{'opportunities': 218, 'shots': 334, 'goals': 35, 'type': '5v4'}, {'opportunities': 8, 'shots': 11, 'goals': 1, 'type': '5v3'}, {'opportunities': 3, 'shots': 2, 'goals': 1, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 175, 'faceoffs_lost': 270, 'shots': 74, 'goals': 7, 'missed_shots': 14, 'assists': 3, 'faceoff_win_pct': 39.3, 'opportunities': 243, 'faceoffs': 445, 'goals_against': 49, 'kill_pct': 79.8, 'strength': [{'shots': 73, 'goals': 7, 'type': '4v5'}, {'shots': 1, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1685, 'faceoffs_lost': 2027, 'shots': 2113, 'goals': 200, 'missed_shots': 917, 'assists': 319, 'faceoff_win_pct': 45.4, 'faceoffs': 3712, 'strength': [{'shots': 2053, 'goals': 194, 'type': '5v5'}, {'shots': 35, 'goals': 3, 'type': '4v4'}, {'shots': 25, 'goals': 3, 'type': '3v3'}]}, 'penalty': {'shots': 1, 'goals': 1, 'missed_shots': 0}, 'average': {'assists': 4.77, 'blocked_shots': 14.65, 'points': 7.74, 'blocked_att': 16.28, 'team_penalty_minutes': 0.17, 'penalties': 3.77, 'missed_shots': 12.88, 'hits': 21.8, 'shots': 30.9, 'takeaways': 6.61, 'giveaways': 5.99, 'goals': 2.98, 'team_penalties': 0.09, 'penalty_minutes': 9.62}}, 'shootout': {'shots': 11, 'missed_shots': 0, 'goals': 5, 'shots_against': 11, 'goals_against': 4, 'saves': 7, 'saves_pct': 0.636}, 'goaltending': {'total': {'shots_against': 2391, 'goals_against': 231, 'saves': 2160, 'total_goals_against': 243, 'total_shots_against': 2403, 'saves_pct': 0.899, 'losses': 37, 'overtime_losses': 6, 'shutouts': 5, 'wins': 39}, 'powerplay': {'shots_against': 62, 'goals_against': 9, 'saves': 53, 'saves_pct': 0.855}, 'shorthanded': {'shots_against': 390, 'goals_against': 49, 'saves': 341, 'saves_pct': 0.874}, 'evenstrength': {'shots_against': 1950, 'goals_against': 184, 'saves': 1766, 'saves_pct': 0.906}, 'penalty': {'shots_against': 0, 'goals_against': 0, 'saves': 0, 'saves_pct': 0.0}, 'average': {'goals_against': 2.82, 'shots_against': 29.16}, 'emptynet': {'total': {'goals_against': 12, 'shots_against': 12}, 'powerplay': {'goals_against': 1}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 11}}, 'time_on_ice': {'total': '4958:25'}}}
# --------------------------------------------------
# Team Name: Senators
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 250, 'assists': 421, 'penalties': 336, 'penalty_minutes': 845, 'team_penalties': 7, 'team_penalty_minutes': 14, 'shots': 2602, 'blocked_att': 1427, 'missed_shots': 1159, 'hits': 1998, 'giveaways': 797, 'takeaways': 597, 'blocked_shots': 1356, 'faceoffs_won': 2376, 'faceoffs_lost': 2284, 'powerplays': 283, 'shooting_pct': 9.6, 'faceoff_win_pct': 51.0, 'faceoffs': 4660, 'points': 671, 'plus_minus': -119, 'overtime_goals': 7, 'overtime_assists': 12, 'overtime_shots': 41, 'emptynet_goals': 13, 'penalties_major': 24, 'penalties_match': 1, 'penalties_minor': 291, 'penalties_misconduct': 12}, 'powerplay': {'faceoffs_won': 288, 'faceoffs_lost': 201, 'shots': 429, 'goals': 51, 'missed_shots': 206, 'assists': 101, 'faceoff_win_pct': 58.9, 'opportunities': 283, 'faceoffs': 489, 'percentage': 18.0, 'strength': [{'opportunities': 272, 'shots': 401, 'goals': 48, 'type': '5v4'}, {'opportunities': 9, 'shots': 13, 'goals': 0, 'type': '5v3'}, {'opportunities': 12, 'shots': 15, 'goals': 3, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 238, 'faceoffs_lost': 206, 'shots': 83, 'goals': 7, 'missed_shots': 17, 'assists': 6, 'faceoff_win_pct': 53.6, 'opportunities': 245, 'faceoffs': 444, 'goals_against': 61, 'kill_pct': 75.1, 'strength': [{'shots': 81, 'goals': 7, 'type': '4v5'}, {'shots': 1, 'goals': 0, 'type': '3v5'}, {'shots': 1, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1850, 'faceoffs_lost': 1877, 'shots': 2090, 'goals': 192, 'missed_shots': 936, 'assists': 314, 'faceoff_win_pct': 49.6, 'faceoffs': 3727, 'strength': [{'shots': 2012, 'goals': 178, 'type': '5v5'}, {'shots': 44, 'goals': 8, 'type': '4v4'}, {'shots': 34, 'goals': 6, 'type': '3v3'}]}, 'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 5.13, 'blocked_shots': 16.54, 'points': 8.18, 'blocked_att': 17.4, 'team_penalty_minutes': 0.17, 'penalties': 4.1, 'missed_shots': 14.13, 'hits': 24.37, 'shots': 31.73, 'takeaways': 7.28, 'giveaways': 9.72, 'goals': 3.05, 'team_penalties': 0.09, 'penalty_minutes': 10.3}}, 'shootout': {'shots': 12, 'missed_shots': 2, 'goals': 6, 'shots_against': 15, 'goals_against': 1, 'saves': 14, 'saves_pct': 0.933}, 'goaltending': {'total': {'shots_against': 2422, 'goals_against': 271, 'saves': 2151, 'total_goals_against': 281, 'total_shots_against': 2432, 'saves_pct': 0.884, 'losses': 41, 'overtime_losses': 4, 'shutouts': 2, 'wins': 37}, 'powerplay': {'shots_against': 71, 'goals_against': 5, 'saves': 66, 'saves_pct': 0.93}, 'shorthanded': {'shots_against': 350, 'goals_against': 61, 'saves': 289, 'saves_pct': 0.826}, 'evenstrength': {'shots_against': 2010, 'goals_against': 214, 'saves': 1796, 'saves_pct': 0.894}, 'penalty': {'shots_against': 3, 'goals_against': 1, 'saves': 2, 'saves_pct': 0.667}, 'average': {'goals_against': 3.3, 'shots_against': 29.54}, 'emptynet': {'total': {'goals_against': 10, 'shots_against': 10}, 'powerplay': {'goals_against': 1}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 9}}, 'time_on_ice': {'total': '4974:57'}}}
# --------------------------------------------------
# Team Name: Sharks
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 180, 'assists': 300, 'penalties': 312, 'penalty_minutes': 780, 'team_penalties': 6, 'team_penalty_minutes': 12, 'shots': 2069, 'blocked_att': 1295, 'missed_shots': 1006, 'hits': 1870, 'giveaways': 451, 'takeaways': 544, 'blocked_shots': 1491, 'faceoffs_won': 2300, 'faceoffs_lost': 2390, 'powerplays': 208, 'shooting_pct': 8.7, 'faceoff_win_pct': 49.0, 'faceoffs': 4690, 'points': 480, 'plus_minus': -645, 'overtime_goals': 4, 'overtime_assists': 5, 'overtime_shots': 22, 'emptynet_goals': 4, 'penalties_major': 20, 'penalties_match': 0, 'penalties_minor': 271, 'penalties_misconduct': 11}, 'powerplay': {'faceoffs_won': 184, 'faceoffs_lost': 167, 'shots': 248, 'goals': 42, 'missed_shots': 135, 'assists': 80, 'faceoff_win_pct': 52.4, 'opportunities': 208, 'faceoffs': 351, 'percentage': 20.2, 'strength': [{'opportunities': 199, 'shots': 235, 'goals': 39, 'type': '5v4'}, {'opportunities': 5, 'shots': 2, 'goals': 0, 'type': '5v3'}, {'opportunities': 9, 'shots': 11, 'goals': 3, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 212, 'faceoffs_lost': 245, 'shots': 54, 'goals': 3, 'missed_shots': 14, 'assists': 4, 'faceoff_win_pct': 46.4, 'opportunities': 252, 'faceoffs': 457, 'goals_against': 62, 'kill_pct': 75.4, 'strength': [{'shots': 54, 'goals': 3, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1904, 'faceoffs_lost': 1978, 'shots': 1767, 'goals': 135, 'missed_shots': 857, 'assists': 216, 'faceoff_win_pct': 49.0, 'faceoffs': 3882, 'strength': [{'shots': 1724, 'goals': 130, 'type': '5v5'}, {'shots': 23, 'goals': 1, 'type': '4v4'}, {'shots': 20, 'goals': 4, 'type': '3v3'}]}, 'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0}, 'average': {'assists': 3.66, 'blocked_shots': 18.18, 'points': 5.85, 'blocked_att': 15.79, 'team_penalty_minutes': 0.15, 'penalties': 3.8, 'missed_shots': 12.27, 'hits': 22.8, 'shots': 25.23, 'takeaways': 6.63, 'giveaways': 5.5, 'goals': 2.2, 'team_penalties': 0.07, 'penalty_minutes': 9.51}}, 'shootout': {'shots': 22, 'missed_shots': 5, 'goals': 5, 'shots_against': 29, 'goals_against': 9, 'saves': 20, 'saves_pct': 0.69}, 'goaltending': {'total': {'shots_against': 2863, 'goals_against': 308, 'saves': 2555, 'total_goals_against': 326, 'total_shots_against': 2881, 'saves_pct': 0.887, 'losses': 54, 'overtime_losses': 9, 'shutouts': 2, 'wins': 19}, 'powerplay': {'shots_against': 83, 'goals_against': 6, 'saves': 77, 'saves_pct': 0.928}, 'shorthanded': {'shots_against': 428, 'goals_against': 62, 'saves': 366, 'saves_pct': 0.855}, 'evenstrength': {'shots_against': 2368, 'goals_against': 256, 'saves': 2112, 'saves_pct': 0.892}, 'penalty': {'shots_against': 1, 'goals_against': 0, 'saves': 1, 'saves_pct': 1.0}, 'average': {'goals_against': 3.76, 'shots_against': 34.91}, 'emptynet': {'total': {'goals_against': 18, 'shots_against': 18}, 'powerplay': {'goals_against': 2}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 16}}, 'time_on_ice': {'total': '4970:09'}}}
# --------------------------------------------------
# Team Name: Stars
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 294, 'assists': 505, 'penalties': 256, 'penalty_minutes': 554, 'team_penalties': 8, 'team_penalty_minutes': 16, 'shots': 2588, 'blocked_att': 1503, 'missed_shots': 1210, 'hits': 1458, 'giveaways': 668, 'takeaways': 560, 'blocked_shots': 1225, 'faceoffs_won': 2617, 'faceoffs_lost': 2228, 'powerplays': 240, 'shooting_pct': 11.4, 'faceoff_win_pct': 54.0, 'faceoffs': 4845, 'points': 799, 'plus_minus': 219, 'overtime_goals': 8, 'overtime_assists': 13, 'overtime_shots': 32, 'emptynet_goals': 13, 'penalties_major': 8, 'penalties_match': 0, 'penalties_minor': 234, 'penalties_misconduct': 1}, 'powerplay': {'faceoffs_won': 238, 'faceoffs_lost': 171, 'shots': 360, 'goals': 58, 'missed_shots': 146, 'assists': 113, 'faceoff_win_pct': 58.2, 'opportunities': 240, 'faceoffs': 409, 'percentage': 24.2, 'strength': [{'opportunities': 231, 'shots': 341, 'goals': 57, 'type': '5v4'}, {'opportunities': 8, 'shots': 14, 'goals': 1, 'type': '5v3'}, {'opportunities': 3, 'shots': 5, 'goals': 0, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 185, 'faceoffs_lost': 221, 'shots': 73, 'goals': 12, 'missed_shots': 17, 'assists': 10, 'faceoff_win_pct': 45.6, 'opportunities': 239, 'faceoffs': 406, 'goals_against': 43, 'kill_pct': 82.0, 'strength': [{'shots': 72, 'goals': 12, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 1, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 2194, 'faceoffs_lost': 1836, 'shots': 2155, 'goals': 224, 'missed_shots': 1047, 'assists': 382, 'faceoff_win_pct': 54.4, 'faceoffs': 4030, 'strength': [{'shots': 2113, 'goals': 212, 'type': '5v5'}, {'shots': 15, 'goals': 4, 'type': '4v4'}, {'shots': 27, 'goals': 8, 'type': '3v3'}]}, 'penalty': {'shots': 4, 'goals': 2, 'missed_shots': 0}, 'average': {'assists': 6.16, 'blocked_shots': 14.94, 'points': 9.74, 'blocked_att': 18.33, 'team_penalty_minutes': 0.2, 'penalties': 3.12, 'missed_shots': 14.76, 'hits': 17.78, 'shots': 31.56, 'takeaways': 6.83, 'giveaways': 8.15, 'goals': 3.59, 'team_penalties': 0.1, 'penalty_minutes': 6.76}}, 'shootout': {'shots': 22, 'missed_shots': 4, 'goals': 8, 'shots_against': 27, 'goals_against': 6, 'saves': 21, 'saves_pct': 0.778}, 'goaltending': {'total': {'shots_against': 2343, 'goals_against': 225, 'saves': 2118, 'total_goals_against': 232, 'total_shots_against': 2350, 'saves_pct': 0.901, 'losses': 21, 'overtime_losses': 9, 'shutouts': 4, 'wins': 52}, 'powerplay': {'shots_against': 70, 'goals_against': 4, 'saves': 66, 'saves_pct': 0.943}, 'shorthanded': {'shots_against': 352, 'goals_against': 43, 'saves': 309, 'saves_pct': 0.878}, 'evenstrength': {'shots_against': 1928, 'goals_against': 185, 'saves': 1743, 'saves_pct': 0.904}, 'penalty': {'shots_against': 1, 'goals_against': 1, 'saves': 0, 'saves_pct': 0.0}, 'average': {'goals_against': 2.74, 'shots_against': 28.57}, 'emptynet': {'total': {'goals_against': 7, 'shots_against': 7}, 'powerplay': {'goals_against': 0}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 7}}, 'time_on_ice': {'total': '4982:07'}}}
# --------------------------------------------------
# Team Name: Wild
# Own Record: {'statistics': {'total': {'games_played': 82, 'goals': 248, 'assists': 424, 'penalties': 351, 'penalty_minutes': 938, 'team_penalties': 6, 'team_penalty_minutes': 12, 'shots': 2471, 'blocked_att': 1401, 'missed_shots': 1131, 'hits': 1600, 'giveaways': 526, 'takeaways': 497, 'blocked_shots': 1305, 'faceoffs_won': 2192, 'faceoffs_lost': 2441, 'powerplays': 273, 'shooting_pct': 10.0, 'faceoff_win_pct': 47.3, 'faceoffs': 4633, 'points': 672, 'plus_minus': -43, 'overtime_goals': 4, 'overtime_assists': 7, 'overtime_shots': 26, 'emptynet_goals': 14, 'penalties_major': 36, 'penalties_match': 0, 'penalties_minor': 290, 'penalties_misconduct': 15}, 'powerplay': {'faceoffs_won': 292, 'faceoffs_lost': 225, 'shots': 527, 'goals': 62, 'missed_shots': 229, 'assists': 120, 'faceoff_win_pct': 56.5, 'opportunities': 273, 'faceoffs': 517, 'percentage': 22.7, 'strength': [{'opportunities': 265, 'shots': 500, 'goals': 54, 'type': '5v4'}, {'opportunities': 15, 'shots': 25, 'goals': 7, 'type': '5v3'}, {'opportunities': 2, 'shots': 2, 'goals': 1, 'type': '4v3'}]}, 'shorthanded': {'faceoffs_won': 204, 'faceoffs_lost': 255, 'shots': 56, 'goals': 3, 'missed_shots': 12, 'assists': 3, 'faceoff_win_pct': 44.4, 'opportunities': 263, 'faceoffs': 459, 'goals_against': 67, 'kill_pct': 74.5, 'strength': [{'shots': 56, 'goals': 3, 'type': '4v5'}, {'shots': 0, 'goals': 0, 'type': '3v5'}, {'shots': 0, 'goals': 0, 'type': '3v4'}]}, 'evenstrength': {'faceoffs_won': 1696, 'faceoffs_lost': 1961, 'shots': 1888, 'goals': 183, 'missed_shots': 890, 'assists': 301, 'faceoff_win_pct': 46.4, 'faceoffs': 3657, 'strength': [{'shots': 1843, 'goals': 176, 'type': '5v5'}, {'shots': 19, 'goals': 3, 'type': '4v4'}, {'shots': 26, 'goals': 4, 'type': '3v3'}]}, 'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 1}, 'average': {'assists': 5.17, 'blocked_shots': 15.91, 'points': 8.2, 'blocked_att': 17.09, 'team_penalty_minutes': 0.15, 'penalties': 4.28, 'missed_shots': 13.79, 'hits': 19.51, 'shots': 30.13, 'takeaways': 6.06, 'giveaways': 6.41, 'goals': 3.02, 'team_penalties': 0.07, 'penalty_minutes': 11.44}}, 'shootout': {'shots': 18, 'missed_shots': 6, 'goals': 6, 'shots_against': 24, 'goals_against': 6, 'saves': 18, 'saves_pct': 0.75}, 'goaltending': {'total': {'shots_against': 2426, 'goals_against': 249, 'saves': 2177, 'total_goals_against': 260, 'total_shots_against': 2437, 'saves_pct': 0.893, 'losses': 34, 'overtime_losses': 9, 'shutouts': 6, 'wins': 39}, 'powerplay': {'shots_against': 56, 'goals_against': 9, 'saves': 47, 'saves_pct': 0.839}, 'shorthanded': {'shots_against': 456, 'goals_against': 67, 'saves': 389, 'saves_pct': 0.853}, 'evenstrength': {'shots_against': 1923, 'goals_against': 182, 'saves': 1741, 'saves_pct': 0.905}, 'penalty': {'shots_against': 0, 'goals_against': 0, 'saves': 0, 'saves_pct': 0.0}, 'average': {'goals_against': 3.04, 'shots_against': 29.59}, 'emptynet': {'total': {'goals_against': 11, 'shots_against': 11}, 'powerplay': {'goals_against': 2}, 'shorthanded': {'goals_against': 0}, 'evenstrength': {'goals_against': 9}}, 'time_on_ice': {'total': '4984:12'}}}
# --------------------------------------------------

# %%
# Make sure have all the team
number_of_teams = len(team_stats_data)
print(f"Total number of teams: {number_of_teams}")
# Out:
# Total number of teams: 32

# %%
team_name_and_records
# Out:
# {'Avalanche': {'statistics': {'total': {'games_played': 82,
#     'goals': 302,
#     'assists': 525,
#     'penalties': 307,
#     'penalty_minutes': 731,
#     'team_penalties': 13,
#     'team_penalty_minutes': 26,
#     'shots': 2705,
#     'blocked_att': 1506,
#     'missed_shots': 1119,
#     'hits': 1671,
#     'giveaways': 603,
#     'takeaways': 647,
#     'blocked_shots': 1214,
#     'faceoffs_won': 2297,
#     'faceoffs_lost': 2494,
#     'powerplays': 278,
#     'shooting_pct': 11.2,
#     'faceoff_win_pct': 47.9,
#     'faceoffs': 4791,
#     'points': 827,
#     'plus_minus': 159,
#     'overtime_goals': 6,
#     'overtime_assists': 11,
#     'overtime_shots': 30,
#     'emptynet_goals': 19,
#     'penalties_major': 11,
#     'penalties_match': 0,
#     'penalties_minor': 268,
#     'penalties_misconduct': 9},
#    'powerplay': {'faceoffs_won': 255,
#     'faceoffs_lost': 208,
#     'shots': 443,
#     'goals': 68,
#     'missed_shots': 177,
#     'assists': 134,
#     'faceoff_win_pct': 55.1,
#     'opportunities': 278,
#     'faceoffs': 463,
#     'percentage': 24.5,
#     'strength': [{'opportunities': 266,
#       'shots': 424,
#       'goals': 62,
#       'type': '5v4'},
#      {'opportunities': 9, 'shots': 5, 'goals': 2, 'type': '5v3'},
#      {'opportunities': 10, 'shots': 14, 'goals': 4, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 183,
#     'faceoffs_lost': 276,
#     'shots': 72,
#     'goals': 7,
#     'missed_shots': 21,
#     'assists': 12,
#     'faceoff_win_pct': 39.9,
#     'opportunities': 264,
#     'faceoffs': 459,
#     'goals_against': 53,
#     'kill_pct': 79.9,
#     'strength': [{'shots': 72, 'goals': 7, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1859,
#     'faceoffs_lost': 2010,
#     'shots': 2190,
#     'goals': 227,
#     'missed_shots': 921,
#     'assists': 379,
#     'faceoff_win_pct': 48.0,
#     'faceoffs': 3869,
#     'strength': [{'shots': 2133, 'goals': 217, 'type': '5v5'},
#      {'shots': 32, 'goals': 7, 'type': '4v4'},
#      {'shots': 25, 'goals': 3, 'type': '3v3'}]},
#    'penalty': {'shots': 2, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 6.4,
#     'blocked_shots': 14.8,
#     'points': 10.09,
#     'blocked_att': 18.37,
#     'team_penalty_minutes': 0.32,
#     'penalties': 3.74,
#     'missed_shots': 13.65,
#     'hits': 20.38,
#     'shots': 32.99,
#     'takeaways': 7.89,
#     'giveaways': 7.35,
#     'goals': 3.68,
#     'team_penalties': 0.16,
#     'penalty_minutes': 8.91}},
#   'shootout': {'shots': 9,
#    'missed_shots': 1,
#    'goals': 2,
#    'shots_against': 11,
#    'goals_against': 3,
#    'saves': 8,
#    'saves_pct': 0.727},
#   'goaltending': {'total': {'shots_against': 2432,
#     'goals_against': 239,
#     'saves': 2193,
#     'total_goals_against': 252,
#     'total_shots_against': 2445,
#     'saves_pct': 0.897,
#     'losses': 25,
#     'overtime_losses': 7,
#     'shutouts': 4,
#     'wins': 50},
#    'powerplay': {'shots_against': 76,
#     'goals_against': 6,
#     'saves': 70,
#     'saves_pct': 0.921},
#    'shorthanded': {'shots_against': 397,
#     'goals_against': 53,
#     'saves': 344,
#     'saves_pct': 0.866},
#    'evenstrength': {'shots_against': 1972,
#     'goals_against': 193,
#     'saves': 1779,
#     'saves_pct': 0.902},
#    'penalty': {'shots_against': 1,
#     'goals_against': 1,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 2.91, 'shots_against': 29.66},
#    'emptynet': {'total': {'goals_against': 13, 'shots_against': 13},
#     'powerplay': {'goals_against': 0},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 13}},
#    'time_on_ice': {'total': '4969:24'}}},
#  'Blackhawks': {'statistics': {'total': {'games_played': 82,
#     'goals': 178,
#     'assists': 303,
#     'penalties': 292,
#     'penalty_minutes': 715,
#     'team_penalties': 7,
#     'team_penalty_minutes': 14,
#     'shots': 2153,
#     'blocked_att': 1210,
#     'missed_shots': 893,
#     'hits': 1874,
#     'giveaways': 747,
#     'takeaways': 714,
#     'blocked_shots': 1340,
#     'faceoffs_won': 2029,
#     'faceoffs_lost': 2357,
#     'powerplays': 235,
#     'shooting_pct': 8.3,
#     'faceoff_win_pct': 46.3,
#     'faceoffs': 4386,
#     'points': 481,
#     'plus_minus': -483,
#     'overtime_goals': 5,
#     'overtime_assists': 7,
#     'overtime_shots': 19,
#     'emptynet_goals': 6,
#     'penalties_major': 27,
#     'penalties_match': 0,
#     'penalties_minor': 251,
#     'penalties_misconduct': 6},
#    'powerplay': {'faceoffs_won': 196,
#     'faceoffs_lost': 193,
#     'shots': 314,
#     'goals': 39,
#     'missed_shots': 144,
#     'assists': 74,
#     'faceoff_win_pct': 50.4,
#     'opportunities': 235,
#     'faceoffs': 389,
#     'percentage': 16.6,
#     'strength': [{'opportunities': 228,
#       'shots': 294,
#       'goals': 33,
#       'type': '5v4'},
#      {'opportunities': 7, 'shots': 14, 'goals': 4, 'type': '5v3'},
#      {'opportunities': 4, 'shots': 6, 'goals': 2, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 167,
#     'faceoffs_lost': 245,
#     'shots': 65,
#     'goals': 3,
#     'missed_shots': 17,
#     'assists': 1,
#     'faceoff_win_pct': 40.5,
#     'opportunities': 231,
#     'faceoffs': 412,
#     'goals_against': 56,
#     'kill_pct': 75.8,
#     'strength': [{'shots': 65, 'goals': 3, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1666,
#     'faceoffs_lost': 1919,
#     'shots': 1774,
#     'goals': 136,
#     'missed_shots': 732,
#     'assists': 228,
#     'faceoff_win_pct': 46.5,
#     'faceoffs': 3585,
#     'strength': [{'shots': 1740, 'goals': 128, 'type': '5v5'},
#      {'shots': 19, 'goals': 4, 'type': '4v4'},
#      {'shots': 15, 'goals': 4, 'type': '3v3'}]},
#    'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 3.7,
#     'blocked_shots': 16.34,
#     'points': 5.87,
#     'blocked_att': 14.76,
#     'team_penalty_minutes': 0.17,
#     'penalties': 3.56,
#     'missed_shots': 10.89,
#     'hits': 22.85,
#     'shots': 26.26,
#     'takeaways': 8.71,
#     'giveaways': 9.11,
#     'goals': 2.17,
#     'team_penalties': 0.09,
#     'penalty_minutes': 8.72}},
#   'shootout': {'shots': 7,
#    'missed_shots': 4,
#    'goals': 3,
#    'shots_against': 10,
#    'goals_against': 4,
#    'saves': 6,
#    'saves_pct': 0.6},
#   'goaltending': {'total': {'shots_against': 2667,
#     'goals_against': 274,
#     'saves': 2393,
#     'total_goals_against': 289,
#     'total_shots_against': 2682,
#     'saves_pct': 0.892,
#     'losses': 53,
#     'overtime_losses': 6,
#     'shutouts': 1,
#     'wins': 23},
#    'powerplay': {'shots_against': 54,
#     'goals_against': 7,
#     'saves': 47,
#     'saves_pct': 0.87},
#    'shorthanded': {'shots_against': 330,
#     'goals_against': 56,
#     'saves': 274,
#     'saves_pct': 0.83},
#    'evenstrength': {'shots_against': 2297,
#     'goals_against': 225,
#     'saves': 2072,
#     'saves_pct': 0.902},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 3.34, 'shots_against': 32.52},
#    'emptynet': {'total': {'goals_against': 15, 'shots_against': 15},
#     'powerplay': {'goals_against': 1},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 14}},
#    'time_on_ice': {'total': '4949:58'}}},
#  'Blue Jackets': {'statistics': {'total': {'games_played': 82,
#     'goals': 234,
#     'assists': 389,
#     'penalties': 291,
#     'penalty_minutes': 670,
#     'team_penalties': 8,
#     'team_penalty_minutes': 14,
#     'shots': 2458,
#     'blocked_att': 1474,
#     'missed_shots': 1120,
#     'hits': 1577,
#     'giveaways': 463,
#     'takeaways': 517,
#     'blocked_shots': 1396,
#     'faceoffs_won': 2184,
#     'faceoffs_lost': 2441,
#     'powerplays': 212,
#     'shooting_pct': 9.5,
#     'faceoff_win_pct': 47.2,
#     'faceoffs': 4625,
#     'points': 623,
#     'plus_minus': -206,
#     'overtime_goals': 3,
#     'overtime_assists': 5,
#     'overtime_shots': 31,
#     'emptynet_goals': 11,
#     'penalties_major': 18,
#     'penalties_match': 0,
#     'penalties_minor': 259,
#     'penalties_misconduct': 4},
#    'powerplay': {'faceoffs_won': 190,
#     'faceoffs_lost': 198,
#     'shots': 329,
#     'goals': 32,
#     'missed_shots': 163,
#     'assists': 59,
#     'faceoff_win_pct': 49.0,
#     'opportunities': 212,
#     'faceoffs': 388,
#     'percentage': 15.1,
#     'strength': [{'opportunities': 205,
#       'shots': 316,
#       'goals': 29,
#       'type': '5v4'},
#      {'opportunities': 3, 'shots': 4, 'goals': 2, 'type': '5v3'},
#      {'opportunities': 5, 'shots': 9, 'goals': 1, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 162,
#     'faceoffs_lost': 232,
#     'shots': 60,
#     'goals': 5,
#     'missed_shots': 16,
#     'assists': 6,
#     'faceoff_win_pct': 41.1,
#     'opportunities': 236,
#     'faceoffs': 394,
#     'goals_against': 56,
#     'kill_pct': 76.3,
#     'strength': [{'shots': 58, 'goals': 5, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 2, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1832,
#     'faceoffs_lost': 2011,
#     'shots': 2069,
#     'goals': 197,
#     'missed_shots': 941,
#     'assists': 324,
#     'faceoff_win_pct': 47.7,
#     'faceoffs': 3843,
#     'strength': [{'shots': 2012, 'goals': 190, 'type': '5v5'},
#      {'shots': 31, 'goals': 4, 'type': '4v4'},
#      {'shots': 26, 'goals': 3, 'type': '3v3'}]},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 4.74,
#     'blocked_shots': 17.02,
#     'points': 7.6,
#     'blocked_att': 17.98,
#     'team_penalty_minutes': 0.17,
#     'penalties': 3.55,
#     'missed_shots': 13.66,
#     'hits': 19.23,
#     'shots': 29.98,
#     'takeaways': 6.3,
#     'giveaways': 5.65,
#     'goals': 2.85,
#     'team_penalties': 0.1,
#     'penalty_minutes': 8.17}},
#   'shootout': {'shots': 13,
#    'missed_shots': 4,
#    'goals': 5,
#    'shots_against': 18,
#    'goals_against': 4,
#    'saves': 14,
#    'saves_pct': 0.778},
#   'goaltending': {'total': {'shots_against': 2803,
#     'goals_against': 279,
#     'saves': 2524,
#     'total_goals_against': 298,
#     'total_shots_against': 2822,
#     'saves_pct': 0.894,
#     'losses': 43,
#     'overtime_losses': 12,
#     'shutouts': 1,
#     'wins': 27},
#    'powerplay': {'shots_against': 70,
#     'goals_against': 6,
#     'saves': 64,
#     'saves_pct': 0.914},
#    'shorthanded': {'shots_against': 410,
#     'goals_against': 56,
#     'saves': 354,
#     'saves_pct': 0.863},
#    'evenstrength': {'shots_against': 2342,
#     'goals_against': 236,
#     'saves': 2106,
#     'saves_pct': 0.899},
#    'penalty': {'shots_against': 2,
#     'goals_against': 0,
#     'saves': 2,
#     'saves_pct': 1.0},
#    'average': {'goals_against': 3.4, 'shots_against': 34.18},
#    'emptynet': {'total': {'goals_against': 19, 'shots_against': 19},
#     'powerplay': {'goals_against': 0},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 19}},
#    'time_on_ice': {'total': '4978:38'}}},
#  'Blues': {'statistics': {'total': {'games_played': 82,
#     'goals': 234,
#     'assists': 401,
#     'penalties': 263,
#     'penalty_minutes': 608,
#     'team_penalties': 9,
#     'team_penalty_minutes': 18,
#     'shots': 2370,
#     'blocked_att': 1182,
#     'missed_shots': 999,
#     'hits': 1654,
#     'giveaways': 621,
#     'takeaways': 726,
#     'blocked_shots': 1219,
#     'faceoffs_won': 2253,
#     'faceoffs_lost': 2262,
#     'powerplays': 250,
#     'shooting_pct': 9.9,
#     'faceoff_win_pct': 49.9,
#     'faceoffs': 4515,
#     'points': 635,
#     'plus_minus': -99,
#     'overtime_goals': 7,
#     'overtime_assists': 9,
#     'overtime_shots': 32,
#     'emptynet_goals': 15,
#     'penalties_major': 16,
#     'penalties_match': 0,
#     'penalties_minor': 233,
#     'penalties_misconduct': 4},
#    'powerplay': {'faceoffs_won': 249,
#     'faceoffs_lost': 188,
#     'shots': 362,
#     'goals': 45,
#     'missed_shots': 158,
#     'assists': 90,
#     'faceoff_win_pct': 57.0,
#     'opportunities': 250,
#     'faceoffs': 437,
#     'percentage': 18.0,
#     'strength': [{'opportunities': 239,
#       'shots': 343,
#       'goals': 43,
#       'type': '5v4'},
#      {'opportunities': 9, 'shots': 17, 'goals': 2, 'type': '5v3'},
#      {'opportunities': 2, 'shots': 2, 'goals': 0, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 179,
#     'faceoffs_lost': 204,
#     'shots': 71,
#     'goals': 11,
#     'missed_shots': 20,
#     'assists': 9,
#     'faceoff_win_pct': 46.7,
#     'opportunities': 215,
#     'faceoffs': 383,
#     'goals_against': 46,
#     'kill_pct': 78.6,
#     'strength': [{'shots': 71, 'goals': 11, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1825,
#     'faceoffs_lost': 1870,
#     'shots': 1937,
#     'goals': 178,
#     'missed_shots': 821,
#     'assists': 302,
#     'faceoff_win_pct': 49.4,
#     'faceoffs': 3695,
#     'strength': [{'shots': 1879, 'goals': 170, 'type': '5v5'},
#      {'shots': 27, 'goals': 1, 'type': '4v4'},
#      {'shots': 31, 'goals': 7, 'type': '3v3'}]},
#    'penalty': {'shots': 2, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 4.89,
#     'blocked_shots': 14.87,
#     'points': 7.74,
#     'blocked_att': 14.41,
#     'team_penalty_minutes': 0.22,
#     'penalties': 3.21,
#     'missed_shots': 12.18,
#     'hits': 20.17,
#     'shots': 28.9,
#     'takeaways': 8.85,
#     'giveaways': 7.57,
#     'goals': 2.85,
#     'team_penalties': 0.11,
#     'penalty_minutes': 7.41}},
#   'shootout': {'shots': 18,
#    'missed_shots': 5,
#    'goals': 9,
#    'shots_against': 25,
#    'goals_against': 6,
#    'saves': 19,
#    'saves_pct': 0.76},
#   'goaltending': {'total': {'shots_against': 2616,
#     'goals_against': 228,
#     'saves': 2388,
#     'total_goals_against': 248,
#     'total_shots_against': 2636,
#     'saves_pct': 0.906,
#     'losses': 33,
#     'overtime_losses': 6,
#     'shutouts': 4,
#     'wins': 43},
#    'powerplay': {'shots_against': 66,
#     'goals_against': 5,
#     'saves': 61,
#     'saves_pct': 0.924},
#    'shorthanded': {'shots_against': 337,
#     'goals_against': 45,
#     'saves': 292,
#     'saves_pct': 0.866},
#    'evenstrength': {'shots_against': 2231,
#     'goals_against': 196,
#     'saves': 2035,
#     'saves_pct': 0.912},
#    'penalty': {'shots_against': 1,
#     'goals_against': 0,
#     'saves': 1,
#     'saves_pct': 1.0},
#    'average': {'goals_against': 2.78, 'shots_against': 31.9},
#    'emptynet': {'total': {'goals_against': 20, 'shots_against': 20},
#     'powerplay': {'goals_against': 2},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 18}},
#    'time_on_ice': {'total': '4977:27'}}},
#  'Bruins': {'statistics': {'total': {'games_played': 82,
#     'goals': 263,
#     'assists': 443,
#     'penalties': 334,
#     'penalty_minutes': 776,
#     'team_penalties': 11,
#     'team_penalty_minutes': 22,
#     'shots': 2399,
#     'blocked_att': 1227,
#     'missed_shots': 984,
#     'hits': 2258,
#     'giveaways': 698,
#     'takeaways': 516,
#     'blocked_shots': 1299,
#     'faceoffs_won': 2298,
#     'faceoffs_lost': 2344,
#     'powerplays': 243,
#     'shooting_pct': 11.0,
#     'faceoff_win_pct': 49.5,
#     'faceoffs': 4642,
#     'points': 706,
#     'plus_minus': 157,
#     'overtime_goals': 7,
#     'overtime_assists': 7,
#     'overtime_shots': 63,
#     'emptynet_goals': 13,
#     'penalties_major': 21,
#     'penalties_match': 1,
#     'penalties_minor': 295,
#     'penalties_misconduct': 4},
#    'powerplay': {'faceoffs_won': 237,
#     'faceoffs_lost': 183,
#     'shots': 386,
#     'goals': 54,
#     'missed_shots': 147,
#     'assists': 106,
#     'faceoff_win_pct': 56.4,
#     'opportunities': 243,
#     'faceoffs': 420,
#     'percentage': 22.2,
#     'strength': [{'opportunities': 232,
#       'shots': 360,
#       'goals': 50,
#       'type': '5v4'},
#      {'opportunities': 8, 'shots': 12, 'goals': 4, 'type': '5v3'},
#      {'opportunities': 7, 'shots': 14, 'goals': 0, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 218,
#     'faceoffs_lost': 265,
#     'shots': 76,
#     'goals': 7,
#     'missed_shots': 20,
#     'assists': 6,
#     'faceoff_win_pct': 45.1,
#     'opportunities': 268,
#     'faceoffs': 483,
#     'goals_against': 47,
#     'kill_pct': 82.5,
#     'strength': [{'shots': 74, 'goals': 7, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 2, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1843,
#     'faceoffs_lost': 1896,
#     'shots': 1937,
#     'goals': 202,
#     'missed_shots': 817,
#     'assists': 331,
#     'faceoff_win_pct': 49.3,
#     'faceoffs': 3739,
#     'strength': [{'shots': 1840, 'goals': 189, 'type': '5v5'},
#      {'shots': 44, 'goals': 6, 'type': '4v4'},
#      {'shots': 53, 'goals': 7, 'type': '3v3'}]},
#    'penalty': {'shots': 2, 'goals': 2, 'missed_shots': 0},
#    'average': {'assists': 5.4,
#     'blocked_shots': 15.84,
#     'points': 8.61,
#     'blocked_att': 14.96,
#     'team_penalty_minutes': 0.27,
#     'penalties': 4.07,
#     'missed_shots': 12.0,
#     'hits': 27.54,
#     'shots': 29.26,
#     'takeaways': 6.29,
#     'giveaways': 8.51,
#     'goals': 3.21,
#     'team_penalties': 0.13,
#     'penalty_minutes': 9.46}},
#   'shootout': {'shots': 24,
#    'missed_shots': 3,
#    'goals': 9,
#    'shots_against': 26,
#    'goals_against': 7,
#    'saves': 19,
#    'saves_pct': 0.731},
#   'goaltending': {'total': {'shots_against': 2495,
#     'goals_against': 211,
#     'saves': 2284,
#     'total_goals_against': 221,
#     'total_shots_against': 2505,
#     'saves_pct': 0.912,
#     'losses': 20,
#     'overtime_losses': 15,
#     'shutouts': 5,
#     'wins': 47},
#    'powerplay': {'shots_against': 78,
#     'goals_against': 5,
#     'saves': 73,
#     'saves_pct': 0.936},
#    'shorthanded': {'shots_against': 384,
#     'goals_against': 47,
#     'saves': 336,
#     'saves_pct': 0.875},
#    'evenstrength': {'shots_against': 2042,
#     'goals_against': 168,
#     'saves': 1875,
#     'saves_pct': 0.918},
#    'penalty': {'shots_against': 1,
#     'goals_against': 0,
#     'saves': 1,
#     'saves_pct': 1.0},
#    'average': {'goals_against': 2.57, 'shots_against': 30.43},
#    'emptynet': {'total': {'goals_against': 10, 'shots_against': 10},
#     'powerplay': {'goals_against': 1},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 9}},
#    'time_on_ice': {'total': '5002:41'}}},
#  'Canadiens': {'statistics': {'total': {'games_played': 82,
#     'goals': 232,
#     'assists': 380,
#     'penalties': 348,
#     'penalty_minutes': 825,
#     'team_penalties': 10,
#     'team_penalty_minutes': 20,
#     'shots': 2269,
#     'blocked_att': 1257,
#     'missed_shots': 1007,
#     'hits': 1808,
#     'giveaways': 788,
#     'takeaways': 463,
#     'blocked_shots': 1464,
#     'faceoffs_won': 2332,
#     'faceoffs_lost': 2200,
#     'powerplays': 252,
#     'shooting_pct': 10.2,
#     'faceoff_win_pct': 51.5,
#     'faceoffs': 4532,
#     'points': 612,
#     'plus_minus': -139,
#     'overtime_goals': 6,
#     'overtime_assists': 10,
#     'overtime_shots': 53,
#     'emptynet_goals': 7,
#     'penalties_major': 24,
#     'penalties_match': 1,
#     'penalties_minor': 301,
#     'penalties_misconduct': 5},
#    'powerplay': {'faceoffs_won': 243,
#     'faceoffs_lost': 178,
#     'shots': 344,
#     'goals': 44,
#     'missed_shots': 145,
#     'assists': 86,
#     'faceoff_win_pct': 57.7,
#     'opportunities': 252,
#     'faceoffs': 421,
#     'percentage': 17.5,
#     'strength': [{'opportunities': 241,
#       'shots': 327,
#       'goals': 42,
#       'type': '5v4'},
#      {'opportunities': 9, 'shots': 7, 'goals': 0, 'type': '5v3'},
#      {'opportunities': 11, 'shots': 10, 'goals': 2, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 227,
#     'faceoffs_lost': 258,
#     'shots': 64,
#     'goals': 7,
#     'missed_shots': 8,
#     'assists': 1,
#     'faceoff_win_pct': 46.8,
#     'opportunities': 277,
#     'faceoffs': 485,
#     'goals_against': 65,
#     'kill_pct': 76.5,
#     'strength': [{'shots': 63, 'goals': 7, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 1, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1862,
#     'faceoffs_lost': 1764,
#     'shots': 1861,
#     'goals': 181,
#     'missed_shots': 854,
#     'assists': 293,
#     'faceoff_win_pct': 51.4,
#     'faceoffs': 3626,
#     'strength': [{'shots': 1784, 'goals': 171, 'type': '5v5'},
#      {'shots': 33, 'goals': 6, 'type': '4v4'},
#      {'shots': 44, 'goals': 4, 'type': '3v3'}]},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 4.63,
#     'blocked_shots': 17.85,
#     'points': 7.46,
#     'blocked_att': 15.33,
#     'team_penalty_minutes': 0.24,
#     'penalties': 4.24,
#     'missed_shots': 12.28,
#     'hits': 22.05,
#     'shots': 27.67,
#     'takeaways': 5.65,
#     'giveaways': 9.61,
#     'goals': 2.83,
#     'team_penalties': 0.12,
#     'penalty_minutes': 10.06}},
#   'shootout': {'shots': 39,
#    'missed_shots': 12,
#    'goals': 13,
#    'shots_against': 53,
#    'goals_against': 17,
#    'saves': 36,
#    'saves_pct': 0.679},
#   'goaltending': {'total': {'shots_against': 2724,
#     'goals_against': 267,
#     'saves': 2457,
#     'total_goals_against': 281,
#     'total_shots_against': 2738,
#     'saves_pct': 0.897,
#     'losses': 36,
#     'overtime_losses': 16,
#     'shutouts': 2,
#     'wins': 30},
#    'powerplay': {'shots_against': 85,
#     'goals_against': 12,
#     'saves': 73,
#     'saves_pct': 0.859},
#    'shorthanded': {'shots_against': 464,
#     'goals_against': 64,
#     'saves': 400,
#     'saves_pct': 0.862},
#    'evenstrength': {'shots_against': 2188,
#     'goals_against': 204,
#     'saves': 1984,
#     'saves_pct': 0.907},
#    'penalty': {'shots_against': 3,
#     'goals_against': 2,
#     'saves': 1,
#     'saves_pct': 0.333},
#    'average': {'goals_against': 3.26, 'shots_against': 33.22},
#    'emptynet': {'total': {'goals_against': 14, 'shots_against': 14},
#     'powerplay': {'goals_against': 0},
#     'shorthanded': {'goals_against': 1},
#     'evenstrength': {'goals_against': 13}},
#    'time_on_ice': {'total': '5013:07'}}},
#  'Canucks': {'statistics': {'total': {'games_played': 82,
#     'goals': 279,
#     'assists': 484,
#     'penalties': 314,
#     'penalty_minutes': 764,
#     'team_penalties': 14,
#     'team_penalty_minutes': 28,
#     'shots': 2328,
#     'blocked_att': 1360,
#     'missed_shots': 1149,
#     'hits': 2178,
#     'giveaways': 492,
#     'takeaways': 499,
#     'blocked_shots': 1152,
#     'faceoffs_won': 2336,
#     'faceoffs_lost': 2145,
#     'powerplays': 257,
#     'shooting_pct': 12.0,
#     'faceoff_win_pct': 52.1,
#     'faceoffs': 4481,
#     'points': 763,
#     'plus_minus': 269,
#     'overtime_goals': 6,
#     'overtime_assists': 9,
#     'overtime_shots': 28,
#     'emptynet_goals': 14,
#     'penalties_major': 20,
#     'penalties_match': 2,
#     'penalties_minor': 267,
#     'penalties_misconduct': 8},
#    'powerplay': {'faceoffs_won': 253,
#     'faceoffs_lost': 164,
#     'shots': 393,
#     'goals': 58,
#     'missed_shots': 182,
#     'assists': 112,
#     'faceoff_win_pct': 60.7,
#     'opportunities': 257,
#     'faceoffs': 417,
#     'percentage': 22.6,
#     'strength': [{'opportunities': 249,
#       'shots': 382,
#       'goals': 55,
#       'type': '5v4'},
#      {'opportunities': 10, 'shots': 9, 'goals': 2, 'type': '5v3'},
#      {'opportunities': 4, 'shots': 2, 'goals': 1, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 224,
#     'faceoffs_lost': 248,
#     'shots': 71,
#     'goals': 7,
#     'missed_shots': 12,
#     'assists': 7,
#     'faceoff_win_pct': 47.5,
#     'opportunities': 254,
#     'faceoffs': 472,
#     'goals_against': 53,
#     'kill_pct': 79.1,
#     'strength': [{'shots': 70, 'goals': 7, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 1, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1859,
#     'faceoffs_lost': 1733,
#     'shots': 1864,
#     'goals': 214,
#     'missed_shots': 955,
#     'assists': 365,
#     'faceoff_win_pct': 51.8,
#     'faceoffs': 3592,
#     'strength': [{'shots': 1815, 'goals': 206, 'type': '5v5'},
#      {'shots': 23, 'goals': 3, 'type': '4v4'},
#      {'shots': 26, 'goals': 5, 'type': '3v3'}]},
#    'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 5.9,
#     'blocked_shots': 14.05,
#     'points': 9.3,
#     'blocked_att': 16.59,
#     'team_penalty_minutes': 0.34,
#     'penalties': 3.83,
#     'missed_shots': 14.01,
#     'hits': 26.56,
#     'shots': 28.39,
#     'takeaways': 6.09,
#     'giveaways': 6.0,
#     'goals': 3.4,
#     'team_penalties': 0.17,
#     'penalty_minutes': 9.32}},
#   'shootout': {'shots': 6,
#    'missed_shots': 1,
#    'goals': 0,
#    'shots_against': 7,
#    'goals_against': 2,
#    'saves': 5,
#    'saves_pct': 0.714},
#   'goaltending': {'total': {'shots_against': 2335,
#     'goals_against': 213,
#     'saves': 2122,
#     'total_goals_against': 221,
#     'total_shots_against': 2343,
#     'saves_pct': 0.906,
#     'losses': 23,
#     'overtime_losses': 9,
#     'shutouts': 6,
#     'wins': 50},
#    'powerplay': {'shots_against': 72,
#     'goals_against': 7,
#     'saves': 65,
#     'saves_pct': 0.903},
#    'shorthanded': {'shots_against': 384,
#     'goals_against': 53,
#     'saves': 331,
#     'saves_pct': 0.862},
#    'evenstrength': {'shots_against': 1887,
#     'goals_against': 161,
#     'saves': 1726,
#     'saves_pct': 0.915},
#    'penalty': {'shots_against': 3,
#     'goals_against': 2,
#     'saves': 1,
#     'saves_pct': 0.333},
#    'average': {'goals_against': 2.6, 'shots_against': 28.48},
#    'emptynet': {'total': {'goals_against': 8, 'shots_against': 8},
#     'powerplay': {'goals_against': 0},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 8}},
#    'time_on_ice': {'total': '4964:45'}}},
#  'Capitals': {'statistics': {'total': {'games_played': 82,
#     'goals': 216,
#     'assists': 371,
#     'penalties': 272,
#     'penalty_minutes': 628,
#     'team_penalties': 9,
#     'team_penalty_minutes': 18,
#     'shots': 2173,
#     'blocked_att': 1353,
#     'missed_shots': 1047,
#     'hits': 1880,
#     'giveaways': 700,
#     'takeaways': 628,
#     'blocked_shots': 1419,
#     'faceoffs_won': 2126,
#     'faceoffs_lost': 2431,
#     'powerplays': 228,
#     'shooting_pct': 9.9,
#     'faceoff_win_pct': 46.7,
#     'faceoffs': 4557,
#     'points': 587,
#     'plus_minus': -169,
#     'overtime_goals': 4,
#     'overtime_assists': 7,
#     'overtime_shots': 41,
#     'emptynet_goals': 12,
#     'penalties_major': 12,
#     'penalties_match': 0,
#     'penalties_minor': 242,
#     'penalties_misconduct': 5},
#    'powerplay': {'faceoffs_won': 235,
#     'faceoffs_lost': 203,
#     'shots': 349,
#     'goals': 47,
#     'missed_shots': 150,
#     'assists': 86,
#     'faceoff_win_pct': 53.7,
#     'opportunities': 228,
#     'faceoffs': 438,
#     'percentage': 20.6,
#     'strength': [{'opportunities': 219,
#       'shots': 324,
#       'goals': 44,
#       'type': '5v4'},
#      {'opportunities': 5, 'shots': 14, 'goals': 1, 'type': '5v3'},
#      {'opportunities': 7, 'shots': 12, 'goals': 2, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 162,
#     'faceoffs_lost': 234,
#     'shots': 49,
#     'goals': 3,
#     'missed_shots': 16,
#     'assists': 5,
#     'faceoff_win_pct': 40.9,
#     'opportunities': 233,
#     'faceoffs': 396,
#     'goals_against': 49,
#     'kill_pct': 79.0,
#     'strength': [{'shots': 49, 'goals': 3, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1729,
#     'faceoffs_lost': 1994,
#     'shots': 1775,
#     'goals': 166,
#     'missed_shots': 881,
#     'assists': 280,
#     'faceoff_win_pct': 46.4,
#     'faceoffs': 3723,
#     'strength': [{'shots': 1726, 'goals': 160, 'type': '5v5'},
#      {'shots': 18, 'goals': 4, 'type': '4v4'},
#      {'shots': 29, 'goals': 2, 'type': '3v3'}]},
#    'penalty': {'shots': 3, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 4.52,
#     'blocked_shots': 17.3,
#     'points': 7.16,
#     'blocked_att': 16.5,
#     'team_penalty_minutes': 0.22,
#     'penalties': 3.32,
#     'missed_shots': 12.77,
#     'hits': 22.93,
#     'shots': 26.5,
#     'takeaways': 7.66,
#     'giveaways': 8.54,
#     'goals': 2.63,
#     'team_penalties': 0.11,
#     'penalty_minutes': 7.66}},
#   'shootout': {'shots': 27,
#    'missed_shots': 7,
#    'goals': 8,
#    'shots_against': 34,
#    'goals_against': 10,
#    'saves': 24,
#    'saves_pct': 0.706},
#   'goaltending': {'total': {'shots_against': 2494,
#     'goals_against': 243,
#     'saves': 2251,
#     'total_goals_against': 252,
#     'total_shots_against': 2503,
#     'saves_pct': 0.899,
#     'losses': 31,
#     'overtime_losses': 11,
#     'shutouts': 7,
#     'wins': 40},
#    'powerplay': {'shots_against': 67,
#     'goals_against': 4,
#     'saves': 63,
#     'saves_pct': 0.94},
#    'shorthanded': {'shots_against': 368,
#     'goals_against': 49,
#     'saves': 319,
#     'saves_pct': 0.867},
#    'evenstrength': {'shots_against': 2067,
#     'goals_against': 198,
#     'saves': 1869,
#     'saves_pct': 0.904},
#    'penalty': {'shots_against': 1,
#     'goals_against': 0,
#     'saves': 1,
#     'saves_pct': 1.0},
#    'average': {'goals_against': 2.96, 'shots_against': 30.41},
#    'emptynet': {'total': {'goals_against': 9, 'shots_against': 9},
#     'powerplay': {'goals_against': 1},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 8}},
#    'time_on_ice': {'total': '4991:21'}}},
#  'Coyotes': {'statistics': {'total': {'games_played': 82,
#     'goals': 254,
#     'assists': 424,
#     'penalties': 358,
#     'penalty_minutes': 944,
#     'team_penalties': 15,
#     'team_penalty_minutes': 30,
#     'shots': 2273,
#     'blocked_att': 1281,
#     'missed_shots': 1094,
#     'hits': 1849,
#     'giveaways': 669,
#     'takeaways': 474,
#     'blocked_shots': 1228,
#     'faceoffs_won': 2113,
#     'faceoffs_lost': 2574,
#     'powerplays': 241,
#     'shooting_pct': 11.2,
#     'faceoff_win_pct': 45.1,
#     'faceoffs': 4687,
#     'points': 678,
#     'plus_minus': -71,
#     'overtime_goals': 6,
#     'overtime_assists': 9,
#     'overtime_shots': 32,
#     'emptynet_goals': 13,
#     'penalties_major': 32,
#     'penalties_match': 0,
#     'penalties_minor': 293,
#     'penalties_misconduct': 16},
#    'powerplay': {'faceoffs_won': 198,
#     'faceoffs_lost': 215,
#     'shots': 329,
#     'goals': 53,
#     'missed_shots': 143,
#     'assists': 100,
#     'faceoff_win_pct': 47.9,
#     'opportunities': 241,
#     'faceoffs': 413,
#     'percentage': 22.0,
#     'strength': [{'opportunities': 232,
#       'shots': 312,
#       'goals': 52,
#       'type': '5v4'},
#      {'opportunities': 6, 'shots': 7, 'goals': 1, 'type': '5v3'},
#      {'opportunities': 5, 'shots': 9, 'goals': 0, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 206,
#     'faceoffs_lost': 290,
#     'shots': 61,
#     'goals': 7,
#     'missed_shots': 20,
#     'assists': 7,
#     'faceoff_win_pct': 41.5,
#     'opportunities': 266,
#     'faceoffs': 496,
#     'goals_against': 63,
#     'kill_pct': 76.3,
#     'strength': [{'shots': 61, 'goals': 7, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1709,
#     'faceoffs_lost': 2069,
#     'shots': 1883,
#     'goals': 194,
#     'missed_shots': 931,
#     'assists': 317,
#     'faceoff_win_pct': 45.2,
#     'faceoffs': 3778,
#     'strength': [{'shots': 1832, 'goals': 187, 'type': '5v5'},
#      {'shots': 28, 'goals': 1, 'type': '4v4'},
#      {'shots': 24, 'goals': 6, 'type': '3v3'}]},
#    'penalty': {'shots': 2, 'goals': 1, 'missed_shots': 0},
#    'average': {'assists': 5.17,
#     'blocked_shots': 14.98,
#     'points': 8.27,
#     'blocked_att': 15.62,
#     'team_penalty_minutes': 0.37,
#     'penalties': 4.37,
#     'missed_shots': 13.34,
#     'hits': 22.55,
#     'shots': 27.72,
#     'takeaways': 5.78,
#     'giveaways': 8.16,
#     'goals': 3.1,
#     'team_penalties': 0.18,
#     'penalty_minutes': 11.51}},
#   'shootout': {'shots': 5,
#    'missed_shots': 0,
#    'goals': 3,
#    'shots_against': 5,
#    'goals_against': 0,
#    'saves': 5,
#    'saves_pct': 1.0},
#   'goaltending': {'total': {'shots_against': 2579,
#     'goals_against': 255,
#     'saves': 2324,
#     'total_goals_against': 274,
#     'total_shots_against': 2598,
#     'saves_pct': 0.895,
#     'losses': 41,
#     'overtime_losses': 5,
#     'shutouts': 7,
#     'wins': 36},
#    'powerplay': {'shots_against': 72,
#     'goals_against': 7,
#     'saves': 65,
#     'saves_pct': 0.903},
#    'shorthanded': {'shots_against': 451,
#     'goals_against': 63,
#     'saves': 388,
#     'saves_pct': 0.86},
#    'evenstrength': {'shots_against': 2075,
#     'goals_against': 204,
#     'saves': 1871,
#     'saves_pct': 0.902},
#    'penalty': {'shots_against': 2,
#     'goals_against': 1,
#     'saves': 1,
#     'saves_pct': 0.5},
#    'average': {'goals_against': 3.11, 'shots_against': 31.45},
#    'emptynet': {'total': {'goals_against': 19, 'shots_against': 19},
#     'powerplay': {'goals_against': 0},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 19}},
#    'time_on_ice': {'total': '4964:02'}}},
#  'Devils': {'statistics': {'total': {'games_played': 82,
#     'goals': 264,
#     'assists': 423,
#     'penalties': 303,
#     'penalty_minutes': 747,
#     'team_penalties': 10,
#     'team_penalty_minutes': 20,
#     'shots': 2516,
#     'blocked_att': 1534,
#     'missed_shots': 1081,
#     'hits': 1668,
#     'giveaways': 644,
#     'takeaways': 563,
#     'blocked_shots': 1116,
#     'faceoffs_won': 2461,
#     'faceoffs_lost': 2136,
#     'powerplays': 245,
#     'shooting_pct': 10.5,
#     'faceoff_win_pct': 53.5,
#     'faceoffs': 4597,
#     'points': 687,
#     'plus_minus': -151,
#     'overtime_goals': 5,
#     'overtime_assists': 7,
#     'overtime_shots': 27,
#     'emptynet_goals': 14,
#     'penalties_major': 19,
#     'penalties_match': 0,
#     'penalties_minor': 262,
#     'penalties_misconduct': 10},
#    'powerplay': {'faceoffs_won': 234,
#     'faceoffs_lost': 194,
#     'shots': 368,
#     'goals': 55,
#     'missed_shots': 127,
#     'assists': 102,
#     'faceoff_win_pct': 54.7,
#     'opportunities': 245,
#     'faceoffs': 428,
#     'percentage': 22.4,
#     'strength': [{'opportunities': 237,
#       'shots': 356,
#       'goals': 48,
#       'type': '5v4'},
#      {'opportunities': 6, 'shots': 7, 'goals': 4, 'type': '5v3'},
#      {'opportunities': 6, 'shots': 5, 'goals': 3, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 212,
#     'faceoffs_lost': 185,
#     'shots': 63,
#     'goals': 3,
#     'missed_shots': 18,
#     'assists': 2,
#     'faceoff_win_pct': 53.4,
#     'opportunities': 243,
#     'faceoffs': 397,
#     'goals_against': 47,
#     'kill_pct': 80.7,
#     'strength': [{'shots': 62, 'goals': 3, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 1, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 2015,
#     'faceoffs_lost': 1757,
#     'shots': 2085,
#     'goals': 206,
#     'missed_shots': 936,
#     'assists': 319,
#     'faceoff_win_pct': 53.4,
#     'faceoffs': 3772,
#     'strength': [{'shots': 2030, 'goals': 196, 'type': '5v5'},
#      {'shots': 29, 'goals': 5, 'type': '4v4'},
#      {'shots': 26, 'goals': 5, 'type': '3v3'}]},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 1},
#    'average': {'assists': 5.16,
#     'blocked_shots': 13.61,
#     'points': 8.38,
#     'blocked_att': 18.71,
#     'team_penalty_minutes': 0.24,
#     'penalties': 3.7,
#     'missed_shots': 13.18,
#     'hits': 20.34,
#     'shots': 30.68,
#     'takeaways': 6.87,
#     'giveaways': 7.85,
#     'goals': 3.22,
#     'team_penalties': 0.12,
#     'penalty_minutes': 9.11}},
#   'shootout': {'shots': 5,
#    'missed_shots': 0,
#    'goals': 0,
#    'shots_against': 4,
#    'goals_against': 3,
#    'saves': 1,
#    'saves_pct': 0.25},
#   'goaltending': {'total': {'shots_against': 2431,
#     'goals_against': 254,
#     'saves': 2177,
#     'total_goals_against': 281,
#     'total_shots_against': 2458,
#     'saves_pct': 0.886,
#     'losses': 39,
#     'overtime_losses': 5,
#     'shutouts': 1,
#     'wins': 38},
#    'powerplay': {'shots_against': 68,
#     'goals_against': 8,
#     'saves': 60,
#     'saves_pct': 0.882},
#    'shorthanded': {'shots_against': 335,
#     'goals_against': 47,
#     'saves': 288,
#     'saves_pct': 0.86},
#    'evenstrength': {'shots_against': 2054,
#     'goals_against': 225,
#     'saves': 1829,
#     'saves_pct': 0.89},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 3.1, 'shots_against': 29.65},
#    'emptynet': {'total': {'goals_against': 27, 'shots_against': 27},
#     'powerplay': {'goals_against': 1},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 26}},
#    'time_on_ice': {'total': '4949:18'}}},
#  'Ducks': {'statistics': {'total': {'games_played': 82,
#     'goals': 203,
#     'assists': 351,
#     'penalties': 440,
#     'penalty_minutes': 1108,
#     'team_penalties': 17,
#     'team_penalty_minutes': 32,
#     'shots': 2194,
#     'blocked_att': 1175,
#     'missed_shots': 962,
#     'hits': 1912,
#     'giveaways': 579,
#     'takeaways': 502,
#     'blocked_shots': 1343,
#     'faceoffs_won': 2115,
#     'faceoffs_lost': 2419,
#     'powerplays': 235,
#     'shooting_pct': 9.3,
#     'faceoff_win_pct': 46.6,
#     'faceoffs': 4534,
#     'points': 554,
#     'plus_minus': -227,
#     'overtime_goals': 5,
#     'overtime_assists': 8,
#     'overtime_shots': 23,
#     'emptynet_goals': 7,
#     'penalties_major': 30,
#     'penalties_match': 0,
#     'penalties_minor': 371,
#     'penalties_misconduct': 16},
#    'powerplay': {'faceoffs_won': 206,
#     'faceoffs_lost': 215,
#     'shots': 322,
#     'goals': 43,
#     'missed_shots': 129,
#     'assists': 79,
#     'faceoff_win_pct': 48.9,
#     'opportunities': 235,
#     'faceoffs': 421,
#     'percentage': 18.3,
#     'strength': [{'opportunities': 231,
#       'shots': 306,
#       'goals': 39,
#       'type': '5v4'},
#      {'opportunities': 7, 'shots': 11, 'goals': 2, 'type': '5v3'},
#      {'opportunities': 4, 'shots': 5, 'goals': 1, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 261,
#     'faceoffs_lost': 322,
#     'shots': 85,
#     'goals': 12,
#     'missed_shots': 19,
#     'assists': 12,
#     'faceoff_win_pct': 44.8,
#     'opportunities': 330,
#     'faceoffs': 583,
#     'goals_against': 91,
#     'kill_pct': 72.4,
#     'strength': [{'shots': 83, 'goals': 12, 'type': '4v5'},
#      {'shots': 1, 'goals': 0, 'type': '3v5'},
#      {'shots': 1, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1648,
#     'faceoffs_lost': 1882,
#     'shots': 1787,
#     'goals': 148,
#     'missed_shots': 814,
#     'assists': 260,
#     'faceoff_win_pct': 46.7,
#     'faceoffs': 3530,
#     'strength': [{'shots': 1721, 'goals': 138, 'type': '5v5'},
#      {'shots': 43, 'goals': 6, 'type': '4v4'},
#      {'shots': 23, 'goals': 5, 'type': '3v3'}]},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 4.28,
#     'blocked_shots': 16.38,
#     'points': 6.76,
#     'blocked_att': 14.33,
#     'team_penalty_minutes': 0.39,
#     'penalties': 5.37,
#     'missed_shots': 11.73,
#     'hits': 23.32,
#     'shots': 26.76,
#     'takeaways': 6.12,
#     'giveaways': 7.06,
#     'goals': 2.48,
#     'team_penalties': 0.21,
#     'penalty_minutes': 13.51}},
#   'shootout': {'shots': 7,
#    'missed_shots': 1,
#    'goals': 2,
#    'shots_against': 8,
#    'goals_against': 3,
#    'saves': 5,
#    'saves_pct': 0.625},
#   'goaltending': {'total': {'shots_against': 2653,
#     'goals_against': 280,
#     'saves': 2373,
#     'total_goals_against': 293,
#     'total_shots_against': 2666,
#     'saves_pct': 0.89,
#     'losses': 50,
#     'overtime_losses': 5,
#     'shutouts': 1,
#     'wins': 27},
#    'powerplay': {'shots_against': 59,
#     'goals_against': 4,
#     'saves': 55,
#     'saves_pct': 0.932},
#    'shorthanded': {'shots_against': 559,
#     'goals_against': 90,
#     'saves': 469,
#     'saves_pct': 0.839},
#    'evenstrength': {'shots_against': 2046,
#     'goals_against': 197,
#     'saves': 1849,
#     'saves_pct': 0.904},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 3.41, 'shots_against': 32.35},
#    'emptynet': {'total': {'goals_against': 13, 'shots_against': 13},
#     'powerplay': {'goals_against': 1},
#     'shorthanded': {'goals_against': 1},
#     'evenstrength': {'goals_against': 11}},
#    'time_on_ice': {'total': '4951:39'}}},
#  'Flames': {'statistics': {'total': {'games_played': 82,
#     'goals': 253,
#     'assists': 433,
#     'penalties': 317,
#     'penalty_minutes': 757,
#     'team_penalties': 9,
#     'team_penalty_minutes': 18,
#     'shots': 2572,
#     'blocked_att': 1486,
#     'missed_shots': 1198,
#     'hits': 1749,
#     'giveaways': 811,
#     'takeaways': 621,
#     'blocked_shots': 1379,
#     'faceoffs_won': 2393,
#     'faceoffs_lost': 2429,
#     'powerplays': 252,
#     'shooting_pct': 9.8,
#     'faceoff_win_pct': 49.6,
#     'faceoffs': 4822,
#     'points': 686,
#     'plus_minus': -92,
#     'overtime_goals': 6,
#     'overtime_assists': 8,
#     'overtime_shots': 37,
#     'emptynet_goals': 18,
#     'penalties_major': 20,
#     'penalties_match': 1,
#     'penalties_minor': 278,
#     'penalties_misconduct': 7},
#    'powerplay': {'faceoffs_won': 261,
#     'faceoffs_lost': 203,
#     'shots': 363,
#     'goals': 45,
#     'missed_shots': 184,
#     'assists': 89,
#     'faceoff_win_pct': 56.3,
#     'opportunities': 252,
#     'faceoffs': 464,
#     'percentage': 17.9,
#     'strength': [{'opportunities': 246,
#       'shots': 338,
#       'goals': 42,
#       'type': '5v4'},
#      {'opportunities': 8, 'shots': 14, 'goals': 1, 'type': '5v3'},
#      {'opportunities': 4, 'shots': 11, 'goals': 2, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 188,
#     'faceoffs_lost': 236,
#     'shots': 81,
#     'goals': 11,
#     'missed_shots': 25,
#     'assists': 13,
#     'faceoff_win_pct': 44.3,
#     'opportunities': 245,
#     'faceoffs': 424,
#     'goals_against': 47,
#     'kill_pct': 80.8,
#     'strength': [{'shots': 81, 'goals': 11, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1944,
#     'faceoffs_lost': 1990,
#     'shots': 2128,
#     'goals': 197,
#     'missed_shots': 989,
#     'assists': 331,
#     'faceoff_win_pct': 49.4,
#     'faceoffs': 3934,
#     'strength': [{'shots': 2054, 'goals': 186, 'type': '5v5'},
#      {'shots': 48, 'goals': 7, 'type': '4v4'},
#      {'shots': 26, 'goals': 4, 'type': '3v3'}]},
#    'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 5.28,
#     'blocked_shots': 16.82,
#     'points': 8.37,
#     'blocked_att': 18.12,
#     'team_penalty_minutes': 0.22,
#     'penalties': 3.87,
#     'missed_shots': 14.61,
#     'hits': 21.33,
#     'shots': 31.37,
#     'takeaways': 7.57,
#     'giveaways': 9.89,
#     'goals': 3.09,
#     'team_penalties': 0.11,
#     'penalty_minutes': 9.23}},
#   'shootout': {'shots': 13,
#    'missed_shots': 3,
#    'goals': 3,
#    'shots_against': 16,
#    'goals_against': 7,
#    'saves': 9,
#    'saves_pct': 0.563},
#   'goaltending': {'total': {'shots_against': 2420,
#     'goals_against': 249,
#     'saves': 2171,
#     'total_goals_against': 267,
#     'total_shots_against': 2438,
#     'saves_pct': 0.89,
#     'losses': 39,
#     'overtime_losses': 5,
#     'shutouts': 2,
#     'wins': 38},
#    'powerplay': {'shots_against': 78,
#     'goals_against': 11,
#     'saves': 67,
#     'saves_pct': 0.859},
#    'shorthanded': {'shots_against': 345,
#     'goals_against': 47,
#     'saves': 298,
#     'saves_pct': 0.864},
#    'evenstrength': {'shots_against': 2015,
#     'goals_against': 209,
#     'saves': 1806,
#     'saves_pct': 0.896},
#    'penalty': {'shots_against': 2,
#     'goals_against': 1,
#     'saves': 1,
#     'saves_pct': 0.5},
#    'average': {'goals_against': 3.04, 'shots_against': 29.51},
#    'emptynet': {'total': {'goals_against': 18, 'shots_against': 18},
#     'powerplay': {'goals_against': 0},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 18}},
#    'time_on_ice': {'total': '4962:12'}}},
#  'Flyers': {'statistics': {'total': {'games_played': 82,
#     'goals': 231,
#     'assists': 369,
#     'penalties': 321,
#     'penalty_minutes': 830,
#     'team_penalties': 10,
#     'team_penalty_minutes': 18,
#     'shots': 2708,
#     'blocked_att': 1425,
#     'missed_shots': 1119,
#     'hits': 2024,
#     'giveaways': 507,
#     'takeaways': 496,
#     'blocked_shots': 1533,
#     'faceoffs_won': 2321,
#     'faceoffs_lost': 2351,
#     'powerplays': 254,
#     'shooting_pct': 8.5,
#     'faceoff_win_pct': 49.7,
#     'faceoffs': 4672,
#     'points': 600,
#     'plus_minus': -120,
#     'overtime_goals': 4,
#     'overtime_assists': 4,
#     'overtime_shots': 40,
#     'emptynet_goals': 9,
#     'penalties_major': 24,
#     'penalties_match': 0,
#     'penalties_minor': 270,
#     'penalties_misconduct': 14},
#    'powerplay': {'faceoffs_won': 230,
#     'faceoffs_lost': 185,
#     'shots': 380,
#     'goals': 31,
#     'missed_shots': 152,
#     'assists': 60,
#     'faceoff_win_pct': 55.4,
#     'opportunities': 254,
#     'faceoffs': 415,
#     'percentage': 12.2,
#     'strength': [{'opportunities': 247,
#       'shots': 359,
#       'goals': 29,
#       'type': '5v4'},
#      {'opportunities': 7, 'shots': 14, 'goals': 1, 'type': '5v3'},
#      {'opportunities': 2, 'shots': 7, 'goals': 1, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 183,
#     'faceoffs_lost': 230,
#     'shots': 112,
#     'goals': 16,
#     'missed_shots': 20,
#     'assists': 25,
#     'faceoff_win_pct': 44.3,
#     'opportunities': 241,
#     'faceoffs': 413,
#     'goals_against': 40,
#     'kill_pct': 83.4,
#     'strength': [{'shots': 112, 'goals': 16, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1908,
#     'faceoffs_lost': 1936,
#     'shots': 2216,
#     'goals': 184,
#     'missed_shots': 947,
#     'assists': 284,
#     'faceoff_win_pct': 49.6,
#     'faceoffs': 3844,
#     'strength': [{'shots': 2134, 'goals': 178, 'type': '5v5'},
#      {'shots': 46, 'goals': 3, 'type': '4v4'},
#      {'shots': 36, 'goals': 3, 'type': '3v3'}]},
#    'penalty': {'shots': 5, 'goals': 5, 'missed_shots': 0},
#    'average': {'assists': 4.5,
#     'blocked_shots': 18.7,
#     'points': 7.32,
#     'blocked_att': 17.38,
#     'team_penalty_minutes': 0.22,
#     'penalties': 3.91,
#     'missed_shots': 13.65,
#     'hits': 24.68,
#     'shots': 33.02,
#     'takeaways': 6.05,
#     'giveaways': 6.18,
#     'goals': 2.82,
#     'team_penalties': 0.12,
#     'penalty_minutes': 10.12}},
#   'shootout': {'shots': 16,
#    'missed_shots': 6,
#    'goals': 6,
#    'shots_against': 22,
#    'goals_against': 6,
#    'saves': 16,
#    'saves_pct': 0.727},
#   'goaltending': {'total': {'shots_against': 2212,
#     'goals_against': 245,
#     'saves': 1967,
#     'total_goals_against': 258,
#     'total_shots_against': 2225,
#     'saves_pct': 0.884,
#     'losses': 33,
#     'overtime_losses': 11,
#     'shutouts': 5,
#     'wins': 38},
#    'powerplay': {'shots_against': 80,
#     'goals_against': 4,
#     'saves': 76,
#     'saves_pct': 0.95},
#    'shorthanded': {'shots_against': 299,
#     'goals_against': 40,
#     'saves': 259,
#     'saves_pct': 0.866},
#    'evenstrength': {'shots_against': 1846,
#     'goals_against': 214,
#     'saves': 1632,
#     'saves_pct': 0.884},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 2.99, 'shots_against': 26.98},
#    'emptynet': {'total': {'goals_against': 13, 'shots_against': 13},
#     'powerplay': {'goals_against': 0},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 13}},
#    'time_on_ice': {'total': '4976:52'}}},
#  'Golden Knights': {'statistics': {'total': {'games_played': 82,
#     'goals': 263,
#     'assists': 459,
#     'penalties': 248,
#     'penalty_minutes': 605,
#     'team_penalties': 8,
#     'team_penalty_minutes': 16,
#     'shots': 2548,
#     'blocked_att': 1432,
#     'missed_shots': 1002,
#     'hits': 2022,
#     'giveaways': 565,
#     'takeaways': 690,
#     'blocked_shots': 1506,
#     'faceoffs_won': 2314,
#     'faceoffs_lost': 2296,
#     'powerplays': 252,
#     'shooting_pct': 10.3,
#     'faceoff_win_pct': 50.2,
#     'faceoffs': 4610,
#     'points': 722,
#     'plus_minus': 40,
#     'overtime_goals': 7,
#     'overtime_assists': 12,
#     'overtime_shots': 29,
#     'emptynet_goals': 18,
#     'penalties_major': 15,
#     'penalties_match': 2,
#     'penalties_minor': 216,
#     'penalties_misconduct': 4},
#    'powerplay': {'faceoffs_won': 255,
#     'faceoffs_lost': 199,
#     'shots': 385,
#     'goals': 51,
#     'missed_shots': 137,
#     'assists': 98,
#     'faceoff_win_pct': 56.2,
#     'opportunities': 252,
#     'faceoffs': 454,
#     'percentage': 20.2,
#     'strength': [{'opportunities': 245,
#       'shots': 377,
#       'goals': 49,
#       'type': '5v4'},
#      {'opportunities': 8, 'shots': 5, 'goals': 1, 'type': '5v3'},
#      {'opportunities': 2, 'shots': 3, 'goals': 1, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 152,
#     'faceoffs_lost': 204,
#     'shots': 64,
#     'goals': 9,
#     'missed_shots': 20,
#     'assists': 11,
#     'faceoff_win_pct': 42.7,
# ...
#      {'shots': 35, 'goals': 3, 'type': '4v4'},
#      {'shots': 25, 'goals': 3, 'type': '3v3'}]},
#    'penalty': {'shots': 1, 'goals': 1, 'missed_shots': 0},
#    'average': {'assists': 4.77,
#     'blocked_shots': 14.65,
#     'points': 7.74,
#     'blocked_att': 16.28,
#     'team_penalty_minutes': 0.17,
#     'penalties': 3.77,
#     'missed_shots': 12.88,
#     'hits': 21.8,
#     'shots': 30.9,
#     'takeaways': 6.61,
#     'giveaways': 5.99,
#     'goals': 2.98,
#     'team_penalties': 0.09,
#     'penalty_minutes': 9.62}},
#   'shootout': {'shots': 11,
#    'missed_shots': 0,
#    'goals': 5,
#    'shots_against': 11,
#    'goals_against': 4,
#    'saves': 7,
#    'saves_pct': 0.636},
#   'goaltending': {'total': {'shots_against': 2391,
#     'goals_against': 231,
#     'saves': 2160,
#     'total_goals_against': 243,
#     'total_shots_against': 2403,
#     'saves_pct': 0.899,
#     'losses': 37,
#     'overtime_losses': 6,
#     'shutouts': 5,
#     'wins': 39},
#    'powerplay': {'shots_against': 62,
#     'goals_against': 9,
#     'saves': 53,
#     'saves_pct': 0.855},
#    'shorthanded': {'shots_against': 390,
#     'goals_against': 49,
#     'saves': 341,
#     'saves_pct': 0.874},
#    'evenstrength': {'shots_against': 1950,
#     'goals_against': 184,
#     'saves': 1766,
#     'saves_pct': 0.906},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 2.82, 'shots_against': 29.16},
#    'emptynet': {'total': {'goals_against': 12, 'shots_against': 12},
#     'powerplay': {'goals_against': 1},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 11}},
#    'time_on_ice': {'total': '4958:25'}}},
#  'Senators': {'statistics': {'total': {'games_played': 82,
#     'goals': 250,
#     'assists': 421,
#     'penalties': 336,
#     'penalty_minutes': 845,
#     'team_penalties': 7,
#     'team_penalty_minutes': 14,
#     'shots': 2602,
#     'blocked_att': 1427,
#     'missed_shots': 1159,
#     'hits': 1998,
#     'giveaways': 797,
#     'takeaways': 597,
#     'blocked_shots': 1356,
#     'faceoffs_won': 2376,
#     'faceoffs_lost': 2284,
#     'powerplays': 283,
#     'shooting_pct': 9.6,
#     'faceoff_win_pct': 51.0,
#     'faceoffs': 4660,
#     'points': 671,
#     'plus_minus': -119,
#     'overtime_goals': 7,
#     'overtime_assists': 12,
#     'overtime_shots': 41,
#     'emptynet_goals': 13,
#     'penalties_major': 24,
#     'penalties_match': 1,
#     'penalties_minor': 291,
#     'penalties_misconduct': 12},
#    'powerplay': {'faceoffs_won': 288,
#     'faceoffs_lost': 201,
#     'shots': 429,
#     'goals': 51,
#     'missed_shots': 206,
#     'assists': 101,
#     'faceoff_win_pct': 58.9,
#     'opportunities': 283,
#     'faceoffs': 489,
#     'percentage': 18.0,
#     'strength': [{'opportunities': 272,
#       'shots': 401,
#       'goals': 48,
#       'type': '5v4'},
#      {'opportunities': 9, 'shots': 13, 'goals': 0, 'type': '5v3'},
#      {'opportunities': 12, 'shots': 15, 'goals': 3, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 238,
#     'faceoffs_lost': 206,
#     'shots': 83,
#     'goals': 7,
#     'missed_shots': 17,
#     'assists': 6,
#     'faceoff_win_pct': 53.6,
#     'opportunities': 245,
#     'faceoffs': 444,
#     'goals_against': 61,
#     'kill_pct': 75.1,
#     'strength': [{'shots': 81, 'goals': 7, 'type': '4v5'},
#      {'shots': 1, 'goals': 0, 'type': '3v5'},
#      {'shots': 1, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1850,
#     'faceoffs_lost': 1877,
#     'shots': 2090,
#     'goals': 192,
#     'missed_shots': 936,
#     'assists': 314,
#     'faceoff_win_pct': 49.6,
#     'faceoffs': 3727,
#     'strength': [{'shots': 2012, 'goals': 178, 'type': '5v5'},
#      {'shots': 44, 'goals': 8, 'type': '4v4'},
#      {'shots': 34, 'goals': 6, 'type': '3v3'}]},
#    'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 5.13,
#     'blocked_shots': 16.54,
#     'points': 8.18,
#     'blocked_att': 17.4,
#     'team_penalty_minutes': 0.17,
#     'penalties': 4.1,
#     'missed_shots': 14.13,
#     'hits': 24.37,
#     'shots': 31.73,
#     'takeaways': 7.28,
#     'giveaways': 9.72,
#     'goals': 3.05,
#     'team_penalties': 0.09,
#     'penalty_minutes': 10.3}},
#   'shootout': {'shots': 12,
#    'missed_shots': 2,
#    'goals': 6,
#    'shots_against': 15,
#    'goals_against': 1,
#    'saves': 14,
#    'saves_pct': 0.933},
#   'goaltending': {'total': {'shots_against': 2422,
#     'goals_against': 271,
#     'saves': 2151,
#     'total_goals_against': 281,
#     'total_shots_against': 2432,
#     'saves_pct': 0.884,
#     'losses': 41,
#     'overtime_losses': 4,
#     'shutouts': 2,
#     'wins': 37},
#    'powerplay': {'shots_against': 71,
#     'goals_against': 5,
#     'saves': 66,
#     'saves_pct': 0.93},
#    'shorthanded': {'shots_against': 350,
#     'goals_against': 61,
#     'saves': 289,
#     'saves_pct': 0.826},
#    'evenstrength': {'shots_against': 2010,
#     'goals_against': 214,
#     'saves': 1796,
#     'saves_pct': 0.894},
#    'penalty': {'shots_against': 3,
#     'goals_against': 1,
#     'saves': 2,
#     'saves_pct': 0.667},
#    'average': {'goals_against': 3.3, 'shots_against': 29.54},
#    'emptynet': {'total': {'goals_against': 10, 'shots_against': 10},
#     'powerplay': {'goals_against': 1},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 9}},
#    'time_on_ice': {'total': '4974:57'}}},
#  'Sharks': {'statistics': {'total': {'games_played': 82,
#     'goals': 180,
#     'assists': 300,
#     'penalties': 312,
#     'penalty_minutes': 780,
#     'team_penalties': 6,
#     'team_penalty_minutes': 12,
#     'shots': 2069,
#     'blocked_att': 1295,
#     'missed_shots': 1006,
#     'hits': 1870,
#     'giveaways': 451,
#     'takeaways': 544,
#     'blocked_shots': 1491,
#     'faceoffs_won': 2300,
#     'faceoffs_lost': 2390,
#     'powerplays': 208,
#     'shooting_pct': 8.7,
#     'faceoff_win_pct': 49.0,
#     'faceoffs': 4690,
#     'points': 480,
#     'plus_minus': -645,
#     'overtime_goals': 4,
#     'overtime_assists': 5,
#     'overtime_shots': 22,
#     'emptynet_goals': 4,
#     'penalties_major': 20,
#     'penalties_match': 0,
#     'penalties_minor': 271,
#     'penalties_misconduct': 11},
#    'powerplay': {'faceoffs_won': 184,
#     'faceoffs_lost': 167,
#     'shots': 248,
#     'goals': 42,
#     'missed_shots': 135,
#     'assists': 80,
#     'faceoff_win_pct': 52.4,
#     'opportunities': 208,
#     'faceoffs': 351,
#     'percentage': 20.2,
#     'strength': [{'opportunities': 199,
#       'shots': 235,
#       'goals': 39,
#       'type': '5v4'},
#      {'opportunities': 5, 'shots': 2, 'goals': 0, 'type': '5v3'},
#      {'opportunities': 9, 'shots': 11, 'goals': 3, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 212,
#     'faceoffs_lost': 245,
#     'shots': 54,
#     'goals': 3,
#     'missed_shots': 14,
#     'assists': 4,
#     'faceoff_win_pct': 46.4,
#     'opportunities': 252,
#     'faceoffs': 457,
#     'goals_against': 62,
#     'kill_pct': 75.4,
#     'strength': [{'shots': 54, 'goals': 3, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1904,
#     'faceoffs_lost': 1978,
#     'shots': 1767,
#     'goals': 135,
#     'missed_shots': 857,
#     'assists': 216,
#     'faceoff_win_pct': 49.0,
#     'faceoffs': 3882,
#     'strength': [{'shots': 1724, 'goals': 130, 'type': '5v5'},
#      {'shots': 23, 'goals': 1, 'type': '4v4'},
#      {'shots': 20, 'goals': 4, 'type': '3v3'}]},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 3.66,
#     'blocked_shots': 18.18,
#     'points': 5.85,
#     'blocked_att': 15.79,
#     'team_penalty_minutes': 0.15,
#     'penalties': 3.8,
#     'missed_shots': 12.27,
#     'hits': 22.8,
#     'shots': 25.23,
#     'takeaways': 6.63,
#     'giveaways': 5.5,
#     'goals': 2.2,
#     'team_penalties': 0.07,
#     'penalty_minutes': 9.51}},
#   'shootout': {'shots': 22,
#    'missed_shots': 5,
#    'goals': 5,
#    'shots_against': 29,
#    'goals_against': 9,
#    'saves': 20,
#    'saves_pct': 0.69},
#   'goaltending': {'total': {'shots_against': 2863,
#     'goals_against': 308,
#     'saves': 2555,
#     'total_goals_against': 326,
#     'total_shots_against': 2881,
#     'saves_pct': 0.887,
#     'losses': 54,
#     'overtime_losses': 9,
#     'shutouts': 2,
#     'wins': 19},
#    'powerplay': {'shots_against': 83,
#     'goals_against': 6,
#     'saves': 77,
#     'saves_pct': 0.928},
#    'shorthanded': {'shots_against': 428,
#     'goals_against': 62,
#     'saves': 366,
#     'saves_pct': 0.855},
#    'evenstrength': {'shots_against': 2368,
#     'goals_against': 256,
#     'saves': 2112,
#     'saves_pct': 0.892},
#    'penalty': {'shots_against': 1,
#     'goals_against': 0,
#     'saves': 1,
#     'saves_pct': 1.0},
#    'average': {'goals_against': 3.76, 'shots_against': 34.91},
#    'emptynet': {'total': {'goals_against': 18, 'shots_against': 18},
#     'powerplay': {'goals_against': 2},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 16}},
#    'time_on_ice': {'total': '4970:09'}}},
#  'Stars': {'statistics': {'total': {'games_played': 82,
#     'goals': 294,
#     'assists': 505,
#     'penalties': 256,
#     'penalty_minutes': 554,
#     'team_penalties': 8,
#     'team_penalty_minutes': 16,
#     'shots': 2588,
#     'blocked_att': 1503,
#     'missed_shots': 1210,
#     'hits': 1458,
#     'giveaways': 668,
#     'takeaways': 560,
#     'blocked_shots': 1225,
#     'faceoffs_won': 2617,
#     'faceoffs_lost': 2228,
#     'powerplays': 240,
#     'shooting_pct': 11.4,
#     'faceoff_win_pct': 54.0,
#     'faceoffs': 4845,
#     'points': 799,
#     'plus_minus': 219,
#     'overtime_goals': 8,
#     'overtime_assists': 13,
#     'overtime_shots': 32,
#     'emptynet_goals': 13,
#     'penalties_major': 8,
#     'penalties_match': 0,
#     'penalties_minor': 234,
#     'penalties_misconduct': 1},
#    'powerplay': {'faceoffs_won': 238,
#     'faceoffs_lost': 171,
#     'shots': 360,
#     'goals': 58,
#     'missed_shots': 146,
#     'assists': 113,
#     'faceoff_win_pct': 58.2,
#     'opportunities': 240,
#     'faceoffs': 409,
#     'percentage': 24.2,
#     'strength': [{'opportunities': 231,
#       'shots': 341,
#       'goals': 57,
#       'type': '5v4'},
#      {'opportunities': 8, 'shots': 14, 'goals': 1, 'type': '5v3'},
#      {'opportunities': 3, 'shots': 5, 'goals': 0, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 185,
#     'faceoffs_lost': 221,
#     'shots': 73,
#     'goals': 12,
#     'missed_shots': 17,
#     'assists': 10,
#     'faceoff_win_pct': 45.6,
#     'opportunities': 239,
#     'faceoffs': 406,
#     'goals_against': 43,
#     'kill_pct': 82.0,
#     'strength': [{'shots': 72, 'goals': 12, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 1, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 2194,
#     'faceoffs_lost': 1836,
#     'shots': 2155,
#     'goals': 224,
#     'missed_shots': 1047,
#     'assists': 382,
#     'faceoff_win_pct': 54.4,
#     'faceoffs': 4030,
#     'strength': [{'shots': 2113, 'goals': 212, 'type': '5v5'},
#      {'shots': 15, 'goals': 4, 'type': '4v4'},
#      {'shots': 27, 'goals': 8, 'type': '3v3'}]},
#    'penalty': {'shots': 4, 'goals': 2, 'missed_shots': 0},
#    'average': {'assists': 6.16,
#     'blocked_shots': 14.94,
#     'points': 9.74,
#     'blocked_att': 18.33,
#     'team_penalty_minutes': 0.2,
#     'penalties': 3.12,
#     'missed_shots': 14.76,
#     'hits': 17.78,
#     'shots': 31.56,
#     'takeaways': 6.83,
#     'giveaways': 8.15,
#     'goals': 3.59,
#     'team_penalties': 0.1,
#     'penalty_minutes': 6.76}},
#   'shootout': {'shots': 22,
#    'missed_shots': 4,
#    'goals': 8,
#    'shots_against': 27,
#    'goals_against': 6,
#    'saves': 21,
#    'saves_pct': 0.778},
#   'goaltending': {'total': {'shots_against': 2343,
#     'goals_against': 225,
#     'saves': 2118,
#     'total_goals_against': 232,
#     'total_shots_against': 2350,
#     'saves_pct': 0.901,
#     'losses': 21,
#     'overtime_losses': 9,
#     'shutouts': 4,
#     'wins': 52},
#    'powerplay': {'shots_against': 70,
#     'goals_against': 4,
#     'saves': 66,
#     'saves_pct': 0.943},
#    'shorthanded': {'shots_against': 352,
#     'goals_against': 43,
#     'saves': 309,
#     'saves_pct': 0.878},
#    'evenstrength': {'shots_against': 1928,
#     'goals_against': 185,
#     'saves': 1743,
#     'saves_pct': 0.904},
#    'penalty': {'shots_against': 1,
#     'goals_against': 1,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 2.74, 'shots_against': 28.57},
#    'emptynet': {'total': {'goals_against': 7, 'shots_against': 7},
#     'powerplay': {'goals_against': 0},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 7}},
#    'time_on_ice': {'total': '4982:07'}}},
#  'Wild': {'statistics': {'total': {'games_played': 82,
#     'goals': 248,
#     'assists': 424,
#     'penalties': 351,
#     'penalty_minutes': 938,
#     'team_penalties': 6,
#     'team_penalty_minutes': 12,
#     'shots': 2471,
#     'blocked_att': 1401,
#     'missed_shots': 1131,
#     'hits': 1600,
#     'giveaways': 526,
#     'takeaways': 497,
#     'blocked_shots': 1305,
#     'faceoffs_won': 2192,
#     'faceoffs_lost': 2441,
#     'powerplays': 273,
#     'shooting_pct': 10.0,
#     'faceoff_win_pct': 47.3,
#     'faceoffs': 4633,
#     'points': 672,
#     'plus_minus': -43,
#     'overtime_goals': 4,
#     'overtime_assists': 7,
#     'overtime_shots': 26,
#     'emptynet_goals': 14,
#     'penalties_major': 36,
#     'penalties_match': 0,
#     'penalties_minor': 290,
#     'penalties_misconduct': 15},
#    'powerplay': {'faceoffs_won': 292,
#     'faceoffs_lost': 225,
#     'shots': 527,
#     'goals': 62,
#     'missed_shots': 229,
#     'assists': 120,
#     'faceoff_win_pct': 56.5,
#     'opportunities': 273,
#     'faceoffs': 517,
#     'percentage': 22.7,
#     'strength': [{'opportunities': 265,
#       'shots': 500,
#       'goals': 54,
#       'type': '5v4'},
#      {'opportunities': 15, 'shots': 25, 'goals': 7, 'type': '5v3'},
#      {'opportunities': 2, 'shots': 2, 'goals': 1, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 204,
#     'faceoffs_lost': 255,
#     'shots': 56,
#     'goals': 3,
#     'missed_shots': 12,
#     'assists': 3,
#     'faceoff_win_pct': 44.4,
#     'opportunities': 263,
#     'faceoffs': 459,
#     'goals_against': 67,
#     'kill_pct': 74.5,
#     'strength': [{'shots': 56, 'goals': 3, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1696,
#     'faceoffs_lost': 1961,
#     'shots': 1888,
#     'goals': 183,
#     'missed_shots': 890,
#     'assists': 301,
#     'faceoff_win_pct': 46.4,
#     'faceoffs': 3657,
#     'strength': [{'shots': 1843, 'goals': 176, 'type': '5v5'},
#      {'shots': 19, 'goals': 3, 'type': '4v4'},
#      {'shots': 26, 'goals': 4, 'type': '3v3'}]},
#    'penalty': {'shots': 1, 'goals': 0, 'missed_shots': 1},
#    'average': {'assists': 5.17,
#     'blocked_shots': 15.91,
#     'points': 8.2,
#     'blocked_att': 17.09,
#     'team_penalty_minutes': 0.15,
#     'penalties': 4.28,
#     'missed_shots': 13.79,
#     'hits': 19.51,
#     'shots': 30.13,
#     'takeaways': 6.06,
#     'giveaways': 6.41,
#     'goals': 3.02,
#     'team_penalties': 0.07,
#     'penalty_minutes': 11.44}},
#   'shootout': {'shots': 18,
#    'missed_shots': 6,
#    'goals': 6,
#    'shots_against': 24,
#    'goals_against': 6,
#    'saves': 18,
#    'saves_pct': 0.75},
#   'goaltending': {'total': {'shots_against': 2426,
#     'goals_against': 249,
#     'saves': 2177,
#     'total_goals_against': 260,
#     'total_shots_against': 2437,
#     'saves_pct': 0.893,
#     'losses': 34,
#     'overtime_losses': 9,
#     'shutouts': 6,
#     'wins': 39},
#    'powerplay': {'shots_against': 56,
#     'goals_against': 9,
#     'saves': 47,
#     'saves_pct': 0.839},
#    'shorthanded': {'shots_against': 456,
#     'goals_against': 67,
#     'saves': 389,
#     'saves_pct': 0.853},
#    'evenstrength': {'shots_against': 1923,
#     'goals_against': 182,
#     'saves': 1741,
#     'saves_pct': 0.905},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 3.04, 'shots_against': 29.59},
#    'emptynet': {'total': {'goals_against': 11, 'shots_against': 11},
#     'powerplay': {'goals_against': 2},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 9}},
#    'time_on_ice': {'total': '4984:12'}}}}

# %%
simplified_data_list = []

# Extracting and formatting the data
for team, team_data in team_name_and_records.items():
    # Check if 'statistics' key exists in the team's data
    if 'statistics' in team_data:
        stats = team_data['statistics']
        goaltending_stats = team_data['goaltending']
        team_info = {
            'team_name': team,
            'games_played': stats['total'].get('games_played', 0),
            'goals': stats['total'].get('goals', 0),
            'assists': stats['total'].get('assists', 0),
            'penalties': stats['total'].get('penalties', 0),
            'penalty_minutes': stats['total'].get('penalty_minutes', 0),
            'shots': stats['total'].get('shots', 0),
            'hits': stats['total'].get('hits', 0),
            'blocked_shots': stats['total'].get('blocked_shots', 0),
            'powerplays': stats['total'].get('powerplays', 0),
            'points': stats['total'].get('points', 0),
            'powerplay_shots': stats['powerplay'].get('shots', 0),
            'powerplay_goals': stats['powerplay'].get('goals', 0),
            'powerplay_percentage': stats['powerplay'].get('percentage', 0.0),
            'shots_against': goaltending_stats['total'].get('shots_against', 0.0),  
            'goals_against': goaltending_stats['total'].get('goals_against', 0),  
            'saves': goaltending_stats['total'].get('saves', 0),  
            'saves_percentage': goaltending_stats['total'].get('saves_pct', 0.0),  
        }
        simplified_data_list.append(team_info)
    else:
        print(f"Missing 'statistics' for team: {team}")

# %%
simplified_data_list
# Out:
# [{'team_name': 'Avalanche',
#   'games_played': 82,
#   'goals': 302,
#   'assists': 525,
#   'penalties': 307,
#   'penalty_minutes': 731,
#   'shots': 2705,
#   'hits': 1671,
#   'blocked_shots': 1214,
#   'powerplays': 278,
#   'points': 827,
#   'powerplay_shots': 443,
#   'powerplay_goals': 68,
#   'powerplay_percentage': 24.5,
#   'shots_against': 2432,
#   'goals_against': 239,
#   'saves': 2193,
#   'saves_percentage': 0.897},
#  {'team_name': 'Blackhawks',
#   'games_played': 82,
#   'goals': 178,
#   'assists': 303,
#   'penalties': 292,
#   'penalty_minutes': 715,
#   'shots': 2153,
#   'hits': 1874,
#   'blocked_shots': 1340,
#   'powerplays': 235,
#   'points': 481,
#   'powerplay_shots': 314,
#   'powerplay_goals': 39,
#   'powerplay_percentage': 16.6,
#   'shots_against': 2667,
#   'goals_against': 274,
#   'saves': 2393,
#   'saves_percentage': 0.892},
#  {'team_name': 'Blue Jackets',
#   'games_played': 82,
#   'goals': 234,
#   'assists': 389,
#   'penalties': 291,
#   'penalty_minutes': 670,
#   'shots': 2458,
#   'hits': 1577,
#   'blocked_shots': 1396,
#   'powerplays': 212,
#   'points': 623,
#   'powerplay_shots': 329,
#   'powerplay_goals': 32,
#   'powerplay_percentage': 15.1,
#   'shots_against': 2803,
#   'goals_against': 279,
#   'saves': 2524,
#   'saves_percentage': 0.894},
#  {'team_name': 'Blues',
#   'games_played': 82,
#   'goals': 234,
#   'assists': 401,
#   'penalties': 263,
#   'penalty_minutes': 608,
#   'shots': 2370,
#   'hits': 1654,
#   'blocked_shots': 1219,
#   'powerplays': 250,
#   'points': 635,
#   'powerplay_shots': 362,
#   'powerplay_goals': 45,
#   'powerplay_percentage': 18.0,
#   'shots_against': 2616,
#   'goals_against': 228,
#   'saves': 2388,
#   'saves_percentage': 0.906},
#  {'team_name': 'Bruins',
#   'games_played': 82,
#   'goals': 263,
#   'assists': 443,
#   'penalties': 334,
#   'penalty_minutes': 776,
#   'shots': 2399,
#   'hits': 2258,
#   'blocked_shots': 1299,
#   'powerplays': 243,
#   'points': 706,
#   'powerplay_shots': 386,
#   'powerplay_goals': 54,
#   'powerplay_percentage': 22.2,
#   'shots_against': 2495,
#   'goals_against': 211,
#   'saves': 2284,
#   'saves_percentage': 0.912},
#  {'team_name': 'Canadiens',
#   'games_played': 82,
#   'goals': 232,
#   'assists': 380,
#   'penalties': 348,
#   'penalty_minutes': 825,
#   'shots': 2269,
#   'hits': 1808,
#   'blocked_shots': 1464,
#   'powerplays': 252,
#   'points': 612,
#   'powerplay_shots': 344,
#   'powerplay_goals': 44,
#   'powerplay_percentage': 17.5,
#   'shots_against': 2724,
#   'goals_against': 267,
#   'saves': 2457,
#   'saves_percentage': 0.897},
#  {'team_name': 'Canucks',
#   'games_played': 82,
#   'goals': 279,
#   'assists': 484,
#   'penalties': 314,
#   'penalty_minutes': 764,
#   'shots': 2328,
#   'hits': 2178,
#   'blocked_shots': 1152,
#   'powerplays': 257,
#   'points': 763,
#   'powerplay_shots': 393,
#   'powerplay_goals': 58,
#   'powerplay_percentage': 22.6,
#   'shots_against': 2335,
#   'goals_against': 213,
#   'saves': 2122,
#   'saves_percentage': 0.906},
#  {'team_name': 'Capitals',
#   'games_played': 82,
#   'goals': 216,
#   'assists': 371,
#   'penalties': 272,
#   'penalty_minutes': 628,
#   'shots': 2173,
#   'hits': 1880,
#   'blocked_shots': 1419,
#   'powerplays': 228,
#   'points': 587,
#   'powerplay_shots': 349,
#   'powerplay_goals': 47,
#   'powerplay_percentage': 20.6,
#   'shots_against': 2494,
#   'goals_against': 243,
#   'saves': 2251,
#   'saves_percentage': 0.899},
#  {'team_name': 'Coyotes',
#   'games_played': 82,
#   'goals': 254,
#   'assists': 424,
#   'penalties': 358,
#   'penalty_minutes': 944,
#   'shots': 2273,
#   'hits': 1849,
#   'blocked_shots': 1228,
#   'powerplays': 241,
#   'points': 678,
#   'powerplay_shots': 329,
#   'powerplay_goals': 53,
#   'powerplay_percentage': 22.0,
#   'shots_against': 2579,
#   'goals_against': 255,
#   'saves': 2324,
#   'saves_percentage': 0.895},
#  {'team_name': 'Devils',
#   'games_played': 82,
#   'goals': 264,
#   'assists': 423,
#   'penalties': 303,
#   'penalty_minutes': 747,
#   'shots': 2516,
#   'hits': 1668,
#   'blocked_shots': 1116,
#   'powerplays': 245,
#   'points': 687,
#   'powerplay_shots': 368,
#   'powerplay_goals': 55,
#   'powerplay_percentage': 22.4,
#   'shots_against': 2431,
#   'goals_against': 254,
#   'saves': 2177,
#   'saves_percentage': 0.886},
#  {'team_name': 'Ducks',
#   'games_played': 82,
#   'goals': 203,
#   'assists': 351,
#   'penalties': 440,
#   'penalty_minutes': 1108,
#   'shots': 2194,
#   'hits': 1912,
#   'blocked_shots': 1343,
#   'powerplays': 235,
#   'points': 554,
#   'powerplay_shots': 322,
#   'powerplay_goals': 43,
#   'powerplay_percentage': 18.3,
#   'shots_against': 2653,
#   'goals_against': 280,
#   'saves': 2373,
#   'saves_percentage': 0.89},
#  {'team_name': 'Flames',
#   'games_played': 82,
#   'goals': 253,
#   'assists': 433,
#   'penalties': 317,
#   'penalty_minutes': 757,
#   'shots': 2572,
#   'hits': 1749,
#   'blocked_shots': 1379,
#   'powerplays': 252,
#   'points': 686,
#   'powerplay_shots': 363,
#   'powerplay_goals': 45,
#   'powerplay_percentage': 17.9,
#   'shots_against': 2420,
#   'goals_against': 249,
#   'saves': 2171,
#   'saves_percentage': 0.89},
#  {'team_name': 'Flyers',
#   'games_played': 82,
#   'goals': 231,
#   'assists': 369,
#   'penalties': 321,
#   'penalty_minutes': 830,
#   'shots': 2708,
#   'hits': 2024,
#   'blocked_shots': 1533,
#   'powerplays': 254,
#   'points': 600,
#   'powerplay_shots': 380,
#   'powerplay_goals': 31,
#   'powerplay_percentage': 12.2,
#   'shots_against': 2212,
#   'goals_against': 245,
#   'saves': 1967,
#   'saves_percentage': 0.884},
#  {'team_name': 'Golden Knights',
#   'games_played': 82,
#   'goals': 263,
#   'assists': 459,
#   'penalties': 248,
#   'penalty_minutes': 605,
#   'shots': 2548,
#   'hits': 2022,
#   'blocked_shots': 1506,
#   'powerplays': 252,
#   'points': 722,
#   'powerplay_shots': 385,
#   'powerplay_goals': 51,
#   'powerplay_percentage': 20.2,
#   'shots_against': 2473,
#   'goals_against': 229,
#   'saves': 2244,
#   'saves_percentage': 0.902},
#  {'team_name': 'Hurricanes',
#   'games_played': 82,
#   'goals': 277,
#   'assists': 485,
#   'penalties': 300,
#   'penalty_minutes': 693,
#   'shots': 2733,
#   'hits': 1384,
#   'blocked_shots': 937,
#   'powerplays': 249,
#   'points': 762,
#   'powerplay_shots': 391,
#   'powerplay_goals': 67,
#   'powerplay_percentage': 26.9,
#   'shots_against': 2089,
#   'goals_against': 199,
#   'saves': 1890,
#   'saves_percentage': 0.9},
#  {'team_name': 'Islanders',
#   'games_played': 82,
#   'goals': 245,
#   'assists': 410,
#   'penalties': 259,
#   'penalty_minutes': 586,
#   'shots': 2470,
#   'hits': 2061,
#   'blocked_shots': 1551,
#   'powerplays': 231,
#   'points': 655,
#   'powerplay_shots': 327,
#   'powerplay_goals': 47,
#   'powerplay_percentage': 20.3,
#   'shots_against': 2667,
#   'goals_against': 238,
#   'saves': 2429,
#   'saves_percentage': 0.904},
#  {'team_name': 'Jets',
#   'games_played': 82,
#   'goals': 259,
#   'assists': 440,
#   'penalties': 275,
#   'penalty_minutes': 659,
#   'shots': 2488,
#   'hits': 1854,
#   'blocked_shots': 1230,
#   'powerplays': 240,
#   'points': 699,
#   'powerplay_shots': 334,
#   'powerplay_goals': 45,
#   'powerplay_percentage': 18.8,
#   'shots_against': 2418,
#   'goals_against': 187,
#   'saves': 2231,
#   'saves_percentage': 0.918},
#  {'team_name': 'Kings',
#   'games_played': 82,
#   'goals': 254,
#   'assists': 431,
#   'penalties': 303,
#   'penalty_minutes': 715,
#   'shots': 2616,
#   'hits': 1763,
#   'blocked_shots': 1267,
#   'powerplays': 248,
#   'points': 685,
#   'powerplay_shots': 332,
#   'powerplay_goals': 56,
#   'powerplay_percentage': 22.6,
#   'shots_against': 2288,
#   'goals_against': 202,
#   'saves': 2086,
#   'saves_percentage': 0.909},
#  {'team_name': 'Kraken',
#   'games_played': 82,
#   'goals': 214,
#   'assists': 372,
#   'penalties': 267,
#   'penalty_minutes': 653,
#   'shots': 2347,
#   'hits': 1831,
#   'blocked_shots': 1218,
#   'powerplays': 242,
#   'points': 586,
#   'powerplay_shots': 312,
#   'powerplay_goals': 50,
#   'powerplay_percentage': 20.7,
#   'shots_against': 2375,
#   'goals_against': 216,
#   'saves': 2159,
#   'saves_percentage': 0.903},
#  {'team_name': 'Lightning',
#   'games_played': 82,
#   'goals': 288,
#   'assists': 496,
#   'penalties': 330,
#   'penalty_minutes': 901,
#   'shots': 2401,
#   'hits': 1984,
#   'blocked_shots': 1247,
#   'powerplays': 248,
#   'points': 784,
#   'powerplay_shots': 385,
#   'powerplay_goals': 71,
#   'powerplay_percentage': 28.6,
#   'shots_against': 2414,
#   'goals_against': 251,
#   'saves': 2163,
#   'saves_percentage': 0.89},
#  {'team_name': 'Maple Leafs',
#   'games_played': 82,
#   'goals': 298,
#   'assists': 487,
#   'penalties': 320,
#   'penalty_minutes': 815,
#   'shots': 2671,
#   'hits': 2279,
#   'blocked_shots': 1352,
#   'powerplays': 238,
#   'points': 785,
#   'powerplay_shots': 389,
#   'powerplay_goals': 57,
#   'powerplay_percentage': 23.9,
#   'shots_against': 2433,
#   'goals_against': 248,
#   'saves': 2185,
#   'saves_percentage': 0.893},
#  {'team_name': 'Oilers',
#   'games_played': 82,
#   'goals': 292,
#   'assists': 507,
#   'penalties': 321,
#   'penalty_minutes': 780,
#   'shots': 2768,
#   'hits': 1876,
#   'blocked_shots': 1103,
#   'powerplays': 243,
#   'points': 799,
#   'powerplay_shots': 379,
#   'powerplay_goals': 64,
#   'powerplay_percentage': 26.3,
#   'shots_against': 2291,
#   'goals_against': 220,
#   'saves': 2071,
#   'saves_percentage': 0.898},
#  {'team_name': 'Panthers',
#   'games_played': 82,
#   'goals': 265,
#   'assists': 445,
#   'penalties': 415,
#   'penalty_minutes': 1106,
#   'shots': 2764,
#   'hits': 2344,
#   'blocked_shots': 1044,
#   'powerplays': 268,
#   'points': 710,
#   'powerplay_shots': 494,
#   'powerplay_goals': 63,
#   'powerplay_percentage': 23.5,
#   'shots_against': 2268,
#   'goals_against': 186,
#   'saves': 2082,
#   'saves_percentage': 0.913},
#  {'team_name': 'Penguins',
#   'games_played': 82,
#   'goals': 253,
#   'assists': 420,
#   'penalties': 274,
#   'penalty_minutes': 603,
#   'shots': 2685,
#   'hits': 1631,
#   'blocked_shots': 1250,
#   'powerplays': 262,
#   'points': 673,
#   'powerplay_shots': 417,
#   'powerplay_goals': 40,
#   'powerplay_percentage': 15.3,
#   'shots_against': 2472,
#   'goals_against': 240,
#   'saves': 2232,
#   'saves_percentage': 0.9},
#  {'team_name': 'Predators',
#   'games_played': 82,
#   'goals': 266,
#   'assists': 449,
#   'penalties': 309,
#   'penalty_minutes': 776,
#   'shots': 2642,
#   'hits': 2153,
#   'blocked_shots': 1265,
#   'powerplays': 269,
#   'points': 715,
#   'powerplay_shots': 414,
#   'powerplay_goals': 58,
#   'powerplay_percentage': 21.6,
#   'shots_against': 2490,
#   'goals_against': 231,
#   'saves': 2259,
#   'saves_percentage': 0.901},
#  {'team_name': 'Rangers',
#   'games_played': 82,
#   'goals': 278,
#   'assists': 476,
#   'penalties': 303,
#   'penalty_minutes': 763,
#   'shots': 2582,
#   'hits': 1981,
#   'blocked_shots': 1289,
#   'powerplays': 246,
#   'points': 754,
#   'powerplay_shots': 412,
#   'powerplay_goals': 65,
#   'powerplay_percentage': 26.4,
#   'shots_against': 2403,
#   'goals_against': 211,
#   'saves': 2192,
#   'saves_percentage': 0.907},
#  {'team_name': 'Red Wings',
#   'games_played': 82,
#   'goals': 275,
#   'assists': 464,
#   'penalties': 312,
#   'penalty_minutes': 706,
#   'shots': 2375,
#   'hits': 1684,
#   'blocked_shots': 1361,
#   'powerplays': 273,
#   'points': 739,
#   'powerplay_shots': 426,
#   'powerplay_goals': 63,
#   'powerplay_percentage': 23.1,
#   'shots_against': 2644,
#   'goals_against': 260,
#   'saves': 2384,
#   'saves_percentage': 0.897},
#  {'team_name': 'Sabres',
#   'games_played': 82,
#   'goals': 244,
#   'assists': 391,
#   'penalties': 309,
#   'penalty_minutes': 789,
#   'shots': 2534,
#   'hits': 1788,
#   'blocked_shots': 1201,
#   'powerplays': 223,
#   'points': 635,
#   'powerplay_shots': 347,
#   'powerplay_goals': 37,
#   'powerplay_percentage': 16.6,
#   'shots_against': 2391,
#   'goals_against': 231,
#   'saves': 2160,
#   'saves_percentage': 0.899},
#  {'team_name': 'Senators',
#   'games_played': 82,
#   'goals': 250,
#   'assists': 421,
#   'penalties': 336,
#   'penalty_minutes': 845,
#   'shots': 2602,
#   'hits': 1998,
#   'blocked_shots': 1356,
#   'powerplays': 283,
#   'points': 671,
#   'powerplay_shots': 429,
#   'powerplay_goals': 51,
#   'powerplay_percentage': 18.0,
#   'shots_against': 2422,
#   'goals_against': 271,
#   'saves': 2151,
#   'saves_percentage': 0.884},
#  {'team_name': 'Sharks',
#   'games_played': 82,
#   'goals': 180,
#   'assists': 300,
#   'penalties': 312,
#   'penalty_minutes': 780,
#   'shots': 2069,
#   'hits': 1870,
#   'blocked_shots': 1491,
#   'powerplays': 208,
#   'points': 480,
#   'powerplay_shots': 248,
#   'powerplay_goals': 42,
#   'powerplay_percentage': 20.2,
#   'shots_against': 2863,
#   'goals_against': 308,
#   'saves': 2555,
#   'saves_percentage': 0.887},
#  {'team_name': 'Stars',
#   'games_played': 82,
#   'goals': 294,
#   'assists': 505,
#   'penalties': 256,
#   'penalty_minutes': 554,
#   'shots': 2588,
#   'hits': 1458,
#   'blocked_shots': 1225,
#   'powerplays': 240,
#   'points': 799,
#   'powerplay_shots': 360,
#   'powerplay_goals': 58,
#   'powerplay_percentage': 24.2,
#   'shots_against': 2343,
#   'goals_against': 225,
#   'saves': 2118,
#   'saves_percentage': 0.901},
#  {'team_name': 'Wild',
#   'games_played': 82,
#   'goals': 248,
#   'assists': 424,
#   'penalties': 351,
#   'penalty_minutes': 938,
#   'shots': 2471,
#   'hits': 1600,
#   'blocked_shots': 1305,
#   'powerplays': 273,
#   'points': 672,
#   'powerplay_shots': 527,
#   'powerplay_goals': 62,
#   'powerplay_percentage': 22.7,
#   'shots_against': 2426,
#   'goals_against': 249,
#   'saves': 2177,
#   'saves_percentage': 0.893}]

# %%
type(simplified_data_list)
# Out:
# list

# %%
# dictionary to store data
team_stats = {
    'name':[],
    'games_played':[],
    'goals': [],
    'assists':[],
    'points': [],
    'penalties':[],
    'penalty_minutes':[],
    'shots':[],
    'hits':[],
    'blocked_shots':[],
    'powerplays':[],
    'powerplay_shots':[],
    'powerplay_goals':[],
    'powerplay_percentage':[],
    'shots_against':[],
    'goals_against':[],
    'saves':[],
    'saves_percentage':[]
}
# loop for get the data
for stat in simplified_data_list:
    name = stat['team_name']
    team_stats['name'].append(name)
    print(name)
    
    games_played = stat['games_played']
    team_stats['games_played'].append(games_played)
    print(games_played)
    
    goals = stat['goals']
    team_stats['goals'].append(goals)
    print(goals)
    
    assists = stat['assists']
    team_stats['assists'].append(assists)
    print(assists)
    
    penalties = stat['penalties']
    team_stats['penalties'].append(penalties)
    print(penalties)
    
    penalty_minutes = stat['penalty_minutes']
    team_stats['penalty_minutes'].append(penalty_minutes)
    print(penalty_minutes)
    
    shots = stat['shots']
    team_stats['shots'].append(shots)
    print(shots)
    
    hits = stat['hits']
    team_stats['hits'].append(hits)
    print(hits)
    
    blocked_shots = stat['blocked_shots']
    team_stats['blocked_shots'].append(blocked_shots)
    print(blocked_shots)
    
    powerplays = stat['powerplays']
    team_stats['powerplays'].append(powerplays)
    print(powerplays)
    
    points = stat['points']
    team_stats['points'].append(points)
    print(points)
    
    powerplay_shots = stat['powerplay_shots']
    team_stats['powerplay_shots'].append(powerplay_shots)
    print(powerplay_shots)
    
    powerplay_goals = stat['powerplay_goals']
    team_stats['powerplay_goals'].append(powerplay_goals)
    print(powerplay_goals)
    
    powerplay_percentage = stat['powerplay_percentage']
    team_stats['powerplay_percentage'].append(powerplay_percentage)
    print(powerplay_percentage)
    
    shots_against = stat['shots_against']
    team_stats['shots_against'].append(shots_against)
    print(shots_against)
    
    goals_against = stat['goals_against']
    team_stats['goals_against'].append(goals_against)
    print(powerplay_percentage)
    
    saves = stat['saves']
    team_stats['saves'].append(saves)
    print(saves)
    
    saves_percentage = stat['saves_percentage']
    team_stats['saves_percentage'].append(saves_percentage)
    print(saves_percentage)
# Out:
# Avalanche
# 82
# 302
# 525
# 307
# 731
# 2705
# 1671
# 1214
# 278
# 827
# 443
# 68
# 24.5
# 2432
# 24.5
# 2193
# 0.897
# Blackhawks
# 82
# 178
# 303
# 292
# 715
# 2153
# 1874
# 1340
# 235
# 481
# 314
# 39
# 16.6
# 2667
# 16.6
# 2393
# 0.892
# Blue Jackets
# 82
# 234
# 389
# 291
# 670
# 2458
# 1577
# 1396
# 212
# 623
# 329
# 32
# 15.1
# 2803
# 15.1
# 2524
# 0.894
# Blues
# 82
# 234
# 401
# 263
# 608
# 2370
# 1654
# 1219
# 250
# 635
# 362
# 45
# 18.0
# 2616
# 18.0
# 2388
# 0.906
# Bruins
# 82
# 263
# 443
# 334
# 776
# 2399
# 2258
# 1299
# 243
# 706
# 386
# 54
# 22.2
# 2495
# 22.2
# 2284
# 0.912
# Canadiens
# 82
# 232
# 380
# 348
# 825
# 2269
# 1808
# 1464
# 252
# 612
# 344
# 44
# 17.5
# 2724
# 17.5
# 2457
# 0.897
# Canucks
# 82
# 279
# 484
# 314
# 764
# 2328
# 2178
# 1152
# 257
# 763
# 393
# 58
# 22.6
# 2335
# 22.6
# 2122
# 0.906
# Capitals
# 82
# 216
# 371
# 272
# 628
# 2173
# 1880
# 1419
# 228
# 587
# 349
# 47
# 20.6
# 2494
# 20.6
# 2251
# 0.899
# Coyotes
# 82
# 254
# 424
# 358
# 944
# 2273
# 1849
# 1228
# 241
# 678
# 329
# 53
# 22.0
# 2579
# 22.0
# 2324
# 0.895
# Devils
# 82
# 264
# 423
# 303
# 747
# 2516
# 1668
# 1116
# 245
# 687
# 368
# 55
# 22.4
# 2431
# 22.4
# 2177
# 0.886
# Ducks
# 82
# 203
# 351
# 440
# 1108
# 2194
# 1912
# 1343
# 235
# 554
# 322
# 43
# 18.3
# 2653
# 18.3
# 2373
# 0.89
# Flames
# 82
# 253
# 433
# 317
# 757
# 2572
# 1749
# 1379
# 252
# 686
# 363
# 45
# 17.9
# 2420
# 17.9
# 2171
# 0.89
# Flyers
# 82
# 231
# 369
# 321
# 830
# 2708
# 2024
# 1533
# 254
# 600
# 380
# 31
# 12.2
# 2212
# 12.2
# 1967
# 0.884
# Golden Knights
# 82
# 263
# 459
# 248
# 605
# 2548
# 2022
# 1506
# 252
# 722
# 385
# 51
# 20.2
# 2473
# 20.2
# 2244
# 0.902
# Hurricanes
# 82
# 277
# 485
# 300
# 693
# 2733
# 1384
# 937
# 249
# 762
# 391
# 67
# 26.9
# 2089
# 26.9
# 1890
# 0.9
# Islanders
# 82
# 245
# 410
# 259
# 586
# 2470
# 2061
# 1551
# 231
# 655
# 327
# 47
# 20.3
# 2667
# 20.3
# 2429
# 0.904
# Jets
# 82
# 259
# 440
# 275
# 659
# 2488
# 1854
# 1230
# 240
# 699
# 334
# 45
# 18.8
# 2418
# 18.8
# 2231
# 0.918
# Kings
# 82
# 254
# 431
# 303
# 715
# 2616
# 1763
# 1267
# 248
# 685
# 332
# 56
# 22.6
# 2288
# 22.6
# 2086
# 0.909
# Kraken
# 82
# 214
# 372
# 267
# 653
# 2347
# 1831
# 1218
# 242
# 586
# 312
# 50
# 20.7
# 2375
# 20.7
# 2159
# 0.903
# Lightning
# 82
# 288
# 496
# 330
# 901
# 2401
# 1984
# 1247
# 248
# 784
# 385
# 71
# 28.6
# 2414
# 28.6
# 2163
# 0.89
# Maple Leafs
# 82
# 298
# 487
# 320
# 815
# 2671
# 2279
# 1352
# 238
# 785
# 389
# 57
# 23.9
# 2433
# 23.9
# 2185
# 0.893
# Oilers
# 82
# 292
# 507
# 321
# 780
# 2768
# 1876
# 1103
# 243
# 799
# 379
# 64
# 26.3
# 2291
# 26.3
# 2071
# 0.898
# Panthers
# 82
# 265
# 445
# 415
# 1106
# 2764
# 2344
# 1044
# 268
# 710
# 494
# 63
# 23.5
# 2268
# 23.5
# 2082
# 0.913
# Penguins
# 82
# 253
# 420
# 274
# 603
# 2685
# 1631
# 1250
# 262
# 673
# 417
# 40
# 15.3
# 2472
# 15.3
# 2232
# 0.9
# Predators
# 82
# 266
# 449
# 309
# 776
# 2642
# 2153
# 1265
# 269
# 715
# 414
# 58
# 21.6
# 2490
# 21.6
# 2259
# 0.901
# Rangers
# 82
# 278
# 476
# 303
# 763
# 2582
# 1981
# 1289
# 246
# 754
# 412
# 65
# 26.4
# 2403
# 26.4
# 2192
# 0.907
# Red Wings
# 82
# 275
# 464
# 312
# 706
# 2375
# 1684
# 1361
# 273
# 739
# 426
# 63
# 23.1
# 2644
# 23.1
# 2384
# 0.897
# Sabres
# 82
# 244
# 391
# 309
# 789
# 2534
# 1788
# 1201
# 223
# 635
# 347
# 37
# 16.6
# 2391
# 16.6
# 2160
# 0.899
# Senators
# 82
# 250
# 421
# 336
# 845
# 2602
# 1998
# 1356
# 283
# 671
# 429
# 51
# 18.0
# 2422
# 18.0
# 2151
# 0.884
# Sharks
# 82
# 180
# 300
# 312
# 780
# 2069
# 1870
# 1491
# 208
# 480
# 248
# 42
# 20.2
# 2863
# 20.2
# 2555
# 0.887
# Stars
# 82
# 294
# 505
# 256
# 554
# 2588
# 1458
# 1225
# 240
# 799
# 360
# 58
# 24.2
# 2343
# 24.2
# 2118
# 0.901
# Wild
# 82
# 248
# 424
# 351
# 938
# 2471
# 1600
# 1305
# 273
# 672
# 527
# 62
# 22.7
# 2426
# 22.7
# 2177
# 0.893

# %%
team_stats
# Out:
# {'name': ['Avalanche',
#   'Blackhawks',
#   'Blue Jackets',
#   'Blues',
#   'Bruins',
#   'Canadiens',
#   'Canucks',
#   'Capitals',
#   'Coyotes',
#   'Devils',
#   'Ducks',
#   'Flames',
#   'Flyers',
#   'Golden Knights',
#   'Hurricanes',
#   'Islanders',
#   'Jets',
#   'Kings',
#   'Kraken',
#   'Lightning',
#   'Maple Leafs',
#   'Oilers',
#   'Panthers',
#   'Penguins',
#   'Predators',
#   'Rangers',
#   'Red Wings',
#   'Sabres',
#   'Senators',
#   'Sharks',
#   'Stars',
#   'Wild'],
#  'games_played': [82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82,
#   82],
#  'goals': [302,
#   178,
#   234,
#   234,
#   263,
#   232,
#   279,
#   216,
#   254,
#   264,
#   203,
#   253,
#   231,
#   263,
#   277,
#   245,
#   259,
#   254,
#   214,
#   288,
#   298,
#   292,
#   265,
#   253,
#   266,
#   278,
#   275,
#   244,
#   250,
#   180,
#   294,
#   248],
#  'assists': [525,
#   303,
#   389,
#   401,
#   443,
#   380,
#   484,
#   371,
#   424,
#   423,
#   351,
#   433,
#   369,
#   459,
#   485,
#   410,
#   440,
#   431,
#   372,
#   496,
#   487,
#   507,
#   445,
#   420,
#   449,
#   476,
#   464,
#   391,
#   421,
#   300,
#   505,
#   424],
#  'points': [827,
#   481,
#   623,
#   635,
#   706,
#   612,
#   763,
#   587,
#   678,
#   687,
#   554,
#   686,
#   600,
#   722,
#   762,
#   655,
#   699,
#   685,
#   586,
#   784,
#   785,
#   799,
#   710,
#   673,
#   715,
#   754,
#   739,
#   635,
#   671,
#   480,
#   799,
#   672],
#  'penalties': [307,
#   292,
#   291,
#   263,
#   334,
#   348,
#   314,
#   272,
#   358,
#   303,
#   440,
#   317,
#   321,
#   248,
#   300,
#   259,
#   275,
#   303,
#   267,
#   330,
#   320,
#   321,
#   415,
#   274,
#   309,
#   303,
#   312,
#   309,
#   336,
#   312,
#   256,
#   351],
#  'penalty_minutes': [731,
#   715,
#   670,
#   608,
#   776,
#   825,
#   764,
#   628,
#   944,
#   747,
#   1108,
#   757,
#   830,
#   605,
#   693,
#   586,
#   659,
#   715,
#   653,
#   901,
#   815,
#   780,
#   1106,
#   603,
#   776,
#   763,
#   706,
#   789,
#   845,
#   780,
#   554,
#   938],
#  'shots': [2705,
#   2153,
#   2458,
#   2370,
#   2399,
#   2269,
#   2328,
#   2173,
#   2273,
#   2516,
#   2194,
#   2572,
#   2708,
#   2548,
#   2733,
#   2470,
#   2488,
#   2616,
#   2347,
#   2401,
#   2671,
#   2768,
#   2764,
#   2685,
#   2642,
#   2582,
#   2375,
#   2534,
#   2602,
#   2069,
#   2588,
#   2471],
#  'hits': [1671,
#   1874,
#   1577,
#   1654,
#   2258,
#   1808,
#   2178,
#   1880,
#   1849,
#   1668,
#   1912,
#   1749,
#   2024,
#   2022,
#   1384,
#   2061,
#   1854,
#   1763,
#   1831,
#   1984,
#   2279,
#   1876,
#   2344,
#   1631,
#   2153,
#   1981,
#   1684,
#   1788,
#   1998,
#   1870,
#   1458,
#   1600],
#  'blocked_shots': [1214,
#   1340,
#   1396,
#   1219,
#   1299,
#   1464,
#   1152,
#   1419,
#   1228,
#   1116,
#   1343,
#   1379,
#   1533,
#   1506,
#   937,
#   1551,
#   1230,
#   1267,
#   1218,
#   1247,
#   1352,
#   1103,
#   1044,
#   1250,
#   1265,
#   1289,
#   1361,
#   1201,
#   1356,
#   1491,
#   1225,
#   1305],
#  'powerplays': [278,
#   235,
#   212,
#   250,
#   243,
#   252,
#   257,
#   228,
#   241,
#   245,
#   235,
#   252,
#   254,
#   252,
#   249,
#   231,
#   240,
#   248,
#   242,
#   248,
#   238,
#   243,
#   268,
#   262,
#   269,
#   246,
#   273,
#   223,
#   283,
#   208,
#   240,
#   273],
#  'powerplay_shots': [443,
#   314,
#   329,
#   362,
#   386,
#   344,
#   393,
#   349,
#   329,
#   368,
#   322,
#   363,
#   380,
#   385,
#   391,
#   327,
#   334,
#   332,
#   312,
#   385,
#   389,
#   379,
#   494,
#   417,
#   414,
#   412,
#   426,
#   347,
#   429,
#   248,
#   360,
#   527],
#  'powerplay_goals': [68,
#   39,
#   32,
#   45,
#   54,
#   44,
#   58,
#   47,
#   53,
#   55,
#   43,
#   45,
#   31,
#   51,
#   67,
#   47,
#   45,
#   56,
#   50,
#   71,
#   57,
#   64,
#   63,
#   40,
#   58,
#   65,
#   63,
#   37,
#   51,
#   42,
#   58,
#   62],
#  'powerplay_percentage': [24.5,
#   16.6,
#   15.1,
#   18.0,
#   22.2,
#   17.5,
#   22.6,
#   20.6,
#   22.0,
#   22.4,
#   18.3,
#   17.9,
#   12.2,
#   20.2,
#   26.9,
#   20.3,
#   18.8,
#   22.6,
#   20.7,
#   28.6,
#   23.9,
#   26.3,
#   23.5,
#   15.3,
#   21.6,
#   26.4,
#   23.1,
#   16.6,
#   18.0,
#   20.2,
#   24.2,
#   22.7],
#  'shots_against': [2432,
#   2667,
#   2803,
#   2616,
#   2495,
#   2724,
#   2335,
#   2494,
#   2579,
#   2431,
#   2653,
#   2420,
#   2212,
#   2473,
#   2089,
#   2667,
#   2418,
#   2288,
#   2375,
#   2414,
#   2433,
#   2291,
#   2268,
#   2472,
#   2490,
#   2403,
#   2644,
#   2391,
#   2422,
#   2863,
#   2343,
#   2426],
#  'goals_against': [239,
#   274,
#   279,
#   228,
#   211,
#   267,
#   213,
#   243,
#   255,
#   254,
#   280,
#   249,
#   245,
#   229,
#   199,
#   238,
#   187,
#   202,
#   216,
#   251,
#   248,
#   220,
#   186,
#   240,
#   231,
#   211,
#   260,
#   231,
#   271,
#   308,
#   225,
#   249],
#  'saves': [2193,
#   2393,
#   2524,
#   2388,
#   2284,
#   2457,
#   2122,
#   2251,
#   2324,
#   2177,
#   2373,
#   2171,
#   1967,
#   2244,
#   1890,
#   2429,
#   2231,
#   2086,
#   2159,
#   2163,
#   2185,
#   2071,
#   2082,
#   2232,
#   2259,
#   2192,
#   2384,
#   2160,
#   2151,
#   2555,
#   2118,
#   2177],
#  'saves_percentage': [0.897,
#   0.892,
#   0.894,
#   0.906,
#   0.912,
#   0.897,
#   0.906,
#   0.899,
#   0.895,
#   0.886,
#   0.89,
#   0.89,
#   0.884,
#   0.902,
#   0.9,
#   0.904,
#   0.918,
#   0.909,
#   0.903,
#   0.89,
#   0.893,
#   0.898,
#   0.913,
#   0.9,
#   0.901,
#   0.907,
#   0.897,
#   0.899,
#   0.884,
#   0.887,
#   0.901,
#   0.893]}

# %%
df =pd.DataFrame(team_stats)

# %%
df.head()
# Out:
#            name  games_played  goals  assists  points  penalties  \
# 0     Avalanche            82    302      525     827        307
# 1    Blackhawks            82    178      303     481        292
# 2  Blue Jackets            82    234      389     623        291
# 3         Blues            82    234      401     635        263
# 4        Bruins            82    263      443     706        334
#
#    penalty_minutes  shots  hits  blocked_shots  powerplays  powerplay_shots  \
# 0              731   2705  1671           1214         278              443
# 1              715   2153  1874           1340         235              314
# 2              670   2458  1577           1396         212              329
# 3              608   2370  1654           1219         250              362
# 4              776   2399  2258           1299         243              386
#
#    powerplay_goals  powerplay_percentage  shots_against  goals_against  saves  \
# 0               68                  24.5           2432            239   2193
# 1               39                  16.6           2667            274   2393
# 2               32                  15.1           2803            279   2524
# 3               45                  18.0           2616            228   2388
# 4               54                  22.2           2495            211   2284
#
#    saves_percentage
# 0             0.897
# 1             0.892
# 2             0.894
# 3             0.906
# 4             0.912

# %%
df.to_csv('nhl_teams_stats.csv', index=False)

# %% [markdown]
# # LA kings player stats

# %%
kings_player_stats_url = 'https://api.sportradar.com/nhl/production/v7/en/seasons/2023/REG/teams/44151f7a-0f24-11e2-8525-18a905767e44/statistics.json'
# 3XZ4cbvj3w6hRONhHDelw92rvKqucxRk5ux3ZBpI
team_params = {'api_key':'3XZ4cbvj3w6hRONhHDelw92rvKqucxRk5ux3ZBpI'}

kings_player_stats_api_request = requests.get(kings_player_stats_url, params=team_params)

# %%
kings_player_stats_api_request
# Out:
# <Response [200]>

# %%
json.loads(kings_player_stats_api_request.text)
# Out:
# {'id': '44151f7a-0f24-11e2-8525-18a905767e44',
#  'name': 'Kings',
#  'market': 'Los Angeles',
#  'sr_id': 'sr:team:3688',
#  'reference': '26',
#  'season': {'id': '9a5fb1fb-5cd9-4b9b-a957-c1dc5eb1a0f3',
#   'year': 2023,
#   'type': 'REG'},
#  'own_record': {'statistics': {'total': {'games_played': 82,
#     'goals': 254,
#     'assists': 431,
#     'penalties': 303,
#     'penalty_minutes': 715,
#     'team_penalties': 8,
#     'team_penalty_minutes': 16,
#     'shots': 2616,
#     'blocked_att': 1389,
#     'missed_shots': 1189,
#     'hits': 1763,
#     'giveaways': 564,
#     'takeaways': 424,
#     'blocked_shots': 1267,
#     'faceoffs_won': 2328,
#     'faceoffs_lost': 2273,
#     'powerplays': 248,
#     'shooting_pct': 9.7,
#     'faceoff_win_pct': 50.6,
#     'faceoffs': 4601,
#     'points': 685,
#     'plus_minus': 124,
#     'overtime_goals': 5,
#     'overtime_assists': 6,
#     'overtime_shots': 30,
#     'emptynet_goals': 13,
#     'penalties_major': 13,
#     'penalties_match': 0,
#     'penalties_minor': 268,
#     'penalties_misconduct': 7},
#    'powerplay': {'faceoffs_won': 229,
#     'faceoffs_lost': 185,
#     'shots': 332,
#     'goals': 56,
#     'missed_shots': 178,
#     'assists': 107,
#     'faceoff_win_pct': 55.3,
#     'opportunities': 248,
#     'faceoffs': 414,
#     'percentage': 22.6,
#     'strength': [{'opportunities': 245,
#       'shots': 322,
#       'goals': 55,
#       'type': '5v4'},
#      {'opportunities': 6, 'shots': 8, 'goals': 1, 'type': '5v3'},
#      {'opportunities': 2, 'shots': 2, 'goals': 0, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 215,
#     'faceoffs_lost': 277,
#     'shots': 78,
#     'goals': 11,
#     'missed_shots': 16,
#     'assists': 11,
#     'faceoff_win_pct': 43.7,
#     'opportunities': 253,
#     'faceoffs': 492,
#     'goals_against': 39,
#     'kill_pct': 84.6,
#     'strength': [{'shots': 77, 'goals': 11, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 1, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1884,
#     'faceoffs_lost': 1811,
#     'shots': 2206,
#     'goals': 187,
#     'missed_shots': 995,
#     'assists': 313,
#     'faceoff_win_pct': 51.0,
#     'faceoffs': 3695,
#     'strength': [{'shots': 2163, 'goals': 181, 'type': '5v5'},
#      {'shots': 15, 'goals': 1, 'type': '4v4'},
#      {'shots': 28, 'goals': 5, 'type': '3v3'}]},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 5.26,
#     'blocked_shots': 15.45,
#     'points': 8.35,
#     'blocked_att': 16.94,
#     'team_penalty_minutes': 0.2,
#     'penalties': 3.7,
#     'missed_shots': 14.5,
#     'hits': 21.5,
#     'shots': 31.9,
#     'takeaways': 5.17,
#     'giveaways': 6.88,
#     'goals': 3.1,
#     'team_penalties': 0.1,
#     'penalty_minutes': 8.72}},
#   'shootout': {'shots': 26,
#    'missed_shots': 5,
#    'goals': 10,
#    'shots_against': 31,
#    'goals_against': 15,
#    'saves': 16,
#    'saves_pct': 0.516},
#   'goaltending': {'total': {'shots_against': 2288,
#     'goals_against': 202,
#     'saves': 2086,
#     'total_goals_against': 210,
#     'total_shots_against': 2296,
#     'saves_pct': 0.909,
#     'losses': 27,
#     'overtime_losses': 11,
#     'shutouts': 7,
#     'wins': 44},
#    'powerplay': {'shots_against': 65,
#     'goals_against': 7,
#     'saves': 58,
#     'saves_pct': 0.892},
#    'shorthanded': {'shots_against': 417,
#     'goals_against': 39,
#     'saves': 378,
#     'saves_pct': 0.906},
#    'evenstrength': {'shots_against': 1814,
#     'goals_against': 164,
#     'saves': 1650,
#     'saves_pct': 0.91},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 2.46, 'shots_against': 27.9},
#    'emptynet': {'total': {'goals_against': 8, 'shots_against': 8},
#     'powerplay': {'goals_against': 0},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 8}},
#    'time_on_ice': {'total': '4976:17'}}},
#  'opponents': {'statistics': {'total': {'games_played': 82,
#     'goals': 210,
#     'assists': 357,
#     'penalties': 312,
#     'penalty_minutes': 777,
#     'team_penalties': 6,
#     'team_penalty_minutes': 12,
#     'shots': 2296,
#     'blocked_att': 1356,
#     'missed_shots': 1039,
#     'hits': 2039,
#     'giveaways': 554,
#     'takeaways': 473,
#     'blocked_shots': 1289,
#     'faceoffs_won': 2273,
#     'faceoffs_lost': 2328,
#     'powerplays': 253,
#     'shooting_pct': 9.1,
#     'faceoff_win_pct': 49.4,
#     'faceoffs': 4601,
#     'points': 567,
#     'plus_minus': -151,
#     'overtime_goals': 6,
#     'overtime_assists': 10,
#     'overtime_shots': 24,
#     'emptynet_goals': 8,
#     'penalties_major': 13,
#     'penalties_match': 0,
#     'penalties_minor': 278,
#     'penalties_misconduct': 14},
#    'powerplay': {'faceoffs_won': 277,
#     'faceoffs_lost': 215,
#     'shots': 416,
#     'goals': 39,
#     'missed_shots': 188,
#     'assists': 76,
#     'faceoff_win_pct': 56.3,
#     'opportunities': 253,
#     'faceoffs': 492,
#     'percentage': 15.4,
#     'strength': [{'opportunities': 241,
#       'shots': 400,
#       'goals': 36,
#       'type': '5v4'},
#      {'opportunities': 6, 'shots': 7, 'goals': 2, 'type': '5v3'},
#      {'opportunities': 9, 'shots': 9, 'goals': 1, 'type': '4v3'}]},
#    'shorthanded': {'faceoffs_won': 185,
#     'faceoffs_lost': 229,
#     'shots': 65,
#     'goals': 7,
#     'missed_shots': 22,
#     'assists': 6,
#     'faceoff_win_pct': 44.7,
#     'opportunities': 248,
#     'faceoffs': 414,
#     'goals_against': 56,
#     'kill_pct': 77.4,
#     'strength': [{'shots': 65, 'goals': 7, 'type': '4v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v5'},
#      {'shots': 0, 'goals': 0, 'type': '3v4'}]},
#    'evenstrength': {'faceoffs_won': 1811,
#     'faceoffs_lost': 1884,
#     'shots': 1815,
#     'goals': 164,
#     'missed_shots': 829,
#     'assists': 275,
#     'faceoff_win_pct': 49.0,
#     'faceoffs': 3695,
#     'strength': [{'shots': 1771, 'goals': 156, 'type': '5v5'},
#      {'shots': 26, 'goals': 3, 'type': '4v4'},
#      {'shots': 18, 'goals': 5, 'type': '3v3'}]},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 4.35,
#     'blocked_shots': 15.72,
#     'points': 6.91,
#     'blocked_att': 16.54,
#     'team_penalty_minutes': 0.15,
#     'penalties': 3.8,
#     'missed_shots': 12.67,
#     'hits': 24.87,
#     'shots': 28.0,
#     'takeaways': 5.77,
#     'giveaways': 6.76,
#     'goals': 2.56,
#     'team_penalties': 0.07,
#     'penalty_minutes': 9.48}},
#   'shootout': {'shots': 30,
#    'missed_shots': 1,
#    'goals': 15,
#    'shots_against': 31,
#    'goals_against': 10,
#    'saves': 21,
#    'saves_pct': 0.677},
#   'goaltending': {'total': {'shots_against': 2603,
#     'goals_against': 241,
#     'saves': 2362,
#     'total_goals_against': 254,
#     'total_shots_against': 2616,
#     'saves_pct': 0.903,
#     'losses': 37,
#     'overtime_losses': 7,
#     'shutouts': 2,
#     'wins': 38},
#    'powerplay': {'shots_against': 75,
#     'goals_against': 8,
#     'saves': 67,
#     'saves_pct': 0.893},
#    'shorthanded': {'shots_against': 332,
#     'goals_against': 56,
#     'saves': 276,
#     'saves_pct': 0.831},
#    'evenstrength': {'shots_against': 2206,
#     'goals_against': 187,
#     'saves': 2019,
#     'saves_pct': 0.915},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'average': {'goals_against': 2.94, 'shots_against': 31.74},
#    'emptynet': {'total': {'goals_against': 13, 'shots_against': 13},
#     'powerplay': {'goals_against': 3},
#     'shorthanded': {'goals_against': 0},
#     'evenstrength': {'goals_against': 10}},
#    'time_on_ice': {'total': '4976:17'}}},
#  'players': [{'id': '677c3651-f73b-4fbf-9a71-f6f16874617d',
#    'full_name': 'David Rittich',
#    'first_name': 'David',
#    'last_name': 'Rittich',
#    'position': 'G',
#    'primary_position': 'G',
#    'jersey_number': '31',
#    'sr_id': 'sr:player:604562',
#    'reference': '8479496',
#    'statistics': {'total': {'games_played': 24,
#      'goals': 0,
#      'assists': 0,
#      'penalties': 0,
#      'penalty_minutes': 0,
#      'shots': 0,
#      'blocked_att': 0,
#      'missed_shots': 0,
#      'hits': 0,
#      'giveaways': 7,
#      'takeaways': 1,
#      'blocked_shots': 0,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 0,
#      'winning_goals': 0,
#      'plus_minus': 0,
#      'games_scratched': 0,
#      'games_started': 22,
#      'shooting_pct': 0.0,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 0,
#      'points': 0,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 0,
#      'penalties_misconduct': 0,
#      'first_star': 2,
#      'second_star': 5,
#      'third_star': 1},
#     'powerplay': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.0,
#      'blocked_shots': 0.0,
#      'points': 0.0,
#      'blocked_att': 0.0,
#      'penalties': 0.0,
#      'missed_shots': 0.0,
#      'hits': 0.0,
#      'shots': 0.0,
#      'takeaways': 0.04,
#      'giveaways': 0.29,
#      'goals': 0.0,
#      'penalty_minutes': 0.0}},
#    'time_on_ice': {'total': {'shifts': 93,
#      'total': '1364:31',
#      'overtime': '20:37',
#      'powerplay': '107:11',
#      'shorthanded': '124:58',
#      'evenstrength': '1132:22'},
#     'average': {'shifts': 3.88,
#      'total': '56:51',
#      'overtime': '4:07',
#      'powerplay': '4:28',
#      'shorthanded': '5:12',
#      'evenstrength': '47:11'}},
#    'goaltending': {'total': {'games_played': 24,
#      'shots_against': 621,
#      'goals_against': 49,
#      'saves': 572,
#      'shutouts': 3,
#      'wins': 13,
#      'losses': 6,
#      'overtime_losses': 3,
#      'saves_pct': 0.921,
#      'avg_goals_against': 2.15},
#     'powerplay': {'shots_against': 16,
#      'goals_against': 1,
#      'saves': 15,
#      'saves_pct': 0.938},
#     'shorthanded': {'shots_against': 124,
#      'goals_against': 13,
#      'saves': 111,
#      'saves_pct': 0.895},
#     'evenstrength': {'shots_against': 481,
#      'goals_against': 35,
#      'saves': 446,
#      'saves_pct': 0.927},
#     'penalty': {'shots_against': 0,
#      'goals_against': 0,
#      'saves': 0,
#      'saves_pct': 0.0},
#     'shootout': {'shots_against': 7,
#      'goals_against': 5,
#      'saves': 2,
#      'saves_pct': 0.286},
#     'average': {'shots_against': 25.88, 'goals_against': 2.04}}},
#   {'id': '421f9f71-d1ee-4917-afc6-ca11f6b761b0',
#    'full_name': 'Trevor Moore',
#    'first_name': 'Trevor',
#    'last_name': 'Moore',
#    'position': 'F',
#    'primary_position': 'LW',
#    'jersey_number': '12',
#    'sr_id': 'sr:player:1051357',
#    'reference': '8479675',
#    'statistics': {'total': {'games_played': 82,
#      'goals': 31,
#      'assists': 26,
#      'penalties': 13,
#      'penalty_minutes': 28,
#      'shots': 244,
#      'blocked_att': 74,
#      'missed_shots': 122,
#      'hits': 92,
#      'giveaways': 25,
#      'takeaways': 39,
#      'blocked_shots': 58,
#      'faceoffs_won': 14,
#      'faceoffs_lost': 34,
#      'winning_goals': 5,
#      'plus_minus': 11,
#      'games_scratched': 0,
#      'games_started': 36,
#      'shooting_pct': 12.7,
#      'faceoff_win_pct': 29.2,
#      'faceoffs': 48,
#      'points': 57,
#      'emptynet_goals': 2,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 4,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 12,
#      'penalties_misconduct': 0,
#      'first_star': 3,
#      'second_star': 1,
#      'third_star': 4},
#     'powerplay': {'shots': 29,
#      'goals': 2,
#      'missed_shots': 23,
#      'assists': 5,
#      'faceoffs_won': 1,
#      'faceoffs': 1,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 100.0},
#     'shorthanded': {'shots': 14,
#      'goals': 2,
#      'missed_shots': 7,
#      'assists': 0,
#      'faceoffs_won': 1,
#      'faceoffs': 1,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 100.0},
#     'evenstrength': {'shots': 201,
#      'goals': 27,
#      'missed_shots': 92,
#      'assists': 21,
#      'faceoffs_won': 12,
#      'faceoffs': 46,
#      'faceoffs_lost': 34,
#      'faceoff_win_pct': 26.1},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 7, 'goals': 3, 'missed_shots': 0},
#     'average': {'assists': 0.32,
#      'blocked_shots': 0.71,
#      'points': 0.7,
#      'blocked_att': 0.9,
#      'penalties': 0.16,
#      'missed_shots': 1.49,
#      'hits': 1.12,
#      'shots': 2.98,
#      'takeaways': 0.48,
#      'giveaways': 0.3,
#      'goals': 0.38,
#      'penalty_minutes': 0.34}},
#    'time_on_ice': {'total': {'shifts': 1825,
#      'total': '1474:21',
#      'overtime': '14:12',
#      'powerplay': '151:45',
#      'shorthanded': '136:30',
#      'evenstrength': '1186:06'},
#     'average': {'shifts': 22.26,
#      'total': '17:59',
#      'overtime': '00:47',
#      'powerplay': '1:51',
#      'shorthanded': '1:40',
#      'evenstrength': '14:28'}}},
#   {'id': 'cd3e3e6c-23c2-4a3e-af08-e498246c50ad',
#    'full_name': 'Viktor Arvidsson',
#    'first_name': 'Viktor',
#    'last_name': 'Arvidsson',
#    'position': 'F',
#    'primary_position': 'RW',
#    'jersey_number': '33',
#    'sr_id': 'sr:player:266577',
#    'reference': '8478042',
#    'statistics': {'total': {'games_played': 18,
#      'goals': 6,
#      'assists': 9,
#      'penalties': 7,
#      'penalty_minutes': 14,
#      'shots': 59,
#      'blocked_att': 19,
#      'missed_shots': 22,
#      'hits': 8,
#      'giveaways': 5,
#      'takeaways': 8,
#      'blocked_shots': 18,
#      'faceoffs_won': 3,
#      'faceoffs_lost': 6,
#      'winning_goals': 1,
#      'plus_minus': 4,
#      'games_scratched': 1,
#      'games_started': 12,
#      'shooting_pct': 10.2,
#      'faceoff_win_pct': 33.3,
#      'faceoffs': 9,
#      'points': 15,
#      'emptynet_goals': 1,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 7,
#      'penalties_misconduct': 0,
#      'first_star': 3,
#      'second_star': 0,
#      'third_star': 1},
#     'powerplay': {'shots': 7,
#      'goals': 1,
#      'missed_shots': 2,
#      'assists': 4,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 52,
#      'goals': 5,
#      'missed_shots': 20,
#      'assists': 5,
#      'faceoffs_won': 3,
#      'faceoffs': 9,
#      'faceoffs_lost': 6,
#      'faceoff_win_pct': 33.3},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.5,
#      'blocked_shots': 1.0,
#      'points': 0.83,
#      'blocked_att': 1.06,
#      'penalties': 0.39,
#      'missed_shots': 1.22,
#      'hits': 0.44,
#      'shots': 3.28,
#      'takeaways': 0.44,
#      'giveaways': 0.28,
#      'goals': 0.33,
#      'penalty_minutes': 0.78}},
#    'time_on_ice': {'total': {'shifts': 345,
#      'total': '300:27',
#      'overtime': '00:33',
#      'powerplay': '58:08',
#      'shorthanded': '00:26',
#      'evenstrength': '241:53'},
#     'average': {'shifts': 19.17,
#      'total': '16:42',
#      'overtime': '00:11',
#      'powerplay': '3:14',
#      'shorthanded': '00:01',
#      'evenstrength': '13:26'}}},
#   {'id': 'c86ff633-7f27-420c-84a7-be1e08ede9a6',
#    'full_name': 'Kevin Fiala',
#    'first_name': 'Kevin',
#    'last_name': 'Fiala',
#    'position': 'F',
#    'primary_position': 'LW',
#    'jersey_number': '22',
#    'sr_id': 'sr:player:376846',
#    'reference': '8477942',
#    'statistics': {'total': {'games_played': 82,
#      'goals': 29,
#      'assists': 44,
#      'penalties': 26,
#      'penalty_minutes': 62,
#      'shots': 225,
#      'blocked_att': 124,
#      'missed_shots': 118,
#      'hits': 67,
#      'giveaways': 57,
#      'takeaways': 45,
#      'blocked_shots': 28,
#      'faceoffs_won': 10,
#      'faceoffs_lost': 28,
#      'winning_goals': 2,
#      'plus_minus': 1,
#      'games_scratched': 0,
#      'games_started': 24,
#      'shooting_pct': 12.9,
#      'faceoff_win_pct': 26.3,
#      'faceoffs': 38,
#      'points': 73,
#      'emptynet_goals': 1,
#      'overtime_goals': 1,
#      'overtime_assists': 0,
#      'overtime_shots': 5,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 24,
#      'penalties_misconduct': 1,
#      'first_star': 3,
#      'second_star': 5,
#      'third_star': 6},
#     'powerplay': {'shots': 56,
#      'goals': 11,
#      'missed_shots': 32,
#      'assists': 19,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 169,
#      'goals': 18,
#      'missed_shots': 86,
#      'assists': 25,
#      'faceoffs_won': 10,
#      'faceoffs': 38,
#      'faceoffs_lost': 28,
#      'faceoff_win_pct': 26.3},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 3, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.54,
#      'blocked_shots': 0.34,
#      'points': 0.89,
#      'blocked_att': 1.51,
#      'penalties': 0.32,
#      'missed_shots': 1.44,
#      'hits': 0.82,
#      'shots': 2.74,
#      'takeaways': 0.55,
#      'giveaways': 0.7,
#      'goals': 0.35,
#      'penalty_minutes': 0.76}},
#    'time_on_ice': {'total': {'shifts': 1632,
#      'total': '1478:55',
#      'overtime': '14:35',
#      'powerplay': '258:13',
#      'shorthanded': '1:53',
#      'evenstrength': '1218:49'},
#     'average': {'shifts': 19.9,
#      'total': '18:02',
#      'overtime': '00:49',
#      'powerplay': '3:09',
#      'shorthanded': '00:01',
#      'evenstrength': '14:52'}}},
#   {'id': '6767e821-5a9c-4379-9bfa-9f19314cfc2f',
#    'full_name': 'Mikey Anderson',
#    'first_name': 'Mikey',
#    'last_name': 'Anderson',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '44',
#    'sr_id': 'sr:player:1117735',
#    'reference': '8479998',
#    'statistics': {'total': {'games_played': 74,
#      'goals': 2,
#      'assists': 16,
#      'penalties': 9,
#      'penalty_minutes': 18,
#      'shots': 89,
#      'blocked_att': 74,
#      'missed_shots': 43,
#      'hits': 128,
#      'giveaways': 27,
#      'takeaways': 14,
#      'blocked_shots': 129,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 0,
#      'winning_goals': 0,
#      'plus_minus': 22,
#      'games_scratched': 8,
#      'games_started': 49,
#      'shooting_pct': 2.2,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 0,
#      'points': 18,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 9,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 1,
#      'third_star': 0},
#     'powerplay': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 1,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 3,
#      'goals': 0,
#      'missed_shots': 1,
#      'assists': 1,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 86,
#      'goals': 2,
#      'missed_shots': 41,
#      'assists': 15,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.22,
#      'blocked_shots': 1.74,
#      'points': 0.24,
#      'blocked_att': 1.0,
#      'penalties': 0.12,
#      'missed_shots': 0.58,
#      'hits': 1.73,
#      'shots': 1.2,
#      'takeaways': 0.19,
#      'giveaways': 0.36,
#      'goals': 0.03,
#      'penalty_minutes': 0.24}},
#    'time_on_ice': {'total': {'shifts': 1630,
#      'total': '1526:43',
#      'overtime': '4:15',
#      'powerplay': '1:40',
#      'shorthanded': '171:39',
#      'evenstrength': '1353:24'},
#     'average': {'shifts': 22.03,
#      'total': '20:38',
#      'overtime': '00:17',
#      'powerplay': '00:01',
#      'shorthanded': '2:19',
#      'evenstrength': '18:17'}}},
#   {'id': '638a55b3-4846-4909-a0d9-14eb38dc26c1',
#    'full_name': 'Jaret Anderson-Dolan',
#    'first_name': 'Jaret',
#    'last_name': 'Anderson-Dolan',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '28',
#    'sr_id': 'sr:player:1117753',
#    'reference': '8479994',
#    'statistics': {'total': {'games_played': 30,
#      'goals': 1,
#      'assists': 3,
#      'penalties': 3,
#      'penalty_minutes': 6,
#      'shots': 29,
#      'blocked_att': 14,
#      'missed_shots': 11,
#      'hits': 53,
#      'giveaways': 8,
#      'takeaways': 2,
#      'blocked_shots': 21,
#      'faceoffs_won': 20,
#      'faceoffs_lost': 27,
#      'winning_goals': 0,
#      'plus_minus': -4,
#      'games_scratched': 30,
#      'games_started': 3,
#      'shooting_pct': 3.4,
#      'faceoff_win_pct': 42.6,
#      'faceoffs': 47,
#      'points': 4,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 3,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 0,
#      'third_star': 0},
#     'powerplay': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 1,
#      'goals': 1,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 2,
#      'faceoffs': 4,
#      'faceoffs_lost': 2,
#      'faceoff_win_pct': 50.0},
#     'evenstrength': {'shots': 28,
#      'goals': 0,
#      'missed_shots': 11,
#      'assists': 3,
#      'faceoffs_won': 18,
#      'faceoffs': 43,
#      'faceoffs_lost': 25,
#      'faceoff_win_pct': 41.9},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.1,
#      'blocked_shots': 0.7,
#      'points': 0.13,
#      'blocked_att': 0.47,
#      'penalties': 0.1,
#      'missed_shots': 0.37,
#      'hits': 1.77,
#      'shots': 0.97,
#      'takeaways': 0.07,
#      'giveaways': 0.27,
#      'goals': 0.03,
#      'penalty_minutes': 0.2}},
#    'time_on_ice': {'total': {'shifts': 432,
#      'total': '328:54',
#      'overtime': '00:00',
#      'powerplay': '00:29',
#      'shorthanded': '17:54',
#      'evenstrength': '310:31'},
#     'average': {'shifts': 14.4,
#      'total': '10:58',
#      'overtime': '00:00',
#      'powerplay': '00:01',
#      'shorthanded': '00:36',
#      'evenstrength': '10:21'}}},
#   {'id': 'a0b91f2e-bb6d-409a-9e58-cc764edafe64',
#    'full_name': 'Adrian Kempe',
#    'first_name': 'Adrian',
#    'last_name': 'Kempe',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '9',
#    'sr_id': 'sr:player:361870',
#    'reference': '8477960',
#    'statistics': {'total': {'games_played': 77,
#      'goals': 28,
#      'assists': 47,
#      'penalties': 30,
#      'penalty_minutes': 72,
#      'shots': 246,
#      'blocked_att': 147,
#      'missed_shots': 106,
#      'hits': 112,
#      'giveaways': 24,
#      'takeaways': 31,
#      'blocked_shots': 32,
#      'faceoffs_won': 3,
#      'faceoffs_lost': 10,
#      'winning_goals': 4,
#      'plus_minus': 13,
#      'games_scratched': 5,
#      'games_started': 31,
#      'shooting_pct': 11.4,
#      'faceoff_win_pct': 23.1,
#      'faceoffs': 13,
#      'points': 75,
#      'emptynet_goals': 2,
#      'overtime_goals': 1,
#      'overtime_assists': 2,
#      'overtime_shots': 8,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 27,
#      'penalties_misconduct': 1,
#      'first_star': 6,
#      'second_star': 9,
#      'third_star': 2},
#     'powerplay': {'shots': 51,
#      'goals': 5,
#      'missed_shots': 33,
#      'assists': 22,
#      'faceoffs_won': 2,
#      'faceoffs': 5,
#      'faceoffs_lost': 3,
#      'faceoff_win_pct': 40.0},
#     'shorthanded': {'shots': 18,
#      'goals': 3,
#      'missed_shots': 3,
#      'assists': 1,
#      'faceoffs_won': 1,
#      'faceoffs': 2,
#      'faceoffs_lost': 1,
#      'faceoff_win_pct': 50.0},
#     'evenstrength': {'shots': 177,
#      'goals': 20,
#      'missed_shots': 70,
#      'assists': 24,
#      'faceoffs_won': 0,
#      'faceoffs': 6,
#      'faceoffs_lost': 6,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 4, 'goals': 2, 'missed_shots': 1},
#     'average': {'assists': 0.61,
#      'blocked_shots': 0.42,
#      'points': 0.97,
#      'blocked_att': 1.91,
#      'penalties': 0.39,
#      'missed_shots': 1.38,
#      'hits': 1.45,
#      'shots': 3.19,
#      'takeaways': 0.4,
#      'giveaways': 0.31,
#      'goals': 0.36,
#      'penalty_minutes': 0.94}},
#    'time_on_ice': {'total': {'shifts': 1729,
#      'total': '1457:55',
#      'overtime': '19:39',
#      'powerplay': '239:13',
#      'shorthanded': '129:40',
#      'evenstrength': '1089:02'},
#     'average': {'shifts': 22.45,
#      'total': '18:56',
#      'overtime': '1:14',
#      'powerplay': '3:06',
#      'shorthanded': '1:41',
#      'evenstrength': '14:09'}}},
#   {'id': 'd7ca41dc-2465-490b-ac76-0ac83f64185f',
#    'full_name': 'Alex Turcotte',
#    'first_name': 'Alex',
#    'last_name': 'Turcotte',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '38',
#    'sr_id': 'sr:player:1650183',
#    'reference': '8481532',
#    'statistics': {'total': {'games_played': 20,
#      'goals': 1,
#      'assists': 3,
#      'penalties': 3,
#      'penalty_minutes': 6,
#      'shots': 14,
#      'blocked_att': 9,
#      'missed_shots': 13,
#      'hits': 7,
#      'giveaways': 1,
#      'takeaways': 6,
#      'blocked_shots': 10,
#      'faceoffs_won': 21,
#      'faceoffs_lost': 21,
#      'winning_goals': 0,
#      'plus_minus': 5,
#      'games_scratched': 8,
#      'games_started': 2,
#      'shooting_pct': 7.1,
#      'faceoff_win_pct': 50.0,
#      'faceoffs': 42,
#      'points': 4,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 3,
#      'penalties_misconduct': 0,
#      'first_star': 1,
#      'second_star': 0,
#      'third_star': 0},
#     'powerplay': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 1,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 14,
#      'goals': 1,
#      'missed_shots': 12,
#      'assists': 3,
#      'faceoffs_won': 21,
#      'faceoffs': 42,
#      'faceoffs_lost': 21,
#      'faceoff_win_pct': 50.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.15,
#      'blocked_shots': 0.5,
#      'points': 0.2,
#      'blocked_att': 0.45,
#      'penalties': 0.15,
#      'missed_shots': 0.65,
#      'hits': 0.35,
#      'shots': 0.7,
#      'takeaways': 0.3,
#      'giveaways': 0.05,
#      'goals': 0.05,
#      'penalty_minutes': 0.3}},
#    'time_on_ice': {'total': {'shifts': 264,
#      'total': '185:36',
#      'overtime': '00:00',
#      'powerplay': '2:29',
#      'shorthanded': '00:00',
#      'evenstrength': '183:07'},
#     'average': {'shifts': 13.2,
#      'total': '9:17',
#      'overtime': '00:00',
#      'powerplay': '00:07',
#      'shorthanded': '00:00',
#      'evenstrength': '9:09'}}},
#   {'id': 'f0cdc175-e8c9-4dd9-877d-0f067d8c2e31',
#    'full_name': 'Arthur Kaliyev',
#    'first_name': 'Arthur',
#    'last_name': 'Kaliyev',
#    'position': 'F',
#    'primary_position': 'RW',
#    'jersey_number': '34',
#    'sr_id': 'sr:player:1650147',
#    'reference': '8481560',
#    'statistics': {'total': {'games_played': 51,
#      'goals': 7,
#      'assists': 8,
#      'penalties': 6,
#      'penalty_minutes': 14,
#      'shots': 101,
#      'blocked_att': 56,
#      'missed_shots': 54,
#      'hits': 33,
#      'giveaways': 15,
#      'takeaways': 11,
#      'blocked_shots': 14,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 1,
#      'winning_goals': 0,
#      'plus_minus': -3,
#      'games_scratched': 31,
#      'games_started': 4,
#      'shooting_pct': 6.9,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 1,
#      'points': 15,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 2,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 5,
#      'penalties_misconduct': 0,
#      'first_star': 2,
#      'second_star': 1,
#      'third_star': 0},
#     'powerplay': {'shots': 18,
#      'goals': 3,
#      'missed_shots': 10,
#      'assists': 1,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 83,
#      'goals': 4,
#      'missed_shots': 44,
#      'assists': 7,
#      'faceoffs_won': 0,
#      'faceoffs': 1,
#      'faceoffs_lost': 1,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 1, 'goals': 1, 'missed_shots': 0},
#     'average': {'assists': 0.16,
#      'blocked_shots': 0.27,
#      'points': 0.29,
#      'blocked_att': 1.1,
#      'penalties': 0.12,
#      'missed_shots': 1.06,
#      'hits': 0.65,
#      'shots': 1.98,
#      'takeaways': 0.22,
#      'giveaways': 0.29,
#      'goals': 0.14,
#      'penalty_minutes': 0.27}},
#    'time_on_ice': {'total': {'shifts': 767,
#      'total': '601:55',
#      'overtime': '00:30',
#      'powerplay': '74:50',
#      'shorthanded': '00:00',
#      'evenstrength': '527:05'},
#     'average': {'shifts': 15.04,
#      'total': '11:48',
#      'overtime': '00:03',
#      'powerplay': '1:28',
#      'shorthanded': '00:00',
#      'evenstrength': '10:20'}}},
#   {'id': '0a1a1d3a-7118-4d30-a2bd-a2f95822d22c',
#    'full_name': 'Pheonix Copley',
#    'first_name': 'Pheonix',
#    'last_name': 'Copley',
#    'position': 'G',
#    'primary_position': 'G',
#    'jersey_number': '29',
#    'sr_id': 'sr:player:791897',
#    'reference': '8477831',
#    'statistics': {'total': {'games_played': 8,
#      'goals': 0,
#      'assists': 0,
#      'penalties': 0,
#      'penalty_minutes': 0,
#      'shots': 0,
#      'blocked_att': 0,
#      'missed_shots': 0,
#      'hits': 0,
#      'giveaways': 0,
#      'takeaways': 0,
#      'blocked_shots': 0,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 0,
#      'winning_goals': 0,
#      'plus_minus': 0,
#      'games_scratched': 1,
#      'games_started': 8,
#      'shooting_pct': 0.0,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 0,
#      'points': 0,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 0,
#      'penalties_misconduct': 0,
#      'first_star': 1,
#      'second_star': 1,
#      'third_star': 0},
#     'powerplay': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.0,
#      'blocked_shots': 0.0,
#      'points': 0.0,
#      'blocked_att': 0.0,
#      'penalties': 0.0,
#      'missed_shots': 0.0,
#      'hits': 0.0,
#      'shots': 0.0,
#      'takeaways': 0.0,
#      'giveaways': 0.0,
#      'goals': 0.0,
#      'penalty_minutes': 0.0}},
#    'time_on_ice': {'total': {'shifts': 30,
#      'total': '436:17',
#      'overtime': '9:18',
#      'powerplay': '44:10',
#      'shorthanded': '44:11',
#      'evenstrength': '347:56'},
#     'average': {'shifts': 3.75,
#      'total': '54:32',
#      'overtime': '3:06',
#      'powerplay': '5:31',
#      'shorthanded': '5:31',
#      'evenstrength': '43:30'}},
#    'goaltending': {'total': {'games_played': 8,
#      'shots_against': 177,
#      'goals_against': 23,
#      'saves': 154,
#      'shutouts': 1,
#      'wins': 4,
#      'losses': 1,
#      'overtime_losses': 2,
#      'saves_pct': 0.87,
#      'avg_goals_against': 3.17},
#     'powerplay': {'shots_against': 8,
#      'goals_against': 3,
#      'saves': 5,
#      'saves_pct': 0.625},
#     'shorthanded': {'shots_against': 48,
#      'goals_against': 4,
#      'saves': 44,
#      'saves_pct': 0.917},
#     'evenstrength': {'shots_against': 121,
#      'goals_against': 16,
#      'saves': 105,
#      'saves_pct': 0.868},
#     'penalty': {'shots_against': 0,
#      'goals_against': 0,
#      'saves': 0,
#      'saves_pct': 0.0},
#     'shootout': {'shots_against': 9,
#      'goals_against': 3,
#      'saves': 6,
#      'saves_pct': 0.667},
#     'average': {'shots_against': 22.13, 'goals_against': 2.88}}},
#   {'id': '091b5891-b9bc-4a3a-a2b3-782dd6e94c8e',
#    'full_name': 'Brandt Clarke',
#    'first_name': 'Brandt',
#    'last_name': 'Clarke',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '92',
#    'sr_id': 'sr:player:2113752',
#    'reference': '8482730',
#    'statistics': {'total': {'games_played': 16,
#      'goals': 2,
#      'assists': 4,
#      'penalties': 5,
#      'penalty_minutes': 10,
#      'shots': 31,
#      'blocked_att': 14,
#      'missed_shots': 9,
#      'hits': 6,
#      'giveaways': 2,
#      'takeaways': 1,
#      'blocked_shots': 21,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 0,
#      'winning_goals': 1,
#      'plus_minus': -6,
#      'games_scratched': 12,
#      'games_started': 0,
#      'shooting_pct': 6.5,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 0,
#      'points': 6,
#      'emptynet_goals': 0,
#      'overtime_goals': 1,
#      'overtime_assists': 0,
#      'overtime_shots': 1,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 5,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 1,
#      'third_star': 0},
#     'powerplay': {'shots': 3,
#      'goals': 0,
#      'missed_shots': 1,
#      'assists': 3,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 28,
#      'goals': 2,
#      'missed_shots': 8,
#      'assists': 1,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.25,
#      'blocked_shots': 1.31,
#      'points': 0.38,
#      'blocked_att': 0.88,
#      'penalties': 0.31,
#      'missed_shots': 0.56,
#      'hits': 0.38,
#      'shots': 1.94,
#      'takeaways': 0.06,
#      'giveaways': 0.13,
#      'goals': 0.13,
#      'penalty_minutes': 0.63}},
#    'time_on_ice': {'total': {'shifts': 263,
#      'total': '218:25',
#      'overtime': '3:11',
#      'powerplay': '23:18',
#      'shorthanded': '00:00',
#      'evenstrength': '195:07'},
#     'average': {'shifts': 16.44,
#      'total': '13:39',
#      'overtime': '00:38',
#      'powerplay': '1:27',
#      'shorthanded': '00:00',
#      'evenstrength': '12:12'}}},
#   {'id': '8eef97c0-56c8-493b-bd12-9ab5b1456bda',
#    'full_name': 'Andreas Englund',
#    'first_name': 'Andreas',
#    'last_name': 'Englund',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '5',
#    'sr_id': 'sr:player:382576',
#    'reference': '8477971',
#    'statistics': {'total': {'games_played': 82,
#      'goals': 1,
#      'assists': 9,
#      'penalties': 24,
#      'penalty_minutes': 81,
#      'shots': 41,
#      'blocked_att': 54,
#      'missed_shots': 15,
#      'hits': 189,
#      'giveaways': 22,
#      'takeaways': 8,
#      'blocked_shots': 87,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 0,
#      'winning_goals': 0,
#      'plus_minus': -3,
#      'games_scratched': 0,
#      'games_started': 3,
#      'shooting_pct': 2.4,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 0,
#      'points': 10,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 11,
#      'penalties_match': 0,
#      'penalties_minor': 13,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 0,
#      'third_star': 0},
#     'powerplay': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 41,
#      'goals': 1,
#      'missed_shots': 15,
#      'assists': 9,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.11,
#      'blocked_shots': 1.06,
#      'points': 0.12,
#      'blocked_att': 0.66,
#      'penalties': 0.29,
#      'missed_shots': 0.18,
#      'hits': 2.3,
#      'shots': 0.5,
#      'takeaways': 0.1,
#      'giveaways': 0.27,
#      'goals': 0.01,
#      'penalty_minutes': 0.99}},
#    'time_on_ice': {'total': {'shifts': 1333,
#      'total': '1084:14',
#      'overtime': '00:16',
#      'powerplay': '1:15',
#      'shorthanded': '75:20',
#      'evenstrength': '1007:39'},
#     'average': {'shifts': 16.26,
#      'total': '13:13',
#      'overtime': '00:01',
#      'powerplay': '00:01',
#      'shorthanded': '00:55',
#      'evenstrength': '12:17'}}},
#   {'id': '533ebbc8-ad3c-459e-8b29-660030ac140f',
#    'full_name': 'Alex Laferriere',
#    'first_name': 'Alex',
#    'last_name': 'Laferriere',
#    'position': 'F',
#    'primary_position': 'RW',
#    'jersey_number': '78',
#    'sr_id': 'sr:player:2056465',
#    'reference': '8482155',
#    'statistics': {'total': {'games_played': 81,
#      'goals': 12,
#      'assists': 11,
#      'penalties': 20,
#      'penalty_minutes': 46,
#      'shots': 147,
#      'blocked_att': 82,
#      'missed_shots': 90,
#      'hits': 113,
#      'giveaways': 26,
#      'takeaways': 21,
#      'blocked_shots': 27,
#      'faceoffs_won': 7,
#      'faceoffs_lost': 6,
#      'winning_goals': 2,
#      'plus_minus': -14,
#      'games_scratched': 1,
#      'games_started': 11,
#      'shooting_pct': 8.2,
#      'faceoff_win_pct': 53.8,
#      'faceoffs': 13,
#      'points': 23,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 2,
#      'penalties_match': 0,
#      'penalties_minor': 18,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 0,
#      'third_star': 3},
#     'powerplay': {'shots': 6,
#      'goals': 0,
#      'missed_shots': 4,
#      'assists': 3,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 1,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 1,
#      'faceoffs_lost': 1,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 140,
#      'goals': 12,
#      'missed_shots': 86,
#      'assists': 8,
#      'faceoffs_won': 7,
#      'faceoffs': 12,
#      'faceoffs_lost': 5,
#      'faceoff_win_pct': 58.3},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 1},
#     'average': {'assists': 0.14,
#      'blocked_shots': 0.33,
#      'points': 0.28,
#      'blocked_att': 1.01,
#      'penalties': 0.25,
#      'missed_shots': 1.11,
#      'hits': 1.4,
#      'shots': 1.81,
#      'takeaways': 0.26,
#      'giveaways': 0.32,
#      'goals': 0.15,
#      'penalty_minutes': 0.57}},
#    'time_on_ice': {'total': {'shifts': 1366,
#      'total': '1070:50',
#      'overtime': '00:00',
#      'powerplay': '50:40',
#      'shorthanded': '5:48',
#      'evenstrength': '1014:22'},
#     'average': {'shifts': 16.86,
#      'total': '13:13',
#      'overtime': '00:00',
#      'powerplay': '00:38',
#      'shorthanded': '00:04',
#      'evenstrength': '12:31'}}},
#   {'id': '427d1fda-0f24-11e2-8525-18a905767e44',
#    'full_name': 'Anze Kopitar',
#    'first_name': 'Anze',
#    'last_name': 'Kopitar',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '11',
#    'sr_id': 'sr:player:29571',
#    'reference': '8471685',
#    'statistics': {'total': {'games_played': 81,
#      'goals': 26,
#      'assists': 44,
#      'penalties': 7,
#      'penalty_minutes': 22,
#      'shots': 133,
#      'blocked_att': 50,
#      'missed_shots': 49,
#      'hits': 37,
#      'giveaways': 37,
#      'takeaways': 49,
#      'blocked_shots': 65,
#      'faceoffs_won': 859,
#      'faceoffs_lost': 701,
#      'winning_goals': 6,
#      'plus_minus': 11,
#      'games_scratched': 1,
#      'games_started': 34,
#      'shooting_pct': 19.5,
#      'faceoff_win_pct': 55.1,
#      'faceoffs': 1560,
#      'points': 70,
#      'emptynet_goals': 1,
#      'overtime_goals': 0,
#      'overtime_assists': 2,
#      'overtime_shots': 1,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 6,
#      'penalties_misconduct': 1,
#      'first_star': 6,
#      'second_star': 7,
#      'third_star': 2},
#     'powerplay': {'shots': 32,
#      'goals': 9,
#      'missed_shots': 11,
#      'assists': 14,
#      'faceoffs_won': 143,
#      'faceoffs': 251,
#      'faceoffs_lost': 108,
#      'faceoff_win_pct': 57.0},
#     'shorthanded': {'shots': 4,
#      'goals': 1,
#      'missed_shots': 0,
#      'assists': 2,
#      'faceoffs_won': 85,
#      'faceoffs': 189,
#      'faceoffs_lost': 104,
#      'faceoff_win_pct': 45.0},
#     'evenstrength': {'shots': 97,
#      'goals': 16,
#      'missed_shots': 38,
#      'assists': 28,
#      'faceoffs_won': 631,
#      'faceoffs': 1121,
#      'faceoffs_lost': 490,
#      'faceoff_win_pct': 56.3},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 2, 'goals': 0, 'missed_shots': 1},
#     'average': {'assists': 0.54,
#      'blocked_shots': 0.8,
#      'points': 0.86,
#      'blocked_att': 0.62,
#      'penalties': 0.09,
#      'missed_shots': 0.6,
#      'hits': 0.46,
#      'shots': 1.64,
#      'takeaways': 0.6,
#      'giveaways': 0.46,
#      'goals': 0.32,
#      'penalty_minutes': 0.27}},
#    'time_on_ice': {'total': {'shifts': 1833,
#      'total': '1592:19',
#      'overtime': '25:14',
#      'powerplay': '248:17',
#      'shorthanded': '147:46',
#      'evenstrength': '1196:16'},
#     'average': {'shifts': 22.63,
#      'total': '19:39',
#      'overtime': '1:24',
#      'powerplay': '3:04',
#      'shorthanded': '1:49',
#      'evenstrength': '14:46'}}},
#   {'id': 'd57c7da4-b733-4137-94d3-388dd2b60cba',
#    'full_name': 'Vladislav Gavrikov',
#    'first_name': 'Vladislav',
#    'last_name': 'Gavrikov',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '84',
#    'sr_id': 'sr:player:793408',
#    'reference': '8478882',
#    'statistics': {'total': {'games_played': 77,
#      'goals': 6,
#      'assists': 17,
#      'penalties': 10,
#      'penalty_minutes': 28,
#      'shots': 114,
#      'blocked_att': 72,
#      'missed_shots': 33,
#      'hits': 55,
#      'giveaways': 42,
#      'takeaways': 23,
#      'blocked_shots': 114,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 0,
#      'winning_goals': 1,
#      'plus_minus': 9,
#      'games_scratched': 1,
#      'games_started': 23,
#      'shooting_pct': 5.3,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 0,
#      'points': 23,
#      'emptynet_goals': 0,
#      'overtime_goals': 1,
#      'overtime_assists': 0,
#      'overtime_shots': 1,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 9,
#      'penalties_misconduct': 1,
#      'first_star': 1,
#      'second_star': 0,
#      'third_star': 2},
#     'powerplay': {'shots': 2,
#      'goals': 0,
#      'missed_shots': 1,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 1,
#      'goals': 0,
#      'missed_shots': 1,
#      'assists': 1,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 111,
#      'goals': 6,
#      'missed_shots': 31,
#      'assists': 16,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.22,
#      'blocked_shots': 1.48,
#      'points': 0.3,
#      'blocked_att': 0.94,
#      'penalties': 0.13,
#      'missed_shots': 0.43,
#      'hits': 0.71,
#      'shots': 1.48,
#      'takeaways': 0.3,
#      'giveaways': 0.55,
#      'goals': 0.08,
#      'penalty_minutes': 0.36}},
#    'time_on_ice': {'total': {'shifts': 1774,
#      'total': '1587:30',
#      'overtime': '10:26',
#      'powerplay': '17:21',
#      'shorthanded': '191:56',
#      'evenstrength': '1378:13'},
#     'average': {'shifts': 23.04,
#      'total': '20:37',
#      'overtime': '00:37',
#      'powerplay': '00:14',
#      'shorthanded': '2:30',
#      'evenstrength': '17:54'}}},
#   {'id': '9a2d02cf-a8f2-43a4-9079-d9f72238facb',
#    'full_name': 'Jacob Moverare',
#    'first_name': 'Jacob',
#    'last_name': 'Moverare',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '43',
#    'sr_id': 'sr:player:983687',
#    'reference': '8479421',
#    'statistics': {'total': {'games_played': 24,
#      'goals': 1,
#      'assists': 0,
#      'penalties': 3,
#      'penalty_minutes': 6,
#      'shots': 11,
#      'blocked_att': 12,
#      'missed_shots': 6,
#      'hits': 12,
#      'giveaways': 3,
#      'takeaways': 0,
#      'blocked_shots': 23,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 0,
#      'winning_goals': 0,
#      'plus_minus': 0,
#      'games_scratched': 19,
#      'games_started': 7,
#      'shooting_pct': 9.1,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 0,
#      'points': 1,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 3,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 0,
#      'third_star': 1},
#     'powerplay': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 11,
#      'goals': 1,
#      'missed_shots': 6,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.0,
#      'blocked_shots': 0.96,
#      'points': 0.04,
#      'blocked_att': 0.5,
#      'penalties': 0.13,
#      'missed_shots': 0.25,
#      'hits': 0.5,
#      'shots': 0.46,
#      'takeaways': 0.0,
#      'giveaways': 0.13,
#      'goals': 0.04,
#      'penalty_minutes': 0.25}},
#    'time_on_ice': {'total': {'shifts': 311,
#      'total': '250:43',
#      'overtime': '00:00',
#      'powerplay': '00:19',
#      'shorthanded': '14:36',
#      'evenstrength': '235:48'},
#     'average': {'shifts': 12.96,
# ...
#     'powerplay': {'shots': 31,
#      'goals': 6,
#      'missed_shots': 13,
#      'assists': 8,
#      'faceoffs_won': 7,
#      'faceoffs': 17,
#      'faceoffs_lost': 10,
#      'faceoff_win_pct': 41.2},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 1,
#      'faceoffs': 1,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 100.0},
#     'evenstrength': {'shots': 130,
#      'goals': 14,
#      'missed_shots': 73,
#      'assists': 27,
#      'faceoffs_won': 33,
#      'faceoffs': 72,
#      'faceoffs_lost': 39,
#      'faceoff_win_pct': 45.8},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 1, 'goals': 0, 'missed_shots': 1},
#     'average': {'assists': 0.44,
#      'blocked_shots': 0.24,
#      'points': 0.69,
#      'blocked_att': 0.83,
#      'penalties': 0.21,
#      'missed_shots': 1.08,
#      'hits': 0.83,
#      'shots': 2.01,
#      'takeaways': 0.58,
#      'giveaways': 0.19,
#      'goals': 0.25,
#      'penalty_minutes': 0.53}},
#    'time_on_ice': {'total': {'shifts': 1616,
#      'total': '1318:42',
#      'overtime': '6:35',
#      'powerplay': '184:32',
#      'shorthanded': '1:58',
#      'evenstrength': '1132:12'},
#     'average': {'shifts': 20.2,
#      'total': '16:29',
#      'overtime': '00:23',
#      'powerplay': '2:18',
#      'shorthanded': '00:01',
#      'evenstrength': '14:09'}}},
#   {'id': '76967e78-08fa-4e9c-8ec5-b42ea00d0a37',
#    'full_name': 'Phillip Danault',
#    'first_name': 'Phillip',
#    'last_name': 'Danault',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '24',
#    'sr_id': 'sr:player:353682',
#    'reference': '8476479',
#    'statistics': {'total': {'games_played': 78,
#      'goals': 17,
#      'assists': 30,
#      'penalties': 9,
#      'penalty_minutes': 18,
#      'shots': 159,
#      'blocked_att': 57,
#      'missed_shots': 62,
#      'hits': 80,
#      'giveaways': 38,
#      'takeaways': 22,
#      'blocked_shots': 60,
#      'faceoffs_won': 600,
#      'faceoffs_lost': 557,
#      'winning_goals': 2,
#      'plus_minus': 12,
#      'games_scratched': 4,
#      'games_started': 36,
#      'shooting_pct': 10.7,
#      'faceoff_win_pct': 51.9,
#      'faceoffs': 1157,
#      'points': 47,
#      'emptynet_goals': 1,
#      'overtime_goals': 0,
#      'overtime_assists': 1,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 9,
#      'penalties_misconduct': 0,
#      'first_star': 2,
#      'second_star': 2,
#      'third_star': 2},
#     'powerplay': {'shots': 17,
#      'goals': 3,
#      'missed_shots': 4,
#      'assists': 6,
#      'faceoffs_won': 50,
#      'faceoffs': 93,
#      'faceoffs_lost': 43,
#      'faceoff_win_pct': 53.8},
#     'shorthanded': {'shots': 9,
#      'goals': 0,
#      'missed_shots': 2,
#      'assists': 2,
#      'faceoffs_won': 69,
#      'faceoffs': 144,
#      'faceoffs_lost': 75,
#      'faceoff_win_pct': 47.9},
#     'evenstrength': {'shots': 133,
#      'goals': 14,
#      'missed_shots': 56,
#      'assists': 22,
#      'faceoffs_won': 481,
#      'faceoffs': 920,
#      'faceoffs_lost': 439,
#      'faceoff_win_pct': 52.3},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 1, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.38,
#      'blocked_shots': 0.77,
#      'points': 0.6,
#      'blocked_att': 0.73,
#      'penalties': 0.12,
#      'missed_shots': 0.79,
#      'hits': 1.03,
#      'shots': 2.04,
#      'takeaways': 0.28,
#      'giveaways': 0.49,
#      'goals': 0.22,
#      'penalty_minutes': 0.23}},
#    'time_on_ice': {'total': {'shifts': 1738,
#      'total': '1405:39',
#      'overtime': '15:39',
#      'powerplay': '144:03',
#      'shorthanded': '140:25',
#      'evenstrength': '1121:11'},
#     'average': {'shifts': 22.28,
#      'total': '18:01',
#      'overtime': '00:52',
#      'powerplay': '1:51',
#      'shorthanded': '1:48',
#      'evenstrength': '14:22'}}},
#   {'id': '427d4479-0f24-11e2-8525-18a905767e44',
#    'full_name': 'Trevor Lewis',
#    'first_name': 'Trevor',
#    'last_name': 'Lewis',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '61',
#    'sr_id': 'sr:player:93721',
#    'reference': '8473453',
#    'statistics': {'total': {'games_played': 82,
#      'goals': 8,
#      'assists': 8,
#      'penalties': 10,
#      'penalty_minutes': 20,
#      'shots': 130,
#      'blocked_att': 36,
#      'missed_shots': 45,
#      'hits': 90,
#      'giveaways': 17,
#      'takeaways': 15,
#      'blocked_shots': 62,
#      'faceoffs_won': 133,
#      'faceoffs_lost': 179,
#      'winning_goals': 2,
#      'plus_minus': 7,
#      'games_scratched': 0,
#      'games_started': 1,
#      'shooting_pct': 6.2,
#      'faceoff_win_pct': 42.6,
#      'faceoffs': 312,
#      'points': 16,
#      'emptynet_goals': 1,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 10,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 1,
#      'third_star': 0},
#     'powerplay': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 1,
#      'faceoffs_won': 5,
#      'faceoffs': 7,
#      'faceoffs_lost': 2,
#      'faceoff_win_pct': 71.4},
#     'shorthanded': {'shots': 13,
#      'goals': 1,
#      'missed_shots': 1,
#      'assists': 1,
#      'faceoffs_won': 32,
#      'faceoffs': 95,
#      'faceoffs_lost': 63,
#      'faceoff_win_pct': 33.7},
#     'evenstrength': {'shots': 117,
#      'goals': 7,
#      'missed_shots': 44,
#      'assists': 6,
#      'faceoffs_won': 96,
#      'faceoffs': 210,
#      'faceoffs_lost': 114,
#      'faceoff_win_pct': 45.7},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 1, 'goals': 1, 'missed_shots': 0},
#     'average': {'assists': 0.1,
#      'blocked_shots': 0.76,
#      'points': 0.2,
#      'blocked_att': 0.44,
#      'penalties': 0.12,
#      'missed_shots': 0.55,
#      'hits': 1.1,
#      'shots': 1.59,
#      'takeaways': 0.18,
#      'giveaways': 0.21,
#      'goals': 0.1,
#      'penalty_minutes': 0.24}},
#    'time_on_ice': {'total': {'shifts': 1373,
#      'total': '954:08',
#      'overtime': '00:00',
#      'powerplay': '3:58',
#      'shorthanded': '145:46',
#      'evenstrength': '804:24'},
#     'average': {'shifts': 16.74,
#      'total': '11:38',
#      'overtime': '00:00',
#      'powerplay': '00:03',
#      'shorthanded': '1:47',
#      'evenstrength': '9:49'}}},
#   {'id': '14360232-2f8c-46b0-91a3-4a00aa48de41',
#    'full_name': 'Akil Thomas',
#    'first_name': 'Akil',
#    'last_name': 'Thomas',
#    'position': 'F',
#    'primary_position': 'C',
#    'jersey_number': '41',
#    'sr_id': 'sr:player:1401461',
#    'reference': '8480851',
#    'statistics': {'total': {'games_played': 7,
#      'goals': 3,
#      'assists': 1,
#      'penalties': 1,
#      'penalty_minutes': 2,
#      'shots': 9,
#      'blocked_att': 4,
#      'missed_shots': 3,
#      'hits': 8,
#      'giveaways': 0,
#      'takeaways': 2,
#      'blocked_shots': 3,
#      'faceoffs_won': 4,
#      'faceoffs_lost': 6,
#      'winning_goals': 1,
#      'plus_minus': 0,
#      'games_scratched': 1,
#      'games_started': 0,
#      'shooting_pct': 33.3,
#      'faceoff_win_pct': 40.0,
#      'faceoffs': 10,
#      'points': 4,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 1,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 1,
#      'third_star': 0},
#     'powerplay': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 9,
#      'goals': 3,
#      'missed_shots': 3,
#      'assists': 1,
#      'faceoffs_won': 4,
#      'faceoffs': 10,
#      'faceoffs_lost': 6,
#      'faceoff_win_pct': 40.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.14,
#      'blocked_shots': 0.43,
#      'points': 0.57,
#      'blocked_att': 0.57,
#      'penalties': 0.14,
#      'missed_shots': 0.43,
#      'hits': 1.14,
#      'shots': 1.29,
#      'takeaways': 0.29,
#      'giveaways': 0.0,
#      'goals': 0.43,
#      'penalty_minutes': 0.29}},
#    'time_on_ice': {'total': {'shifts': 84,
#      'total': '61:06',
#      'overtime': '00:00',
#      'powerplay': '00:02',
#      'shorthanded': '1:25',
#      'evenstrength': '59:39'},
#     'average': {'shifts': 12.0,
#      'total': '8:44',
#      'overtime': '00:00',
#      'powerplay': '00:00',
#      'shorthanded': '00:12',
#      'evenstrength': '8:31'}}},
#   {'id': '5b0377bd-412a-44aa-8b8d-8e8eabeb290e',
#    'full_name': 'Carl Grundstrom',
#    'first_name': 'Carl',
#    'last_name': 'Grundstrom',
#    'position': 'F',
#    'primary_position': 'RW',
#    'jersey_number': '91',
#    'sr_id': 'sr:player:774887',
#    'reference': '8479336',
#    'statistics': {'total': {'games_played': 50,
#      'goals': 8,
#      'assists': 4,
#      'penalties': 6,
#      'penalty_minutes': 12,
#      'shots': 95,
#      'blocked_att': 43,
#      'missed_shots': 39,
#      'hits': 115,
#      'giveaways': 13,
#      'takeaways': 10,
#      'blocked_shots': 16,
#      'faceoffs_won': 2,
#      'faceoffs_lost': 8,
#      'winning_goals': 1,
#      'plus_minus': -2,
#      'games_scratched': 0,
#      'games_started': 6,
#      'shooting_pct': 8.4,
#      'faceoff_win_pct': 20.0,
#      'faceoffs': 10,
#      'points': 12,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 0,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 6,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 2,
#      'third_star': 0},
#     'powerplay': {'shots': 2,
#      'goals': 1,
#      'missed_shots': 1,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 1,
#      'goals': 1,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 1,
#      'faceoffs': 3,
#      'faceoffs_lost': 2,
#      'faceoff_win_pct': 33.3},
#     'evenstrength': {'shots': 92,
#      'goals': 6,
#      'missed_shots': 38,
#      'assists': 4,
#      'faceoffs_won': 1,
#      'faceoffs': 7,
#      'faceoffs_lost': 6,
#      'faceoff_win_pct': 14.3},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 2, 'goals': 1, 'missed_shots': 1},
#     'average': {'assists': 0.08,
#      'blocked_shots': 0.32,
#      'points': 0.24,
#      'blocked_att': 0.86,
#      'penalties': 0.12,
#      'missed_shots': 0.78,
#      'hits': 2.3,
#      'shots': 1.9,
#      'takeaways': 0.2,
#      'giveaways': 0.26,
#      'goals': 0.16,
#      'penalty_minutes': 0.24}},
#    'time_on_ice': {'total': {'shifts': 753,
#      'total': '546:51',
#      'overtime': '00:00',
#      'powerplay': '5:31',
#      'shorthanded': '16:38',
#      'evenstrength': '524:42'},
#     'average': {'shifts': 15.06,
#      'total': '10:56',
#      'overtime': '00:00',
#      'powerplay': '00:07',
#      'shorthanded': '00:20',
#      'evenstrength': '10:30'}}},
#   {'id': '4281a6e1-0f24-11e2-8525-18a905767e44',
#    'full_name': 'Drew Doughty',
#    'first_name': 'Drew',
#    'last_name': 'Doughty',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '8',
#    'sr_id': 'sr:player:42413',
#    'reference': '8474563',
#    'statistics': {'total': {'games_played': 82,
#      'goals': 15,
#      'assists': 35,
#      'penalties': 22,
#      'penalty_minutes': 44,
#      'shots': 135,
#      'blocked_att': 122,
#      'missed_shots': 49,
#      'hits': 109,
#      'giveaways': 45,
#      'takeaways': 20,
#      'blocked_shots': 142,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 0,
#      'winning_goals': 3,
#      'plus_minus': 15,
#      'games_scratched': 0,
#      'games_started': 53,
#      'shooting_pct': 11.1,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 0,
#      'points': 50,
#      'emptynet_goals': 1,
#      'overtime_goals': 1,
#      'overtime_assists': 0,
#      'overtime_shots': 1,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 22,
#      'penalties_misconduct': 0,
#      'first_star': 2,
#      'second_star': 2,
#      'third_star': 6},
#     'powerplay': {'shots': 36,
#      'goals': 7,
#      'missed_shots': 14,
#      'assists': 13,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 2,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 97,
#      'goals': 8,
#      'missed_shots': 35,
#      'assists': 22,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.43,
#      'blocked_shots': 1.73,
#      'points': 0.61,
#      'blocked_att': 1.49,
#      'penalties': 0.27,
#      'missed_shots': 0.6,
#      'hits': 1.33,
#      'shots': 1.65,
#      'takeaways': 0.24,
#      'giveaways': 0.55,
#      'goals': 0.18,
#      'penalty_minutes': 0.54}},
#    'time_on_ice': {'total': {'shifts': 2071,
#      'total': '2115:04',
#      'overtime': '25:02',
#      'powerplay': '265:50',
#      'shorthanded': '182:17',
#      'evenstrength': '1666:57'},
#     'average': {'shifts': 25.26,
#      'total': '25:48',
#      'overtime': '1:23',
#      'powerplay': '3:15',
#      'shorthanded': '2:13',
#      'evenstrength': '20:20'}}},
#   {'id': 'bceebd33-2eee-4987-9a24-39ff8d8b01eb',
#    'full_name': 'Jordan Spence',
#    'first_name': 'Jordan',
#    'last_name': 'Spence',
#    'position': 'D',
#    'primary_position': 'D',
#    'jersey_number': '21',
#    'sr_id': 'sr:player:1770298',
#    'reference': '8481606',
#    'statistics': {'total': {'games_played': 71,
#      'goals': 2,
#      'assists': 22,
#      'penalties': 5,
#      'penalty_minutes': 12,
#      'shots': 80,
#      'blocked_att': 86,
#      'missed_shots': 32,
#      'hits': 67,
#      'giveaways': 18,
#      'takeaways': 6,
#      'blocked_shots': 55,
#      'faceoffs_won': 0,
#      'faceoffs_lost': 0,
#      'winning_goals': 0,
#      'plus_minus': 5,
#      'games_scratched': 9,
#      'games_started': 1,
#      'shooting_pct': 2.5,
#      'faceoff_win_pct': 0.0,
#      'faceoffs': 0,
#      'points': 24,
#      'emptynet_goals': 0,
#      'overtime_goals': 0,
#      'overtime_assists': 0,
#      'overtime_shots': 1,
#      'penalties_major': 0,
#      'penalties_match': 0,
#      'penalties_minor': 4,
#      'penalties_misconduct': 0,
#      'first_star': 0,
#      'second_star': 0,
#      'third_star': 0},
#     'powerplay': {'shots': 15,
#      'goals': 1,
#      'missed_shots': 7,
#      'assists': 5,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'shorthanded': {'shots': 0,
#      'goals': 0,
#      'missed_shots': 0,
#      'assists': 0,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'evenstrength': {'shots': 65,
#      'goals': 1,
#      'missed_shots': 25,
#      'assists': 17,
#      'faceoffs_won': 0,
#      'faceoffs': 0,
#      'faceoffs_lost': 0,
#      'faceoff_win_pct': 0.0},
#     'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#     'average': {'assists': 0.31,
#      'blocked_shots': 0.77,
#      'points': 0.34,
#      'blocked_att': 1.21,
#      'penalties': 0.07,
#      'missed_shots': 0.45,
#      'hits': 0.94,
#      'shots': 1.13,
#      'takeaways': 0.08,
#      'giveaways': 0.25,
#      'goals': 0.03,
#      'penalty_minutes': 0.17}},
#    'time_on_ice': {'total': {'shifts': 1207,
#      'total': '1024:15',
#      'overtime': '8:12',
#      'powerplay': '111:02',
#      'shorthanded': '1:20',
#      'evenstrength': '911:53'},
#     'average': {'shifts': 17.0,
#      'total': '14:26',
#      'overtime': '00:29',
#      'powerplay': '1:34',
#      'shorthanded': '00:01',
#      'evenstrength': '12:51'}}}]}

# %%
kings_player_stats_api_response = (json.loads(kings_player_stats_api_request.text))

# %%
kings_player_stats_api_response['players']
# Out:
# [{'id': '677c3651-f73b-4fbf-9a71-f6f16874617d',
#   'full_name': 'David Rittich',
#   'first_name': 'David',
#   'last_name': 'Rittich',
#   'position': 'G',
#   'primary_position': 'G',
#   'jersey_number': '31',
#   'sr_id': 'sr:player:604562',
#   'reference': '8479496',
#   'statistics': {'total': {'games_played': 24,
#     'goals': 0,
#     'assists': 0,
#     'penalties': 0,
#     'penalty_minutes': 0,
#     'shots': 0,
#     'blocked_att': 0,
#     'missed_shots': 0,
#     'hits': 0,
#     'giveaways': 7,
#     'takeaways': 1,
#     'blocked_shots': 0,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 0,
#     'plus_minus': 0,
#     'games_scratched': 0,
#     'games_started': 22,
#     'shooting_pct': 0.0,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 0,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 0,
#     'penalties_misconduct': 0,
#     'first_star': 2,
#     'second_star': 5,
#     'third_star': 1},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.0,
#     'blocked_shots': 0.0,
#     'points': 0.0,
#     'blocked_att': 0.0,
#     'penalties': 0.0,
#     'missed_shots': 0.0,
#     'hits': 0.0,
#     'shots': 0.0,
#     'takeaways': 0.04,
#     'giveaways': 0.29,
#     'goals': 0.0,
#     'penalty_minutes': 0.0}},
#   'time_on_ice': {'total': {'shifts': 93,
#     'total': '1364:31',
#     'overtime': '20:37',
#     'powerplay': '107:11',
#     'shorthanded': '124:58',
#     'evenstrength': '1132:22'},
#    'average': {'shifts': 3.88,
#     'total': '56:51',
#     'overtime': '4:07',
#     'powerplay': '4:28',
#     'shorthanded': '5:12',
#     'evenstrength': '47:11'}},
#   'goaltending': {'total': {'games_played': 24,
#     'shots_against': 621,
#     'goals_against': 49,
#     'saves': 572,
#     'shutouts': 3,
#     'wins': 13,
#     'losses': 6,
#     'overtime_losses': 3,
#     'saves_pct': 0.921,
#     'avg_goals_against': 2.15},
#    'powerplay': {'shots_against': 16,
#     'goals_against': 1,
#     'saves': 15,
#     'saves_pct': 0.938},
#    'shorthanded': {'shots_against': 124,
#     'goals_against': 13,
#     'saves': 111,
#     'saves_pct': 0.895},
#    'evenstrength': {'shots_against': 481,
#     'goals_against': 35,
#     'saves': 446,
#     'saves_pct': 0.927},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'shootout': {'shots_against': 7,
#     'goals_against': 5,
#     'saves': 2,
#     'saves_pct': 0.286},
#    'average': {'shots_against': 25.88, 'goals_against': 2.04}}},
#  {'id': '421f9f71-d1ee-4917-afc6-ca11f6b761b0',
#   'full_name': 'Trevor Moore',
#   'first_name': 'Trevor',
#   'last_name': 'Moore',
#   'position': 'F',
#   'primary_position': 'LW',
#   'jersey_number': '12',
#   'sr_id': 'sr:player:1051357',
#   'reference': '8479675',
#   'statistics': {'total': {'games_played': 82,
#     'goals': 31,
#     'assists': 26,
#     'penalties': 13,
#     'penalty_minutes': 28,
#     'shots': 244,
#     'blocked_att': 74,
#     'missed_shots': 122,
#     'hits': 92,
#     'giveaways': 25,
#     'takeaways': 39,
#     'blocked_shots': 58,
#     'faceoffs_won': 14,
#     'faceoffs_lost': 34,
#     'winning_goals': 5,
#     'plus_minus': 11,
#     'games_scratched': 0,
#     'games_started': 36,
#     'shooting_pct': 12.7,
#     'faceoff_win_pct': 29.2,
#     'faceoffs': 48,
#     'points': 57,
#     'emptynet_goals': 2,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 4,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 12,
#     'penalties_misconduct': 0,
#     'first_star': 3,
#     'second_star': 1,
#     'third_star': 4},
#    'powerplay': {'shots': 29,
#     'goals': 2,
#     'missed_shots': 23,
#     'assists': 5,
#     'faceoffs_won': 1,
#     'faceoffs': 1,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 100.0},
#    'shorthanded': {'shots': 14,
#     'goals': 2,
#     'missed_shots': 7,
#     'assists': 0,
#     'faceoffs_won': 1,
#     'faceoffs': 1,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 100.0},
#    'evenstrength': {'shots': 201,
#     'goals': 27,
#     'missed_shots': 92,
#     'assists': 21,
#     'faceoffs_won': 12,
#     'faceoffs': 46,
#     'faceoffs_lost': 34,
#     'faceoff_win_pct': 26.1},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 7, 'goals': 3, 'missed_shots': 0},
#    'average': {'assists': 0.32,
#     'blocked_shots': 0.71,
#     'points': 0.7,
#     'blocked_att': 0.9,
#     'penalties': 0.16,
#     'missed_shots': 1.49,
#     'hits': 1.12,
#     'shots': 2.98,
#     'takeaways': 0.48,
#     'giveaways': 0.3,
#     'goals': 0.38,
#     'penalty_minutes': 0.34}},
#   'time_on_ice': {'total': {'shifts': 1825,
#     'total': '1474:21',
#     'overtime': '14:12',
#     'powerplay': '151:45',
#     'shorthanded': '136:30',
#     'evenstrength': '1186:06'},
#    'average': {'shifts': 22.26,
#     'total': '17:59',
#     'overtime': '00:47',
#     'powerplay': '1:51',
#     'shorthanded': '1:40',
#     'evenstrength': '14:28'}}},
#  {'id': 'cd3e3e6c-23c2-4a3e-af08-e498246c50ad',
#   'full_name': 'Viktor Arvidsson',
#   'first_name': 'Viktor',
#   'last_name': 'Arvidsson',
#   'position': 'F',
#   'primary_position': 'RW',
#   'jersey_number': '33',
#   'sr_id': 'sr:player:266577',
#   'reference': '8478042',
#   'statistics': {'total': {'games_played': 18,
#     'goals': 6,
#     'assists': 9,
#     'penalties': 7,
#     'penalty_minutes': 14,
#     'shots': 59,
#     'blocked_att': 19,
#     'missed_shots': 22,
#     'hits': 8,
#     'giveaways': 5,
#     'takeaways': 8,
#     'blocked_shots': 18,
#     'faceoffs_won': 3,
#     'faceoffs_lost': 6,
#     'winning_goals': 1,
#     'plus_minus': 4,
#     'games_scratched': 1,
#     'games_started': 12,
#     'shooting_pct': 10.2,
#     'faceoff_win_pct': 33.3,
#     'faceoffs': 9,
#     'points': 15,
#     'emptynet_goals': 1,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 7,
#     'penalties_misconduct': 0,
#     'first_star': 3,
#     'second_star': 0,
#     'third_star': 1},
#    'powerplay': {'shots': 7,
#     'goals': 1,
#     'missed_shots': 2,
#     'assists': 4,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 52,
#     'goals': 5,
#     'missed_shots': 20,
#     'assists': 5,
#     'faceoffs_won': 3,
#     'faceoffs': 9,
#     'faceoffs_lost': 6,
#     'faceoff_win_pct': 33.3},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.5,
#     'blocked_shots': 1.0,
#     'points': 0.83,
#     'blocked_att': 1.06,
#     'penalties': 0.39,
#     'missed_shots': 1.22,
#     'hits': 0.44,
#     'shots': 3.28,
#     'takeaways': 0.44,
#     'giveaways': 0.28,
#     'goals': 0.33,
#     'penalty_minutes': 0.78}},
#   'time_on_ice': {'total': {'shifts': 345,
#     'total': '300:27',
#     'overtime': '00:33',
#     'powerplay': '58:08',
#     'shorthanded': '00:26',
#     'evenstrength': '241:53'},
#    'average': {'shifts': 19.17,
#     'total': '16:42',
#     'overtime': '00:11',
#     'powerplay': '3:14',
#     'shorthanded': '00:01',
#     'evenstrength': '13:26'}}},
#  {'id': 'c86ff633-7f27-420c-84a7-be1e08ede9a6',
#   'full_name': 'Kevin Fiala',
#   'first_name': 'Kevin',
#   'last_name': 'Fiala',
#   'position': 'F',
#   'primary_position': 'LW',
#   'jersey_number': '22',
#   'sr_id': 'sr:player:376846',
#   'reference': '8477942',
#   'statistics': {'total': {'games_played': 82,
#     'goals': 29,
#     'assists': 44,
#     'penalties': 26,
#     'penalty_minutes': 62,
#     'shots': 225,
#     'blocked_att': 124,
#     'missed_shots': 118,
#     'hits': 67,
#     'giveaways': 57,
#     'takeaways': 45,
#     'blocked_shots': 28,
#     'faceoffs_won': 10,
#     'faceoffs_lost': 28,
#     'winning_goals': 2,
#     'plus_minus': 1,
#     'games_scratched': 0,
#     'games_started': 24,
#     'shooting_pct': 12.9,
#     'faceoff_win_pct': 26.3,
#     'faceoffs': 38,
#     'points': 73,
#     'emptynet_goals': 1,
#     'overtime_goals': 1,
#     'overtime_assists': 0,
#     'overtime_shots': 5,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 24,
#     'penalties_misconduct': 1,
#     'first_star': 3,
#     'second_star': 5,
#     'third_star': 6},
#    'powerplay': {'shots': 56,
#     'goals': 11,
#     'missed_shots': 32,
#     'assists': 19,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 169,
#     'goals': 18,
#     'missed_shots': 86,
#     'assists': 25,
#     'faceoffs_won': 10,
#     'faceoffs': 38,
#     'faceoffs_lost': 28,
#     'faceoff_win_pct': 26.3},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 3, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.54,
#     'blocked_shots': 0.34,
#     'points': 0.89,
#     'blocked_att': 1.51,
#     'penalties': 0.32,
#     'missed_shots': 1.44,
#     'hits': 0.82,
#     'shots': 2.74,
#     'takeaways': 0.55,
#     'giveaways': 0.7,
#     'goals': 0.35,
#     'penalty_minutes': 0.76}},
#   'time_on_ice': {'total': {'shifts': 1632,
#     'total': '1478:55',
#     'overtime': '14:35',
#     'powerplay': '258:13',
#     'shorthanded': '1:53',
#     'evenstrength': '1218:49'},
#    'average': {'shifts': 19.9,
#     'total': '18:02',
#     'overtime': '00:49',
#     'powerplay': '3:09',
#     'shorthanded': '00:01',
#     'evenstrength': '14:52'}}},
#  {'id': '6767e821-5a9c-4379-9bfa-9f19314cfc2f',
#   'full_name': 'Mikey Anderson',
#   'first_name': 'Mikey',
#   'last_name': 'Anderson',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '44',
#   'sr_id': 'sr:player:1117735',
#   'reference': '8479998',
#   'statistics': {'total': {'games_played': 74,
#     'goals': 2,
#     'assists': 16,
#     'penalties': 9,
#     'penalty_minutes': 18,
#     'shots': 89,
#     'blocked_att': 74,
#     'missed_shots': 43,
#     'hits': 128,
#     'giveaways': 27,
#     'takeaways': 14,
#     'blocked_shots': 129,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 0,
#     'plus_minus': 22,
#     'games_scratched': 8,
#     'games_started': 49,
#     'shooting_pct': 2.2,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 18,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 9,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 1,
#     'third_star': 0},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 1,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 3,
#     'goals': 0,
#     'missed_shots': 1,
#     'assists': 1,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 86,
#     'goals': 2,
#     'missed_shots': 41,
#     'assists': 15,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.22,
#     'blocked_shots': 1.74,
#     'points': 0.24,
#     'blocked_att': 1.0,
#     'penalties': 0.12,
#     'missed_shots': 0.58,
#     'hits': 1.73,
#     'shots': 1.2,
#     'takeaways': 0.19,
#     'giveaways': 0.36,
#     'goals': 0.03,
#     'penalty_minutes': 0.24}},
#   'time_on_ice': {'total': {'shifts': 1630,
#     'total': '1526:43',
#     'overtime': '4:15',
#     'powerplay': '1:40',
#     'shorthanded': '171:39',
#     'evenstrength': '1353:24'},
#    'average': {'shifts': 22.03,
#     'total': '20:38',
#     'overtime': '00:17',
#     'powerplay': '00:01',
#     'shorthanded': '2:19',
#     'evenstrength': '18:17'}}},
#  {'id': '638a55b3-4846-4909-a0d9-14eb38dc26c1',
#   'full_name': 'Jaret Anderson-Dolan',
#   'first_name': 'Jaret',
#   'last_name': 'Anderson-Dolan',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '28',
#   'sr_id': 'sr:player:1117753',
#   'reference': '8479994',
#   'statistics': {'total': {'games_played': 30,
#     'goals': 1,
#     'assists': 3,
#     'penalties': 3,
#     'penalty_minutes': 6,
#     'shots': 29,
#     'blocked_att': 14,
#     'missed_shots': 11,
#     'hits': 53,
#     'giveaways': 8,
#     'takeaways': 2,
#     'blocked_shots': 21,
#     'faceoffs_won': 20,
#     'faceoffs_lost': 27,
#     'winning_goals': 0,
#     'plus_minus': -4,
#     'games_scratched': 30,
#     'games_started': 3,
#     'shooting_pct': 3.4,
#     'faceoff_win_pct': 42.6,
#     'faceoffs': 47,
#     'points': 4,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 3,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 0,
#     'third_star': 0},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 1,
#     'goals': 1,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 2,
#     'faceoffs': 4,
#     'faceoffs_lost': 2,
#     'faceoff_win_pct': 50.0},
#    'evenstrength': {'shots': 28,
#     'goals': 0,
#     'missed_shots': 11,
#     'assists': 3,
#     'faceoffs_won': 18,
#     'faceoffs': 43,
#     'faceoffs_lost': 25,
#     'faceoff_win_pct': 41.9},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.1,
#     'blocked_shots': 0.7,
#     'points': 0.13,
#     'blocked_att': 0.47,
#     'penalties': 0.1,
#     'missed_shots': 0.37,
#     'hits': 1.77,
#     'shots': 0.97,
#     'takeaways': 0.07,
#     'giveaways': 0.27,
#     'goals': 0.03,
#     'penalty_minutes': 0.2}},
#   'time_on_ice': {'total': {'shifts': 432,
#     'total': '328:54',
#     'overtime': '00:00',
#     'powerplay': '00:29',
#     'shorthanded': '17:54',
#     'evenstrength': '310:31'},
#    'average': {'shifts': 14.4,
#     'total': '10:58',
#     'overtime': '00:00',
#     'powerplay': '00:01',
#     'shorthanded': '00:36',
#     'evenstrength': '10:21'}}},
#  {'id': 'a0b91f2e-bb6d-409a-9e58-cc764edafe64',
#   'full_name': 'Adrian Kempe',
#   'first_name': 'Adrian',
#   'last_name': 'Kempe',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '9',
#   'sr_id': 'sr:player:361870',
#   'reference': '8477960',
#   'statistics': {'total': {'games_played': 77,
#     'goals': 28,
#     'assists': 47,
#     'penalties': 30,
#     'penalty_minutes': 72,
#     'shots': 246,
#     'blocked_att': 147,
#     'missed_shots': 106,
#     'hits': 112,
#     'giveaways': 24,
#     'takeaways': 31,
#     'blocked_shots': 32,
#     'faceoffs_won': 3,
#     'faceoffs_lost': 10,
#     'winning_goals': 4,
#     'plus_minus': 13,
#     'games_scratched': 5,
#     'games_started': 31,
#     'shooting_pct': 11.4,
#     'faceoff_win_pct': 23.1,
#     'faceoffs': 13,
#     'points': 75,
#     'emptynet_goals': 2,
#     'overtime_goals': 1,
#     'overtime_assists': 2,
#     'overtime_shots': 8,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 27,
#     'penalties_misconduct': 1,
#     'first_star': 6,
#     'second_star': 9,
#     'third_star': 2},
#    'powerplay': {'shots': 51,
#     'goals': 5,
#     'missed_shots': 33,
#     'assists': 22,
#     'faceoffs_won': 2,
#     'faceoffs': 5,
#     'faceoffs_lost': 3,
#     'faceoff_win_pct': 40.0},
#    'shorthanded': {'shots': 18,
#     'goals': 3,
#     'missed_shots': 3,
#     'assists': 1,
#     'faceoffs_won': 1,
#     'faceoffs': 2,
#     'faceoffs_lost': 1,
#     'faceoff_win_pct': 50.0},
#    'evenstrength': {'shots': 177,
#     'goals': 20,
#     'missed_shots': 70,
#     'assists': 24,
#     'faceoffs_won': 0,
#     'faceoffs': 6,
#     'faceoffs_lost': 6,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 4, 'goals': 2, 'missed_shots': 1},
#    'average': {'assists': 0.61,
#     'blocked_shots': 0.42,
#     'points': 0.97,
#     'blocked_att': 1.91,
#     'penalties': 0.39,
#     'missed_shots': 1.38,
#     'hits': 1.45,
#     'shots': 3.19,
#     'takeaways': 0.4,
#     'giveaways': 0.31,
#     'goals': 0.36,
#     'penalty_minutes': 0.94}},
#   'time_on_ice': {'total': {'shifts': 1729,
#     'total': '1457:55',
#     'overtime': '19:39',
#     'powerplay': '239:13',
#     'shorthanded': '129:40',
#     'evenstrength': '1089:02'},
#    'average': {'shifts': 22.45,
#     'total': '18:56',
#     'overtime': '1:14',
#     'powerplay': '3:06',
#     'shorthanded': '1:41',
#     'evenstrength': '14:09'}}},
#  {'id': 'd7ca41dc-2465-490b-ac76-0ac83f64185f',
#   'full_name': 'Alex Turcotte',
#   'first_name': 'Alex',
#   'last_name': 'Turcotte',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '38',
#   'sr_id': 'sr:player:1650183',
#   'reference': '8481532',
#   'statistics': {'total': {'games_played': 20,
#     'goals': 1,
#     'assists': 3,
#     'penalties': 3,
#     'penalty_minutes': 6,
#     'shots': 14,
#     'blocked_att': 9,
#     'missed_shots': 13,
#     'hits': 7,
#     'giveaways': 1,
#     'takeaways': 6,
#     'blocked_shots': 10,
#     'faceoffs_won': 21,
#     'faceoffs_lost': 21,
#     'winning_goals': 0,
#     'plus_minus': 5,
#     'games_scratched': 8,
#     'games_started': 2,
#     'shooting_pct': 7.1,
#     'faceoff_win_pct': 50.0,
#     'faceoffs': 42,
#     'points': 4,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 3,
#     'penalties_misconduct': 0,
#     'first_star': 1,
#     'second_star': 0,
#     'third_star': 0},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 1,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 14,
#     'goals': 1,
#     'missed_shots': 12,
#     'assists': 3,
#     'faceoffs_won': 21,
#     'faceoffs': 42,
#     'faceoffs_lost': 21,
#     'faceoff_win_pct': 50.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.15,
#     'blocked_shots': 0.5,
#     'points': 0.2,
#     'blocked_att': 0.45,
#     'penalties': 0.15,
#     'missed_shots': 0.65,
#     'hits': 0.35,
#     'shots': 0.7,
#     'takeaways': 0.3,
#     'giveaways': 0.05,
#     'goals': 0.05,
#     'penalty_minutes': 0.3}},
#   'time_on_ice': {'total': {'shifts': 264,
#     'total': '185:36',
#     'overtime': '00:00',
#     'powerplay': '2:29',
#     'shorthanded': '00:00',
#     'evenstrength': '183:07'},
#    'average': {'shifts': 13.2,
#     'total': '9:17',
#     'overtime': '00:00',
#     'powerplay': '00:07',
#     'shorthanded': '00:00',
#     'evenstrength': '9:09'}}},
#  {'id': 'f0cdc175-e8c9-4dd9-877d-0f067d8c2e31',
#   'full_name': 'Arthur Kaliyev',
#   'first_name': 'Arthur',
#   'last_name': 'Kaliyev',
#   'position': 'F',
#   'primary_position': 'RW',
#   'jersey_number': '34',
#   'sr_id': 'sr:player:1650147',
#   'reference': '8481560',
#   'statistics': {'total': {'games_played': 51,
#     'goals': 7,
#     'assists': 8,
#     'penalties': 6,
#     'penalty_minutes': 14,
#     'shots': 101,
#     'blocked_att': 56,
#     'missed_shots': 54,
#     'hits': 33,
#     'giveaways': 15,
#     'takeaways': 11,
#     'blocked_shots': 14,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 1,
#     'winning_goals': 0,
#     'plus_minus': -3,
#     'games_scratched': 31,
#     'games_started': 4,
#     'shooting_pct': 6.9,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 1,
#     'points': 15,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 2,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 5,
#     'penalties_misconduct': 0,
#     'first_star': 2,
#     'second_star': 1,
#     'third_star': 0},
#    'powerplay': {'shots': 18,
#     'goals': 3,
#     'missed_shots': 10,
#     'assists': 1,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 83,
#     'goals': 4,
#     'missed_shots': 44,
#     'assists': 7,
#     'faceoffs_won': 0,
#     'faceoffs': 1,
#     'faceoffs_lost': 1,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 1, 'goals': 1, 'missed_shots': 0},
#    'average': {'assists': 0.16,
#     'blocked_shots': 0.27,
#     'points': 0.29,
#     'blocked_att': 1.1,
#     'penalties': 0.12,
#     'missed_shots': 1.06,
#     'hits': 0.65,
#     'shots': 1.98,
#     'takeaways': 0.22,
#     'giveaways': 0.29,
#     'goals': 0.14,
#     'penalty_minutes': 0.27}},
#   'time_on_ice': {'total': {'shifts': 767,
#     'total': '601:55',
#     'overtime': '00:30',
#     'powerplay': '74:50',
#     'shorthanded': '00:00',
#     'evenstrength': '527:05'},
#    'average': {'shifts': 15.04,
#     'total': '11:48',
#     'overtime': '00:03',
#     'powerplay': '1:28',
#     'shorthanded': '00:00',
#     'evenstrength': '10:20'}}},
#  {'id': '0a1a1d3a-7118-4d30-a2bd-a2f95822d22c',
#   'full_name': 'Pheonix Copley',
#   'first_name': 'Pheonix',
#   'last_name': 'Copley',
#   'position': 'G',
#   'primary_position': 'G',
#   'jersey_number': '29',
#   'sr_id': 'sr:player:791897',
#   'reference': '8477831',
#   'statistics': {'total': {'games_played': 8,
#     'goals': 0,
#     'assists': 0,
#     'penalties': 0,
#     'penalty_minutes': 0,
#     'shots': 0,
#     'blocked_att': 0,
#     'missed_shots': 0,
#     'hits': 0,
#     'giveaways': 0,
#     'takeaways': 0,
#     'blocked_shots': 0,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 0,
#     'plus_minus': 0,
#     'games_scratched': 1,
#     'games_started': 8,
#     'shooting_pct': 0.0,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 0,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 0,
#     'penalties_misconduct': 0,
#     'first_star': 1,
#     'second_star': 1,
#     'third_star': 0},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.0,
#     'blocked_shots': 0.0,
#     'points': 0.0,
#     'blocked_att': 0.0,
#     'penalties': 0.0,
#     'missed_shots': 0.0,
#     'hits': 0.0,
#     'shots': 0.0,
#     'takeaways': 0.0,
#     'giveaways': 0.0,
#     'goals': 0.0,
#     'penalty_minutes': 0.0}},
#   'time_on_ice': {'total': {'shifts': 30,
#     'total': '436:17',
#     'overtime': '9:18',
#     'powerplay': '44:10',
#     'shorthanded': '44:11',
#     'evenstrength': '347:56'},
#    'average': {'shifts': 3.75,
#     'total': '54:32',
#     'overtime': '3:06',
#     'powerplay': '5:31',
#     'shorthanded': '5:31',
#     'evenstrength': '43:30'}},
#   'goaltending': {'total': {'games_played': 8,
#     'shots_against': 177,
#     'goals_against': 23,
#     'saves': 154,
#     'shutouts': 1,
#     'wins': 4,
#     'losses': 1,
#     'overtime_losses': 2,
#     'saves_pct': 0.87,
#     'avg_goals_against': 3.17},
#    'powerplay': {'shots_against': 8,
#     'goals_against': 3,
#     'saves': 5,
#     'saves_pct': 0.625},
#    'shorthanded': {'shots_against': 48,
#     'goals_against': 4,
#     'saves': 44,
#     'saves_pct': 0.917},
#    'evenstrength': {'shots_against': 121,
#     'goals_against': 16,
#     'saves': 105,
#     'saves_pct': 0.868},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'shootout': {'shots_against': 9,
#     'goals_against': 3,
#     'saves': 6,
#     'saves_pct': 0.667},
#    'average': {'shots_against': 22.13, 'goals_against': 2.88}}},
#  {'id': '091b5891-b9bc-4a3a-a2b3-782dd6e94c8e',
#   'full_name': 'Brandt Clarke',
#   'first_name': 'Brandt',
#   'last_name': 'Clarke',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '92',
#   'sr_id': 'sr:player:2113752',
#   'reference': '8482730',
#   'statistics': {'total': {'games_played': 16,
#     'goals': 2,
#     'assists': 4,
#     'penalties': 5,
#     'penalty_minutes': 10,
#     'shots': 31,
#     'blocked_att': 14,
#     'missed_shots': 9,
#     'hits': 6,
#     'giveaways': 2,
#     'takeaways': 1,
#     'blocked_shots': 21,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 1,
#     'plus_minus': -6,
#     'games_scratched': 12,
#     'games_started': 0,
#     'shooting_pct': 6.5,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 6,
#     'emptynet_goals': 0,
#     'overtime_goals': 1,
#     'overtime_assists': 0,
#     'overtime_shots': 1,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 5,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 1,
#     'third_star': 0},
#    'powerplay': {'shots': 3,
#     'goals': 0,
#     'missed_shots': 1,
#     'assists': 3,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 28,
#     'goals': 2,
#     'missed_shots': 8,
#     'assists': 1,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.25,
#     'blocked_shots': 1.31,
#     'points': 0.38,
#     'blocked_att': 0.88,
#     'penalties': 0.31,
#     'missed_shots': 0.56,
#     'hits': 0.38,
#     'shots': 1.94,
#     'takeaways': 0.06,
#     'giveaways': 0.13,
#     'goals': 0.13,
#     'penalty_minutes': 0.63}},
#   'time_on_ice': {'total': {'shifts': 263,
#     'total': '218:25',
#     'overtime': '3:11',
#     'powerplay': '23:18',
#     'shorthanded': '00:00',
#     'evenstrength': '195:07'},
#    'average': {'shifts': 16.44,
#     'total': '13:39',
#     'overtime': '00:38',
#     'powerplay': '1:27',
#     'shorthanded': '00:00',
#     'evenstrength': '12:12'}}},
#  {'id': '8eef97c0-56c8-493b-bd12-9ab5b1456bda',
#   'full_name': 'Andreas Englund',
#   'first_name': 'Andreas',
#   'last_name': 'Englund',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '5',
#   'sr_id': 'sr:player:382576',
#   'reference': '8477971',
#   'statistics': {'total': {'games_played': 82,
#     'goals': 1,
#     'assists': 9,
#     'penalties': 24,
#     'penalty_minutes': 81,
#     'shots': 41,
#     'blocked_att': 54,
#     'missed_shots': 15,
#     'hits': 189,
#     'giveaways': 22,
#     'takeaways': 8,
#     'blocked_shots': 87,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 0,
#     'plus_minus': -3,
#     'games_scratched': 0,
#     'games_started': 3,
#     'shooting_pct': 2.4,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 10,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 11,
#     'penalties_match': 0,
#     'penalties_minor': 13,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 0,
#     'third_star': 0},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 41,
#     'goals': 1,
#     'missed_shots': 15,
#     'assists': 9,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.11,
#     'blocked_shots': 1.06,
#     'points': 0.12,
#     'blocked_att': 0.66,
#     'penalties': 0.29,
#     'missed_shots': 0.18,
#     'hits': 2.3,
#     'shots': 0.5,
#     'takeaways': 0.1,
#     'giveaways': 0.27,
#     'goals': 0.01,
#     'penalty_minutes': 0.99}},
#   'time_on_ice': {'total': {'shifts': 1333,
#     'total': '1084:14',
#     'overtime': '00:16',
#     'powerplay': '1:15',
#     'shorthanded': '75:20',
#     'evenstrength': '1007:39'},
#    'average': {'shifts': 16.26,
#     'total': '13:13',
#     'overtime': '00:01',
#     'powerplay': '00:01',
#     'shorthanded': '00:55',
#     'evenstrength': '12:17'}}},
#  {'id': '533ebbc8-ad3c-459e-8b29-660030ac140f',
#   'full_name': 'Alex Laferriere',
#   'first_name': 'Alex',
#   'last_name': 'Laferriere',
#   'position': 'F',
#   'primary_position': 'RW',
#   'jersey_number': '78',
#   'sr_id': 'sr:player:2056465',
#   'reference': '8482155',
#   'statistics': {'total': {'games_played': 81,
#     'goals': 12,
#     'assists': 11,
#     'penalties': 20,
#     'penalty_minutes': 46,
#     'shots': 147,
#     'blocked_att': 82,
#     'missed_shots': 90,
#     'hits': 113,
#     'giveaways': 26,
#     'takeaways': 21,
#     'blocked_shots': 27,
#     'faceoffs_won': 7,
#     'faceoffs_lost': 6,
#     'winning_goals': 2,
#     'plus_minus': -14,
#     'games_scratched': 1,
#     'games_started': 11,
#     'shooting_pct': 8.2,
#     'faceoff_win_pct': 53.8,
#     'faceoffs': 13,
#     'points': 23,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 2,
#     'penalties_match': 0,
#     'penalties_minor': 18,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 0,
#     'third_star': 3},
#    'powerplay': {'shots': 6,
#     'goals': 0,
#     'missed_shots': 4,
#     'assists': 3,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 1,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 1,
#     'faceoffs_lost': 1,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 140,
#     'goals': 12,
#     'missed_shots': 86,
#     'assists': 8,
#     'faceoffs_won': 7,
#     'faceoffs': 12,
#     'faceoffs_lost': 5,
#     'faceoff_win_pct': 58.3},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 1},
#    'average': {'assists': 0.14,
#     'blocked_shots': 0.33,
#     'points': 0.28,
#     'blocked_att': 1.01,
#     'penalties': 0.25,
#     'missed_shots': 1.11,
#     'hits': 1.4,
#     'shots': 1.81,
#     'takeaways': 0.26,
#     'giveaways': 0.32,
#     'goals': 0.15,
#     'penalty_minutes': 0.57}},
#   'time_on_ice': {'total': {'shifts': 1366,
#     'total': '1070:50',
#     'overtime': '00:00',
#     'powerplay': '50:40',
#     'shorthanded': '5:48',
#     'evenstrength': '1014:22'},
#    'average': {'shifts': 16.86,
#     'total': '13:13',
#     'overtime': '00:00',
#     'powerplay': '00:38',
#     'shorthanded': '00:04',
#     'evenstrength': '12:31'}}},
#  {'id': '427d1fda-0f24-11e2-8525-18a905767e44',
#   'full_name': 'Anze Kopitar',
#   'first_name': 'Anze',
#   'last_name': 'Kopitar',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '11',
#   'sr_id': 'sr:player:29571',
#   'reference': '8471685',
#   'statistics': {'total': {'games_played': 81,
#     'goals': 26,
#     'assists': 44,
#     'penalties': 7,
#     'penalty_minutes': 22,
#     'shots': 133,
#     'blocked_att': 50,
#     'missed_shots': 49,
#     'hits': 37,
#     'giveaways': 37,
#     'takeaways': 49,
#     'blocked_shots': 65,
#     'faceoffs_won': 859,
#     'faceoffs_lost': 701,
#     'winning_goals': 6,
#     'plus_minus': 11,
#     'games_scratched': 1,
#     'games_started': 34,
#     'shooting_pct': 19.5,
#     'faceoff_win_pct': 55.1,
#     'faceoffs': 1560,
#     'points': 70,
#     'emptynet_goals': 1,
#     'overtime_goals': 0,
#     'overtime_assists': 2,
#     'overtime_shots': 1,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 6,
#     'penalties_misconduct': 1,
#     'first_star': 6,
#     'second_star': 7,
#     'third_star': 2},
#    'powerplay': {'shots': 32,
#     'goals': 9,
#     'missed_shots': 11,
#     'assists': 14,
#     'faceoffs_won': 143,
#     'faceoffs': 251,
#     'faceoffs_lost': 108,
#     'faceoff_win_pct': 57.0},
#    'shorthanded': {'shots': 4,
#     'goals': 1,
#     'missed_shots': 0,
#     'assists': 2,
#     'faceoffs_won': 85,
#     'faceoffs': 189,
#     'faceoffs_lost': 104,
#     'faceoff_win_pct': 45.0},
#    'evenstrength': {'shots': 97,
#     'goals': 16,
#     'missed_shots': 38,
#     'assists': 28,
#     'faceoffs_won': 631,
#     'faceoffs': 1121,
#     'faceoffs_lost': 490,
#     'faceoff_win_pct': 56.3},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 2, 'goals': 0, 'missed_shots': 1},
#    'average': {'assists': 0.54,
#     'blocked_shots': 0.8,
#     'points': 0.86,
#     'blocked_att': 0.62,
#     'penalties': 0.09,
#     'missed_shots': 0.6,
#     'hits': 0.46,
#     'shots': 1.64,
#     'takeaways': 0.6,
#     'giveaways': 0.46,
#     'goals': 0.32,
#     'penalty_minutes': 0.27}},
#   'time_on_ice': {'total': {'shifts': 1833,
#     'total': '1592:19',
#     'overtime': '25:14',
#     'powerplay': '248:17',
#     'shorthanded': '147:46',
#     'evenstrength': '1196:16'},
#    'average': {'shifts': 22.63,
#     'total': '19:39',
#     'overtime': '1:24',
#     'powerplay': '3:04',
#     'shorthanded': '1:49',
#     'evenstrength': '14:46'}}},
#  {'id': 'd57c7da4-b733-4137-94d3-388dd2b60cba',
#   'full_name': 'Vladislav Gavrikov',
#   'first_name': 'Vladislav',
#   'last_name': 'Gavrikov',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '84',
#   'sr_id': 'sr:player:793408',
#   'reference': '8478882',
#   'statistics': {'total': {'games_played': 77,
#     'goals': 6,
#     'assists': 17,
#     'penalties': 10,
#     'penalty_minutes': 28,
#     'shots': 114,
#     'blocked_att': 72,
#     'missed_shots': 33,
#     'hits': 55,
#     'giveaways': 42,
#     'takeaways': 23,
#     'blocked_shots': 114,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 1,
#     'plus_minus': 9,
#     'games_scratched': 1,
#     'games_started': 23,
#     'shooting_pct': 5.3,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 23,
#     'emptynet_goals': 0,
#     'overtime_goals': 1,
#     'overtime_assists': 0,
#     'overtime_shots': 1,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 9,
#     'penalties_misconduct': 1,
#     'first_star': 1,
#     'second_star': 0,
#     'third_star': 2},
#    'powerplay': {'shots': 2,
#     'goals': 0,
#     'missed_shots': 1,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 1,
#     'goals': 0,
#     'missed_shots': 1,
#     'assists': 1,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 111,
#     'goals': 6,
#     'missed_shots': 31,
#     'assists': 16,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.22,
#     'blocked_shots': 1.48,
#     'points': 0.3,
#     'blocked_att': 0.94,
#     'penalties': 0.13,
#     'missed_shots': 0.43,
#     'hits': 0.71,
#     'shots': 1.48,
#     'takeaways': 0.3,
#     'giveaways': 0.55,
#     'goals': 0.08,
#     'penalty_minutes': 0.36}},
#   'time_on_ice': {'total': {'shifts': 1774,
#     'total': '1587:30',
#     'overtime': '10:26',
#     'powerplay': '17:21',
#     'shorthanded': '191:56',
#     'evenstrength': '1378:13'},
#    'average': {'shifts': 23.04,
#     'total': '20:37',
#     'overtime': '00:37',
#     'powerplay': '00:14',
#     'shorthanded': '2:30',
#     'evenstrength': '17:54'}}},
#  {'id': '9a2d02cf-a8f2-43a4-9079-d9f72238facb',
#   'full_name': 'Jacob Moverare',
#   'first_name': 'Jacob',
#   'last_name': 'Moverare',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '43',
#   'sr_id': 'sr:player:983687',
#   'reference': '8479421',
#   'statistics': {'total': {'games_played': 24,
#     'goals': 1,
#     'assists': 0,
#     'penalties': 3,
#     'penalty_minutes': 6,
#     'shots': 11,
#     'blocked_att': 12,
#     'missed_shots': 6,
#     'hits': 12,
#     'giveaways': 3,
#     'takeaways': 0,
#     'blocked_shots': 23,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 0,
#     'plus_minus': 0,
#     'games_scratched': 19,
#     'games_started': 7,
#     'shooting_pct': 9.1,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 1,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 3,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 0,
#     'third_star': 1},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 11,
#     'goals': 1,
#     'missed_shots': 6,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.0,
#     'blocked_shots': 0.96,
#     'points': 0.04,
#     'blocked_att': 0.5,
#     'penalties': 0.13,
#     'missed_shots': 0.25,
#     'hits': 0.5,
#     'shots': 0.46,
#     'takeaways': 0.0,
#     'giveaways': 0.13,
#     'goals': 0.04,
#     'penalty_minutes': 0.25}},
#   'time_on_ice': {'total': {'shifts': 311,
#     'total': '250:43',
#     'overtime': '00:00',
#     'powerplay': '00:19',
#     'shorthanded': '14:36',
#     'evenstrength': '235:48'},
#    'average': {'shifts': 12.96,
#     'total': '10:27',
#     'overtime': '00:00',
#     'powerplay': '00:01',
#     'shorthanded': '00:37',
#     'evenstrength': '9:50'}}},
#  {'id': '4333f6f1-0f24-11e2-8525-18a905767e44',
#   'full_name': 'Cam Talbot',
#   'first_name': 'Cam',
#   'last_name': 'Talbot',
#   'position': 'G',
#   'primary_position': 'G',
#   'jersey_number': '39',
#   'sr_id': 'sr:player:606874',
#   'reference': '8475660',
#   'statistics': {'total': {'games_played': 54,
#     'goals': 0,
#     'assists': 3,
#     'penalties': 2,
#     'penalty_minutes': 4,
#     'shots': 0,
#     'blocked_att': 0,
#     'missed_shots': 0,
#     'hits': 0,
#     'giveaways': 17,
#     'takeaways': 0,
#     'blocked_shots': 0,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 0,
#     'plus_minus': 0,
#     'games_scratched': 0,
#     'games_started': 52,
#     'shooting_pct': 0.0,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 3,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 2,
#     'penalties_misconduct': 0,
#     'first_star': 1,
#     'second_star': 6,
#     'third_star': 3},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 1,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 2,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.06,
#     'blocked_shots': 0.0,
#     'points': 0.06,
#     'blocked_att': 0.0,
#     'penalties': 0.04,
#     'missed_shots': 0.0,
#     'hits': 0.0,
#     'shots': 0.0,
#     'takeaways': 0.0,
#     'giveaways': 0.31,
#     'goals': 0.0,
#     'penalty_minutes': 0.07}},
#   'time_on_ice': {'total': {'shifts': 201,
#     'total': '3116:07',
#     'overtime': '26:17',
#     'powerplay': '247:57',
#     'shorthanded': '264:26',
#     'evenstrength': '2603:44'},
#    'average': {'shifts': 3.72,
#     'total': '57:42',
#     'overtime': '2:38',
#     'powerplay': '4:36',
#     'shorthanded': '4:54',
#     'evenstrength': '48:13'}},
#   'goaltending': {'total': {'games_played': 54,
#     'shots_against': 1490,
#     'goals_against': 130,
#     'saves': 1360,
#     'shutouts': 3,
#     'wins': 27,
#     'losses': 20,
#     'overtime_losses': 6,
#     'saves_pct': 0.913,
#     'avg_goals_against': 2.5},
#    'powerplay': {'shots_against': 41,
#     'goals_against': 3,
#     'saves': 38,
#     'saves_pct': 0.927},
#    'shorthanded': {'shots_against': 245,
#     'goals_against': 22,
#     'saves': 223,
#     'saves_pct': 0.91},
#    'evenstrength': {'shots_against': 1204,
#     'goals_against': 105,
#     'saves': 1099,
#     'saves_pct': 0.913},
#    'penalty': {'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'saves_pct': 0.0},
#    'shootout': {'shots_against': 15,
#     'goals_against': 7,
#     'saves': 8,
#     'saves_pct': 0.533},
#    'average': {'shots_against': 27.59, 'goals_against': 2.41}}},
#  {'id': 'ac9643e6-7308-4b57-bf71-aa42e7970c65',
#   'full_name': 'Tobias Bjornfot',
#   'first_name': 'Tobias',
#   'last_name': 'Bjornfot',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '2',
#   'sr_id': 'sr:player:1577522',
#   'reference': '8481600',
#   'statistics': {'total': {'games_played': 1,
#     'goals': 0,
#     'assists': 0,
#     'penalties': 0,
#     'penalty_minutes': 0,
#     'shots': 0,
#     'blocked_att': 0,
#     'missed_shots': 0,
#     'hits': 1,
#     'giveaways': 0,
#     'takeaways': 0,
#     'blocked_shots': 1,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 0,
#     'plus_minus': 0,
#     'games_scratched': 31,
#     'games_started': 0,
#     'shooting_pct': 0.0,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 0,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 0,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 0,
#     'third_star': 0},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.0,
#     'blocked_shots': 1.0,
#     'points': 0.0,
#     'blocked_att': 0.0,
#     'penalties': 0.0,
#     'missed_shots': 0.0,
#     'hits': 1.0,
#     'shots': 0.0,
#     'takeaways': 0.0,
#     'giveaways': 0.0,
#     'goals': 0.0,
#     'penalty_minutes': 0.0}},
#   'time_on_ice': {'total': {'shifts': 15,
#     'total': '10:12',
#     'overtime': '00:00',
#     'powerplay': '00:00',
#     'shorthanded': '00:00',
#     'evenstrength': '10:12'},
#    'average': {'shifts': 15.0,
#     'total': '10:12',
#     'overtime': '00:00',
#     'powerplay': '00:00',
#     'shorthanded': '00:00',
#     'evenstrength': '10:12'}}},
#  {'id': '0cc94754-1f54-4723-939f-8c14dd930759',
#   'full_name': 'Matt Roy',
#   'first_name': 'Matt',
#   'last_name': 'Roy',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '3',
#   'sr_id': 'sr:player:1299308',
#   'reference': '8478911',
#   'statistics': {'total': {'games_played': 81,
#     'goals': 5,
#     'assists': 20,
#     'penalties': 17,
#     'penalty_minutes': 42,
#     'shots': 135,
#     'blocked_att': 88,
#     'missed_shots': 71,
#     'hits': 152,
#     'giveaways': 55,
#     'takeaways': 12,
#     'blocked_shots': 197,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 1,
#     'plus_minus': 21,
#     'games_scratched': 1,
#     'games_started': 28,
#     'shooting_pct': 3.7,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 25,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 1,
#     'overtime_shots': 1,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 16,
#     'penalties_misconduct': 1,
#     'first_star': 1,
#     'second_star': 0,
#     'third_star': 1},
#    'powerplay': {'shots': 1,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 1,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 4,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 2,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 130,
#     'goals': 5,
#     'missed_shots': 71,
#     'assists': 17,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.25,
#     'blocked_shots': 2.43,
#     'points': 0.31,
#     'blocked_att': 1.09,
#     'penalties': 0.21,
#     'missed_shots': 0.88,
#     'hits': 1.88,
#     'shots': 1.67,
#     'takeaways': 0.15,
#     'giveaways': 0.68,
#     'goals': 0.06,
#     'penalty_minutes': 0.52}},
#   'time_on_ice': {'total': {'shifts': 1908,
#     'total': '1692:29',
#     'overtime': '11:06',
#     'powerplay': '14:30',
#     'shorthanded': '230:48',
#     'evenstrength': '1447:11'},
#    'average': {'shifts': 23.56,
#     'total': '20:54',
#     'overtime': '00:39',
#     'powerplay': '00:11',
#     'shorthanded': '2:51',
#     'evenstrength': '17:52'}}},
#  {'id': '070ff077-e59b-4135-b060-352ee716bc7e',
#   'full_name': 'Blake Lizotte',
#   'first_name': 'Blake',
#   'last_name': 'Lizotte',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '46',
#   'sr_id': 'sr:player:1726708',
#   'reference': '8481481',
#   'statistics': {'total': {'games_played': 62,
#     'goals': 7,
#     'assists': 8,
#     'penalties': 9,
#     'penalty_minutes': 20,
#     'shots': 76,
#     'blocked_att': 28,
#     'missed_shots': 24,
#     'hits': 64,
#     'giveaways': 13,
#     'takeaways': 11,
#     'blocked_shots': 28,
#     'faceoffs_won': 171,
#     'faceoffs_lost': 194,
#     'winning_goals': 2,
#     'plus_minus': 11,
#     'games_scratched': 7,
#     'games_started': 2,
#     'shooting_pct': 9.2,
#     'faceoff_win_pct': 46.8,
#     'faceoffs': 365,
#     'points': 15,
#     'emptynet_goals': 1,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 8,
#     'penalties_misconduct': 0,
# ...
#     'hits': 66,
#     'giveaways': 15,
#     'takeaways': 46,
#     'blocked_shots': 19,
#     'faceoffs_won': 41,
#     'faceoffs_lost': 49,
#     'winning_goals': 4,
#     'plus_minus': 19,
#     'games_scratched': 2,
#     'games_started': 33,
#     'shooting_pct': 12.4,
#     'faceoff_win_pct': 45.6,
#     'faceoffs': 90,
#     'points': 55,
#     'emptynet_goals': 2,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 1,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 16,
#     'penalties_misconduct': 1,
#     'first_star': 5,
#     'second_star': 3,
#     'third_star': 1},
#    'powerplay': {'shots': 31,
#     'goals': 6,
#     'missed_shots': 13,
#     'assists': 8,
#     'faceoffs_won': 7,
#     'faceoffs': 17,
#     'faceoffs_lost': 10,
#     'faceoff_win_pct': 41.2},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 1,
#     'faceoffs': 1,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 100.0},
#    'evenstrength': {'shots': 130,
#     'goals': 14,
#     'missed_shots': 73,
#     'assists': 27,
#     'faceoffs_won': 33,
#     'faceoffs': 72,
#     'faceoffs_lost': 39,
#     'faceoff_win_pct': 45.8},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 1, 'goals': 0, 'missed_shots': 1},
#    'average': {'assists': 0.44,
#     'blocked_shots': 0.24,
#     'points': 0.69,
#     'blocked_att': 0.83,
#     'penalties': 0.21,
#     'missed_shots': 1.08,
#     'hits': 0.83,
#     'shots': 2.01,
#     'takeaways': 0.58,
#     'giveaways': 0.19,
#     'goals': 0.25,
#     'penalty_minutes': 0.53}},
#   'time_on_ice': {'total': {'shifts': 1616,
#     'total': '1318:42',
#     'overtime': '6:35',
#     'powerplay': '184:32',
#     'shorthanded': '1:58',
#     'evenstrength': '1132:12'},
#    'average': {'shifts': 20.2,
#     'total': '16:29',
#     'overtime': '00:23',
#     'powerplay': '2:18',
#     'shorthanded': '00:01',
#     'evenstrength': '14:09'}}},
#  {'id': '76967e78-08fa-4e9c-8ec5-b42ea00d0a37',
#   'full_name': 'Phillip Danault',
#   'first_name': 'Phillip',
#   'last_name': 'Danault',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '24',
#   'sr_id': 'sr:player:353682',
#   'reference': '8476479',
#   'statistics': {'total': {'games_played': 78,
#     'goals': 17,
#     'assists': 30,
#     'penalties': 9,
#     'penalty_minutes': 18,
#     'shots': 159,
#     'blocked_att': 57,
#     'missed_shots': 62,
#     'hits': 80,
#     'giveaways': 38,
#     'takeaways': 22,
#     'blocked_shots': 60,
#     'faceoffs_won': 600,
#     'faceoffs_lost': 557,
#     'winning_goals': 2,
#     'plus_minus': 12,
#     'games_scratched': 4,
#     'games_started': 36,
#     'shooting_pct': 10.7,
#     'faceoff_win_pct': 51.9,
#     'faceoffs': 1157,
#     'points': 47,
#     'emptynet_goals': 1,
#     'overtime_goals': 0,
#     'overtime_assists': 1,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 9,
#     'penalties_misconduct': 0,
#     'first_star': 2,
#     'second_star': 2,
#     'third_star': 2},
#    'powerplay': {'shots': 17,
#     'goals': 3,
#     'missed_shots': 4,
#     'assists': 6,
#     'faceoffs_won': 50,
#     'faceoffs': 93,
#     'faceoffs_lost': 43,
#     'faceoff_win_pct': 53.8},
#    'shorthanded': {'shots': 9,
#     'goals': 0,
#     'missed_shots': 2,
#     'assists': 2,
#     'faceoffs_won': 69,
#     'faceoffs': 144,
#     'faceoffs_lost': 75,
#     'faceoff_win_pct': 47.9},
#    'evenstrength': {'shots': 133,
#     'goals': 14,
#     'missed_shots': 56,
#     'assists': 22,
#     'faceoffs_won': 481,
#     'faceoffs': 920,
#     'faceoffs_lost': 439,
#     'faceoff_win_pct': 52.3},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 1, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.38,
#     'blocked_shots': 0.77,
#     'points': 0.6,
#     'blocked_att': 0.73,
#     'penalties': 0.12,
#     'missed_shots': 0.79,
#     'hits': 1.03,
#     'shots': 2.04,
#     'takeaways': 0.28,
#     'giveaways': 0.49,
#     'goals': 0.22,
#     'penalty_minutes': 0.23}},
#   'time_on_ice': {'total': {'shifts': 1738,
#     'total': '1405:39',
#     'overtime': '15:39',
#     'powerplay': '144:03',
#     'shorthanded': '140:25',
#     'evenstrength': '1121:11'},
#    'average': {'shifts': 22.28,
#     'total': '18:01',
#     'overtime': '00:52',
#     'powerplay': '1:51',
#     'shorthanded': '1:48',
#     'evenstrength': '14:22'}}},
#  {'id': '427d4479-0f24-11e2-8525-18a905767e44',
#   'full_name': 'Trevor Lewis',
#   'first_name': 'Trevor',
#   'last_name': 'Lewis',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '61',
#   'sr_id': 'sr:player:93721',
#   'reference': '8473453',
#   'statistics': {'total': {'games_played': 82,
#     'goals': 8,
#     'assists': 8,
#     'penalties': 10,
#     'penalty_minutes': 20,
#     'shots': 130,
#     'blocked_att': 36,
#     'missed_shots': 45,
#     'hits': 90,
#     'giveaways': 17,
#     'takeaways': 15,
#     'blocked_shots': 62,
#     'faceoffs_won': 133,
#     'faceoffs_lost': 179,
#     'winning_goals': 2,
#     'plus_minus': 7,
#     'games_scratched': 0,
#     'games_started': 1,
#     'shooting_pct': 6.2,
#     'faceoff_win_pct': 42.6,
#     'faceoffs': 312,
#     'points': 16,
#     'emptynet_goals': 1,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 10,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 1,
#     'third_star': 0},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 1,
#     'faceoffs_won': 5,
#     'faceoffs': 7,
#     'faceoffs_lost': 2,
#     'faceoff_win_pct': 71.4},
#    'shorthanded': {'shots': 13,
#     'goals': 1,
#     'missed_shots': 1,
#     'assists': 1,
#     'faceoffs_won': 32,
#     'faceoffs': 95,
#     'faceoffs_lost': 63,
#     'faceoff_win_pct': 33.7},
#    'evenstrength': {'shots': 117,
#     'goals': 7,
#     'missed_shots': 44,
#     'assists': 6,
#     'faceoffs_won': 96,
#     'faceoffs': 210,
#     'faceoffs_lost': 114,
#     'faceoff_win_pct': 45.7},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 1, 'goals': 1, 'missed_shots': 0},
#    'average': {'assists': 0.1,
#     'blocked_shots': 0.76,
#     'points': 0.2,
#     'blocked_att': 0.44,
#     'penalties': 0.12,
#     'missed_shots': 0.55,
#     'hits': 1.1,
#     'shots': 1.59,
#     'takeaways': 0.18,
#     'giveaways': 0.21,
#     'goals': 0.1,
#     'penalty_minutes': 0.24}},
#   'time_on_ice': {'total': {'shifts': 1373,
#     'total': '954:08',
#     'overtime': '00:00',
#     'powerplay': '3:58',
#     'shorthanded': '145:46',
#     'evenstrength': '804:24'},
#    'average': {'shifts': 16.74,
#     'total': '11:38',
#     'overtime': '00:00',
#     'powerplay': '00:03',
#     'shorthanded': '1:47',
#     'evenstrength': '9:49'}}},
#  {'id': '14360232-2f8c-46b0-91a3-4a00aa48de41',
#   'full_name': 'Akil Thomas',
#   'first_name': 'Akil',
#   'last_name': 'Thomas',
#   'position': 'F',
#   'primary_position': 'C',
#   'jersey_number': '41',
#   'sr_id': 'sr:player:1401461',
#   'reference': '8480851',
#   'statistics': {'total': {'games_played': 7,
#     'goals': 3,
#     'assists': 1,
#     'penalties': 1,
#     'penalty_minutes': 2,
#     'shots': 9,
#     'blocked_att': 4,
#     'missed_shots': 3,
#     'hits': 8,
#     'giveaways': 0,
#     'takeaways': 2,
#     'blocked_shots': 3,
#     'faceoffs_won': 4,
#     'faceoffs_lost': 6,
#     'winning_goals': 1,
#     'plus_minus': 0,
#     'games_scratched': 1,
#     'games_started': 0,
#     'shooting_pct': 33.3,
#     'faceoff_win_pct': 40.0,
#     'faceoffs': 10,
#     'points': 4,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 1,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 1,
#     'third_star': 0},
#    'powerplay': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 9,
#     'goals': 3,
#     'missed_shots': 3,
#     'assists': 1,
#     'faceoffs_won': 4,
#     'faceoffs': 10,
#     'faceoffs_lost': 6,
#     'faceoff_win_pct': 40.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.14,
#     'blocked_shots': 0.43,
#     'points': 0.57,
#     'blocked_att': 0.57,
#     'penalties': 0.14,
#     'missed_shots': 0.43,
#     'hits': 1.14,
#     'shots': 1.29,
#     'takeaways': 0.29,
#     'giveaways': 0.0,
#     'goals': 0.43,
#     'penalty_minutes': 0.29}},
#   'time_on_ice': {'total': {'shifts': 84,
#     'total': '61:06',
#     'overtime': '00:00',
#     'powerplay': '00:02',
#     'shorthanded': '1:25',
#     'evenstrength': '59:39'},
#    'average': {'shifts': 12.0,
#     'total': '8:44',
#     'overtime': '00:00',
#     'powerplay': '00:00',
#     'shorthanded': '00:12',
#     'evenstrength': '8:31'}}},
#  {'id': '5b0377bd-412a-44aa-8b8d-8e8eabeb290e',
#   'full_name': 'Carl Grundstrom',
#   'first_name': 'Carl',
#   'last_name': 'Grundstrom',
#   'position': 'F',
#   'primary_position': 'RW',
#   'jersey_number': '91',
#   'sr_id': 'sr:player:774887',
#   'reference': '8479336',
#   'statistics': {'total': {'games_played': 50,
#     'goals': 8,
#     'assists': 4,
#     'penalties': 6,
#     'penalty_minutes': 12,
#     'shots': 95,
#     'blocked_att': 43,
#     'missed_shots': 39,
#     'hits': 115,
#     'giveaways': 13,
#     'takeaways': 10,
#     'blocked_shots': 16,
#     'faceoffs_won': 2,
#     'faceoffs_lost': 8,
#     'winning_goals': 1,
#     'plus_minus': -2,
#     'games_scratched': 0,
#     'games_started': 6,
#     'shooting_pct': 8.4,
#     'faceoff_win_pct': 20.0,
#     'faceoffs': 10,
#     'points': 12,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 0,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 6,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 2,
#     'third_star': 0},
#    'powerplay': {'shots': 2,
#     'goals': 1,
#     'missed_shots': 1,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 1,
#     'goals': 1,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 1,
#     'faceoffs': 3,
#     'faceoffs_lost': 2,
#     'faceoff_win_pct': 33.3},
#    'evenstrength': {'shots': 92,
#     'goals': 6,
#     'missed_shots': 38,
#     'assists': 4,
#     'faceoffs_won': 1,
#     'faceoffs': 7,
#     'faceoffs_lost': 6,
#     'faceoff_win_pct': 14.3},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 2, 'goals': 1, 'missed_shots': 1},
#    'average': {'assists': 0.08,
#     'blocked_shots': 0.32,
#     'points': 0.24,
#     'blocked_att': 0.86,
#     'penalties': 0.12,
#     'missed_shots': 0.78,
#     'hits': 2.3,
#     'shots': 1.9,
#     'takeaways': 0.2,
#     'giveaways': 0.26,
#     'goals': 0.16,
#     'penalty_minutes': 0.24}},
#   'time_on_ice': {'total': {'shifts': 753,
#     'total': '546:51',
#     'overtime': '00:00',
#     'powerplay': '5:31',
#     'shorthanded': '16:38',
#     'evenstrength': '524:42'},
#    'average': {'shifts': 15.06,
#     'total': '10:56',
#     'overtime': '00:00',
#     'powerplay': '00:07',
#     'shorthanded': '00:20',
#     'evenstrength': '10:30'}}},
#  {'id': '4281a6e1-0f24-11e2-8525-18a905767e44',
#   'full_name': 'Drew Doughty',
#   'first_name': 'Drew',
#   'last_name': 'Doughty',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '8',
#   'sr_id': 'sr:player:42413',
#   'reference': '8474563',
#   'statistics': {'total': {'games_played': 82,
#     'goals': 15,
#     'assists': 35,
#     'penalties': 22,
#     'penalty_minutes': 44,
#     'shots': 135,
#     'blocked_att': 122,
#     'missed_shots': 49,
#     'hits': 109,
#     'giveaways': 45,
#     'takeaways': 20,
#     'blocked_shots': 142,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 3,
#     'plus_minus': 15,
#     'games_scratched': 0,
#     'games_started': 53,
#     'shooting_pct': 11.1,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 50,
#     'emptynet_goals': 1,
#     'overtime_goals': 1,
#     'overtime_assists': 0,
#     'overtime_shots': 1,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 22,
#     'penalties_misconduct': 0,
#     'first_star': 2,
#     'second_star': 2,
#     'third_star': 6},
#    'powerplay': {'shots': 36,
#     'goals': 7,
#     'missed_shots': 14,
#     'assists': 13,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 2,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 97,
#     'goals': 8,
#     'missed_shots': 35,
#     'assists': 22,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.43,
#     'blocked_shots': 1.73,
#     'points': 0.61,
#     'blocked_att': 1.49,
#     'penalties': 0.27,
#     'missed_shots': 0.6,
#     'hits': 1.33,
#     'shots': 1.65,
#     'takeaways': 0.24,
#     'giveaways': 0.55,
#     'goals': 0.18,
#     'penalty_minutes': 0.54}},
#   'time_on_ice': {'total': {'shifts': 2071,
#     'total': '2115:04',
#     'overtime': '25:02',
#     'powerplay': '265:50',
#     'shorthanded': '182:17',
#     'evenstrength': '1666:57'},
#    'average': {'shifts': 25.26,
#     'total': '25:48',
#     'overtime': '1:23',
#     'powerplay': '3:15',
#     'shorthanded': '2:13',
#     'evenstrength': '20:20'}}},
#  {'id': 'bceebd33-2eee-4987-9a24-39ff8d8b01eb',
#   'full_name': 'Jordan Spence',
#   'first_name': 'Jordan',
#   'last_name': 'Spence',
#   'position': 'D',
#   'primary_position': 'D',
#   'jersey_number': '21',
#   'sr_id': 'sr:player:1770298',
#   'reference': '8481606',
#   'statistics': {'total': {'games_played': 71,
#     'goals': 2,
#     'assists': 22,
#     'penalties': 5,
#     'penalty_minutes': 12,
#     'shots': 80,
#     'blocked_att': 86,
#     'missed_shots': 32,
#     'hits': 67,
#     'giveaways': 18,
#     'takeaways': 6,
#     'blocked_shots': 55,
#     'faceoffs_won': 0,
#     'faceoffs_lost': 0,
#     'winning_goals': 0,
#     'plus_minus': 5,
#     'games_scratched': 9,
#     'games_started': 1,
#     'shooting_pct': 2.5,
#     'faceoff_win_pct': 0.0,
#     'faceoffs': 0,
#     'points': 24,
#     'emptynet_goals': 0,
#     'overtime_goals': 0,
#     'overtime_assists': 0,
#     'overtime_shots': 1,
#     'penalties_major': 0,
#     'penalties_match': 0,
#     'penalties_minor': 4,
#     'penalties_misconduct': 0,
#     'first_star': 0,
#     'second_star': 0,
#     'third_star': 0},
#    'powerplay': {'shots': 15,
#     'goals': 1,
#     'missed_shots': 7,
#     'assists': 5,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'shorthanded': {'shots': 0,
#     'goals': 0,
#     'missed_shots': 0,
#     'assists': 0,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'evenstrength': {'shots': 65,
#     'goals': 1,
#     'missed_shots': 25,
#     'assists': 17,
#     'faceoffs_won': 0,
#     'faceoffs': 0,
#     'faceoffs_lost': 0,
#     'faceoff_win_pct': 0.0},
#    'penalty': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'shootout': {'shots': 0, 'goals': 0, 'missed_shots': 0},
#    'average': {'assists': 0.31,
#     'blocked_shots': 0.77,
#     'points': 0.34,
#     'blocked_att': 1.21,
#     'penalties': 0.07,
#     'missed_shots': 0.45,
#     'hits': 0.94,
#     'shots': 1.13,
#     'takeaways': 0.08,
#     'giveaways': 0.25,
#     'goals': 0.03,
#     'penalty_minutes': 0.17}},
#   'time_on_ice': {'total': {'shifts': 1207,
#     'total': '1024:15',
#     'overtime': '8:12',
#     'powerplay': '111:02',
#     'shorthanded': '1:20',
#     'evenstrength': '911:53'},
#    'average': {'shifts': 17.0,
#     'total': '14:26',
#     'overtime': '00:29',
#     'powerplay': '1:34',
#     'shorthanded': '00:01',
#     'evenstrength': '12:51'}}}]

# %%
players_stats = kings_player_stats_api_response['players']

# %% [markdown]
# ### For Goalies

# %%
goalies_stats_data = {
    'full_name':[],
    'games_played':[],
    'shots_against':[],
    'goals_against':[],
    'saves':[],
    'shutouts':[],
    'saves_pct':[],
    'avg_goals_against':[]
}

for stats in players_stats:
    if stats['position'] != 'G':
        continue
    
    full_name = stats['full_name']
    goalies_stats_data['full_name'].append(full_name)
    print('full_name:',full_name)
    
    games_played = stats['goaltending']['total']['games_played']
    goalies_stats_data['games_played'].append(games_played)
    print('games_played:',games_played)
    
    shots_against = stats['goaltending']['total']['shots_against']
    goalies_stats_data['shots_against'].append(shots_against)
    print('shots_against:',shots_against)
    
    goals_against = stats['goaltending']['total']['goals_against']
    goalies_stats_data['goals_against'].append(goals_against)
    print('goals_against:',goals_against)
    
    saves = stats['goaltending']['total']['saves']
    goalies_stats_data['saves'].append(saves)
    print('saves:',saves)
    
    shutouts = stats['goaltending']['total']['shutouts']
    goalies_stats_data['shutouts'].append(shutouts)
    print('shutouts:',shutouts)
    
    saves_pct = stats['goaltending']['total']['saves_pct']
    goalies_stats_data['saves_pct'].append(saves_pct)
    print('saves_pct:',saves_pct)
    
    avg_goals_against = stats['goaltending']['total']['avg_goals_against']
    goalies_stats_data['avg_goals_against'].append(avg_goals_against)
    print('avg_goals_against:',avg_goals_against)
# Out:
# full_name: David Rittich
# games_played: 24
# shots_against: 621
# goals_against: 49
# saves: 572
# shutouts: 3
# saves_pct: 0.921
# avg_goals_against: 2.15
# full_name: Pheonix Copley
# games_played: 8
# shots_against: 177
# goals_against: 23
# saves: 154
# shutouts: 1
# saves_pct: 0.87
# avg_goals_against: 3.17
# full_name: Cam Talbot
# games_played: 54
# shots_against: 1490
# goals_against: 130
# saves: 1360
# shutouts: 3
# saves_pct: 0.913
# avg_goals_against: 2.5

# %%
goalies_stats_data
# Out:
# {'full_name': ['David Rittich', 'Pheonix Copley', 'Cam Talbot'],
#  'games_played': [24, 8, 54],
#  'shots_against': [621, 177, 1490],
#  'goals_against': [49, 23, 130],
#  'saves': [572, 154, 1360],
#  'shutouts': [3, 1, 3],
#  'saves_pct': [0.921, 0.87, 0.913],
#  'avg_goals_against': [2.15, 3.17, 2.5]}

# %%
df =pd.DataFrame(goalies_stats_data)

# %%
df.head()
# Out:
#         full_name  games_played  shots_against  goals_against  saves  \
# 0   David Rittich            24            621             49    572
# 1  Pheonix Copley             8            177             23    154
# 2      Cam Talbot            54           1490            130   1360
#
#    shutouts  saves_pct  avg_goals_against
# 0         3      0.921               2.15
# 1         1      0.870               3.17
# 2         3      0.913               2.50

# %%
df.to_csv('goalies_stats_data.csv', index=False)

# %% [markdown]
# ### For players

# %%
players_stats_data = {
    'full_name':[],
    'games_played':[],
    'goals':[],
    'assists':[],
    'points':[],
    'penalties':[],
    'penalty_minutes':[],
    'shots':[],
    'blocked_att':[],
    'missed_shots':[],
    'hits':[],
    'blocked_shots':[],
    'powerplay_shots':[],
    'powperplay_goals':[],
    'powerplay_assists':[]
}

for stats in players_stats:
    if stats['position'] == 'G':
        continue
        
    full_name = stats['full_name']
    players_stats_data['full_name'].append(full_name)
    print('full_name:',full_name)
    
    games_played = stats['statistics']['total']['games_played']
    players_stats_data['games_played'].append(games_played)
    print('games_played:',games_played)
    
    goals = stats['statistics']['total']['goals']
    players_stats_data['goals'].append(goals)
    print('goals:',goals)
    
    assists = stats['statistics']['total']['assists']
    players_stats_data['assists'].append(assists)
    print('assists:',assists)
    
    points = stats['statistics']['total']['points']
    players_stats_data['points'].append(points)
    print('points:',points)
    
    penalties = stats['statistics']['total']['penalties']
    players_stats_data['penalties'].append(penalties)
    print('penalties:',penalties)
    
    penalty_minutes = stats['statistics']['total']['penalty_minutes']
    players_stats_data['penalty_minutes'].append(penalty_minutes)
    print('penalty minutes:',penalty_minutes)
    
    shots = stats['statistics']['total']['shots']
    players_stats_data['shots'].append(shots)
    print('shots:',shots)
    
    blocked_att = stats['statistics']['total']['blocked_att']
    players_stats_data['blocked_att'].append(blocked_att)
    print('blocked_att:',blocked_att)
    
    missed_shots = stats['statistics']['total']['missed_shots']
    players_stats_data['missed_shots'].append(missed_shots)
    print('missed_shots:',missed_shots)
    
    hits = stats['statistics']['total']['hits']
    players_stats_data['hits'].append(hits)
    print('hits:',hits)
    
    blocked_shots = stats['statistics']['total']['blocked_shots']
    players_stats_data['blocked_shots'].append(blocked_shots)
    print('blocked_shots:',blocked_shots)
    
    powerplay_shots = stats['statistics']['powerplay']['shots']
    players_stats_data['powerplay_shots'].append(powerplay_shots)
    print('powerplay_shots:',powerplay_shots)
    
    powperplay_goals = stats['statistics']['powerplay']['goals']
    players_stats_data['powperplay_goals'].append(powperplay_goals)
    print('powperplay_goals:',powperplay_goals)
    
    powerplay_assists = stats['statistics']['powerplay']['assists']
    players_stats_data['powerplay_assists'].append(powerplay_assists)
    print('powerplay_assists:',powerplay_assists)
# Out:
# full_name: Trevor Moore
# games_played: 82
# goals: 31
# assists: 26
# points: 57
# penalties: 13
# penalty minutes: 28
# shots: 244
# blocked_att: 74
# missed_shots: 122
# hits: 92
# blocked_shots: 58
# powerplay_shots: 29
# powperplay_goals: 2
# powerplay_assists: 5
# full_name: Viktor Arvidsson
# games_played: 18
# goals: 6
# assists: 9
# points: 15
# penalties: 7
# penalty minutes: 14
# shots: 59
# blocked_att: 19
# missed_shots: 22
# hits: 8
# blocked_shots: 18
# powerplay_shots: 7
# powperplay_goals: 1
# powerplay_assists: 4
# full_name: Kevin Fiala
# games_played: 82
# goals: 29
# assists: 44
# points: 73
# penalties: 26
# penalty minutes: 62
# shots: 225
# blocked_att: 124
# missed_shots: 118
# hits: 67
# blocked_shots: 28
# powerplay_shots: 56
# powperplay_goals: 11
# powerplay_assists: 19
# full_name: Mikey Anderson
# games_played: 74
# goals: 2
# assists: 16
# points: 18
# penalties: 9
# penalty minutes: 18
# shots: 89
# blocked_att: 74
# missed_shots: 43
# hits: 128
# blocked_shots: 129
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Jaret Anderson-Dolan
# games_played: 30
# goals: 1
# assists: 3
# points: 4
# penalties: 3
# penalty minutes: 6
# shots: 29
# blocked_att: 14
# missed_shots: 11
# hits: 53
# blocked_shots: 21
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Adrian Kempe
# games_played: 77
# goals: 28
# assists: 47
# points: 75
# penalties: 30
# penalty minutes: 72
# shots: 246
# blocked_att: 147
# missed_shots: 106
# hits: 112
# blocked_shots: 32
# powerplay_shots: 51
# powperplay_goals: 5
# powerplay_assists: 22
# full_name: Alex Turcotte
# games_played: 20
# goals: 1
# assists: 3
# points: 4
# penalties: 3
# penalty minutes: 6
# shots: 14
# blocked_att: 9
# missed_shots: 13
# hits: 7
# blocked_shots: 10
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Arthur Kaliyev
# games_played: 51
# goals: 7
# assists: 8
# points: 15
# penalties: 6
# penalty minutes: 14
# shots: 101
# blocked_att: 56
# missed_shots: 54
# hits: 33
# blocked_shots: 14
# powerplay_shots: 18
# powperplay_goals: 3
# powerplay_assists: 1
# full_name: Brandt Clarke
# games_played: 16
# goals: 2
# assists: 4
# points: 6
# penalties: 5
# penalty minutes: 10
# shots: 31
# blocked_att: 14
# missed_shots: 9
# hits: 6
# blocked_shots: 21
# powerplay_shots: 3
# powperplay_goals: 0
# powerplay_assists: 3
# full_name: Andreas Englund
# games_played: 82
# goals: 1
# assists: 9
# points: 10
# penalties: 24
# penalty minutes: 81
# shots: 41
# blocked_att: 54
# missed_shots: 15
# hits: 189
# blocked_shots: 87
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Alex Laferriere
# games_played: 81
# goals: 12
# assists: 11
# points: 23
# penalties: 20
# penalty minutes: 46
# shots: 147
# blocked_att: 82
# missed_shots: 90
# hits: 113
# blocked_shots: 27
# powerplay_shots: 6
# powperplay_goals: 0
# powerplay_assists: 3
# full_name: Anze Kopitar
# games_played: 81
# goals: 26
# assists: 44
# points: 70
# penalties: 7
# penalty minutes: 22
# shots: 133
# blocked_att: 50
# missed_shots: 49
# hits: 37
# blocked_shots: 65
# powerplay_shots: 32
# powperplay_goals: 9
# powerplay_assists: 14
# full_name: Vladislav Gavrikov
# games_played: 77
# goals: 6
# assists: 17
# points: 23
# penalties: 10
# penalty minutes: 28
# shots: 114
# blocked_att: 72
# missed_shots: 33
# hits: 55
# blocked_shots: 114
# powerplay_shots: 2
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Jacob Moverare
# games_played: 24
# goals: 1
# assists: 0
# points: 1
# penalties: 3
# penalty minutes: 6
# shots: 11
# blocked_att: 12
# missed_shots: 6
# hits: 12
# blocked_shots: 23
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Tobias Bjornfot
# games_played: 1
# goals: 0
# assists: 0
# points: 0
# penalties: 0
# penalty minutes: 0
# shots: 0
# blocked_att: 0
# missed_shots: 0
# hits: 1
# blocked_shots: 1
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Matt Roy
# games_played: 81
# goals: 5
# assists: 20
# points: 25
# penalties: 17
# penalty minutes: 42
# shots: 135
# blocked_att: 88
# missed_shots: 71
# hits: 152
# blocked_shots: 197
# powerplay_shots: 1
# powperplay_goals: 0
# powerplay_assists: 1
# full_name: Blake Lizotte
# games_played: 62
# goals: 7
# assists: 8
# points: 15
# penalties: 9
# penalty minutes: 20
# shots: 76
# blocked_att: 28
# missed_shots: 24
# hits: 64
# blocked_shots: 28
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Pierre-Luc Dubois
# games_played: 82
# goals: 16
# assists: 24
# points: 40
# penalties: 31
# penalty minutes: 70
# shots: 146
# blocked_att: 55
# missed_shots: 85
# hits: 96
# blocked_shots: 37
# powerplay_shots: 26
# powperplay_goals: 7
# powerplay_assists: 1
# full_name: Samuel Fagemo
# games_played: 4
# goals: 0
# assists: 0
# points: 0
# penalties: 0
# penalty minutes: 0
# shots: 6
# blocked_att: 3
# missed_shots: 2
# hits: 4
# blocked_shots: 0
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Quinton Byfield
# games_played: 80
# goals: 20
# assists: 35
# points: 55
# penalties: 17
# penalty minutes: 42
# shots: 161
# blocked_att: 66
# missed_shots: 86
# hits: 66
# blocked_shots: 19
# powerplay_shots: 31
# powperplay_goals: 6
# powerplay_assists: 8
# full_name: Phillip Danault
# games_played: 78
# goals: 17
# assists: 30
# points: 47
# penalties: 9
# penalty minutes: 18
# shots: 159
# blocked_att: 57
# missed_shots: 62
# hits: 80
# blocked_shots: 60
# powerplay_shots: 17
# powperplay_goals: 3
# powerplay_assists: 6
# full_name: Trevor Lewis
# games_played: 82
# goals: 8
# assists: 8
# points: 16
# penalties: 10
# penalty minutes: 20
# shots: 130
# blocked_att: 36
# missed_shots: 45
# hits: 90
# blocked_shots: 62
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 1
# full_name: Akil Thomas
# games_played: 7
# goals: 3
# assists: 1
# points: 4
# penalties: 1
# penalty minutes: 2
# shots: 9
# blocked_att: 4
# missed_shots: 3
# hits: 8
# blocked_shots: 3
# powerplay_shots: 0
# powperplay_goals: 0
# powerplay_assists: 0
# full_name: Carl Grundstrom
# games_played: 50
# goals: 8
# assists: 4
# points: 12
# penalties: 6
# penalty minutes: 12
# shots: 95
# blocked_att: 43
# missed_shots: 39
# hits: 115
# blocked_shots: 16
# powerplay_shots: 2
# powperplay_goals: 1
# powerplay_assists: 0
# full_name: Drew Doughty
# games_played: 82
# goals: 15
# assists: 35
# points: 50
# penalties: 22
# penalty minutes: 44
# shots: 135
# blocked_att: 122
# missed_shots: 49
# hits: 109
# blocked_shots: 142
# powerplay_shots: 36
# powperplay_goals: 7
# powerplay_assists: 13
# full_name: Jordan Spence
# games_played: 71
# goals: 2
# assists: 22
# points: 24
# penalties: 5
# penalty minutes: 12
# shots: 80
# blocked_att: 86
# missed_shots: 32
# hits: 67
# blocked_shots: 55
# powerplay_shots: 15
# powperplay_goals: 1
# powerplay_assists: 5

# %%
players_stats_data
# Out:
# {'full_name': ['Trevor Moore',
#   'Viktor Arvidsson',
#   'Kevin Fiala',
#   'Mikey Anderson',
#   'Jaret Anderson-Dolan',
#   'Adrian Kempe',
#   'Alex Turcotte',
#   'Arthur Kaliyev',
#   'Brandt Clarke',
#   'Andreas Englund',
#   'Alex Laferriere',
#   'Anze Kopitar',
#   'Vladislav Gavrikov',
#   'Jacob Moverare',
#   'Tobias Bjornfot',
#   'Matt Roy',
#   'Blake Lizotte',
#   'Pierre-Luc Dubois',
#   'Samuel Fagemo',
#   'Quinton Byfield',
#   'Phillip Danault',
#   'Trevor Lewis',
#   'Akil Thomas',
#   'Carl Grundstrom',
#   'Drew Doughty',
#   'Jordan Spence'],
#  'games_played': [82,
#   18,
#   82,
#   74,
#   30,
#   77,
#   20,
#   51,
#   16,
#   82,
#   81,
#   81,
#   77,
#   24,
#   1,
#   81,
#   62,
#   82,
#   4,
#   80,
#   78,
#   82,
#   7,
#   50,
#   82,
#   71],
#  'goals': [31,
#   6,
#   29,
#   2,
#   1,
#   28,
#   1,
#   7,
#   2,
#   1,
#   12,
#   26,
#   6,
#   1,
#   0,
#   5,
#   7,
#   16,
#   0,
#   20,
#   17,
#   8,
#   3,
#   8,
#   15,
#   2],
#  'assists': [26,
#   9,
#   44,
#   16,
#   3,
#   47,
#   3,
#   8,
#   4,
#   9,
#   11,
#   44,
#   17,
#   0,
#   0,
#   20,
#   8,
#   24,
#   0,
#   35,
#   30,
#   8,
#   1,
#   4,
#   35,
#   22],
#  'points': [57,
#   15,
#   73,
#   18,
#   4,
#   75,
#   4,
#   15,
#   6,
#   10,
#   23,
#   70,
#   23,
#   1,
#   0,
#   25,
#   15,
#   40,
#   0,
#   55,
#   47,
#   16,
#   4,
#   12,
#   50,
#   24],
#  'penalties': [13,
#   7,
#   26,
#   9,
#   3,
#   30,
#   3,
#   6,
#   5,
#   24,
#   20,
#   7,
#   10,
#   3,
#   0,
#   17,
#   9,
#   31,
#   0,
#   17,
#   9,
#   10,
#   1,
#   6,
#   22,
#   5],
#  'penalty_minutes': [28,
#   14,
#   62,
#   18,
#   6,
#   72,
#   6,
#   14,
#   10,
#   81,
#   46,
#   22,
#   28,
#   6,
#   0,
#   42,
#   20,
#   70,
#   0,
#   42,
#   18,
#   20,
#   2,
#   12,
#   44,
#   12],
#  'shots': [244,
#   59,
#   225,
#   89,
#   29,
#   246,
#   14,
#   101,
#   31,
#   41,
#   147,
#   133,
#   114,
#   11,
#   0,
#   135,
#   76,
#   146,
#   6,
#   161,
#   159,
#   130,
#   9,
#   95,
#   135,
#   80],
#  'blocked_att': [74,
#   19,
#   124,
#   74,
#   14,
#   147,
#   9,
#   56,
#   14,
#   54,
#   82,
#   50,
#   72,
#   12,
#   0,
#   88,
#   28,
#   55,
#   3,
#   66,
#   57,
#   36,
#   4,
#   43,
#   122,
#   86],
#  'missed_shots': [122,
#   22,
#   118,
#   43,
#   11,
#   106,
#   13,
#   54,
#   9,
#   15,
#   90,
#   49,
#   33,
#   6,
#   0,
#   71,
#   24,
#   85,
#   2,
#   86,
#   62,
#   45,
#   3,
#   39,
#   49,
#   32],
#  'hits': [92,
#   8,
#   67,
#   128,
#   53,
#   112,
#   7,
#   33,
#   6,
#   189,
#   113,
#   37,
#   55,
#   12,
#   1,
#   152,
#   64,
#   96,
#   4,
#   66,
#   80,
#   90,
#   8,
#   115,
#   109,
#   67],
#  'blocked_shots': [58,
#   18,
#   28,
#   129,
#   21,
#   32,
#   10,
#   14,
#   21,
#   87,
#   27,
#   65,
#   114,
#   23,
#   1,
#   197,
#   28,
#   37,
#   0,
#   19,
#   60,
#   62,
#   3,
#   16,
#   142,
#   55],
#  'powerplay_shots': [29,
#   7,
#   56,
#   0,
#   0,
#   51,
#   0,
#   18,
#   3,
#   0,
#   6,
#   32,
#   2,
#   0,
#   0,
#   1,
#   0,
#   26,
#   0,
#   31,
#   17,
#   0,
#   0,
#   2,
#   36,
#   15],
#  'powperplay_goals': [2,
#   1,
#   11,
#   0,
#   0,
#   5,
#   0,
#   3,
#   0,
#   0,
#   0,
#   9,
#   0,
#   0,
#   0,
#   0,
#   0,
#   7,
#   0,
#   6,
#   3,
#   0,
#   0,
#   1,
#   7,
#   1],
#  'powerplay_assists': [5,
#   4,
#   19,
#   0,
#   0,
#   22,
#   0,
#   1,
#   3,
#   0,
#   3,
#   14,
#   0,
#   0,
#   0,
#   1,
#   0,
#   1,
#   0,
#   8,
#   6,
#   1,
#   0,
#   0,
#   13,
#   5]}

# %%
df =pd.DataFrame(players_stats_data)

# %%
df.head()
# Out:
#               full_name  games_played  goals  assists  points  penalties  \
# 0          Trevor Moore            82     31       26      57         13
# 1      Viktor Arvidsson            18      6        9      15          7
# 2           Kevin Fiala            82     29       44      73         26
# 3        Mikey Anderson            74      2       16      18          9
# 4  Jaret Anderson-Dolan            30      1        3       4          3
#
#    penalty_minutes  shots  blocked_att  missed_shots  hits  blocked_shots  \
# 0               28    244           74           122    92             58
# 1               14     59           19            22     8             18
# 2               62    225          124           118    67             28
# 3               18     89           74            43   128            129
# 4                6     29           14            11    53             21
#
#    powerplay_shots  powperplay_goals  powerplay_assists
# 0               29                 2                  5
# 1                7                 1                  4
# 2               56                11                 19
# 3                0                 0                  0
# 4                0                 0                  0

# %%
df.to_csv('players_stats_data.csv', index=False)

# %% [markdown]
# # Connect Database and Load the Data

# %%
# connect to database
raw_host = os.getenv('Database_host')
raw_username = os.getenv('Database_username')
raw_password = os.getenv('Database_password')
raw_schema = os.getenv('Database_schema')

raw_db_config = {
    "host": raw_host,
    "username": raw_username,
    "password": raw_password,
    "schema": raw_schema
}

#driver://username:password@host/database
raw_engine = create_engine(f"mysql+mysqlconnector://{raw_db_config['username']}:{raw_db_config['password']}@{raw_db_config['host']}/{raw_db_config['schema']}")

# %% [markdown]
# ## Team stats

# %%
nhl_teams_source_csv = 'nhl_teams_cleaned.csv'

# %%
nhl_teams_source_csv_df = pd.read_csv(nhl_teams_source_csv)

# %%
nhl_teams_source_csv_df.head()
# Out:
#                                      id          name       area alias
# 0  4415ce44-0f24-11e2-8525-18a905767e44     Avalanche   Colorado   COL
# 1  4416272f-0f24-11e2-8525-18a905767e44    Blackhawks    Chicago   CHI
# 2  44167db4-0f24-11e2-8525-18a905767e44  Blue Jackets   Columbus   CBJ
# 3  441660ea-0f24-11e2-8525-18a905767e44         Blues  St. Louis   STL
# 4  4416ba1a-0f24-11e2-8525-18a905767e44        Bruins     Boston   BOS

# %%
raw_table = "nhl_teams"

nhl_teams_source_csv_df.to_sql(raw_table, raw_engine, index=False, if_exists="replace")
# Out:
# 32

# %% [markdown]
# ## Player stats

# %%
nhl_players_source_csv = 'nhl_players_cleaned.csv'

# %%
nhl_players_source_csv_df = pd.read_csv(nhl_players_source_csv)

# %%
nhl_players_source_csv_df.head()
# Out:
#                                      id   team status       full_name  \
# 0  070ff077-e59b-4135-b060-352ee716bc7e  Kings    ACT   Blake Lizotte
# 1  0a1a1d3a-7118-4d30-a2bd-a2f95822d22c  Kings     IR  Pheonix Copley
# 2  0cc94754-1f54-4723-939f-8c14dd930759  Kings    ACT        Matt Roy
# 3  240ad2f4-8860-45a6-94d0-79b87dffd3ea  Kings    ACT      Aaron Dell
# 4  421f9f71-d1ee-4917-afc6-ca11f6b761b0  Kings    ACT    Trevor Moore
#
#   first_name last_name height  weight handedness position primary_position  \
# 0      Blake   Lizotte    6'9     170          L        F                C
# 1    Pheonix    Copley    7'6     200          L        G                G
# 2       Matt       Roy    7'3     205          R        D                D
# 3      Aaron      Dell    7'2     213          L        G                G
# 4     Trevor     Moore    7'0     195          L        F               LW
#
#    jersey_number  experience             birth_place birthdate
# 0             46           5      Lindstrom, MN, USA  12/13/97
# 1             29           5     North Pole, AK, USA   1/18/92
# 2              3           5        Detroit, MI, USA    3/1/95
# 3             30           7        Airdrie, AB, CAN    5/4/89
# 4             12           5  Thousand Oaks, CA, USA   3/31/95

# %%
raw_table = "players"

nhl_players_source_csv_df.to_sql(raw_table, raw_engine, index=False, if_exists="replace")
# Out:
# 25

# %% [markdown]
# ## Teams Stats

# %%
nhl_teams_stats_source_csv = 'nhl_teams_stats_cleaned.csv'

# %%
nhl_teams_stats_source_csv_df = pd.read_csv(nhl_teams_stats_source_csv)

# %%
nhl_teams_stats_source_csv_df.head()
# Out:
#            name  games_played  goals  assists  points  penalties  \
# 0     Avalanche            82    302      525     827        307
# 1    Blackhawks            82    178      303     481        292
# 2  Blue Jackets            82    234      389     623        291
# 3         Blues            82    234      401     635        263
# 4        Bruins            82    263      443     706        334
#
#    penalty_minutes  shots  hits  blocked_shots  powerplays  powerplay_shots  \
# 0              731   2705  1671           1214         278              443
# 1              715   2153  1874           1340         235              314
# 2              670   2458  1577           1396         212              329
# 3              608   2370  1654           1219         250              362
# 4              776   2399  2258           1299         243              386
#
#    powerplay_goals  powerplay_percentage  shots_against  goals_against  saves  \
# 0               68                  24.5           2432            239   2193
# 1               39                  16.6           2667            274   2393
# 2               32                  15.1           2803            279   2524
# 3               45                  18.0           2616            228   2388
# 4               54                  22.2           2495            211   2284
#
#    saves_percentage
# 0              0.90
# 1              0.89
# 2              0.89
# 3              0.91
# 4              0.91

# %%
raw_table = "nhl_team_stats"

nhl_teams_stats_source_csv_df.to_sql(raw_table, raw_engine, index=False, if_exists="replace")
# Out:
# 32

# %% [markdown]
# ## player_stats_data

# %%
player_stats_source_csv ='players_stats_data.csv'

# %%
player_stats_source_csv_df = pd.read_csv(player_stats_source_csv)

# %%
player_stats_source_csv_df.head()
# Out:
#            name  games_played  goals  assists  points  penalties  \
# 0     Avalanche            82    302      525     827        307
# 1    Blackhawks            82    178      303     481        292
# 2  Blue Jackets            82    234      389     623        291
# 3         Blues            82    234      401     635        263
# 4        Bruins            82    263      443     706        334
#
#    penalty_minutes  shots  hits  blocked_shots  powerplays  powerplay_shots  \
# 0              731   2705  1671           1214         278              443
# 1              715   2153  1874           1340         235              314
# 2              670   2458  1577           1396         212              329
# 3              608   2370  1654           1219         250              362
# 4              776   2399  2258           1299         243              386
#
#    powerplay_goals  powerplay_percentage  shots_against  goals_against  saves  \
# 0               68                  24.5           2432            239   2193
# 1               39                  16.6           2667            274   2393
# 2               32                  15.1           2803            279   2524
# 3               45                  18.0           2616            228   2388
# 4               54                  22.2           2495            211   2284
#
#    saves_percentage
# 0              0.90
# 1              0.89
# 2              0.89
# 3              0.91
# 4              0.91

# %%
raw_table = "PlayerStats"

player_stats_source_csv_df.to_sql(raw_table, raw_engine, index=False, if_exists="replace")
# Out:
# 26

# %% [markdown]
# ## Goalies_stats_data

# %%
goalies_stats_source_csv ='goalies_stats_data.csv'

# %%
goalies_stats_source_csv_df = pd.read_csv(goalies_stats_source_csv)

# %%
goalies_stats_source_csv_df.head()
# Out:
#         full_name  games_played  shots_against  goals_against  saves  \
# 0   David Rittich            24            621             49    572
# 1  Pheonix Copley             8            177             23    154
# 2      Cam Talbot            54           1490            130   1360
#
#    shutouts  saves_pct  avg_goals_against
# 0         3      0.921               2.15
# 1         1      0.870               3.17
# 2         3      0.913               2.50

# %%
raw_table = "GoalieStats"

goalies_stats_source_csv_df.to_sql(raw_table, raw_engine, index=False, if_exists="replace")
# Out:
# 3
